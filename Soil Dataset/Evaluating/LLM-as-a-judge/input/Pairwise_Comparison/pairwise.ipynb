# %%
# # ================================
# # Pairwise Comparison (AvalAI - Gemma) - Folder Images
# # JSON-mode free (no response_format), per-item verbose output, robust rate limiting
# # ================================
# import io
# import json
# import csv
# import time
# import random
# from pathlib import Path
# from typing import Dict, List, Optional, Tuple
# import requests
# import os
# import sys
# import re

# # Kaggle secrets (for API key)
# try:
#     from kaggle_secrets import UserSecretsClient
#     KAGGLE_ENV = True
# except ImportError:
#     KAGGLE_ENV = False

# # Colab helpers (optional downloads)
# try:
#     from google.colab import files
#     IN_COLAB = True
# except ImportError:
#     IN_COLAB = False

# # ----------------------
# # User configuration
# # ----------------------
# RANDOM_SEED = 7
# JUDGE_MODE = "avalai"
# # در Colab: Path("/content/pairwise_out")
# OUTPUT_DIR = Path("/kaggle/working/pairwise_out")

# ONE_SHOT_JSON_PATH = "/kaggle/input/rdf-evaluation/rdf_extractions_oneShot.json"
# FEW_SHOT_JSON_PATH = "/kaggle/input/rdf-evaluation/rdf_extractions_FewShot.json"
# IMAGES_DIR_PATH = "/kaggle/input/rdf-evaluation/Dataset/Dataset"  # اگر پوشه تصاویر داری

# # Debug/control knobs
# MAX_CHARS = 2000          # کاهش برای جلوگیری از 400
# SLEEP_BETWEEN_ITEMS = 1.5 # مکث بین آیتم‌ها برای دور زدن 429
# PRINT_REQUEST_SIZES = True
# PRINT_RESPONSE_SNIPPET = True
# REQUEST_TIMEOUT = 90
# MAX_RETRIES = 8

# # ----------------------
# # AvalAI settings
# # ----------------------
# AVALAI_API_KEY = None
# if KAGGLE_ENV:
#     try:
#         user_secrets = UserSecretsClient()
#         AVALAI_API_KEY = user_secrets.get_secret("avalai_api")
#     except Exception:
#         AVALAI_API_KEY = None

# if not AVALAI_API_KEY:
#     AVALAI_API_KEY = os.environ.get("AVALAI_API_KEY", None)

# BASE_URL = "https://api.avalai.ir/v1"
# AVALAI_MODEL = "gemma-3n-e4b-it"  # نام مدل را مطابق مستندات AvalAI بررسی کن

# # ----------------------
# # Core functions
# # ----------------------
# def load_dataset_from_bytes(b: bytes, source_hint: str = "") -> Dict[str, str]:
#     try:
#         data = json.loads(b.decode("utf-8"))
#     except Exception as e:
#         raise ValueError(f"Could not read JSON from {source_hint}: {e}")
#     if isinstance(data, dict) and "dataset" in data:
#         records = data["dataset"]
#     elif isinstance(data, list):
#         records = data
#     else:
#         raise ValueError(f"Unrecognized JSON structure in {source_hint}.")
#     mapping = {}
#     for rec in records:
#         img = rec.get("source_image") or rec.get("image_id") or rec.get("image") or rec.get("id", f"item_{len(mapping)+1:05d}")
#         turtle = rec.get("rdf_graph_turtle") or rec.get("turtle") or rec.get("triples_turtle", "")
#         if not isinstance(turtle, str):
#             turtle = json.dumps(turtle, ensure_ascii=False)
#         mapping[str(img)] = turtle
#     return mapping

# ALLOWED_EXTS = {".jpg", ".jpeg", ".png", ".webp", ".bmp", ".tif", ".tiff"}

# def index_images(images_dir: Optional[Path]) -> Dict[str, str]:
#     idx = {}
#     if not images_dir or not images_dir.exists():
#         return idx
#     for p in images_dir.rglob("*"):
#         if p.is_file() and p.suffix.lower() in ALLOWED_EXTS:
#             idx.setdefault(p.stem, str(p.resolve()))
#     return idx

# def find_image_path_indexed(idx: Dict[str, str], name: str) -> Optional[str]:
#     stem = Path(name).stem
#     return idx.get(stem, None)

# def _truncate(s: str, max_chars: int = MAX_CHARS) -> str:
#     s = s or ""
#     return s if len(s) <= max_chars else (s[:max_chars] + "\n... [TRUNCATED]")

# def _sleep_with_backoff(attempt: int, retry_after: Optional[str]):
#     if retry_after:
#         try:
#             time.sleep(float(retry_after))
#             return
#         except Exception:
#             pass
#     delay = min(60, 0.7 * (2 ** attempt))
#     delay = delay * (0.7 + random.random()*0.6)
#     time.sleep(delay)

# def _extract_json_from_text(txt: str) -> dict:
#     """
#     Tries to extract a single JSON object from model text.
#     Handles code fences and extra prose.
#     """
#     if not txt:
#         raise ValueError("Empty response text.")
#     # If fenced, strip to inside
#     if "```" in txt:
#         s = txt.find("{"); e = txt.rfind("}")
#         if s != -1 and e != -1 and e > s:
#             txt = txt[s:e+1]
#     # Try direct parse
#     try:
#         return json.loads(txt)
#     except Exception:
#         # Greedy: take first {...} block
#         m = re.search(r"\{.*\}", txt, flags=re.DOTALL)
#         if not m:
#             raise ValueError(f"Cannot find JSON in: {txt[:200]}")
#         return json.loads(m.group(0))

# def avalai_judge(triples_A: str, label_A: str,
#                  triples_B: str, label_B: str,
#                  api_key: str, base_url: str, model_name: str,
#                  debug_prefix: str = "") -> Tuple[str, List[str], List[str], List[str]]:
#     """
#     Judge via AvalAI (OpenAI-compatible /v1/chat/completions).
#     - بدون response_format و بدون system
#     - truncate ورودی‌ها
#     - احترام به Retry-After و backoff
#     - استخراج JSON از متن پاسخ
#     """
#     if not api_key:
#         raise ValueError("AVALAI_API_KEY is not set. Configure Kaggle Secret 'avalai_api' or env var 'AVALAI_API_KEY'.")

#     endpoint = f"{base_url}/chat/completions"
#     headers = {
#         "Content-Type": "application/json",
#         "Authorization": f"Bearer {api_key}",
#         "Accept": "application/json",
#     }

#     instruction = (
#         "You are evaluating RDF triples extracted from the SAME image by two methods.\n"
#         "Return ONLY valid JSON with this schema:\n"
#         "{\n"
#         '  \"winner\": \"A\" | \"B\" | \"Tie\",\n'
#         '  \"reasons\": [\"...\"],\n'
#         '  \"major_errors_A\": [\"...\"],\n'
#         '  \"major_errors_B\": [\"...\"]\n'
#         "}\n"
#         "No extra text before or after the JSON.\n"
#         "Consider correctness w.r.t image content, completeness, and RDF validity.\n"
#         "Do not bias by length; longer ≠ better."
#     )

#     triples_A_tr = _truncate(triples_A, MAX_CHARS)
#     triples_B_tr = _truncate(triples_B, MAX_CHARS)

#     user_prompt = (
#         f"{instruction}\n\n"
#         f"Method A ({label_A}):\n{json.dumps(triples_A_tr)}\n\n"
#         f"Method B ({label_B}):\n{json.dumps(triples_B_tr)}\n"
#     )

#     payload = {
#         "model": model_name,
#         "messages": [
#             {"role": "user", "content": user_prompt}
#         ],
#         "temperature": 0.0,
#         "max_tokens": 1024,
#         # ❌ مهم: response_format را حذف کردیم چون JSON mode فعال نیست
#     }

#     if PRINT_REQUEST_SIZES:
#         print(f"{debug_prefix} [sizes] A:{len(triples_A)}->{len(triples_A_tr)} chars | "
#               f"B:{len(triples_B)}->{len(triples_B_tr)} chars")

#     last_err = None
#     for attempt in range(MAX_RETRIES):
#         try:
#             resp = requests.post(endpoint, headers=headers, json=payload, timeout=REQUEST_TIMEOUT)
#             status = resp.status_code

#             if PRINT_RESPONSE_SNIPPET:
#                 snippet = resp.text[:300].replace("\n", " ")
#                 print(f"{debug_prefix} [HTTP {status}] resp head: {snippet}")

#             if status in (429, 500, 502, 503, 504):
#                 _sleep_with_backoff(attempt, resp.headers.get("Retry-After"))
#                 continue

#             if status != 200:
#                 # چاپ بدنه خطا برای دیباگ و raise
#                 try:
#                     err_json = resp.json()
#                 except Exception:
#                     err_json = {"raw_text": resp.text[:1000]}
#                 print(f"{debug_prefix} ERROR {status}: {json.dumps(err_json, ensure_ascii=False)[:500]}")
#                 resp.raise_for_status()

#             data = resp.json()
#             content_text = (
#                 data.get("choices", [{}])[0]
#                     .get("message", {})
#                     .get("content", "")
#             ).strip()

#             out = _extract_json_from_text(content_text)

#             winner = out.get("winner", "Tie")
#             reasons = out.get("reasons", [])
#             errA = out.get("major_errors_A", [])
#             errB = out.get("major_errors_B", [])

#             if winner not in {"A", "B", "Tie"}:
#                 winner = "Tie"
#             if not isinstance(reasons, list): reasons = [str(reasons)]
#             if not isinstance(errA, list): errA = [str(errA)]
#             if not isinstance(errB, list): errB = [str(errB)]

#             return winner, reasons, errA, errB

#         except Exception as e:
#             last_err = e
#             _sleep_with_backoff(attempt, None)

#     raise RuntimeError(f"AvalAI judge failed after retries: {type(last_err).__name__}: {last_err}")

# # ----------------------
# # Workflow (runs once)
# # ----------------------
# random.seed(RANDOM_SEED)
# OUTPUT_DIR.mkdir(parents=True, exist_ok=True)
# ERROR_LOG = OUTPUT_DIR / "avalai_errors.log"

# def _log_error(msg: str):
#     try:
#         with ERROR_LOG.open("a", encoding="utf-8") as f:
#             f.write(msg.rstrip() + "\n")
#     except Exception:
#         pass

# print("📂 Accessing data from specified paths...")

# if not os.path.exists(ONE_SHOT_JSON_PATH) or not os.path.exists(FEW_SHOT_JSON_PATH):
#     raise FileNotFoundError("One or both JSON file paths are incorrect. Please check the paths.")

# one_name = Path(ONE_SHOT_JSON_PATH).name
# few_name = Path(FEW_SHOT_JSON_PATH).name

# uploaded = {
#     one_name: Path(ONE_SHOT_JSON_PATH).read_bytes(),
#     few_name: Path(FEW_SHOT_JSON_PATH).read_bytes()
# }
# print(f"📄 One-Shot file: {one_name}")
# print(f"📄 Few-Shot file: {few_name}")

# one_map = load_dataset_from_bytes(uploaded[one_name], source_hint=one_name)
# few_map = load_dataset_from_bytes(uploaded[few_name], source_hint=few_name)

# shared = sorted(set(one_map.keys()) & set(few_map.keys()))
# print(f"✅ Shared items: {len(shared)}")

# IMAGES_DIR = Path(IMAGES_DIR_PATH)
# if IMAGES_DIR.exists():
#     print(f"🗂️ Indexing images in folder: {IMAGES_DIR}")
#     IMAGE_INDEX = index_images(IMAGES_DIR)
#     print(f"  -> Found {len(IMAGE_INDEX)} images")
# else:
#     print(f"ℹ️ Images folder not found at: {IMAGES_DIR}")
#     IMAGE_INDEX = {}

# # Prepare outputs
# summary_csv = OUTPUT_DIR / "pairwise_summary.csv"
# pairs_jsonl = OUTPUT_DIR / "pairwise_pairs.jsonl"
# prompt_txt = OUTPUT_DIR / "judge_prompt.txt"
# judge_csv = OUTPUT_DIR / "judge_report.csv"
# aggregate_csv = OUTPUT_DIR / "judge_aggregate.csv"

# prompt_txt.write_text(
# """You are evaluating RDF triples extracted from the SAME image by two methods.
# Return ONLY valid JSON with this schema:
# {
#   "winner": "A" | "B" | "Tie",
#   "reasons": ["..."],
#   "major_errors_A": ["..."],
#   "major_errors_B": ["..."]
# }
# (Actual prompt is created dynamically per request without response_format.)
# """, encoding="utf-8"
# )

# # Build rows + JSONL
# rows = []
# with pairs_jsonl.open("w", encoding="utf-8") as jout:
#     for img in shared:
#         turtle_one = one_map.get(img, "")
#         turtle_few = few_map.get(img, "")
#         if random.random() < 0.5:
#             A_label, B_label, A_turtle, B_turtle = "One-Shot", "Few-Shot", turtle_one, turtle_few
#         else:
#             A_label, B_label, A_turtle, B_turtle = "Few-Shot", "One-Shot", turtle_few, turtle_one

#         img_path = find_image_path_indexed(IMAGE_INDEX, img)

#         rows.append({"image_id": img, "img_path": img_path or "", "A_model": A_label, "B_model": B_label})
#         jout.write(json.dumps({
#             "image_id": img,
#             "image_path": img_path,
#             "A_label": A_label,
#             "B_label": B_label,
#             "triples_A_turtle": A_turtle,
#             "triples_B_turtle": B_turtle,
#             "seed": RANDOM_SEED
#         }, ensure_ascii=False) + "\n")

# if rows:
#     with summary_csv.open("w", newline="", encoding="utf-8") as f:
#         writer = csv.DictWriter(f, fieldnames=list(rows[0].keys()))
#         writer.writeheader()
#         writer.writerows(rows)

# print("\n📝 Wrote:")
# print(f"- {summary_csv}")
# print(f"- {pairs_jsonl}")
# print(f"- {prompt_txt}")

# # ----------------------
# # AvalAI judge (per-item printing)
# # ----------------------
# if JUDGE_MODE == "avalai":
#     print(f"\n🤖 Running judge: {JUDGE_MODE} with model {AVALAI_MODEL}")
#     with pairs_jsonl.open("r", encoding="utf-8") as f:
#         lines = [json.loads(ln) for ln in f]

#     results = []
#     total_items = len(lines)
#     for i, rec in enumerate(lines, start=1):
#         prefix = f"[{i}/{total_items}] image_id={rec['image_id']}"
#         print(f"{prefix} → sending...", flush=True)
#         try:
#             winner, reasons, errA, errB = avalai_judge(
#                 rec["triples_A_turtle"], rec["A_label"],
#                 rec["triples_B_turtle"], rec["B_label"],
#                 api_key=AVALAI_API_KEY, base_url=BASE_URL, model_name=AVALAI_MODEL,
#                 debug_prefix=prefix
#             )
#             print(f"{prefix} ✓ winner={winner} | reasons={'; '.join(reasons)[:200]}", flush=True)
#         except Exception as e:
#             winner, reasons, errA, errB = "Tie", [f"AvalAIError: {e}"], [], []
#             print(f"{prefix} ✗ error={e}", flush=True)

#         results.append({
#             "image_id": rec["image_id"],
#             "A_label": rec["A_label"],
#             "B_label": rec["B_label"],
#             "winner": winner,
#             "reasons": " | ".join(reasons),
#             "errors_A": " | ".join(errA),
#             "errors_B": " | ".join(errB)
#         })

#         # مکث بین آیتم‌ها برای جلوگیری از 429
#         if SLEEP_BETWEEN_ITEMS > 0:
#             time.sleep(SLEEP_BETWEEN_ITEMS)

#     # Aggregate
#     winA = sum(1 for r in results if r["winner"] == "A")
#     winB = sum(1 for r in results if r["winner"] == "B")
#     ties = sum(1 for r in results if r["winner"] == "Tie")
#     total = len(results)

#     if results:
#         with judge_csv.open("w", newline="", encoding="utf-8") as f:
#             writer = csv.DictWriter(f, fieldnames=list(results[0].keys()))
#             writer.writeheader()
#             writer.writerows(results)

#         with aggregate_csv.open("w", newline="", encoding="utf-8") as f:
#             writer = csv.DictWriter(f, fieldnames=["total", "A_wins", "B_wins", "ties"])
#             writer.writeheader()
#             writer.writerow({"total": total, "A_wins": winA, "B_wins": winB, "ties": ties})

#     print("\n🧮 Judge summary")
#     print(f"total={total} | A_wins={winA} | B_wins={winB} | ties={ties}")
#     print(f"📝 Wrote: {judge_csv}")
#     print(f"📝 Wrote: {aggregate_csv}")

# # ----------------------
# # Offer downloads in Colab
# # ----------------------
# if IN_COLAB:
#     print("\n⬇️ Click to download:")
#     for p in [summary_csv, pairs_jsonl, prompt_txt, judge_csv, aggregate_csv]:
#         if Path(p).exists():
#             try:
#                 files.download(str(p))
#             except Exception:
#                 pass

# print("\n✅ Done.")

# %%
# ================================
# Improved Pairwise Comparison (AvalAI - Gemma) - Robust Error Handling
# Enhanced rate limiting, better error handling, and API compatibility
# ================================
import io
import json
import csv
import time
import random
from pathlib import Path
from typing import Dict, List, Optional, Tuple
import requests
import os
import sys
import re
from datetime import datetime, timedelta

# Kaggle secrets (for API key)
try:
    from kaggle_secrets import UserSecretsClient
    KAGGLE_ENV = True
except ImportError:
    KAGGLE_ENV = False

# Colab helpers (optional downloads)
try:
    from google.colab import files
    IN_COLAB = True
except ImportError:
    IN_COLAB = False

# ----------------------
# Enhanced User Configuration
# ----------------------
RANDOM_SEED = 7
JUDGE_MODE = "avalai"
OUTPUT_DIR = Path("/kaggle/working/pairwise_out")

ONE_SHOT_JSON_PATH = "/kaggle/input/rdf-evaluation/rdf_extractions_oneShot.json"
FEW_SHOT_JSON_PATH = "/kaggle/input/rdf-evaluation/rdf_extractions_FewShot.json"
IMAGES_DIR_PATH = "/kaggle/input/rdf-evaluation/Dataset/Dataset"

# Enhanced rate limiting and error handling
MAX_CHARS = 1500          # Further reduced to avoid 400 errors
MIN_SLEEP_BETWEEN_ITEMS = 2.0  # Minimum sleep between requests
MAX_SLEEP_BETWEEN_ITEMS = 5.0  # Maximum sleep between requests
PRINT_REQUEST_SIZES = True
PRINT_RESPONSE_SNIPPET = True
REQUEST_TIMEOUT = 120     # Increased timeout
MAX_RETRIES = 5           # Reduced retries but better logic
EXPONENTIAL_BACKOFF_BASE = 2.0
MAX_BACKOFF_DELAY = 300   # Maximum backoff delay (5 minutes)

# Rate limiting tracking
class RateLimiter:
    def __init__(self, min_interval=2.0, max_interval=5.0):
        self.min_interval = min_interval
        self.max_interval = max_interval
        self.last_request_time = 0
        self.consecutive_errors = 0
        self.success_count = 0
        
    def wait_if_needed(self):
        """Wait appropriate time before next request"""
        current_time = time.time()
        elapsed = current_time - self.last_request_time
        
        # Calculate required wait time based on error history
        if self.consecutive_errors > 0:
            # Increase wait time after errors
            required_wait = self.max_interval * (1.5 ** min(self.consecutive_errors, 5))
        else:
            # Normal wait time
            required_wait = random.uniform(self.min_interval, self.max_interval)
            
        if elapsed < required_wait:
            sleep_time = required_wait - elapsed
            print(f"⏳ Rate limiting: sleeping {sleep_time:.1f}s")
            time.sleep(sleep_time)
            
        self.last_request_time = time.time()
    
    def record_success(self):
        self.consecutive_errors = 0
        self.success_count += 1
        
    def record_error(self):
        self.consecutive_errors += 1

# ----------------------
# AvalAI settings
# ----------------------
AVALAI_API_KEY = None
if KAGGLE_ENV:
    try:
        user_secrets = UserSecretsClient()
        AVALAI_API_KEY = user_secrets.get_secret("avalai_api")
    except Exception:
        AVALAI_API_KEY = None

if not AVALAI_API_KEY:
    AVALAI_API_KEY = os.environ.get("AVALAI_API_KEY", None)

BASE_URL = "https://api.avalai.ir/v1"
AVALAI_MODEL = "gemma-3n-e4b-it"

# ----------------------
# Enhanced Core Functions
# ----------------------
def load_dataset_from_bytes(b: bytes, source_hint: str = "") -> Dict[str, str]:
    try:
        data = json.loads(b.decode("utf-8"))
    except Exception as e:
        raise ValueError(f"Could not read JSON from {source_hint}: {e}")
    if isinstance(data, dict) and "dataset" in data:
        records = data["dataset"]
    elif isinstance(data, list):
        records = data
    else:
        raise ValueError(f"Unrecognized JSON structure in {source_hint}.")
    mapping = {}
    for rec in records:
        img = rec.get("source_image") or rec.get("image_id") or rec.get("image") or rec.get("id", f"item_{len(mapping)+1:05d}")
        turtle = rec.get("rdf_graph_turtle") or rec.get("turtle") or rec.get("triples_turtle", "")
        if not isinstance(turtle, str):
            turtle = json.dumps(turtle, ensure_ascii=False)
        mapping[str(img)] = turtle
    return mapping

ALLOWED_EXTS = {".jpg", ".jpeg", ".png", ".webp", ".bmp", ".tif", ".tiff"}

def index_images(images_dir: Optional[Path]) -> Dict[str, str]:
    idx = {}
    if not images_dir or not images_dir.exists():
        return idx
    for p in images_dir.rglob("*"):
        if p.is_file() and p.suffix.lower() in ALLOWED_EXTS:
            idx.setdefault(p.stem, str(p.resolve()))
    return idx

def find_image_path_indexed(idx: Dict[str, str], name: str) -> Optional[str]:
    stem = Path(name).stem
    return idx.get(stem, None)

def _truncate_smart(s: str, max_chars: int = MAX_CHARS) -> str:
    """Smart truncation that tries to preserve structure"""
    s = s or ""
    if len(s) <= max_chars:
        return s
    
    # Try to truncate at natural boundaries
    truncated = s[:max_chars]
    
    # Look for last complete line or triple
    last_newline = truncated.rfind('\n')
    last_period = truncated.rfind('.')
    
    if last_newline > max_chars * 0.8:  # If newline is in last 20%
        truncated = s[:last_newline]
    elif last_period > max_chars * 0.8:  # If period is in last 20%
        truncated = s[:last_period + 1]
    
    return truncated + "\n... [TRUNCATED]"

def _calculate_backoff_delay(attempt: int, base_delay: float = EXPONENTIAL_BACKOFF_BASE) -> float:
    """Calculate exponential backoff delay with jitter"""
    delay = min(MAX_BACKOFF_DELAY, base_delay ** attempt)
    # Add jitter (±25%)
    jitter = delay * 0.25 * (2 * random.random() - 1)
    return max(1.0, delay + jitter)

def _sleep_with_backoff(attempt: int, retry_after: Optional[str] = None, rate_limit_error: bool = False):
    """Enhanced backoff with different strategies for different error types"""
    if retry_after:
        try:
            sleep_time = float(retry_after)
            print(f"⏱️ API requested {sleep_time}s delay")
            time.sleep(min(sleep_time, MAX_BACKOFF_DELAY))
            return
        except (ValueError, TypeError):
            pass
    
    if rate_limit_error:
        # More aggressive backoff for rate limit errors
        delay = _calculate_backoff_delay(attempt, base_delay=5.0)
        print(f"🚫 Rate limit backoff: {delay:.1f}s")
    else:
        # Standard backoff for other errors
        delay = _calculate_backoff_delay(attempt)
        print(f"⏳ Retry backoff: {delay:.1f}s")
    
    time.sleep(delay)

def _extract_json_from_text(txt: str) -> dict:
    """Enhanced JSON extraction with better error handling"""
    if not txt or not txt.strip():
        raise ValueError("Empty or whitespace-only response text.")
    
    txt = txt.strip()
    
    # Handle code fences
    if "```json" in txt:
        start = txt.find("```json") + 7
        end = txt.find("```", start)
        if end != -1:
            txt = txt[start:end].strip()
    elif "```" in txt:
        # Generic code fence
        start = txt.find("```")
        end = txt.rfind("```")
        if start != end and start != -1:
            txt = txt[start+3:end].strip()
    
    # Try direct parse first
    try:
        result = json.loads(txt)
        if isinstance(result, dict):
            return result
    except json.JSONDecodeError:
        pass
    
    # Try to find JSON object bounds
    brace_start = txt.find("{")
    if brace_start == -1:
        raise ValueError(f"No opening brace found in response: {txt[:200]}")
    
    # Find matching closing brace
    brace_count = 0
    for i, char in enumerate(txt[brace_start:], brace_start):
        if char == "{":
            brace_count += 1
        elif char == "}":
            brace_count -= 1
            if brace_count == 0:
                json_str = txt[brace_start:i+1]
                try:
                    return json.loads(json_str)
                except json.JSONDecodeError:
                    break
    
    raise ValueError(f"Could not extract valid JSON from response: {txt[:300]}")

def _validate_and_fix_response(response_dict: dict) -> Tuple[str, List[str], List[str], List[str]]:
    """Validate and fix the API response structure"""
    winner = response_dict.get("winner", "Tie")
    if winner not in {"A", "B", "Tie"}:
        print(f"⚠️ Invalid winner '{winner}', defaulting to 'Tie'")
        winner = "Tie"
    
    reasons = response_dict.get("reasons", [])
    if not isinstance(reasons, list):
        reasons = [str(reasons)] if reasons else ["No reasons provided"]
    
    errA = response_dict.get("major_errors_A", [])
    if not isinstance(errA, list):
        errA = [str(errA)] if errA else []
    
    errB = response_dict.get("major_errors_B", [])
    if not isinstance(errB, list):
        errB = [str(errB)] if errB else []
    
    return winner, reasons, errA, errB

def avalai_judge_robust(triples_A: str, label_A: str,
                       triples_B: str, label_B: str,
                       api_key: str, base_url: str, model_name: str,
                       rate_limiter: RateLimiter,
                       debug_prefix: str = "") -> Tuple[str, List[str], List[str], List[str]]:
    """
    Enhanced AvalAI judge with robust error handling and rate limiting
    """
    if not api_key:
        raise ValueError("AVALAI_API_KEY is not set. Configure Kaggle Secret 'avalai_api' or env var 'AVALAI_API_KEY'.")

    endpoint = f"{base_url}/chat/completions"
    headers = {
        "Content-Type": "application/json",
        "Authorization": f"Bearer {api_key}",
        "Accept": "application/json",
        "User-Agent": "PairwiseComparison/1.0"
    }

    # Enhanced instruction with clearer formatting requirements
    instruction = (
        "You are evaluating RDF triples extracted from the same image by two different methods. "
        "Analyze both extractions for correctness, completeness, and RDF validity.\n\n"
        "IMPORTANT: Respond with ONLY a valid JSON object in this exact format:\n"
        "{\n"
        '  "winner": "A",\n'
        '  "reasons": ["reason 1", "reason 2"],\n'
        '  "major_errors_A": ["error 1 in method A"],\n'
        '  "major_errors_B": ["error 1 in method B"]\n'
        "}\n\n"
        "Rules:\n"
        "- winner must be exactly 'A', 'B', or 'Tie'\n"
        "- All arrays must contain strings\n"
        "- Do not include extra text before or after the JSON\n"
        "- Consider: correctness relative to image content, completeness, RDF syntax validity\n"
        "- Longer extractions are not automatically better"
    )

    # Smart truncation
    triples_A_tr = _truncate_smart(triples_A, MAX_CHARS)
    triples_B_tr = _truncate_smart(triples_B, MAX_CHARS)

    user_prompt = (
        f"{instruction}\n\n"
        f"Method A ({label_A}) triples:\n{triples_A_tr}\n\n"
        f"Method B ({label_B}) triples:\n{triples_B_tr}\n"
    )

    # Simplified payload - remove potentially problematic parameters
    payload = {
        "model": model_name,
        "messages": [
            {"role": "user", "content": user_prompt}
        ],
        "temperature": 0.1,  # Slightly increased for more natural responses
        "max_tokens": 800,   # Reduced to avoid long responses
    }

    if PRINT_REQUEST_SIZES:
        print(f"{debug_prefix} [sizes] A:{len(triples_A)}->{len(triples_A_tr)} chars | "
              f"B:{len(triples_B)}->{len(triples_B_tr)} chars | prompt:{len(user_prompt)} chars")

    last_error = None
    
    for attempt in range(MAX_RETRIES):
        try:
            # Wait according to rate limiter
            rate_limiter.wait_if_needed()
            
            # Make request
            response = requests.post(
                endpoint, 
                headers=headers, 
                json=payload, 
                timeout=REQUEST_TIMEOUT
            )
            
            status_code = response.status_code
            
            if PRINT_RESPONSE_SNIPPET:
                snippet = response.text[:400].replace("\n", " ")
                print(f"{debug_prefix} [HTTP {status_code}] response: {snippet}")

            # Handle different status codes
            if status_code == 200:
                # Success case
                try:
                    data = response.json()
                    content_text = (
                        data.get("choices", [{}])[0]
                            .get("message", {})
                            .get("content", "")
                    ).strip()
                    
                    if not content_text:
                        raise ValueError("Empty response content")
                    
                    parsed_response = _extract_json_from_text(content_text)
                    winner, reasons, errA, errB = _validate_and_fix_response(parsed_response)
                    
                    rate_limiter.record_success()
                    return winner, reasons, errA, errB
                    
                except (json.JSONDecodeError, ValueError, KeyError) as parse_error:
                    print(f"{debug_prefix} ⚠️ Parse error: {parse_error}")
                    last_error = parse_error
                    if attempt < MAX_RETRIES - 1:
                        time.sleep(1)  # Brief pause before retry
                        continue
                    
            elif status_code == 429:
                # Rate limit error
                rate_limiter.record_error()
                print(f"{debug_prefix} 🚫 Rate limit exceeded (attempt {attempt + 1}/{MAX_RETRIES})")
                
                if attempt < MAX_RETRIES - 1:
                    _sleep_with_backoff(
                        attempt, 
                        response.headers.get("Retry-After"),
                        rate_limit_error=True
                    )
                    continue
                
            elif status_code in [400, 401, 403]:
                # Client errors - don't retry
                try:
                    error_data = response.json()
                    error_msg = error_data.get("error", {}).get("message", "Unknown error")
                except:
                    error_msg = response.text[:500]
                
                print(f"{debug_prefix} ❌ Client error {status_code}: {error_msg}")
                raise requests.exceptions.HTTPError(f"Client error {status_code}: {error_msg}")
                
            elif status_code in [500, 502, 503, 504]:
                # Server errors - retry with backoff
                rate_limiter.record_error()
                print(f"{debug_prefix} 🔄 Server error {status_code} (attempt {attempt + 1}/{MAX_RETRIES})")
                
                if attempt < MAX_RETRIES - 1:
                    _sleep_with_backoff(attempt)
                    continue
                    
            else:
                # Other errors
                print(f"{debug_prefix} ❓ Unexpected status {status_code}")
                response.raise_for_status()

        except requests.exceptions.Timeout:
            last_error = "Request timeout"
            print(f"{debug_prefix} ⏰ Timeout (attempt {attempt + 1}/{MAX_RETRIES})")
            if attempt < MAX_RETRIES - 1:
                _sleep_with_backoff(attempt)
                continue
                
        except requests.exceptions.ConnectionError as conn_error:
            last_error = conn_error
            print(f"{debug_prefix} 🔌 Connection error (attempt {attempt + 1}/{MAX_RETRIES})")
            if attempt < MAX_RETRIES - 1:
                _sleep_with_backoff(attempt)
                continue
                
        except Exception as unexpected_error:
            last_error = unexpected_error
            print(f"{debug_prefix} ❌ Unexpected error: {unexpected_error}")
            if attempt < MAX_RETRIES - 1:
                time.sleep(2)
                continue
    
    # All retries exhausted
    rate_limiter.record_error()
    error_msg = f"Failed after {MAX_RETRIES} attempts. Last error: {last_error}"
    print(f"{debug_prefix} 💥 {error_msg}")
    
    # Return neutral result instead of crashing
    return "Tie", [f"API_ERROR: {error_msg}"], [], []

# ----------------------
# Main Workflow
# ----------------------
def main():
    random.seed(RANDOM_SEED)
    OUTPUT_DIR.mkdir(parents=True, exist_ok=True)
    
    # Initialize rate limiter
    rate_limiter = RateLimiter(MIN_SLEEP_BETWEEN_ITEMS, MAX_SLEEP_BETWEEN_ITEMS)
    
    # Error logging
    ERROR_LOG = OUTPUT_DIR / "avalai_errors.log"
    
    def log_error(msg: str):
        timestamp = datetime.now().isoformat()
        try:
            with ERROR_LOG.open("a", encoding="utf-8") as f:
                f.write(f"[{timestamp}] {msg}\n")
        except Exception:
            pass

    print("📂 Loading datasets...")

    if not os.path.exists(ONE_SHOT_JSON_PATH) or not os.path.exists(FEW_SHOT_JSON_PATH):
        raise FileNotFoundError("One or both JSON file paths are incorrect. Please check the paths.")

    one_name = Path(ONE_SHOT_JSON_PATH).name
    few_name = Path(FEW_SHOT_JSON_PATH).name

    uploaded = {
        one_name: Path(ONE_SHOT_JSON_PATH).read_bytes(),
        few_name: Path(FEW_SHOT_JSON_PATH).read_bytes()
    }
    print(f"📄 One-Shot file: {one_name}")
    print(f"📄 Few-Shot file: {few_name}")

    one_map = load_dataset_from_bytes(uploaded[one_name], source_hint=one_name)
    few_map = load_dataset_from_bytes(uploaded[few_name], source_hint=few_name)

    shared = sorted(set(one_map.keys()) & set(few_map.keys()))
    print(f"✅ Shared items: {len(shared)}")

    # Index images
    IMAGES_DIR = Path(IMAGES_DIR_PATH)
    if IMAGES_DIR.exists():
        print(f"🗂️ Indexing images in folder: {IMAGES_DIR}")
        IMAGE_INDEX = index_images(IMAGES_DIR)
        print(f"  -> Found {len(IMAGE_INDEX)} images")
    else:
        print(f"ℹ️ Images folder not found at: {IMAGES_DIR}")
        IMAGE_INDEX = {}

    # Prepare output files
    summary_csv = OUTPUT_DIR / "pairwise_summary.csv"
    pairs_jsonl = OUTPUT_DIR / "pairwise_pairs.jsonl"
    prompt_txt = OUTPUT_DIR / "judge_prompt.txt"
    judge_csv = OUTPUT_DIR / "judge_report.csv"
    aggregate_csv = OUTPUT_DIR / "judge_aggregate.csv"

    # Save prompt template
    prompt_txt.write_text(
    """Enhanced Pairwise RDF Evaluation Prompt:

    You are evaluating RDF triples extracted from the same image by two methods.
    Analyze both extractions for correctness, completeness, and RDF validity.

    Respond with ONLY a valid JSON object in this exact format:
    {
      "winner": "A",
      "reasons": ["reason 1", "reason 2"],
      "major_errors_A": ["error 1 in method A"],
      "major_errors_B": ["error 1 in method B"]
    }

    Rules:
    - winner must be exactly 'A', 'B', or 'Tie'
    - All arrays must contain strings
    - No extra text before or after JSON
    - Consider: correctness, completeness, RDF syntax validity
    - Longer extractions are not automatically better
    """, encoding="utf-8"
    )

    # Build comparison pairs
    rows = []
    with pairs_jsonl.open("w", encoding="utf-8") as jout:
        for img in shared:
            turtle_one = one_map.get(img, "")
            turtle_few = few_map.get(img, "")
            
            # Randomize A/B assignment
            if random.random() < 0.5:
                A_label, B_label = "One-Shot", "Few-Shot"
                A_turtle, B_turtle = turtle_one, turtle_few
            else:
                A_label, B_label = "Few-Shot", "One-Shot"
                A_turtle, B_turtle = turtle_few, turtle_one

            img_path = find_image_path_indexed(IMAGE_INDEX, img)

            rows.append({
                "image_id": img, 
                "img_path": img_path or "", 
                "A_model": A_label, 
                "B_model": B_label
            })
            
            jout.write(json.dumps({
                "image_id": img,
                "image_path": img_path,
                "A_label": A_label,
                "B_label": B_label,
                "triples_A_turtle": A_turtle,
                "triples_B_turtle": B_turtle,
                "seed": RANDOM_SEED
            }, ensure_ascii=False) + "\n")

    # Write summary
    if rows:
        with summary_csv.open("w", newline="", encoding="utf-8") as f:
            writer = csv.DictWriter(f, fieldnames=list(rows[0].keys()))
            writer.writeheader()
            writer.writerows(rows)

    print(f"\n📝 Generated {len(rows)} comparison pairs")
    print(f"📝 Files: {summary_csv}, {pairs_jsonl}, {prompt_txt}")

    # ----------------------
    # Run AvalAI judging
    # ----------------------
    if JUDGE_MODE == "avalai":
        print(f"\n🤖 Starting robust judge: {JUDGE_MODE} with model {AVALAI_MODEL}")
        print(f"🛡️ Rate limiting: {MIN_SLEEP_BETWEEN_ITEMS}-{MAX_SLEEP_BETWEEN_ITEMS}s between requests")
        
        # Load pairs
        with pairs_jsonl.open("r", encoding="utf-8") as f:
            lines = [json.loads(ln) for ln in f]

        results = []
        total_items = len(lines)
        errors_count = 0
        start_time = time.time()

        print(f"🚀 Processing {total_items} items...")
        
        for i, rec in enumerate(lines, start=1):
            prefix = f"[{i}/{total_items}]"
            item_start_time = time.time()
            
            print(f"\n{prefix} Processing: {rec['image_id']}")
            
            try:
                winner, reasons, errA, errB = avalai_judge_robust(
                    rec["triples_A_turtle"], rec["A_label"],
                    rec["triples_B_turtle"], rec["B_label"],
                    api_key=AVALAI_API_KEY, 
                    base_url=BASE_URL, 
                    model_name=AVALAI_MODEL,
                    rate_limiter=rate_limiter,
                    debug_prefix=prefix
                )
                
                item_time = time.time() - item_start_time
                
                if "API_ERROR" in str(reasons):
                    errors_count += 1
                    status_emoji = "⚠️"
                else:
                    status_emoji = "✅"
                
                print(f"{prefix} {status_emoji} Winner: {winner} | "
                      f"Time: {item_time:.1f}s | "
                      f"Reasons: {'; '.join(reasons)[:150]}")
                
                # Log detailed info
                log_error(f"Item {i}: {rec['image_id']} -> Winner: {winner}, "
                         f"Reasons: {reasons}, ErrorsA: {errA}, ErrorsB: {errB}")
                
            except Exception as e:
                errors_count += 1
                winner, reasons, errA, errB = "Tie", [f"FATAL_ERROR: {str(e)[:200]}"], [], []
                print(f"{prefix} ❌ Fatal error: {e}")
                log_error(f"FATAL ERROR Item {i} ({rec['image_id']}): {e}")

            results.append({
                "image_id": rec["image_id"],
                "A_label": rec["A_label"],
                "B_label": rec["B_label"],
                "winner": winner,
                "reasons": " | ".join(reasons),
                "errors_A": " | ".join(errA),
                "errors_B": " | ".join(errB)
            })

            # Progress update
            if i % 10 == 0:
                elapsed = time.time() - start_time
                rate = i / elapsed if elapsed > 0 else 0
                eta = (total_items - i) / rate if rate > 0 else 0
                print(f"📊 Progress: {i}/{total_items} ({i/total_items*100:.1f}%) | "
                      f"Rate: {rate:.2f} items/min | ETA: {eta/60:.1f}min | Errors: {errors_count}")

        # Final statistics
        total_time = time.time() - start_time
        print(f"\n🏁 Completed processing in {total_time/60:.1f} minutes")
        print(f"📈 Average rate: {len(results) / total_time * 60:.2f} items/minute")
        print(f"❌ Total errors: {errors_count}/{len(results)} ({errors_count/len(results)*100:.1f}%)")

        # Calculate aggregates
        winA = sum(1 for r in results if r["winner"] == "A")
        winB = sum(1 for r in results if r["winner"] == "B")
        ties = sum(1 for r in results if r["winner"] == "Tie")
        total = len(results)

        # Save detailed results
        if results:
            with judge_csv.open("w", newline="", encoding="utf-8") as f:
                writer = csv.DictWriter(f, fieldnames=list(results[0].keys()))
                writer.writeheader()
                writer.writerows(results)

            with aggregate_csv.open("w", newline="", encoding="utf-8") as f:
                writer = csv.DictWriter(f, fieldnames=[
                    "total", "A_wins", "B_wins", "ties", "errors", 
                    "processing_time_min", "avg_rate_per_min"
                ])
                writer.writeheader()
                writer.writerow({
                    "total": total, 
                    "A_wins": winA, 
                    "B_wins": winB, 
                    "ties": ties,
                    "errors": errors_count,
                    "processing_time_min": round(total_time / 60, 2),
                    "avg_rate_per_min": round(len(results) / total_time * 60, 2)
                })

        print(f"\n🧮 Final Results:")
        print(f"   Total: {total}")
        print(f"   A wins: {winA} ({winA/total*100:.1f}%)")
        print(f"   B wins: {winB} ({winB/total*100:.1f}%)")
        print(f"   Ties: {ties} ({ties/total*100:.1f}%)")
        print(f"   Errors: {errors_count} ({errors_count/total*100:.1f}%)")
        print(f"\n📝 Output files:")
        print(f"   - {judge_csv}")
        print(f"   - {aggregate_csv}")
        print(f"   - {ERROR_LOG}")

    # Download files in Colab
    if IN_COLAB:
        print("\n⬇️ Downloading results...")
        for filepath in [summary_csv, pairs_jsonl, prompt_txt, judge_csv, aggregate_csv, ERROR_LOG]:
            if filepath.exists():
                try:
                    files.download(str(filepath))
                    print(f"✅ Downloaded: {filepath.name}")
                except Exception as e:
                    print(f"❌ Failed to download {filepath.name}: {e}")

    print("\n🎉 All done!")


# ----------------------
# Execute main function
# ----------------------
if __name__ == "__main__":
    try:
        main()
    except KeyboardInterrupt:
        print("\n⏹️ Process interrupted by user")
        sys.exit(1)
    except Exception as e:
        print(f"\n💥 Fatal error in main execution: {e}")
        import traceback
        traceback.print_exc()
        sys.exit(1)
# Out:
# 📂 Loading datasets...
# 📄 One-Shot file: rdf_extractions_oneShot.json
# 📄 Few-Shot file: rdf_extractions_FewShot.json
# ✅ Shared items: 56
# 🗂️ Indexing images in folder: /kaggle/input/rdf-evaluation/Dataset/Dataset
#   -> Found 71 images
#
# 📝 Generated 56 comparison pairs
# 📝 Files: /kaggle/working/pairwise_out/pairwise_summary.csv, /kaggle/working/pairwise_out/pairwise_pairs.jsonl, /kaggle/working/pairwise_out/judge_prompt.txt
#
# 🤖 Starting robust judge: avalai with model gemma-3n-e4b-it
# 🛡️ Rate limiting: 2.0-5.0s between requests
# 🚀 Processing 56 items...
#
# [1/56] Processing: box_5.1.jpg
# [1/56] [sizes] A:3992->1486 chars | B:3692->1476 chars | prompt:3680 chars
# [1/56] [HTTP 200] response: {   "id": "KwfBaMzyL-vUvdIP9fvN-QQ",   "created": 1757480744,   "model": "gemma-3n-e4b-it",   "object": "chat.completion",   "system_fingerprint": null,   "choices": [     {       "finish_reason": "stop",       "index": 0,       "message": {         "content": "```json\n{\n  \"winner\": \"B\",\n  \"reasons\": [\n    \"Method B demonstrates better completeness by explicitly linking concepts like 'M
# [1/56] ✅ Winner: B | Time: 4.2s | Reasons: Method B demonstrates better completeness by explicitly linking concepts like 'MaxAllowedConcentrationInDrinkingWater' to the pathways and data needed
#
# [2/56] Processing: figure_1.2.jpg
# [2/56] [sizes] A:1446->1446 chars | B:1456->1456 chars | prompt:3620 chars
# [2/56] [HTTP 200] response: {   "id": "LgfBaLK9Ns3VvdIPof-PiAU",   "created": 1757480748,   "model": "gemma-3n-e4b-it",   "object": "chat.completion",   "system_fingerprint": null,   "choices": [     {       "finish_reason": "stop",       "index": 0,       "message": {         "content": "```json\n{\n  \"winner\": \"B\",\n  \"reasons\": [\n    \"Method B demonstrates better completeness by including the relationships 'narrow
# [2/56] ✅ Winner: B | Time: 3.1s | Reasons: Method B demonstrates better completeness by including the relationships 'narrower' and 'isAssessedAs' which provide more specific connections between
#
# [3/56] Processing: figure_1.3.jpg
# [3/56] [sizes] A:3175->1490 chars | B:3238->1493 chars | prompt:3701 chars
# ⏳ Rate limiting: sleeping 1.2s
# [3/56] [HTTP 429] response: {   "error": {     "message": "Rate limit reached for requests.",     "type": "rate_limit_exceeded",     "param": null,     "code": "rate_limit_exceeded",     "solution": "Pace your requests or upgrade to higher levels. Read the Rate limit guide at https://chat.avalai.ir/platform/limits"   } }
# [3/56] 🚫 Rate limit exceeded (attempt 1/5)
# 🚫 Rate limit backoff: 1.0s
# ⏳ Rate limiting: sleeping 6.1s
# [3/56] [HTTP 429] response: {   "error": {     "message": "Rate limit reached for requests.",     "type": "rate_limit_exceeded",     "param": null,     "code": "rate_limit_exceeded",     "solution": "Pace your requests or upgrade to higher levels. Read the Rate limit guide at https://chat.avalai.ir/platform/limits"   } }
# [3/56] 🚫 Rate limit exceeded (attempt 2/5)
# 🚫 Rate limit backoff: 5.9s
# ⏳ Rate limiting: sleeping 5.0s
# [3/56] [HTTP 200] response: {   "id": "RAfBaI2QLafXvdIP84-b4QM",   "created": 1757480771,   "model": "gemma-3n-e4b-it",   "object": "chat.completion",   "system_fingerprint": null,   "choices": [     {       "finish_reason": "stop",       "index": 0,       "message": {         "content": "```json\n{\n  \"winner\": \"Tie\",\n  \"reasons\": [\n    \"Both methods extract the same triples, indicating identical correctness and co
# [3/56] ✅ Winner: Tie | Time: 21.8s | Reasons: Both methods extract the same triples, indicating identical correctness and completeness.; The truncated nature of the triples makes a definitive dete
#
# [4/56] Processing: figure_2.1.jpg
# [4/56] [sizes] A:3981->1500 chars | B:3726->1469 chars | prompt:3687 chars
# ⏳ Rate limiting: sleeping 1.0s
# [4/56] [HTTP 200] response: {   "id": "SgfBaOnsD5-MvdIP7dKC0Qc",   "created": 1757480774,   "model": "gemma-3n-e4b-it",   "object": "chat.completion",   "system_fingerprint": null,   "choices": [     {       "finish_reason": "stop",       "index": 0,       "message": {         "content": "```json\n{\n  \"winner\": \"B\",\n  \"reasons\": [\n    \"Method B provides more specific relationships between concepts (e.g., `she:repre
# [4/56] ✅ Winner: B | Time: 5.5s | Reasons: Method B provides more specific relationships between concepts (e.g., `she:representsUpperLimitOf`, `she:isBelow`) which are more informative than the
#
# [5/56] Processing: figure_3.1.jpg
# [5/56] [sizes] A:5657->1494 chars | B:3638->1496 chars | prompt:3708 chars
# [5/56] [HTTP 429] response: {   "error": {     "message": "Rate limit reached for requests.",     "type": "rate_limit_exceeded",     "param": null,     "code": "rate_limit_exceeded",     "solution": "Pace your requests or upgrade to higher levels. Read the Rate limit guide at https://chat.avalai.ir/platform/limits"   } }
# [5/56] 🚫 Rate limit exceeded (attempt 1/5)
# 🚫 Rate limit backoff: 1.0s
# ⏳ Rate limiting: sleeping 6.3s
# [5/56] [HTTP 429] response: {   "error": {     "message": "Rate limit reached for requests.",     "type": "rate_limit_exceeded",     "param": null,     "code": "rate_limit_exceeded",     "solution": "Pace your requests or upgrade to higher levels. Read the Rate limit guide at https://chat.avalai.ir/platform/limits"   } }
# [5/56] 🚫 Rate limit exceeded (attempt 2/5)
# 🚫 Rate limit backoff: 5.2s
# ⏳ Rate limiting: sleeping 5.9s
# [5/56] [HTTP 429] response: {   "error": {     "message": "Rate limit reached for requests.",     "type": "rate_limit_exceeded",     "param": null,     "code": "rate_limit_exceeded",     "solution": "Pace your requests or upgrade to higher levels. Read the Rate limit guide at https://chat.avalai.ir/platform/limits"   } }
# [5/56] 🚫 Rate limit exceeded (attempt 3/5)
# 🚫 Rate limit backoff: 24.5s
# [5/56] [HTTP 200] response: {   "id": "eQfBaIyqG92C7M8P5t2fkAM",   "created": 1757480822,   "model": "gemma-3n-e4b-it",   "object": "chat.completion",   "system_fingerprint": null,   "choices": [     {       "finish_reason": "stop",       "index": 0,       "message": {         "content": "```json\n{\n  \"winner\": \"A\",\n  \"reasons\": [\n    \"Method A provides a more complete hierarchy of concepts, including more specific
# [5/56] ✅ Winner: A | Time: 47.2s | Reasons: Method A provides a more complete hierarchy of concepts, including more specific concepts like CalciumIon, MagnesiumIon, and PotassiumIon.; Method A i
#
# [6/56] Processing: figure_3.2.jpg
# [6/56] [sizes] A:1634->1487 chars | B:1921->1456 chars | prompt:3661 chars
# ⏳ Rate limiting: sleeping 0.8s
# [6/56] [HTTP 200] response: {   "id": "fgfBaP7hCZ6Dxs0Pi_bm8AM",   "created": 1757480826,   "model": "gemma-3n-e4b-it",   "object": "chat.completion",   "system_fingerprint": null,   "choices": [     {       "finish_reason": "stop",       "index": 0,       "message": {         "content": "```json\n{\n  \"winner\": \"B\",\n  \"reasons\": [\n    \"Method B provides more nuanced relationships, such as 'reachesMaximumAt' and 'in
# [6/56] ✅ Winner: B | Time: 4.7s | Reasons: Method B provides more nuanced relationships, such as 'reachesMaximumAt' and 'increasesRapidlyBeyond', which are more descriptive than 'isInfluencedBy
#
# [7/56] Processing: figure_3.3.jpg
# [7/56] [sizes] A:3378->1512 chars | B:3519->1507 chars | prompt:3737 chars
# ⏳ Rate limiting: sleeping 1.0s
# [7/56] [HTTP 429] response: {   "error": {     "message": "Rate limit reached for requests.",     "type": "rate_limit_exceeded",     "param": null,     "code": "rate_limit_exceeded",     "solution": "Pace your requests or upgrade to higher levels. Read the Rate limit guide at https://chat.avalai.ir/platform/limits"   } }
# [7/56] 🚫 Rate limit exceeded (attempt 1/5)
# 🚫 Rate limit backoff: 1.0s
# ⏳ Rate limiting: sleeping 6.0s
# [7/56] [HTTP 429] response: {   "error": {     "message": "Rate limit reached for requests.",     "type": "rate_limit_exceeded",     "param": null,     "code": "rate_limit_exceeded",     "solution": "Pace your requests or upgrade to higher levels. Read the Rate limit guide at https://chat.avalai.ir/platform/limits"   } }
# [7/56] 🚫 Rate limit exceeded (attempt 2/5)
# 🚫 Rate limit backoff: 5.4s
# ⏳ Rate limiting: sleeping 5.4s
# [7/56] [HTTP 429] response: {   "error": {     "message": "Rate limit reached for requests.",     "type": "rate_limit_exceeded",     "param": null,     "code": "rate_limit_exceeded",     "solution": "Pace your requests or upgrade to higher levels. Read the Rate limit guide at https://chat.avalai.ir/platform/limits"   } }
# [7/56] 🚫 Rate limit exceeded (attempt 3/5)
# 🚫 Rate limit backoff: 19.5s
# [7/56] [HTTP 429] response: {   "error": {     "message": "Rate limit reached for requests.",     "type": "rate_limit_exceeded",     "param": null,     "code": "rate_limit_exceeded",     "solution": "Pace your requests or upgrade to higher levels. Read the Rate limit guide at https://chat.avalai.ir/platform/limits"   } }
# [7/56] 🚫 Rate limit exceeded (attempt 4/5)
# 🚫 Rate limit backoff: 137.6s
# [7/56] [HTTP 200] response: {   "id": "MwjBaIedF__6nsEPhLOi2Q4",   "created": 1757481007,   "model": "gemma-3n-e4b-it",   "object": "chat.completion",   "system_fingerprint": null,   "choices": [     {       "finish_reason": "stop",       "index": 0,       "message": {         "content": "```json\n{\n  \"winner\": \"B\",\n  \"reasons\": [\n    \"Method B provides more context and relationships between concepts, such as 'illu
# [7/56] ✅ Winner: B | Time: 181.2s | Reasons: Method B provides more context and relationships between concepts, such as 'illustratesDynamicRelationshipBetween' and 'hasPRecommendation'.; Method B
#
# [8/56] Processing: figure_3.4.jpg
# [8/56] [sizes] A:3110->1493 chars | B:4999->1510 chars | prompt:3721 chars
# [8/56] [HTTP 200] response: {   "id": "NgjBaJL6I5fhnsEPxc7XuAM",   "created": 1757481011,   "model": "gemma-3n-e4b-it",   "object": "chat.completion",   "system_fingerprint": null,   "choices": [     {       "finish_reason": "stop",       "index": 0,       "message": {         "content": "```json\n{\n  \"winner\": \"A\",\n  \"reasons\": [\n    \"Method A provides more detailed information about the relationships between conc
# [8/56] ✅ Winner: A | Time: 3.2s | Reasons: Method A provides more detailed information about the relationships between concepts, including specific relationships like 'depictsRelationshipBetwee
#
# [9/56] Processing: figure_4.1.jpg
# [9/56] [sizes] A:1980->1512 chars | B:2036->1502 chars | prompt:3732 chars
# ⏳ Rate limiting: sleeping 1.8s
# [9/56] [HTTP 429] response: {   "error": {     "message": "Rate limit reached for requests.",     "type": "rate_limit_exceeded",     "param": null,     "code": "rate_limit_exceeded",     "solution": "Pace your requests or upgrade to higher levels. Read the Rate limit guide at https://chat.avalai.ir/platform/limits"   } }
# [9/56] 🚫 Rate limit exceeded (attempt 1/5)
# 🚫 Rate limit backoff: 1.2s
# ⏳ Rate limiting: sleeping 6.2s
# [9/56] [HTTP 429] response: {   "error": {     "message": "Rate limit reached for requests.",     "type": "rate_limit_exceeded",     "param": null,     "code": "rate_limit_exceeded",     "solution": "Pace your requests or upgrade to higher levels. Read the Rate limit guide at https://chat.avalai.ir/platform/limits"   } }
# [9/56] 🚫 Rate limit exceeded (attempt 2/5)
# 🚫 Rate limit backoff: 4.5s
# ⏳ Rate limiting: sleeping 6.6s
# [9/56] [HTTP 429] response: {   "error": {     "message": "Rate limit reached for requests.",     "type": "rate_limit_exceeded",     "param": null,     "code": "rate_limit_exceeded",     "solution": "Pace your requests or upgrade to higher levels. Read the Rate limit guide at https://chat.avalai.ir/platform/limits"   } }
# [9/56] 🚫 Rate limit exceeded (attempt 3/5)
# 🚫 Rate limit backoff: 23.6s
# [9/56] [HTTP 429] response: {   "error": {     "message": "Rate limit reached for requests.",     "type": "rate_limit_exceeded",     "param": null,     "code": "rate_limit_exceeded",     "solution": "Pace your requests or upgrade to higher levels. Read the Rate limit guide at https://chat.avalai.ir/platform/limits"   } }
# [9/56] 🚫 Rate limit exceeded (attempt 4/5)
# 🚫 Rate limit backoff: 135.5s
# [9/56] [HTTP 200] response: {   "id": "7QjBaN2LLKjVxN8P5Kic-As",   "created": 1757481195,   "model": "gemma-3n-e4b-it",   "object": "chat.completion",   "system_fingerprint": null,   "choices": [     {       "finish_reason": "stop",       "index": 0,       "message": {         "content": "```json\n{\n  \"winner\": \"A\",\n  \"reasons\": [\n    \"Method A provides more detailed information about the relationships between conc
# [9/56] ✅ Winner: A | Time: 183.1s | Reasons: Method A provides more detailed information about the relationships between concepts, including the specific axes of the plot and the source of the da
#
# [10/56] Processing: figure_5.2.jpg
# [10/56] [sizes] A:3550->1509 chars | B:3478->1479 chars | prompt:3706 chars
# [10/56] [HTTP 429] response: {   "error": {     "message": "Rate limit reached for requests.",     "type": "rate_limit_exceeded",     "param": null,     "code": "rate_limit_exceeded",     "solution": "Pace your requests or upgrade to higher levels. Read the Rate limit guide at https://chat.avalai.ir/platform/limits"   } }
# [10/56] 🚫 Rate limit exceeded (attempt 1/5)
# 🚫 Rate limit backoff: 1.0s
# ⏳ Rate limiting: sleeping 5.7s
# [10/56] [HTTP 200] response: {   "id": "-QjBaOa_Dqq_vdIPwdyO-Qc",   "created": 1757481205,   "model": "gemma-3n-e4b-it",   "object": "chat.completion",   "system_fingerprint": null,   "choices": [     {       "finish_reason": "stop",       "index": 0,       "message": {         "content": "```json\n{\n  \"winner\": \"B\",\n  \"reasons\": [\n    \"Method B provides more descriptive definitions for the relationships between con
# [10/56] ✅ Winner: B | Time: 11.5s | Reasons: Method B provides more descriptive definitions for the relationships between concepts (e.g., 'she:definesLowerBoundaryForRisk'). This enhances the sem
# 📊 Progress: 10/56 (17.9%) | Rate: 0.02 items/min | ETA: 35.7min | Errors: 0
#
# [11/56] Processing: figure_6.1.jpg
# [11/56] [sizes] A:1633->1489 chars | B:2109->1485 chars | prompt:3692 chars
# [11/56] [HTTP 429] response: {   "error": {     "message": "Rate limit reached for requests.",     "type": "rate_limit_exceeded",     "param": null,     "code": "rate_limit_exceeded",     "solution": "Pace your requests or upgrade to higher levels. Read the Rate limit guide at https://chat.avalai.ir/platform/limits"   } }
# [11/56] 🚫 Rate limit exceeded (attempt 1/5)
# 🚫 Rate limit backoff: 1.0s
# ⏳ Rate limiting: sleeping 6.3s
# [11/56] [HTTP 429] response: {   "error": {     "message": "Rate limit reached for requests.",     "type": "rate_limit_exceeded",     "param": null,     "code": "rate_limit_exceeded",     "solution": "Pace your requests or upgrade to higher levels. Read the Rate limit guide at https://chat.avalai.ir/platform/limits"   } }
# [11/56] 🚫 Rate limit exceeded (attempt 2/5)
# 🚫 Rate limit backoff: 3.9s
# ⏳ Rate limiting: sleeping 7.2s
# [11/56] [HTTP 429] response: {   "error": {     "message": "Rate limit reached for requests.",     "type": "rate_limit_exceeded",     "param": null,     "code": "rate_limit_exceeded",     "solution": "Pace your requests or upgrade to higher levels. Read the Rate limit guide at https://chat.avalai.ir/platform/limits"   } }
# [11/56] 🚫 Rate limit exceeded (attempt 3/5)
# 🚫 Rate limit backoff: 28.4s
# [11/56] [HTTP 200] response: {   "id": "LAnBaNbRG83qkdUPrJeMwQ4",   "created": 1757481256,   "model": "gemma-3n-e4b-it",   "object": "chat.completion",   "system_fingerprint": null,   "choices": [     {       "finish_reason": "stop",       "index": 0,       "message": {         "content": "```json\n{\n  \"winner\": \"B\",\n  \"reasons\": [\n    \"Method B provides more descriptive relationships between concepts (e.g., 'isChar
# [11/56] ✅ Winner: B | Time: 51.2s | Reasons: Method B provides more descriptive relationships between concepts (e.g., 'isCharacterizedBy', 'maintains', 'causesTemporaryIncreaseIn', 'describesBeha
#
# [12/56] Processing: figure_8.1.jpg
# [12/56] [sizes] A:5338->1495 chars | B:5949->1493 chars | prompt:3706 chars
# [12/56] [HTTP 200] response: {   "id": "MAnBaNvzC43d7M8PssSxyQ4",   "created": 1757481260,   "model": "gemma-3n-e4b-it",   "object": "chat.completion",   "system_fingerprint": null,   "choices": [     {       "finish_reason": "stop",       "index": 0,       "message": {         "content": "```json\n{\n  \"winner\": \"B\",\n  \"reasons\": [\n    \"Method B provides a definition for 'Machinery' which adds semantic richness and
# [12/56] ✅ Winner: B | Time: 3.7s | Reasons: Method B provides a definition for 'Machinery' which adds semantic richness and context. This is a key advantage of few-shot learning.; Method B expli
#
# [13/56] Processing: table_1.2.jpg
# [13/56] [sizes] A:2104->1444 chars | B:1818->1504 chars | prompt:3666 chars
# [13/56] [HTTP 429] response: {   "error": {     "message": "Rate limit reached for requests.",     "type": "rate_limit_exceeded",     "param": null,     "code": "rate_limit_exceeded",     "solution": "Pace your requests or upgrade to higher levels. Read the Rate limit guide at https://chat.avalai.ir/platform/limits"   } }
# [13/56] 🚫 Rate limit exceeded (attempt 1/5)
# 🚫 Rate limit backoff: 1.0s
# ⏳ Rate limiting: sleeping 6.2s
# [13/56] [HTTP 429] response: {   "error": {     "message": "Rate limit reached for requests.",     "type": "rate_limit_exceeded",     "param": null,     "code": "rate_limit_exceeded",     "solution": "Pace your requests or upgrade to higher levels. Read the Rate limit guide at https://chat.avalai.ir/platform/limits"   } }
# [13/56] 🚫 Rate limit exceeded (attempt 2/5)
# 🚫 Rate limit backoff: 5.9s
# ⏳ Rate limiting: sleeping 5.1s
# [13/56] [HTTP 429] response: {   "error": {     "message": "Rate limit reached for requests.",     "type": "rate_limit_exceeded",     "param": null,     "code": "rate_limit_exceeded",     "solution": "Pace your requests or upgrade to higher levels. Read the Rate limit guide at https://chat.avalai.ir/platform/limits"   } }
# [13/56] 🚫 Rate limit exceeded (attempt 3/5)
# 🚫 Rate limit backoff: 19.8s
# [13/56] [HTTP 200] response: {   "id": "WQnBaJyEK7_4xN8Po_bHyQs",   "created": 1757481303,   "model": "gemma-3n-e4b-it",   "object": "chat.completion",   "system_fingerprint": null,   "choices": [     {       "finish_reason": "stop",       "index": 0,       "message": {         "content": "```json\n{\n  \"winner\": \"B\",\n  \"reasons\": [\n    \"Method B provides more complete definitions for concepts like 'NutrientMobilisat
# [13/56] ✅ Winner: B | Time: 41.5s | Reasons: Method B provides more complete definitions for concepts like 'NutrientMobilisationCapacity' and 'NutrientBufferingCapacity', which enhances understan
#
# [14/56] Processing: table_1.3.jpg
# [14/56] [sizes] A:4588->1493 chars | B:4583->1488 chars | prompt:3699 chars
# ⏳ Rate limiting: sleeping 0.9s
# [14/56] [HTTP 200] response: {   "id": "XAnBaJ67OemvnsEPjKPRsQM",   "created": 1757481306,   "model": "gemma-3n-e4b-it",   "object": "chat.completion",   "system_fingerprint": null,   "choices": [     {       "finish_reason": "stop",       "index": 0,       "message": {         "content": "```json\n{\n  \"winner\": \"A\",\n  \"reasons\": [\n    \"Method A provides more complete definitions and relationships between concepts u
# [14/56] ✅ Winner: A | Time: 3.2s | Reasons: Method A provides more complete definitions and relationships between concepts using skos:narrower and skos:prefLabel.; Method A's triples are more de
#
# [15/56] Processing: table_1.5.jpg
# [15/56] [sizes] A:10092->1483 chars | B:3277->1487 chars | prompt:3688 chars
# ⏳ Rate limiting: sleeping 1.3s
# [15/56] [HTTP 429] response: {   "error": {     "message": "Rate limit reached for requests.",     "type": "rate_limit_exceeded",     "param": null,     "code": "rate_limit_exceeded",     "solution": "Pace your requests or upgrade to higher levels. Read the Rate limit guide at https://chat.avalai.ir/platform/limits"   } }
# [15/56] 🚫 Rate limit exceeded (attempt 1/5)
# 🚫 Rate limit backoff: 1.2s
# ⏳ Rate limiting: sleeping 5.9s
# [15/56] [HTTP 429] response: {   "error": {     "message": "Rate limit reached for requests.",     "type": "rate_limit_exceeded",     "param": null,     "code": "rate_limit_exceeded",     "solution": "Pace your requests or upgrade to higher levels. Read the Rate limit guide at https://chat.avalai.ir/platform/limits"   } }
# [15/56] 🚫 Rate limit exceeded (attempt 2/5)
# 🚫 Rate limit backoff: 5.8s
# ⏳ Rate limiting: sleeping 5.1s
# [15/56] [HTTP 429] response: {   "error": {     "message": "Rate limit reached for requests.",     "type": "rate_limit_exceeded",     "param": null,     "code": "rate_limit_exceeded",     "solution": "Pace your requests or upgrade to higher levels. Read the Rate limit guide at https://chat.avalai.ir/platform/limits"   } }
# [15/56] 🚫 Rate limit exceeded (attempt 3/5)
# 🚫 Rate limit backoff: 29.5s
# [15/56] [HTTP 429] response: {   "error": {     "message": "Rate limit reached for requests.",     "type": "rate_limit_exceeded",     "param": null,     "code": "rate_limit_exceeded",     "solution": "Pace your requests or upgrade to higher levels. Read the Rate limit guide at https://chat.avalai.ir/platform/limits"   } }
# [15/56] 🚫 Rate limit exceeded (attempt 4/5)
# 🚫 Rate limit backoff: 111.2s
# [15/56] [HTTP 200] response: {   "id": "_wnBaPTJL5-AvdIP9PvE2As",   "created": 1757481470,   "model": "gemma-3n-e4b-it",   "object": "chat.completion",   "system_fingerprint": null,   "choices": [     {       "finish_reason": "stop",       "index": 0,       "message": {         "content": "```json\n{\n  \"winner\": \"A\",\n  \"reasons\": [\n    \"Method A provides a complete and valid RDF representation of the provided triple
# [15/56] ✅ Winner: A | Time: 162.8s | Reasons: Method A provides a complete and valid RDF representation of the provided triples.; Method B is identical to Method A, therefore it is equally correct
#
# [16/56] Processing: table_1.7.jpg
# [16/56] [sizes] A:6528->1466 chars | B:7750->1506 chars | prompt:3690 chars
# ⏳ Rate limiting: sleeping 1.5s
# [16/56] [HTTP 429] response: {   "error": {     "message": "Rate limit reached for requests.",     "type": "rate_limit_exceeded",     "param": null,     "code": "rate_limit_exceeded",     "solution": "Pace your requests or upgrade to higher levels. Read the Rate limit guide at https://chat.avalai.ir/platform/limits"   } }
# [16/56] 🚫 Rate limit exceeded (attempt 1/5)
# 🚫 Rate limit backoff: 1.0s
# ⏳ Rate limiting: sleeping 6.1s
# [16/56] [HTTP 200] response: {   "id": "DArBaNW3FdCtvdIP_NLfsAY",   "created": 1757481481,   "model": "gemma-3n-e4b-it",   "object": "chat.completion",   "system_fingerprint": null,   "choices": [     {       "finish_reason": "stop",       "index": 0,       "message": {         "content": "```json\n{\n  \"winner\": \"B\",\n  \"reasons\": [\n    \"Method B demonstrates better completeness by including more of the relevant obje
# [16/56] ✅ Winner: B | Time: 12.6s | Reasons: Method B demonstrates better completeness by including more of the relevant objectives and targets from the image content.; Method B's triples are mor
#
# [17/56] Processing: table_1.7_cont.jpg
# [17/56] [sizes] A:4866->1415 chars | B:3031->1421 chars | prompt:3554 chars
# ⏳ Rate limiting: sleeping 1.1s
# [17/56] [HTTP 429] response: {   "error": {     "message": "Rate limit reached for requests.",     "type": "rate_limit_exceeded",     "param": null,     "code": "rate_limit_exceeded",     "solution": "Pace your requests or upgrade to higher levels. Read the Rate limit guide at https://chat.avalai.ir/platform/limits"   } }
# [17/56] 🚫 Rate limit exceeded (attempt 1/5)
# 🚫 Rate limit backoff: 1.2s
# ⏳ Rate limiting: sleeping 5.7s
# [17/56] [HTTP 200] response: {   "id": "GArBaICROb3ukdUP9NCE0Q4",   "created": 1757481493,   "model": "gemma-3n-e4b-it",   "object": "chat.completion",   "system_fingerprint": null,   "choices": [     {       "finish_reason": "stop",       "index": 0,       "message": {         "content": "```json\n{\n  \"winner\": \"A\",\n  \"reasons\": [\n    \"Method A provides more specific relationships between concepts, such as 'she:has
# [17/56] ✅ Winner: A | Time: 12.6s | Reasons: Method A provides more specific relationships between concepts, such as 'she:hasColumn' and 'she:hasTitle', which offer a more granular understanding
#
# [18/56] Processing: table_10.1.jpg
# [18/56] [sizes] A:678->678 chars | B:2261->1481 chars | prompt:2877 chars
# [18/56] [HTTP 429] response: {   "error": {     "message": "Rate limit reached for requests.",     "type": "rate_limit_exceeded",     "param": null,     "code": "rate_limit_exceeded",     "solution": "Pace your requests or upgrade to higher levels. Read the Rate limit guide at https://chat.avalai.ir/platform/limits"   } }
# [18/56] 🚫 Rate limit exceeded (attempt 1/5)
# 🚫 Rate limit backoff: 1.0s
# ⏳ Rate limiting: sleeping 6.3s
# [18/56] [HTTP 429] response: {   "error": {     "message": "Rate limit reached for requests.",     "type": "rate_limit_exceeded",     "param": null,     "code": "rate_limit_exceeded",     "solution": "Pace your requests or upgrade to higher levels. Read the Rate limit guide at https://chat.avalai.ir/platform/limits"   } }
# [18/56] 🚫 Rate limit exceeded (attempt 2/5)
# 🚫 Rate limit backoff: 4.3s
# ⏳ Rate limiting: sleeping 6.7s
# [18/56] [HTTP 429] response: {   "error": {     "message": "Rate limit reached for requests.",     "type": "rate_limit_exceeded",     "param": null,     "code": "rate_limit_exceeded",     "solution": "Pace your requests or upgrade to higher levels. Read the Rate limit guide at https://chat.avalai.ir/platform/limits"   } }
# [18/56] 🚫 Rate limit exceeded (attempt 3/5)
# 🚫 Rate limit backoff: 21.7s
# [18/56] [HTTP 429] response: {   "error": {     "message": "Rate limit reached for requests.",     "type": "rate_limit_exceeded",     "param": null,     "code": "rate_limit_exceeded",     "solution": "Pace your requests or upgrade to higher levels. Read the Rate limit guide at https://chat.avalai.ir/platform/limits"   } }
# [18/56] 🚫 Rate limit exceeded (attempt 4/5)
# 🚫 Rate limit backoff: 124.1s
# [18/56] [HTTP 200] response: {   "id": "wQrBaNmsJKfXvdIP84-b4QM",   "created": 1757481662,   "model": "gemma-3n-e4b-it",   "object": "chat.completion",   "system_fingerprint": null,   "choices": [     {       "finish_reason": "stop",       "index": 0,       "message": {         "content": "```json\n{\n  \"winner\": \"B\",\n  \"reasons\": [\n    \"Method B provides more specific and detailed information about the relationships
# [18/56] ✅ Winner: B | Time: 168.7s | Reasons: Method B provides more specific and detailed information about the relationships between concepts (e.g., 'occursIn', 'hasIndicator').; Method B includ
#
# [19/56] Processing: table_10.1_cont.jpg
# [19/56] [sizes] A:6867->1474 chars | B:6895->1491 chars | prompt:3683 chars
# ⏳ Rate limiting: sleeping 0.3s
# [19/56] [HTTP 200] response: {   "id": "xQrBaPuRNqSLxN8Po5eu6A4",   "created": 1757481666,   "model": "gemma-3n-e4b-it",   "object": "chat.completion",   "system_fingerprint": null,   "choices": [     {       "finish_reason": "stop",       "index": 0,       "message": {         "content": "```json\n{\n  \"winner\": \"A\",\n  \"reasons\": [\n    \"Method A provides more detailed relationships and a clearer hierarchy of concept
# [19/56] ✅ Winner: A | Time: 4.3s | Reasons: Method A provides more detailed relationships and a clearer hierarchy of concepts (narrower relationships).; Method A includes more specific indicator
#
# [20/56] Processing: table_10.2_cont.jpg
# [20/56] [sizes] A:5535->1508 chars | B:5988->1489 chars | prompt:3715 chars
# [20/56] [HTTP 429] response: {   "error": {     "message": "Rate limit reached for requests.",     "type": "rate_limit_exceeded",     "param": null,     "code": "rate_limit_exceeded",     "solution": "Pace your requests or upgrade to higher levels. Read the Rate limit guide at https://chat.avalai.ir/platform/limits"   } }
# [20/56] 🚫 Rate limit exceeded (attempt 1/5)
# 🚫 Rate limit backoff: 1.0s
# ⏳ Rate limiting: sleeping 6.1s
# [20/56] [HTTP 429] response: {   "error": {     "message": "Rate limit reached for requests.",     "type": "rate_limit_exceeded",     "param": null,     "code": "rate_limit_exceeded",     "solution": "Pace your requests or upgrade to higher levels. Read the Rate limit guide at https://chat.avalai.ir/platform/limits"   } }
# [20/56] 🚫 Rate limit exceeded (attempt 2/5)
# 🚫 Rate limit backoff: 4.8s
# ⏳ Rate limiting: sleeping 6.1s
# [20/56] [HTTP 429] response: {   "error": {     "message": "Rate limit reached for requests.",     "type": "rate_limit_exceeded",     "param": null,     "code": "rate_limit_exceeded",     "solution": "Pace your requests or upgrade to higher levels. Read the Rate limit guide at https://chat.avalai.ir/platform/limits"   } }
# [20/56] 🚫 Rate limit exceeded (attempt 3/5)
# 🚫 Rate limit backoff: 23.4s
# [20/56] [HTTP 429] response: {   "error": {     "message": "Rate limit reached for requests.",     "type": "rate_limit_exceeded",     "param": null,     "code": "rate_limit_exceeded",     "solution": "Pace your requests or upgrade to higher levels. Read the Rate limit guide at https://chat.avalai.ir/platform/limits"   } }
# [20/56] 🚫 Rate limit exceeded (attempt 4/5)
# 🚫 Rate limit backoff: 129.1s
# [20/56] [HTTP 200] response: {   "id": "dQvBaNSgJ5aFvdIPyc3aqQ8",   "created": 1757481842,   "model": "gemma-3n-e4b-it",   "object": "chat.completion",   "system_fingerprint": null,   "choices": [     {       "finish_reason": "stop",       "index": 0,       "message": {         "content": "```json\n{\n  \"winner\": \"A\",\n  \"reasons\": [\n    \"Method A provides a more complete and structured hierarchy of soil monitoring pa
# [20/56] ✅ Winner: A | Time: 175.8s | Reasons: Method A provides a more complete and structured hierarchy of soil monitoring parameters, with clear 'narrower' relationships.; Method A's triples are
# 📊 Progress: 20/56 (35.7%) | Rate: 0.02 items/min | ETA: 33.1min | Errors: 0
#
# [21/56] Processing: table_2.10.jpg
# [21/56] [sizes] A:1473->1473 chars | B:1727->1503 chars | prompt:3694 chars
# ⏳ Rate limiting: sleeping 1.2s
# [21/56] [HTTP 200] response: {   "id": "egvBaLX9MsWFvdIPrqjW8Qw",   "created": 1757481847,   "model": "gemma-3n-e4b-it",   "object": "chat.completion",   "system_fingerprint": null,   "choices": [     {       "finish_reason": "stop",       "index": 0,       "message": {         "content": "```json\n{\n  \"winner\": \"A\",\n  \"reasons\": [\n    \"Method A provides more detailed information, including relationships between con
# [21/56] ✅ Winner: A | Time: 5.2s | Reasons: Method A provides more detailed information, including relationships between concepts (narrower, isElaboratedBasedOn), and specific data sources (hasS
#
# [22/56] Processing: table_2.11.jpg
# [22/56] [sizes] A:5734->1486 chars | B:6037->1490 chars | prompt:3694 chars
# ⏳ Rate limiting: sleeping 0.1s
# [22/56] [HTTP 429] response: {   "error": {     "message": "Rate limit reached for requests.",     "type": "rate_limit_exceeded",     "param": null,     "code": "rate_limit_exceeded",     "solution": "Pace your requests or upgrade to higher levels. Read the Rate limit guide at https://chat.avalai.ir/platform/limits"   } }
# [22/56] 🚫 Rate limit exceeded (attempt 1/5)
# 🚫 Rate limit backoff: 1.0s
# ⏳ Rate limiting: sleeping 6.3s
# [22/56] [HTTP 429] response: {   "error": {     "message": "Rate limit reached for requests.",     "type": "rate_limit_exceeded",     "param": null,     "code": "rate_limit_exceeded",     "solution": "Pace your requests or upgrade to higher levels. Read the Rate limit guide at https://chat.avalai.ir/platform/limits"   } }
# [22/56] 🚫 Rate limit exceeded (attempt 2/5)
# 🚫 Rate limit backoff: 5.3s
# ⏳ Rate limiting: sleeping 5.8s
# [22/56] [HTTP 429] response: {   "error": {     "message": "Rate limit reached for requests.",     "type": "rate_limit_exceeded",     "param": null,     "code": "rate_limit_exceeded",     "solution": "Pace your requests or upgrade to higher levels. Read the Rate limit guide at https://chat.avalai.ir/platform/limits"   } }
# [22/56] 🚫 Rate limit exceeded (attempt 3/5)
# 🚫 Rate limit backoff: 27.2s
# [22/56] [HTTP 429] response: {   "error": {     "message": "Rate limit reached for requests.",     "type": "rate_limit_exceeded",     "param": null,     "code": "rate_limit_exceeded",     "solution": "Pace your requests or upgrade to higher levels. Read the Rate limit guide at https://chat.avalai.ir/platform/limits"   } }
# [22/56] 🚫 Rate limit exceeded (attempt 4/5)
# 🚫 Rate limit backoff: 97.1s
# [22/56] [HTTP 200] response: {   "id": "DgzBaOWoBs3hnsEPgIjHoQM",   "created": 1757481994,   "model": "gemma-3n-e4b-it",   "object": "chat.completion",   "system_fingerprint": null,   "choices": [     {       "finish_reason": "stop",       "index": 0,       "message": {         "content": "```json\n{\n  \"winner\": \"B\",\n  \"reasons\": [\n    \"Method B demonstrates better completeness by explicitly linking climate categori
# [22/56] ✅ Winner: B | Time: 147.3s | Reasons: Method B demonstrates better completeness by explicitly linking climate categories to specific representativity and texture categories, providing a mo
#
# [23/56] Processing: table_2.2.jpg
# [23/56] [sizes] A:1536->1483 chars | B:1536->1483 chars | prompt:3684 chars
# ⏳ Rate limiting: sleeping 1.0s
# [23/56] [HTTP 429] response: {   "error": {     "message": "Rate limit reached for requests.",     "type": "rate_limit_exceeded",     "param": null,     "code": "rate_limit_exceeded",     "solution": "Pace your requests or upgrade to higher levels. Read the Rate limit guide at https://chat.avalai.ir/platform/limits"   } }
# [23/56] 🚫 Rate limit exceeded (attempt 1/5)
# 🚫 Rate limit backoff: 1.1s
# ⏳ Rate limiting: sleeping 6.2s
# [23/56] [HTTP 200] response: {   "id": "GAzBaMypDszo7M8PuZetyA4",   "created": 1757482006,   "model": "gemma-3n-e4b-it",   "object": "chat.completion",   "system_fingerprint": null,   "choices": [     {       "finish_reason": "stop",       "index": 0,       "message": {         "content": "```json\n{\n  \"winner\": \"Tie\",\n  \"reasons\": [\n    \"Both methods extract the same triples and have identical content.\",\n    \"Bo
# [23/56] ✅ Winner: Tie | Time: 10.1s | Reasons: Both methods extract the same triples and have identical content.; Both methods demonstrate valid RDF syntax.
#
# [24/56] Processing: table_2.3.jpg
# [24/56] [sizes] A:4864->1510 chars | B:5068->1493 chars | prompt:3721 chars
# ⏳ Rate limiting: sleeping 3.0s
# [24/56] [HTTP 429] response: {   "error": {     "message": "Rate limit reached for requests.",     "type": "rate_limit_exceeded",     "param": null,     "code": "rate_limit_exceeded",     "solution": "Pace your requests or upgrade to higher levels. Read the Rate limit guide at https://chat.avalai.ir/platform/limits"   } }
# [24/56] 🚫 Rate limit exceeded (attempt 1/5)
# 🚫 Rate limit backoff: 1.1s
# ⏳ Rate limiting: sleeping 6.0s
# [24/56] [HTTP 429] response: {   "error": {     "message": "Rate limit reached for requests.",     "type": "rate_limit_exceeded",     "param": null,     "code": "rate_limit_exceeded",     "solution": "Pace your requests or upgrade to higher levels. Read the Rate limit guide at https://chat.avalai.ir/platform/limits"   } }
# [24/56] 🚫 Rate limit exceeded (attempt 2/5)
# 🚫 Rate limit backoff: 4.7s
# ⏳ Rate limiting: sleeping 6.3s
# [24/56] [HTTP 200] response: {   "id": "MQzBaJjxDKXTvdIPtMLA2Qs",   "created": 1757482030,   "model": "gemma-3n-e4b-it",   "object": "chat.completion",   "system_fingerprint": null,   "choices": [     {       "finish_reason": "stop",       "index": 0,       "message": {         "content": "```json\n{\n  \"winner\": \"B\",\n  \"reasons\": [\n    \"Method B includes more triples and provides more detailed relationships (e.g., `
# [24/56] ✅ Winner: B | Time: 25.0s | Reasons: Method B includes more triples and provides more detailed relationships (e.g., `she:isDerivedFrom`), leading to a more comprehensive representation of
#
# [25/56] Processing: table_2.5.jpg
# [25/56] [sizes] A:3036->1513 chars | B:3684->1500 chars | prompt:3731 chars
# [25/56] [HTTP 429] response: {   "error": {     "message": "Rate limit reached for requests.",     "type": "rate_limit_exceeded",     "param": null,     "code": "rate_limit_exceeded",     "solution": "Pace your requests or upgrade to higher levels. Read the Rate limit guide at https://chat.avalai.ir/platform/limits"   } }
# [25/56] 🚫 Rate limit exceeded (attempt 1/5)
# 🚫 Rate limit backoff: 1.0s
# ⏳ Rate limiting: sleeping 6.0s
# [25/56] [HTTP 429] response: {   "error": {     "message": "Rate limit reached for requests.",     "type": "rate_limit_exceeded",     "param": null,     "code": "rate_limit_exceeded",     "solution": "Pace your requests or upgrade to higher levels. Read the Rate limit guide at https://chat.avalai.ir/platform/limits"   } }
# [25/56] 🚫 Rate limit exceeded (attempt 2/5)
# 🚫 Rate limit backoff: 5.3s
# ⏳ Rate limiting: sleeping 5.5s
# [25/56] [HTTP 200] response: {   "id": "RwzBaPaNGOXVvdIPkrWYmA4",   "created": 1757482052,   "model": "gemma-3n-e4b-it",   "object": "chat.completion",   "system_fingerprint": null,   "choices": [     {       "finish_reason": "stop",       "index": 0,       "message": {         "content": "```json\n{\n  \"winner\": \"A\",\n  \"reasons\": [\n    \"Method A provides more detailed information about the thresholds for different s
# [25/56] ✅ Winner: A | Time: 22.2s | Reasons: Method A provides more detailed information about the thresholds for different soil textures and water balance ranges.; Method A explicitly links the
#
# [26/56] Processing: table_2.6.jpg
# [26/56] [sizes] A:3933->1509 chars | B:5016->1500 chars | prompt:3727 chars
# [26/56] [HTTP 429] response: {   "error": {     "message": "Rate limit reached for requests.",     "type": "rate_limit_exceeded",     "param": null,     "code": "rate_limit_exceeded",     "solution": "Pace your requests or upgrade to higher levels. Read the Rate limit guide at https://chat.avalai.ir/platform/limits"   } }
# [26/56] 🚫 Rate limit exceeded (attempt 1/5)
# 🚫 Rate limit backoff: 1.0s
# ⏳ Rate limiting: sleeping 6.3s
# [26/56] [HTTP 429] response: {   "error": {     "message": "Rate limit reached for requests.",     "type": "rate_limit_exceeded",     "param": null,     "code": "rate_limit_exceeded",     "solution": "Pace your requests or upgrade to higher levels. Read the Rate limit guide at https://chat.avalai.ir/platform/limits"   } }
# [26/56] 🚫 Rate limit exceeded (attempt 2/5)
# 🚫 Rate limit backoff: 4.3s
# ⏳ Rate limiting: sleeping 6.8s
# [26/56] [HTTP 429] response: {   "error": {     "message": "Rate limit reached for requests.",     "type": "rate_limit_exceeded",     "param": null,     "code": "rate_limit_exceeded",     "solution": "Pace your requests or upgrade to higher levels. Read the Rate limit guide at https://chat.avalai.ir/platform/limits"   } }
# [26/56] 🚫 Rate limit exceeded (attempt 3/5)
# 🚫 Rate limit backoff: 20.8s
# [26/56] [HTTP 200] response: {   "id": "cwzBaMC6GOLm7M8Pue_4oA8",   "created": 1757482095,   "model": "gemma-3n-e4b-it",   "object": "chat.completion",   "system_fingerprint": null,   "choices": [     {       "finish_reason": "stop",       "index": 0,       "message": {         "content": "```json\n{\n  \"winner\": \"A\",\n  \"reasons\": [\n    \"Method A provides more detailed information about the relationships between conc
# [26/56] ✅ Winner: A | Time: 44.0s | Reasons: Method A provides more detailed information about the relationships between concepts (e.g., 'considersTexture', 'considersLandUseType', 'providesBench
#
# [27/56] Processing: table_2.7.jpg
# [27/56] [sizes] A:3100->1486 chars | B:3160->1489 chars | prompt:3693 chars
# [27/56] [HTTP 200] response: {   "id": "dgzBaPLfLrygkdUPoOrt8Q4",   "created": 1757482099,   "model": "gemma-3n-e4b-it",   "object": "chat.completion",   "system_fingerprint": null,   "choices": [     {       "finish_reason": "stop",       "index": 0,       "message": {         "content": "```json\n{\n  \"winner\": \"A\",\n  \"reasons\": [\n    \"Method A provides a more complete and detailed hierarchy of soil structure conce
# [27/56] ✅ Winner: A | Time: 3.4s | Reasons: Method A provides a more complete and detailed hierarchy of soil structure concepts, including specific ranges and explanations.; Method A includes mo
#
# [28/56] Processing: table_2.8.jpg
# [28/56] [sizes] A:2178->1479 chars | B:1764->1483 chars | prompt:3680 chars
# [28/56] [HTTP 429] response: {   "error": {     "message": "Rate limit reached for requests.",     "type": "rate_limit_exceeded",     "param": null,     "code": "rate_limit_exceeded",     "solution": "Pace your requests or upgrade to higher levels. Read the Rate limit guide at https://chat.avalai.ir/platform/limits"   } }
# [28/56] 🚫 Rate limit exceeded (attempt 1/5)
# 🚫 Rate limit backoff: 1.0s
# ⏳ Rate limiting: sleeping 6.3s
# [28/56] [HTTP 429] response: {   "error": {     "message": "Rate limit reached for requests.",     "type": "rate_limit_exceeded",     "param": null,     "code": "rate_limit_exceeded",     "solution": "Pace your requests or upgrade to higher levels. Read the Rate limit guide at https://chat.avalai.ir/platform/limits"   } }
# [28/56] 🚫 Rate limit exceeded (attempt 2/5)
# 🚫 Rate limit backoff: 4.1s
# ⏳ Rate limiting: sleeping 6.9s
# [28/56] [HTTP 429] response: {   "error": {     "message": "Rate limit reached for requests.",     "type": "rate_limit_exceeded",     "param": null,     "code": "rate_limit_exceeded",     "solution": "Pace your requests or upgrade to higher levels. Read the Rate limit guide at https://chat.avalai.ir/platform/limits"   } }
# [28/56] 🚫 Rate limit exceeded (attempt 3/5)
# 🚫 Rate limit backoff: 20.0s
# [28/56] [HTTP 200] response: {   "id": "ogzBaK2nMfSfkdUP2KquwQ4",   "created": 1757482142,   "model": "gemma-3n-e4b-it",   "object": "chat.completion",   "system_fingerprint": null,   "choices": [     {       "finish_reason": "stop",       "index": 0,       "message": {         "content": "```json\n{\n  \"winner\": \"B\",\n  \"reasons\": [\n    \"Method B provides more detailed relationships between concepts, explicitly stati
# [28/56] ✅ Winner: B | Time: 44.0s | Reasons: Method B provides more detailed relationships between concepts, explicitly stating dependencies, application layers, excluded influences, and methods
#
# [29/56] Processing: table_3.1.jpg
# [29/56] [sizes] A:3440->1490 chars | B:3572->1500 chars | prompt:3708 chars
# [29/56] [HTTP 429] response: {   "error": {     "message": "Rate limit reached for requests.",     "type": "rate_limit_exceeded",     "param": null,     "code": "rate_limit_exceeded",     "solution": "Pace your requests or upgrade to higher levels. Read the Rate limit guide at https://chat.avalai.ir/platform/limits"   } }
# [29/56] 🚫 Rate limit exceeded (attempt 1/5)
# 🚫 Rate limit backoff: 1.0s
# ⏳ Rate limiting: sleeping 6.3s
# [29/56] [HTTP 200] response: {   "id": "rQzBaP6XDLu4vdIPo9_rmQQ",   "created": 1757482154,   "model": "gemma-3n-e4b-it",   "object": "chat.completion",   "system_fingerprint": null,   "choices": [     {       "finish_reason": "stop",       "index": 0,       "message": {         "content": "```json\n{\n  \"winner\": \"B\",\n  \"reasons\": [\n    \"Method B is more complete as it includes all the concepts defined in Method A, a
# [29/56] ✅ Winner: B | Time: 10.4s | Reasons: Method B is more complete as it includes all the concepts defined in Method A, and also includes the definitions for the concepts listed in Method A.;
#
# [30/56] Processing: table_3.2.jpg
# [30/56] [sizes] A:1346->1346 chars | B:2081->1488 chars | prompt:3552 chars
# ⏳ Rate limiting: sleeping 1.7s
# [30/56] [HTTP 429] response: {   "error": {     "message": "Rate limit reached for requests.",     "type": "rate_limit_exceeded",     "param": null,     "code": "rate_limit_exceeded",     "solution": "Pace your requests or upgrade to higher levels. Read the Rate limit guide at https://chat.avalai.ir/platform/limits"   } }
# [30/56] 🚫 Rate limit exceeded (attempt 1/5)
# 🚫 Rate limit backoff: 1.1s
# ⏳ Rate limiting: sleeping 6.3s
# [30/56] [HTTP 429] response: {   "error": {     "message": "Rate limit reached for requests.",     "type": "rate_limit_exceeded",     "param": null,     "code": "rate_limit_exceeded",     "solution": "Pace your requests or upgrade to higher levels. Read the Rate limit guide at https://chat.avalai.ir/platform/limits"   } }
# [30/56] 🚫 Rate limit exceeded (attempt 2/5)
# 🚫 Rate limit backoff: 4.1s
# ⏳ Rate limiting: sleeping 6.7s
# [30/56] [HTTP 429] response: {   "error": {     "message": "Rate limit reached for requests.",     "type": "rate_limit_exceeded",     "param": null,     "code": "rate_limit_exceeded",     "solution": "Pace your requests or upgrade to higher levels. Read the Rate limit guide at https://chat.avalai.ir/platform/limits"   } }
# [30/56] 🚫 Rate limit exceeded (attempt 3/5)
# 🚫 Rate limit backoff: 21.9s
# [30/56] [HTTP 200] response: {   "id": "3AzBaNvvDKD7nsEPqqTRoAM",   "created": 1757482200,   "model": "gemma-3n-e4b-it",   "object": "chat.completion",   "system_fingerprint": null,   "choices": [     {       "finish_reason": "stop",       "index": 0,       "message": {         "content": "```json\n{\n  \"winner\": \"A\",\n  \"reasons\": [\n    \"Method A provides a more complete and structured representation of the relations
# [30/56] ✅ Winner: A | Time: 47.0s | Reasons: Method A provides a more complete and structured representation of the relationships between the concepts.; Method A explicitly defines the relationsh
# 📊 Progress: 30/56 (53.6%) | Rate: 0.02 items/min | ETA: 21.1min | Errors: 0
#
# [31/56] Processing: table_4.1.jpg
# [31/56] [sizes] A:3316->1494 chars | B:3530->1484 chars | prompt:3696 chars
# [31/56] [HTTP 200] response: {   "id": "4AzBaJatFeDTvdIPqvHX-AI",   "created": 1757482204,   "model": "gemma-3n-e4b-it",   "object": "chat.completion",   "system_fingerprint": null,   "choices": [     {       "finish_reason": "stop",       "index": 0,       "message": {         "content": "```json\n{\n  \"winner\": \"A\",\n  \"reasons\": [\n    \"Method A provides a more complete and structured ontology by explicitly defining
# [31/56] ✅ Winner: A | Time: 4.2s | Reasons: Method A provides a more complete and structured ontology by explicitly defining relationships between concepts (e.g., 'RelationshipOfSoilAcidificatio
#
# [32/56] Processing: table_4.2.jpg
# [32/56] [sizes] A:2058->1502 chars | B:1030->1030 chars | prompt:3250 chars
# [32/56] [HTTP 429] response: {   "error": {     "message": "Rate limit reached for requests.",     "type": "rate_limit_exceeded",     "param": null,     "code": "rate_limit_exceeded",     "solution": "Pace your requests or upgrade to higher levels. Read the Rate limit guide at https://chat.avalai.ir/platform/limits"   } }
# [32/56] 🚫 Rate limit exceeded (attempt 1/5)
# 🚫 Rate limit backoff: 1.0s
# ⏳ Rate limiting: sleeping 6.3s
# [32/56] [HTTP 429] response: {   "error": {     "message": "Rate limit reached for requests.",     "type": "rate_limit_exceeded",     "param": null,     "code": "rate_limit_exceeded",     "solution": "Pace your requests or upgrade to higher levels. Read the Rate limit guide at https://chat.avalai.ir/platform/limits"   } }
# [32/56] 🚫 Rate limit exceeded (attempt 2/5)
# 🚫 Rate limit backoff: 5.9s
# ⏳ Rate limiting: sleeping 5.1s
# [32/56] [HTTP 429] response: {   "error": {     "message": "Rate limit reached for requests.",     "type": "rate_limit_exceeded",     "param": null,     "code": "rate_limit_exceeded",     "solution": "Pace your requests or upgrade to higher levels. Read the Rate limit guide at https://chat.avalai.ir/platform/limits"   } }
# [32/56] 🚫 Rate limit exceeded (attempt 3/5)
# 🚫 Rate limit backoff: 31.2s
# [32/56] [HTTP 429] response: {   "error": {     "message": "Rate limit reached for requests.",     "type": "rate_limit_exceeded",     "param": null,     "code": "rate_limit_exceeded",     "solution": "Pace your requests or upgrade to higher levels. Read the Rate limit guide at https://chat.avalai.ir/platform/limits"   } }
# [32/56] 🚫 Rate limit exceeded (attempt 4/5)
# 🚫 Rate limit backoff: 122.9s
# ...
# [46/56] ✅ Winner: A | Time: 47.9s | Reasons: Method A provides more specific information about individual soil loss entries (e.g., 'SoilErosionByWaterEntry1', 'SoilErosionByWaterEntry2') includin
#
# [47/56] Processing: table_7.3.jpg
# [47/56] [sizes] A:3508->1510 chars | B:3520->1510 chars | prompt:3738 chars
# ⏳ Rate limiting: sleeping 0.1s
# [47/56] [HTTP 429] response: {   "error": {     "message": "Rate limit reached for requests.",     "type": "rate_limit_exceeded",     "param": null,     "code": "rate_limit_exceeded",     "solution": "Pace your requests or upgrade to higher levels. Read the Rate limit guide at https://chat.avalai.ir/platform/limits"   } }
# [47/56] 🚫 Rate limit exceeded (attempt 1/5)
# 🚫 Rate limit backoff: 1.2s
# ⏳ Rate limiting: sleeping 6.0s
# [47/56] [HTTP 200] response: {   "id": "fxDBaNm0PPH6nsEP8oqIsQM",   "created": 1757483134,   "model": "gemma-3n-e4b-it",   "object": "chat.completion",   "system_fingerprint": null,   "choices": [     {       "finish_reason": "stop",       "index": 0,       "message": {         "content": "```json\n{\n  \"winner\": \"Tie\",\n  \"reasons\": [\n    \"Both methods extract the same core concepts and relationships.\",\n    \"The c
# [47/56] ✅ Winner: Tie | Time: 10.6s | Reasons: Both methods extract the same core concepts and relationships.; The completeness of the extractions appears similar, covering the same hierarchical st
#
# [48/56] Processing: table_7.4.jpg
# [48/56] [sizes] A:3310->1503 chars | B:3786->1460 chars | prompt:3681 chars
# ⏳ Rate limiting: sleeping 1.9s
# [48/56] [HTTP 429] response: {   "error": {     "message": "Rate limit reached for requests.",     "type": "rate_limit_exceeded",     "param": null,     "code": "rate_limit_exceeded",     "solution": "Pace your requests or upgrade to higher levels. Read the Rate limit guide at https://chat.avalai.ir/platform/limits"   } }
# [48/56] 🚫 Rate limit exceeded (attempt 1/5)
# 🚫 Rate limit backoff: 1.0s
# ⏳ Rate limiting: sleeping 6.3s
# [48/56] [HTTP 429] response: {   "error": {     "message": "Rate limit reached for requests.",     "type": "rate_limit_exceeded",     "param": null,     "code": "rate_limit_exceeded",     "solution": "Pace your requests or upgrade to higher levels. Read the Rate limit guide at https://chat.avalai.ir/platform/limits"   } }
# [48/56] 🚫 Rate limit exceeded (attempt 2/5)
# 🚫 Rate limit backoff: 4.3s
# ⏳ Rate limiting: sleeping 6.7s
# [48/56] [HTTP 429] response: {   "error": {     "message": "Rate limit reached for requests.",     "type": "rate_limit_exceeded",     "param": null,     "code": "rate_limit_exceeded",     "solution": "Pace your requests or upgrade to higher levels. Read the Rate limit guide at https://chat.avalai.ir/platform/limits"   } }
# [48/56] 🚫 Rate limit exceeded (attempt 3/5)
# 🚫 Rate limit backoff: 21.6s
# [48/56] [HTTP 200] response: {   "id": "rhDBaPz2MoeZkdUPv-mf8Q4",   "created": 1757483179,   "model": "gemma-3n-e4b-it",   "object": "chat.completion",   "system_fingerprint": null,   "choices": [     {       "finish_reason": "stop",       "index": 0,       "message": {         "content": "```json\n{\n  \"winner\": \"A\",\n  \"reasons\": [\n    \"Method A provides more detailed information about the relationships between conc
# [48/56] ✅ Winner: A | Time: 46.3s | Reasons: Method A provides more detailed information about the relationships between concepts, including specific narrowers and broader concepts.; Method A exp
#
# [49/56] Processing: table_8.1.jpg
# [49/56] [sizes] A:4918->1513 chars | B:3914->1496 chars | prompt:3727 chars
# [49/56] [HTTP 200] response: {   "id": "shDBaK7vFoH8nsEP8-jSmQM",   "created": 1757483183,   "model": "gemma-3n-e4b-it",   "object": "chat.completion",   "system_fingerprint": null,   "choices": [     {       "finish_reason": "stop",       "index": 0,       "message": {         "content": "```json\n{\n  \"winner\": \"A\",\n  \"reasons\": [\n    \"Method A provides more detailed relationships and a more complete hierarchy of c
# [49/56] ✅ Winner: A | Time: 3.5s | Reasons: Method A provides more detailed relationships and a more complete hierarchy of concepts.; Method A includes 'Impact' as a narrower concept of 'Relatio
#
# [50/56] Processing: table_8.3.jpg
# [50/56] [sizes] A:1681->1437 chars | B:10317->1498 chars | prompt:3653 chars
# [50/56] [HTTP 429] response: {   "error": {     "message": "Rate limit reached for requests.",     "type": "rate_limit_exceeded",     "param": null,     "code": "rate_limit_exceeded",     "solution": "Pace your requests or upgrade to higher levels. Read the Rate limit guide at https://chat.avalai.ir/platform/limits"   } }
# [50/56] 🚫 Rate limit exceeded (attempt 1/5)
# 🚫 Rate limit backoff: 1.1s
# ⏳ Rate limiting: sleeping 6.3s
# [50/56] [HTTP 429] response: {   "error": {     "message": "Rate limit reached for requests.",     "type": "rate_limit_exceeded",     "param": null,     "code": "rate_limit_exceeded",     "solution": "Pace your requests or upgrade to higher levels. Read the Rate limit guide at https://chat.avalai.ir/platform/limits"   } }
# [50/56] 🚫 Rate limit exceeded (attempt 2/5)
# 🚫 Rate limit backoff: 6.0s
# ⏳ Rate limiting: sleeping 5.1s
# [50/56] [HTTP 429] response: {   "error": {     "message": "Rate limit reached for requests.",     "type": "rate_limit_exceeded",     "param": null,     "code": "rate_limit_exceeded",     "solution": "Pace your requests or upgrade to higher levels. Read the Rate limit guide at https://chat.avalai.ir/platform/limits"   } }
# [50/56] 🚫 Rate limit exceeded (attempt 3/5)
# 🚫 Rate limit backoff: 29.3s
# [50/56] [HTTP 200] response: {   "id": "5RDBaLLBHKfXvdIP84-b4QM",   "created": 1757483234,   "model": "gemma-3n-e4b-it",   "object": "chat.completion",   "system_fingerprint": null,   "choices": [     {       "finish_reason": "stop",       "index": 0,       "message": {         "content": "```json\n{\n  \"winner\": \"B\",\n  \"reasons\": [\n    \"Method B includes more properties (hasLevelIParameter, hasLevelIIParameter) whic
# [50/56] ✅ Winner: B | Time: 51.1s | Reasons: Method B includes more properties (hasLevelIParameter, hasLevelIIParameter) which provides more detailed information about the relationships between c
# 📊 Progress: 50/56 (89.3%) | Rate: 0.02 items/min | ETA: 5.0min | Errors: 0
#
# [51/56] Processing: table_8.4.jpg
# [51/56] [sizes] A:6335->1372 chars | B:7683->1505 chars | prompt:3595 chars
# ⏳ Rate limiting: sleeping 0.5s
# [51/56] [HTTP 200] response: {   "id": "6RDBaNiEHseYkdUP64XxmAM",   "created": 1757483238,   "model": "gemma-3n-e4b-it",   "object": "chat.completion",   "system_fingerprint": null,   "choices": [     {       "finish_reason": "stop",       "index": 0,       "message": {         "content": "```json\n{\n  \"winner\": \"A\",\n  \"reasons\": [\n    \"Method A provides more detailed information about the thresholds for bulk densit
# [51/56] ✅ Winner: A | Time: 4.1s | Reasons: Method A provides more detailed information about the thresholds for bulk density, including specific ranges and descriptions for different soil condi
#
# [52/56] Processing: table_8.5.jpg
# [52/56] [sizes] A:2904->1490 chars | B:4559->1469 chars | prompt:3677 chars
# ⏳ Rate limiting: sleeping 0.4s
# [52/56] [HTTP 429] response: {   "error": {     "message": "Rate limit reached for requests.",     "type": "rate_limit_exceeded",     "param": null,     "code": "rate_limit_exceeded",     "solution": "Pace your requests or upgrade to higher levels. Read the Rate limit guide at https://chat.avalai.ir/platform/limits"   } }
# [52/56] 🚫 Rate limit exceeded (attempt 1/5)
# 🚫 Rate limit backoff: 1.1s
# ⏳ Rate limiting: sleeping 5.5s
# [52/56] [HTTP 429] response: {   "error": {     "message": "Rate limit reached for requests.",     "type": "rate_limit_exceeded",     "param": null,     "code": "rate_limit_exceeded",     "solution": "Pace your requests or upgrade to higher levels. Read the Rate limit guide at https://chat.avalai.ir/platform/limits"   } }
# [52/56] 🚫 Rate limit exceeded (attempt 2/5)
# 🚫 Rate limit backoff: 4.0s
# ⏳ Rate limiting: sleeping 7.1s
# [52/56] [HTTP 429] response: {   "error": {     "message": "Rate limit reached for requests.",     "type": "rate_limit_exceeded",     "param": null,     "code": "rate_limit_exceeded",     "solution": "Pace your requests or upgrade to higher levels. Read the Rate limit guide at https://chat.avalai.ir/platform/limits"   } }
# [52/56] 🚫 Rate limit exceeded (attempt 3/5)
# 🚫 Rate limit backoff: 27.0s
# [52/56] [HTTP 200] response: {   "id": "GhHBaMzUHZ6Dxs0PhPbm8AM",   "created": 1757483288,   "model": "gemma-3n-e4b-it",   "object": "chat.completion",   "system_fingerprint": null,   "choices": [     {       "finish_reason": "stop",       "index": 0,       "message": {         "content": "```json\n{\n  \"winner\": \"Tie\",\n  \"reasons\": [\n    \"Both methods correctly identify the core concepts and their relationships.\",\
# [52/56] ✅ Winner: Tie | Time: 48.9s | Reasons: Both methods correctly identify the core concepts and their relationships.; Both methods maintain RDF validity.; Both methods demonstrate reasonable c
#
# [53/56] Processing: table_9.1.jpg
# [53/56] [sizes] A:3076->1507 chars | B:2584->1487 chars | prompt:3712 chars
# ⏳ Rate limiting: sleeping 2.4s
# [53/56] [HTTP 429] response: {   "error": {     "message": "Rate limit reached for requests.",     "type": "rate_limit_exceeded",     "param": null,     "code": "rate_limit_exceeded",     "solution": "Pace your requests or upgrade to higher levels. Read the Rate limit guide at https://chat.avalai.ir/platform/limits"   } }
# [53/56] 🚫 Rate limit exceeded (attempt 1/5)
# 🚫 Rate limit backoff: 1.1s
# ⏳ Rate limiting: sleeping 6.2s
# [53/56] [HTTP 200] response: {   "id": "KBHBaN3GD7WWvdIPoN_aoQg",   "created": 1757483300,   "model": "gemma-3n-e4b-it",   "object": "chat.completion",   "system_fingerprint": null,   "choices": [     {       "finish_reason": "stop",       "index": 0,       "message": {         "content": "```json\n{\n  \"winner\": \"A\",\n  \"reasons\": [\n    \"Method A provides a more comprehensive and detailed ontology of concepts related
# [53/56] ✅ Winner: A | Time: 13.8s | Reasons: Method A provides a more comprehensive and detailed ontology of concepts related to soil health and its societal needs.; Method A explicitly defines r
#
# [54/56] Processing: table_9.2.jpg
# [54/56] [sizes] A:5060->1487 chars | B:3367->1496 chars | prompt:3701 chars
# ⏳ Rate limiting: sleeping 0.3s
# [54/56] [HTTP 429] response: {   "error": {     "message": "Rate limit reached for requests.",     "type": "rate_limit_exceeded",     "param": null,     "code": "rate_limit_exceeded",     "solution": "Pace your requests or upgrade to higher levels. Read the Rate limit guide at https://chat.avalai.ir/platform/limits"   } }
# [54/56] 🚫 Rate limit exceeded (attempt 1/5)
# 🚫 Rate limit backoff: 1.0s
# ⏳ Rate limiting: sleeping 6.1s
# [54/56] [HTTP 429] response: {   "error": {     "message": "Rate limit reached for requests.",     "type": "rate_limit_exceeded",     "param": null,     "code": "rate_limit_exceeded",     "solution": "Pace your requests or upgrade to higher levels. Read the Rate limit guide at https://chat.avalai.ir/platform/limits"   } }
# [54/56] 🚫 Rate limit exceeded (attempt 2/5)
# 🚫 Rate limit backoff: 4.2s
# ⏳ Rate limiting: sleeping 6.9s
# [54/56] [HTTP 429] response: {   "error": {     "message": "Rate limit reached for requests.",     "type": "rate_limit_exceeded",     "param": null,     "code": "rate_limit_exceeded",     "solution": "Pace your requests or upgrade to higher levels. Read the Rate limit guide at https://chat.avalai.ir/platform/limits"   } }
# [54/56] 🚫 Rate limit exceeded (attempt 3/5)
# 🚫 Rate limit backoff: 28.6s
# [54/56] [HTTP 200] response: {   "id": "WxHBaIzPN_z4nsEP4t7vuQM",   "created": 1757483352,   "model": "gemma-3n-e4b-it",   "object": "chat.completion",   "system_fingerprint": null,   "choices": [     {       "finish_reason": "stop",       "index": 0,       "message": {         "content": "```json\n{\n  \"winner\": \"A\",\n  \"reasons\": [\n    \"Method A provides more specific and detailed information about the relationships
# [54/56] ✅ Winner: A | Time: 51.7s | Reasons: Method A provides more specific and detailed information about the relationships between indicators, including narrower concepts and definitions.; Met
#
# [55/56] Processing: table_9.3.jpg
# [55/56] [sizes] A:2899->1481 chars | B:2923->1494 chars | prompt:3693 chars
# [55/56] [HTTP 200] response: {   "id": "XhHBaIb5N4TakdUPkt-pyA4",   "created": 1757483356,   "model": "gemma-3n-e4b-it",   "object": "chat.completion",   "system_fingerprint": null,   "choices": [     {       "finish_reason": "stop",       "index": 0,       "message": {         "content": "```json\n{\n  \"winner\": \"B\",\n  \"reasons\": [\n    \"Method B includes 'SoilSealingData' which is a more specific concept than just '
# [55/56] ✅ Winner: B | Time: 3.0s | Reasons: Method B includes 'SoilSealingData' which is a more specific concept than just 'AvailableNationalSoilSealingDataComparedWithCopernicusData2015'.; Meth
#
# [56/56] Processing: table_9.4.jpg
# [56/56] [sizes] A:5690->1478 chars | B:2490->1368 chars | prompt:3564 chars
# ⏳ Rate limiting: sleeping 1.4s
# [56/56] [HTTP 429] response: {   "error": {     "message": "Rate limit reached for requests.",     "type": "rate_limit_exceeded",     "param": null,     "code": "rate_limit_exceeded",     "solution": "Pace your requests or upgrade to higher levels. Read the Rate limit guide at https://chat.avalai.ir/platform/limits"   } }
# [56/56] 🚫 Rate limit exceeded (attempt 1/5)
# 🚫 Rate limit backoff: 1.2s
# ⏳ Rate limiting: sleeping 6.1s
# [56/56] [HTTP 429] response: {   "error": {     "message": "Rate limit reached for requests.",     "type": "rate_limit_exceeded",     "param": null,     "code": "rate_limit_exceeded",     "solution": "Pace your requests or upgrade to higher levels. Read the Rate limit guide at https://chat.avalai.ir/platform/limits"   } }
# [56/56] 🚫 Rate limit exceeded (attempt 2/5)
# 🚫 Rate limit backoff: 4.7s
# ⏳ Rate limiting: sleeping 6.3s
# [56/56] [HTTP 429] response: {   "error": {     "message": "Rate limit reached for requests.",     "type": "rate_limit_exceeded",     "param": null,     "code": "rate_limit_exceeded",     "solution": "Pace your requests or upgrade to higher levels. Read the Rate limit guide at https://chat.avalai.ir/platform/limits"   } }
# [56/56] 🚫 Rate limit exceeded (attempt 3/5)
# 🚫 Rate limit backoff: 23.8s
# [56/56] [HTTP 200] response: {   "id": "jhHBaMCbE_fjnsEPmPfTqAM",   "created": 1757483403,   "model": "gemma-3n-e4b-it",   "object": "chat.completion",   "system_fingerprint": null,   "choices": [     {       "finish_reason": "stop",       "index": 0,       "message": {         "content": "```json\n{\n  \"winner\": \"B\",\n  \"reasons\": [\n    \"Method B demonstrates better completeness by including relationships between con
# [56/56] ✅ Winner: B | Time: 47.4s | Reasons: Method B demonstrates better completeness by including relationships between concepts (narrower relationships) and explicitly defining column headers
#
# 🏁 Completed processing in 44.4 minutes
# 📈 Average rate: 1.26 items/minute
# ❌ Total errors: 0/56 (0.0%)
#
# 🧮 Final Results:
#    Total: 56
#    A wins: 30 (53.6%)
#    B wins: 22 (39.3%)
#    Ties: 4 (7.1%)
#    Errors: 0 (0.0%)
#
# 📝 Output files:
#    - /kaggle/working/pairwise_out/judge_report.csv
#    - /kaggle/working/pairwise_out/judge_aggregate.csv
#    - /kaggle/working/pairwise_out/avalai_errors.log
#
# ⬇️ Downloading results...
# ✅ Downloaded: pairwise_summary.csv
# ✅ Downloaded: pairwise_pairs.jsonl
# ✅ Downloaded: judge_prompt.txt
# ✅ Downloaded: judge_report.csv
# ✅ Downloaded: judge_aggregate.csv
# ✅ Downloaded: avalai_errors.log
#
# 🎉 All done!

# %%
print(f"\n📁 All outputs saved to: {OUTPUT_DIR.resolve()}")
for p in [summary_csv, pairs_jsonl, prompt_txt, judge_csv, aggregate_csv]:
    if p.exists():
        print(" -", p.name)
