# %%
# !pip install rdflib
# Out:
# Requirement already satisfied: rdflib in /Users/ali/miniconda3/lib/python3.13/site-packages (7.1.4)
# Requirement already satisfied: pyparsing<4,>=2.1.0 in /Users/ali/miniconda3/lib/python3.13/site-packages (from rdflib) (3.2.3)

# %%
import json
from rdflib import Graph
from rdflib.plugins.sparql import prepareQuery

# Configuration - edit these paths directly
INPUT_JSON_PATH = "../Evaluating/LLM-as-a-judge/input/Json files/rdf_extractions_oneShot.json"
OUTPUT_JSON_PATH = "rdf_validation_OneShot.json"


def check_rdf_executability(turtle_text: str) -> dict:
    """
    Parse Turtle RDF content and verify basic executability.
    
    Args:
        turtle_text: String containing Turtle RDF content
        
    Returns:
        dict: Result dictionary with parsing status and counts
    """
    result = {
        "RDF syntax": "is invalid",
        "parsed": "failed", 
        "Number of triples in RDF": 0,
        "skos:Concepts Found": 0
    }
    
    # Create a new RDF graph
    g = Graph()
    
    try:
        # Parse the RDF data
        g.parse(data=turtle_text, format="turtle")
        
        # If parsing succeeds, update result
        result["RDF syntax"] = "is valid"
        result["parsed"] = "successfully"
        result["Number of triples in RDF"] = len(g)
        
    except Exception as e:
        # Parsing failed - return result with default values
        return result
    
    try:
        # Run SPARQL query to count skos:Concept instances
        # Use full URI to avoid namespace prefix dependencies
        query = prepareQuery("""
            SELECT (COUNT(?c) AS ?count) WHERE {
                # ?c a <http://www.w3.org/2004/02/skos/core#Concept> .
            }
        """)
        
        query_results = g.query(query)
        
        # Extract count from query results
        for row in query_results:
            result["skos:Concepts Found"] = int(row[0])
            break
            
    except Exception as e:
        # SPARQL query failed - keep concept count at 0
        pass
    
    return result


def load_input_json(input_path: str) -> dict:
    """
    Load JSON input file.
    
    Args:
        input_path: Path to input JSON file
        
    Returns:
        dict: Loaded JSON data
    """
    with open(input_path, 'r', encoding='utf-8') as f:
        return json.load(f)


def save_output_json(output_path: str, data: dict) -> None:
    """
    Save data to JSON output file.
    
    Args:
        output_path: Path to output JSON file
        data: Dictionary to save as JSON
    """
    with open(output_path, 'w', encoding='utf-8') as f:
        json.dump(data, f, indent=2, ensure_ascii=False)


def main():
    """
    Main processing function that loads input, processes RDF, and saves output.
    """
    try:
        # Load input JSON
        input_data = load_input_json(INPUT_JSON_PATH)
        
        # Process each dataset entry
        all_results = []
        
        for entry in input_data.get("dataset", []):
            # Extract turtle content and source image
            turtle_content = entry.get("rdf_graph_turtle", "")
            source_image = entry.get("source_image", "")
            
            # Check RDF executability
            result = check_rdf_executability(turtle_content)
            
            # Add source image to result
            result["source_image"] = source_image
            
            all_results.append(result)
        
        # Save all results to output JSON
        output_data = {"results": all_results}
        save_output_json(OUTPUT_JSON_PATH, output_data)
        
        # Optional: print results summary
        print(f"Processing complete. Processed {len(all_results)} RDF entries.")
        print(f"Results saved to: {OUTPUT_JSON_PATH}")
        
        # Print individual results
        for i, result in enumerate(all_results, 1):
            print(f"\nEntry {i}: {result['source_image']}")
            print(f"  RDF syntax: {result['RDF syntax']}")
            print(f"  Parsed: {result['parsed']}")
            print(f"  Triples: {result['Number of triples in RDF']}")
            print(f"  SKOS Concepts: {result['skos:Concepts Found']}")
        
    except Exception as e:
        # Handle any unexpected errors
        error_result = {
            "error": str(e),
            "results": []
        }
        save_output_json(OUTPUT_JSON_PATH, error_result)
        print(f"Error during processing: {e}")


if __name__ == "__main__":
    main()
# Out:
# Processing complete. Processed 61 RDF entries.
# Results saved to: rdf_validation_OneShot.json
#
# Entry 1: table_10.2_cont.jpg
#   RDF syntax: is valid
#   Parsed: successfully
#   Triples: 131
#   SKOS Concepts: 41
#
# Entry 2: table_2.4.jpg
#   RDF syntax: is invalid
#   Parsed: failed
#   Triples: 0
#   SKOS Concepts: 0
#
# Entry 3: table_7.3.jpg
#   RDF syntax: is valid
#   Parsed: successfully
#   Triples: 57
#   SKOS Concepts: 17
#
# Entry 4: table_6.2.jpg
#   RDF syntax: is invalid
#   Parsed: failed
#   Triples: 0
#   SKOS Concepts: 0
#
# Entry 5: table_4.2.jpg
#   RDF syntax: is valid
#   Parsed: successfully
#   Triples: 55
#   SKOS Concepts: 13
#
# Entry 6: table_9.4.jpg
#   RDF syntax: is valid
#   Parsed: successfully
#   Triples: 74
#   SKOS Concepts: 21
#
# Entry 7: table_5.9.jpg
#   RDF syntax: is valid
#   Parsed: successfully
#   Triples: 68
#   SKOS Concepts: 19
#
# Entry 8: table_8.1.jpg
#   RDF syntax: is valid
#   Parsed: successfully
#   Triples: 71
#   SKOS Concepts: 20
#
# Entry 9: table_4.1.jpg
#   RDF syntax: is valid
#   Parsed: successfully
#   Triples: 72
#   SKOS Concepts: 20
#
# Entry 10: table_1.7.jpg
#   RDF syntax: is invalid
#   Parsed: failed
#   Triples: 0
#   SKOS Concepts: 0
#
# Entry 11: table_1.5.jpg
#   RDF syntax: is valid
#   Parsed: successfully
#   Triples: 220
#   SKOS Concepts: 38
#
# Entry 12: table_10.1_cont.jpg
#   RDF syntax: is valid
#   Parsed: successfully
#   Triples: 97
#   SKOS Concepts: 34
#
# Entry 13: table_2.2.jpg
#   RDF syntax: is valid
#   Parsed: successfully
#   Triples: 27
#   SKOS Concepts: 6
#
# Entry 14: table_1.2.jpg
#   RDF syntax: is valid
#   Parsed: successfully
#   Triples: 30
#   SKOS Concepts: 8
#
# Entry 15: table_7.1.jpg
#   RDF syntax: is valid
#   Parsed: successfully
#   Triples: 74
#   SKOS Concepts: 19
#
# Entry 16: table_5.7.jpg
#   RDF syntax: is invalid
#   Parsed: failed
#   Triples: 0
#   SKOS Concepts: 0
#
# Entry 17: table_2.1.jpg
#   RDF syntax: is valid
#   Parsed: successfully
#   Triples: 76
#   SKOS Concepts: 21
#
# Entry 18: table_8.5.jpg
#   RDF syntax: is valid
#   Parsed: successfully
#   Triples: 42
#   SKOS Concepts: 10
#
# Entry 19: table_6.4.jpg
#   RDF syntax: is valid
#   Parsed: successfully
#   Triples: 104
#   SKOS Concepts: 35
#
# Entry 20: table_6.5.jpg
#   RDF syntax: is valid
#   Parsed: successfully
#   Triples: 26
#   SKOS Concepts: 6
#
# Entry 21: table_9.1.jpg
#   RDF syntax: is valid
#   Parsed: successfully
#   Triples: 69
#   SKOS Concepts: 19
#
# Entry 22: table_8.3.jpg
#   RDF syntax: is invalid
#   Parsed: failed
#   Triples: 0
#   SKOS Concepts: 0
#
# Entry 23: table_5.10.jpg
#   RDF syntax: is valid
#   Parsed: successfully
#   Triples: 71
#   SKOS Concepts: 20
#
# Entry 24: table_2.3.jpg
#   RDF syntax: is valid
#   Parsed: successfully
#   Triples: 46
#   SKOS Concepts: 12
#
# Entry 25: table_2.11.jpg
#   RDF syntax: is valid
#   Parsed: successfully
#   Triples: 127
#   SKOS Concepts: 18
#
# Entry 26: table_5.5.jpg
#   RDF syntax: is invalid
#   Parsed: failed
#   Triples: 0
#   SKOS Concepts: 0
#
# Entry 27: table_3.2.jpg
#   RDF syntax: is valid
#   Parsed: successfully
#   Triples: 36
#   SKOS Concepts: 11
#
# Entry 28: table_9.3.jpg
#   RDF syntax: is valid
#   Parsed: successfully
#   Triples: 67
#   SKOS Concepts: 18
#
# Entry 29: table_9.2.jpg
#   RDF syntax: is valid
#   Parsed: successfully
#   Triples: 47
#   SKOS Concepts: 11
#
# Entry 30: table_7.4.jpg
#   RDF syntax: is valid
#   Parsed: successfully
#   Triples: 65
#   SKOS Concepts: 20
#
# Entry 31: table_2.10.jpg
#   RDF syntax: is valid
#   Parsed: successfully
#   Triples: 27
#   SKOS Concepts: 8
#
# Entry 32: table_1.7_cont.jpg
#   RDF syntax: is valid
#   Parsed: successfully
#   Triples: 32
#   SKOS Concepts: 11
#
# Entry 33: table_6.3.jpg
#   RDF syntax: is valid
#   Parsed: successfully
#   Triples: 61
#   SKOS Concepts: 16
#
# Entry 34: table_3.1.jpg
#   RDF syntax: is valid
#   Parsed: successfully
#   Triples: 78
#   SKOS Concepts: 21
#
# Entry 35: table_1.3.jpg
#   RDF syntax: is valid
#   Parsed: successfully
#   Triples: 94
#   SKOS Concepts: 23
#
# Entry 36: table_5.2.jpg
#   RDF syntax: is valid
#   Parsed: successfully
#   Triples: 35
#   SKOS Concepts: 9
#
# Entry 37: table_2.5.jpg
#   RDF syntax: is valid
#   Parsed: successfully
#   Triples: 65
#   SKOS Concepts: 10
#
# Entry 38: table_8.4.jpg
#   RDF syntax: is valid
#   Parsed: successfully
#   Triples: 109
#   SKOS Concepts: 14
#
# Entry 39: table_7.2.jpg
#   RDF syntax: is valid
#   Parsed: successfully
#   Triples: 115
#   SKOS Concepts: 24
#
# Entry 40: table_10.1.jpg
#   RDF syntax: is invalid
#   Parsed: failed
#   Triples: 0
#   SKOS Concepts: 0
#
# Entry 41: table_5.1.jpg
#   RDF syntax: is valid
#   Parsed: successfully
#   Triples: 70
#   SKOS Concepts: 19
#
# Entry 42: table_4.3.jpg
#   RDF syntax: is valid
#   Parsed: successfully
#   Triples: 39
#   SKOS Concepts: 9
#
# Entry 43: table_6.1.jpg
#   RDF syntax: is valid
#   Parsed: successfully
#   Triples: 72
#   SKOS Concepts: 19
#
# Entry 44: table_2.7.jpg
#   RDF syntax: is valid
#   Parsed: successfully
#   Triples: 62
#   SKOS Concepts: 18
#
# Entry 45: table_2.6.jpg
#   RDF syntax: is valid
#   Parsed: successfully
#   Triples: 84
#   SKOS Concepts: 13
#
# Entry 46: table_2.8.jpg
#   RDF syntax: is valid
#   Parsed: successfully
#   Triples: 35
#   SKOS Concepts: 11
#
# Entry 47: .ipynb_checkpoints/table_1.2-checkpoint.jpg
#   RDF syntax: is valid
#   Parsed: successfully
#   Triples: 29
#   SKOS Concepts: 8
#
# Entry 48: figure_2.1.jpg
#   RDF syntax: is valid
#   Parsed: successfully
#   Triples: 75
#   SKOS Concepts: 18
#
# Entry 49: figure_8.1.jpg
#   RDF syntax: is valid
#   Parsed: successfully
#   Triples: 120
#   SKOS Concepts: 37
#
# Entry 50: figure_8.2.jpg
#   RDF syntax: is valid
#   Parsed: successfully
#   Triples: 98
#   SKOS Concepts: 28
#
# Entry 51: figure_3.1.jpg
#   RDF syntax: is valid
#   Parsed: successfully
#   Triples: 88
#   SKOS Concepts: 25
#
# Entry 52: figure_5.2.jpg
#   RDF syntax: is valid
#   Parsed: successfully
#   Triples: 71
#   SKOS Concepts: 19
#
# Entry 53: figure_1.3.jpg
#   RDF syntax: is valid
#   Parsed: successfully
#   Triples: 54
#   SKOS Concepts: 15
#
# Entry 54: figure_1.1.jpg
#   RDF syntax: is valid
#   Parsed: successfully
#   Triples: 196
#   SKOS Concepts: 59
#
# Entry 55: figure_1.2.jpg
#   RDF syntax: is valid
#   Parsed: successfully
#   Triples: 30
#   SKOS Concepts: 10
#
# Entry 56: figure_3.2.jpg
#   RDF syntax: is valid
#   Parsed: successfully
#   Triples: 29
#   SKOS Concepts: 8
#
# Entry 57: figure_3.3.jpg
#   RDF syntax: is valid
#   Parsed: successfully
#   Triples: 83
#   SKOS Concepts: 22
#
# Entry 58: figure_3.4.jpg
#   RDF syntax: is valid
#   Parsed: successfully
#   Triples: 102
#   SKOS Concepts: 24
#
# Entry 59: box_5.1.jpg
#   RDF syntax: is valid
#   Parsed: successfully
#   Triples: 67
#   SKOS Concepts: 21
#
# Entry 60: figure_4.1.jpg
#   RDF syntax: is valid
#   Parsed: successfully
#   Triples: 44
#   SKOS Concepts: 12
#
# Entry 61: figure_6.1.jpg
#   RDF syntax: is valid
#   Parsed: successfully
#   Triples: 38
#   SKOS Concepts: 12
