# %% [markdown]
# # download Dataset

# %%
# https://drive.google.com/file/d/1PFq4Ub19NXfPxOmEYQ_KiNoVFkZlTJSt/view?usp=sharing
# !gdown --id 1PFq4Ub19NXfPxOmEYQ_KiNoVFkZlTJSt
# !unzip /kaggle/working/diagram2graph_Dataset.zip
# Out:
# /usr/local/lib/python3.11/dist-packages/gdown/__main__.py:140: FutureWarning: Option `--id` was deprecated in version 4.3.1 and will be removed in 5.0. You don't need to pass it anymore to use a file ID.
#   warnings.warn(
# Downloading...
# From: https://drive.google.com/uc?id=1PFq4Ub19NXfPxOmEYQ_KiNoVFkZlTJSt
# To: /kaggle/working/diagram2graph_Dataset.zip
# 100%|███████████████████████████████████████| 12.3M/12.3M [00:00<00:00, 122MB/s]
# Archive:  /kaggle/working/diagram2graph_Dataset.zip
#    creating: content/drive/MyDrive/RA/WUR/Dataset/diagram2graph/diagram2graph/
#   inflating: content/drive/MyDrive/RA/WUR/Dataset/diagram2graph/diagram2graph/380.png
#   inflating: content/drive/MyDrive/RA/WUR/Dataset/diagram2graph/diagram2graph/25.png
#   inflating: content/drive/MyDrive/RA/WUR/Dataset/diagram2graph/diagram2graph/37.png
#   inflating: content/drive/MyDrive/RA/WUR/Dataset/diagram2graph/diagram2graph/23.png
#   inflating: content/drive/MyDrive/RA/WUR/Dataset/diagram2graph/diagram2graph/580.png
#   inflating: content/drive/MyDrive/RA/WUR/Dataset/diagram2graph/diagram2graph/498.png
#   inflating: content/drive/MyDrive/RA/WUR/Dataset/diagram2graph/diagram2graph/203.png
#   inflating: content/drive/MyDrive/RA/WUR/Dataset/diagram2graph/diagram2graph/48.png
#   inflating: content/drive/MyDrive/RA/WUR/Dataset/diagram2graph/diagram2graph/930.png
#   inflating: content/drive/MyDrive/RA/WUR/Dataset/diagram2graph/diagram2graph/244.png
#   inflating: content/drive/MyDrive/RA/WUR/Dataset/diagram2graph/diagram2graph/288.png
#   inflating: content/drive/MyDrive/RA/WUR/Dataset/diagram2graph/diagram2graph/936.png
#   inflating: content/drive/MyDrive/RA/WUR/Dataset/diagram2graph/diagram2graph/263.png
#   inflating: content/drive/MyDrive/RA/WUR/Dataset/diagram2graph/diagram2graph/428.png
#   inflating: content/drive/MyDrive/RA/WUR/Dataset/diagram2graph/diagram2graph/904.png
#   inflating: content/drive/MyDrive/RA/WUR/Dataset/diagram2graph/diagram2graph/605.png
#   inflating: content/drive/MyDrive/RA/WUR/Dataset/diagram2graph/diagram2graph/920.png
#   inflating: content/drive/MyDrive/RA/WUR/Dataset/diagram2graph/diagram2graph/800.png
#   inflating: content/drive/MyDrive/RA/WUR/Dataset/diagram2graph/diagram2graph/35.png
#   inflating: content/drive/MyDrive/RA/WUR/Dataset/diagram2graph/diagram2graph/2.png
#   inflating: content/drive/MyDrive/RA/WUR/Dataset/diagram2graph/diagram2graph/891.png
#   inflating: content/drive/MyDrive/RA/WUR/Dataset/diagram2graph/diagram2graph/918.png
#   inflating: content/drive/MyDrive/RA/WUR/Dataset/diagram2graph/diagram2graph/87.png
#   inflating: content/drive/MyDrive/RA/WUR/Dataset/diagram2graph/diagram2graph/334.png
#   inflating: content/drive/MyDrive/RA/WUR/Dataset/diagram2graph/diagram2graph/67.png
#   inflating: content/drive/MyDrive/RA/WUR/Dataset/diagram2graph/diagram2graph/684.png
#   inflating: content/drive/MyDrive/RA/WUR/Dataset/diagram2graph/diagram2graph/630.png
#   inflating: content/drive/MyDrive/RA/WUR/Dataset/diagram2graph/diagram2graph/75.png
#   inflating: content/drive/MyDrive/RA/WUR/Dataset/diagram2graph/diagram2graph/238.png
#   inflating: content/drive/MyDrive/RA/WUR/Dataset/diagram2graph/diagram2graph/446.png
#   inflating: content/drive/MyDrive/RA/WUR/Dataset/diagram2graph/diagram2graph/728.png
#   inflating: content/drive/MyDrive/RA/WUR/Dataset/diagram2graph/diagram2graph/148.png
#   inflating: content/drive/MyDrive/RA/WUR/Dataset/diagram2graph/diagram2graph/905.png
#   inflating: content/drive/MyDrive/RA/WUR/Dataset/diagram2graph/diagram2graph/598.png
#   inflating: content/drive/MyDrive/RA/WUR/Dataset/diagram2graph/diagram2graph/497.png
#   inflating: content/drive/MyDrive/RA/WUR/Dataset/diagram2graph/diagram2graph/655.png
#   inflating: content/drive/MyDrive/RA/WUR/Dataset/diagram2graph/diagram2graph/577.png
#   inflating: content/drive/MyDrive/RA/WUR/Dataset/diagram2graph/diagram2graph/45.png
#   inflating: content/drive/MyDrive/RA/WUR/Dataset/diagram2graph/diagram2graph/93.png
#   inflating: content/drive/MyDrive/RA/WUR/Dataset/diagram2graph/diagram2graph/521.png
#   inflating: content/drive/MyDrive/RA/WUR/Dataset/diagram2graph/diagram2graph/542.png
#   inflating: content/drive/MyDrive/RA/WUR/Dataset/diagram2graph/diagram2graph/250.png
#   inflating: content/drive/MyDrive/RA/WUR/Dataset/diagram2graph/diagram2graph/284.png
#   inflating: content/drive/MyDrive/RA/WUR/Dataset/diagram2graph/diagram2graph/589.png
#   inflating: content/drive/MyDrive/RA/WUR/Dataset/diagram2graph/diagram2graph/813.png
#   inflating: content/drive/MyDrive/RA/WUR/Dataset/diagram2graph/diagram2graph/28.png
#   inflating: content/drive/MyDrive/RA/WUR/Dataset/diagram2graph/diagram2graph/411.png
#   inflating: content/drive/MyDrive/RA/WUR/Dataset/diagram2graph/diagram2graph/274.png
#   inflating: content/drive/MyDrive/RA/WUR/Dataset/diagram2graph/diagram2graph/888.png
#   inflating: content/drive/MyDrive/RA/WUR/Dataset/diagram2graph/diagram2graph/46.png
#   inflating: content/drive/MyDrive/RA/WUR/Dataset/diagram2graph/diagram2graph/931.png
#   inflating: content/drive/MyDrive/RA/WUR/Dataset/diagram2graph/diagram2graph/929.png
#   inflating: content/drive/MyDrive/RA/WUR/Dataset/diagram2graph/diagram2graph/3.png
#   inflating: content/drive/MyDrive/RA/WUR/Dataset/diagram2graph/diagram2graph/100.png
#   inflating: content/drive/MyDrive/RA/WUR/Dataset/diagram2graph/diagram2graph/212.png
#   inflating: content/drive/MyDrive/RA/WUR/Dataset/diagram2graph/diagram2graph/14.png
#   inflating: content/drive/MyDrive/RA/WUR/Dataset/diagram2graph/diagram2graph/0.png
#   inflating: content/drive/MyDrive/RA/WUR/Dataset/diagram2graph/diagram2graph/322.png
#   inflating: content/drive/MyDrive/RA/WUR/Dataset/diagram2graph/diagram2graph/607.png
#   inflating: content/drive/MyDrive/RA/WUR/Dataset/diagram2graph/diagram2graph/848.png
#   inflating: content/drive/MyDrive/RA/WUR/Dataset/diagram2graph/diagram2graph/60.png
#   inflating: content/drive/MyDrive/RA/WUR/Dataset/diagram2graph/diagram2graph/328.png
#   inflating: content/drive/MyDrive/RA/WUR/Dataset/diagram2graph/diagram2graph/286.png
#   inflating: content/drive/MyDrive/RA/WUR/Dataset/diagram2graph/diagram2graph/109.png
#   inflating: content/drive/MyDrive/RA/WUR/Dataset/diagram2graph/diagram2graph/49.png
#   inflating: content/drive/MyDrive/RA/WUR/Dataset/diagram2graph/diagram2graph/915.png
#   inflating: content/drive/MyDrive/RA/WUR/Dataset/diagram2graph/diagram2graph/620.png
#   inflating: content/drive/MyDrive/RA/WUR/Dataset/diagram2graph/diagram2graph/937.png
#   inflating: content/drive/MyDrive/RA/WUR/Dataset/diagram2graph/diagram2graph/65.png
#   inflating: content/drive/MyDrive/RA/WUR/Dataset/diagram2graph/diagram2graph/34.png
#   inflating: content/drive/MyDrive/RA/WUR/Dataset/diagram2graph/diagram2graph/347.png
#   inflating: content/drive/MyDrive/RA/WUR/Dataset/diagram2graph/diagram2graph/627.png
#   inflating: content/drive/MyDrive/RA/WUR/Dataset/diagram2graph/diagram2graph/193.png
#   inflating: content/drive/MyDrive/RA/WUR/Dataset/diagram2graph/diagram2graph/13.png
#   inflating: content/drive/MyDrive/RA/WUR/Dataset/diagram2graph/diagram2graph/470.png
#   inflating: content/drive/MyDrive/RA/WUR/Dataset/diagram2graph/diagram2graph/548.png
#   inflating: content/drive/MyDrive/RA/WUR/Dataset/diagram2graph/diagram2graph/273.png
#   inflating: content/drive/MyDrive/RA/WUR/Dataset/diagram2graph/diagram2graph/341.png
#   inflating: content/drive/MyDrive/RA/WUR/Dataset/diagram2graph/diagram2graph/692.png
#   inflating: content/drive/MyDrive/RA/WUR/Dataset/diagram2graph/diagram2graph/11.png
#   inflating: content/drive/MyDrive/RA/WUR/Dataset/diagram2graph/diagram2graph/4.png
#   inflating: content/drive/MyDrive/RA/WUR/Dataset/diagram2graph/diagram2graph/111.png
#   inflating: content/drive/MyDrive/RA/WUR/Dataset/diagram2graph/diagram2graph/418.png
#   inflating: content/drive/MyDrive/RA/WUR/Dataset/diagram2graph/diagram2graph/12.png
#   inflating: content/drive/MyDrive/RA/WUR/Dataset/diagram2graph/diagram2graph/432.png
#   inflating: content/drive/MyDrive/RA/WUR/Dataset/diagram2graph/diagram2graph/922.png
#   inflating: content/drive/MyDrive/RA/WUR/Dataset/diagram2graph/diagram2graph/914.png
#   inflating: content/drive/MyDrive/RA/WUR/Dataset/diagram2graph/diagram2graph/18.png
#   inflating: content/drive/MyDrive/RA/WUR/Dataset/diagram2graph/diagram2graph/78.png
#   inflating: content/drive/MyDrive/RA/WUR/Dataset/diagram2graph/diagram2graph/120.png
#   inflating: content/drive/MyDrive/RA/WUR/Dataset/diagram2graph/diagram2graph/332.png
#   inflating: content/drive/MyDrive/RA/WUR/Dataset/diagram2graph/diagram2graph/259.png
#   inflating: content/drive/MyDrive/RA/WUR/Dataset/diagram2graph/diagram2graph/279.png
#   inflating: content/drive/MyDrive/RA/WUR/Dataset/diagram2graph/diagram2graph/118.png
#   inflating: content/drive/MyDrive/RA/WUR/Dataset/diagram2graph/diagram2graph/361.png
#   inflating: content/drive/MyDrive/RA/WUR/Dataset/diagram2graph/diagram2graph/254.png
#   inflating: content/drive/MyDrive/RA/WUR/Dataset/diagram2graph/diagram2graph/233.png
#   inflating: content/drive/MyDrive/RA/WUR/Dataset/diagram2graph/diagram2graph/68.png
#   inflating: content/drive/MyDrive/RA/WUR/Dataset/diagram2graph/diagram2graph/938.png
#   inflating: content/drive/MyDrive/RA/WUR/Dataset/diagram2graph/diagram2graph/29.png
#   inflating: content/drive/MyDrive/RA/WUR/Dataset/diagram2graph/diagram2graph/166.png
#   inflating: content/drive/MyDrive/RA/WUR/Dataset/diagram2graph/diagram2graph/121.png
#   inflating: content/drive/MyDrive/RA/WUR/Dataset/diagram2graph/diagram2graph/10.png
#   inflating: content/drive/MyDrive/RA/WUR/Dataset/diagram2graph/diagram2graph/6.png
#   inflating: content/drive/MyDrive/RA/WUR/Dataset/diagram2graph/diagram2graph/229.png
#   inflating: content/drive/MyDrive/RA/WUR/Dataset/diagram2graph/diagram2graph/556.png
#   inflating: content/drive/MyDrive/RA/WUR/Dataset/diagram2graph/diagram2graph/358.png
#   inflating: content/drive/MyDrive/RA/WUR/Dataset/diagram2graph/diagram2graph/76.png
#   inflating: content/drive/MyDrive/RA/WUR/Dataset/diagram2graph/diagram2graph/735.png
#   inflating: content/drive/MyDrive/RA/WUR/Dataset/diagram2graph/diagram2graph/147.png
#   inflating: content/drive/MyDrive/RA/WUR/Dataset/diagram2graph/diagram2graph/919.png
#   inflating: content/drive/MyDrive/RA/WUR/Dataset/diagram2graph/diagram2graph/171.png
#   inflating: content/drive/MyDrive/RA/WUR/Dataset/diagram2graph/diagram2graph/222.png
#   inflating: content/drive/MyDrive/RA/WUR/Dataset/diagram2graph/diagram2graph/413.png
#   inflating: content/drive/MyDrive/RA/WUR/Dataset/diagram2graph/diagram2graph/401.png
#   inflating: content/drive/MyDrive/RA/WUR/Dataset/diagram2graph/diagram2graph/8.png
#   inflating: content/drive/MyDrive/RA/WUR/Dataset/diagram2graph/diagram2graph/215.png
#   inflating: content/drive/MyDrive/RA/WUR/Dataset/diagram2graph/diagram2graph/278.png
#   inflating: content/drive/MyDrive/RA/WUR/Dataset/diagram2graph/diagram2graph/192.png
#   inflating: content/drive/MyDrive/RA/WUR/Dataset/diagram2graph/diagram2graph/921.png
#   inflating: content/drive/MyDrive/RA/WUR/Dataset/diagram2graph/diagram2graph/591.png
#   inflating: content/drive/MyDrive/RA/WUR/Dataset/diagram2graph/diagram2graph/41.png
#   inflating: content/drive/MyDrive/RA/WUR/Dataset/diagram2graph/diagram2graph/293.png
#   inflating: content/drive/MyDrive/RA/WUR/Dataset/diagram2graph/diagram2graph/444.png
#   inflating: content/drive/MyDrive/RA/WUR/Dataset/diagram2graph/diagram2graph/62.png
#   inflating: content/drive/MyDrive/RA/WUR/Dataset/diagram2graph/diagram2graph/44.png
#   inflating: content/drive/MyDrive/RA/WUR/Dataset/diagram2graph/diagram2graph/924.png
#   inflating: content/drive/MyDrive/RA/WUR/Dataset/diagram2graph/diagram2graph/291.png
#   inflating: content/drive/MyDrive/RA/WUR/Dataset/diagram2graph/diagram2graph/701.png
#   inflating: content/drive/MyDrive/RA/WUR/Dataset/diagram2graph/diagram2graph/576.png
#   inflating: content/drive/MyDrive/RA/WUR/Dataset/diagram2graph/diagram2graph/258.png
#   inflating: content/drive/MyDrive/RA/WUR/Dataset/diagram2graph/diagram2graph/652.png
#   inflating: content/drive/MyDrive/RA/WUR/Dataset/diagram2graph/diagram2graph/66.png
#   inflating: content/drive/MyDrive/RA/WUR/Dataset/diagram2graph/diagram2graph/174.png
#   inflating: content/drive/MyDrive/RA/WUR/Dataset/diagram2graph/diagram2graph/252.png
#   inflating: content/drive/MyDrive/RA/WUR/Dataset/diagram2graph/diagram2graph/309.png
#   inflating: content/drive/MyDrive/RA/WUR/Dataset/diagram2graph/diagram2graph/55.png
#   inflating: content/drive/MyDrive/RA/WUR/Dataset/diagram2graph/diagram2graph/268.png
#   inflating: content/drive/MyDrive/RA/WUR/Dataset/diagram2graph/diagram2graph/433.png
#   inflating: content/drive/MyDrive/RA/WUR/Dataset/diagram2graph/diagram2graph/351.png
#   inflating: content/drive/MyDrive/RA/WUR/Dataset/diagram2graph/diagram2graph/933.png
#   inflating: content/drive/MyDrive/RA/WUR/Dataset/diagram2graph/diagram2graph/900.png
#   inflating: content/drive/MyDrive/RA/WUR/Dataset/diagram2graph/diagram2graph/911.png
#   inflating: content/drive/MyDrive/RA/WUR/Dataset/diagram2graph/diagram2graph/63.png
#   inflating: content/drive/MyDrive/RA/WUR/Dataset/diagram2graph/diagram2graph/198.png
#   inflating: content/drive/MyDrive/RA/WUR/Dataset/diagram2graph/diagram2graph/412.png
#   inflating: content/drive/MyDrive/RA/WUR/Dataset/diagram2graph/diagram2graph/926.png
#   inflating: content/drive/MyDrive/RA/WUR/Dataset/diagram2graph/diagram2graph/47.png
#   inflating: content/drive/MyDrive/RA/WUR/Dataset/diagram2graph/diagram2graph/107.png
#   inflating: content/drive/MyDrive/RA/WUR/Dataset/diagram2graph/diagram2graph/204.png
#   inflating: content/drive/MyDrive/RA/WUR/Dataset/diagram2graph/diagram2graph/525.png
#   inflating: content/drive/MyDrive/RA/WUR/Dataset/diagram2graph/diagram2graph/17.png
#   inflating: content/drive/MyDrive/RA/WUR/Dataset/diagram2graph/diagram2graph/907.png
#   inflating: content/drive/MyDrive/RA/WUR/Dataset/diagram2graph/diagram2graph/57.png
#   inflating: content/drive/MyDrive/RA/WUR/Dataset/diagram2graph/diagram2graph/319.png
#   inflating: content/drive/MyDrive/RA/WUR/Dataset/diagram2graph/diagram2graph/624.png
#   inflating: content/drive/MyDrive/RA/WUR/Dataset/diagram2graph/diagram2graph/276.png
#   inflating: content/drive/MyDrive/RA/WUR/Dataset/diagram2graph/diagram2graph/71.png
#   inflating: content/drive/MyDrive/RA/WUR/Dataset/diagram2graph/diagram2graph/940.png
#   inflating: content/drive/MyDrive/RA/WUR/Dataset/diagram2graph/diagram2graph/699.png
#   inflating: content/drive/MyDrive/RA/WUR/Dataset/diagram2graph/diagram2graph/310.png
#   inflating: content/drive/MyDrive/RA/WUR/Dataset/diagram2graph/diagram2graph/902.png
#   inflating: content/drive/MyDrive/RA/WUR/Dataset/diagram2graph/diagram2graph/39.png
#   inflating: content/drive/MyDrive/RA/WUR/Dataset/diagram2graph/diagram2graph/81.png
#   inflating: content/drive/MyDrive/RA/WUR/Dataset/diagram2graph/diagram2graph/315.png
#   inflating: content/drive/MyDrive/RA/WUR/Dataset/diagram2graph/diagram2graph/125.png
#   inflating: content/drive/MyDrive/RA/WUR/Dataset/diagram2graph/diagram2graph/706.png
#   inflating: content/drive/MyDrive/RA/WUR/Dataset/diagram2graph/diagram2graph/99.png
#   inflating: content/drive/MyDrive/RA/WUR/Dataset/diagram2graph/diagram2graph/33.png
#   inflating: content/drive/MyDrive/RA/WUR/Dataset/diagram2graph/diagram2graph/731.png
#   inflating: content/drive/MyDrive/RA/WUR/Dataset/diagram2graph/diagram2graph/753.png
#   inflating: content/drive/MyDrive/RA/WUR/Dataset/diagram2graph/diagram2graph/429.png
#   inflating: content/drive/MyDrive/RA/WUR/Dataset/diagram2graph/diagram2graph/40.png
#   inflating: content/drive/MyDrive/RA/WUR/Dataset/diagram2graph/diagram2graph/113.png
#   inflating: content/drive/MyDrive/RA/WUR/Dataset/diagram2graph/diagram2graph/64.png
#   inflating: content/drive/MyDrive/RA/WUR/Dataset/diagram2graph/diagram2graph/163.png
#   inflating: content/drive/MyDrive/RA/WUR/Dataset/diagram2graph/diagram2graph/916.png
#   inflating: content/drive/MyDrive/RA/WUR/Dataset/diagram2graph/diagram2graph/94.png
#   inflating: content/drive/MyDrive/RA/WUR/Dataset/diagram2graph/diagram2graph/80.png
#   inflating: content/drive/MyDrive/RA/WUR/Dataset/diagram2graph/diagram2graph/457.png
#   inflating: content/drive/MyDrive/RA/WUR/Dataset/diagram2graph/diagram2graph/663.png
#   inflating: content/drive/MyDrive/RA/WUR/Dataset/diagram2graph/diagram2graph/38.png
#   inflating: content/drive/MyDrive/RA/WUR/Dataset/diagram2graph/diagram2graph/86.png
#   inflating: content/drive/MyDrive/RA/WUR/Dataset/diagram2graph/diagram2graph/672.png
#   inflating: content/drive/MyDrive/RA/WUR/Dataset/diagram2graph/diagram2graph/345.png
#   inflating: content/drive/MyDrive/RA/WUR/Dataset/diagram2graph/diagram2graph/908.png
#   inflating: content/drive/MyDrive/RA/WUR/Dataset/diagram2graph/diagram2graph/119.png
#   inflating: content/drive/MyDrive/RA/WUR/Dataset/diagram2graph/diagram2graph/761.png
#   inflating: content/drive/MyDrive/RA/WUR/Dataset/diagram2graph/diagram2graph/295.png
#   inflating: content/drive/MyDrive/RA/WUR/Dataset/diagram2graph/diagram2graph/562.png
#   inflating: content/drive/MyDrive/RA/WUR/Dataset/diagram2graph/diagram2graph/935.png
#   inflating: content/drive/MyDrive/RA/WUR/Dataset/diagram2graph/diagram2graph/153.png
#   inflating: content/drive/MyDrive/RA/WUR/Dataset/diagram2graph/diagram2graph/520.png
#   inflating: content/drive/MyDrive/RA/WUR/Dataset/diagram2graph/diagram2graph/823.png
#   inflating: content/drive/MyDrive/RA/WUR/Dataset/diagram2graph/diagram2graph/224.png
#   inflating: content/drive/MyDrive/RA/WUR/Dataset/diagram2graph/diagram2graph/416.png
#   inflating: content/drive/MyDrive/RA/WUR/Dataset/diagram2graph/diagram2graph/31.png
#   inflating: content/drive/MyDrive/RA/WUR/Dataset/diagram2graph/diagram2graph/262.png
#   inflating: content/drive/MyDrive/RA/WUR/Dataset/diagram2graph/diagram2graph/9.png
#   inflating: content/drive/MyDrive/RA/WUR/Dataset/diagram2graph/diagram2graph/52.png
#   inflating: content/drive/MyDrive/RA/WUR/Dataset/diagram2graph/diagram2graph/934.png
#   inflating: content/drive/MyDrive/RA/WUR/Dataset/diagram2graph/diagram2graph/394.png
#   inflating: content/drive/MyDrive/RA/WUR/Dataset/diagram2graph/diagram2graph/170.png
#   inflating: content/drive/MyDrive/RA/WUR/Dataset/diagram2graph/diagram2graph/818.png
#   inflating: content/drive/MyDrive/RA/WUR/Dataset/diagram2graph/diagram2graph/114.png
#   inflating: content/drive/MyDrive/RA/WUR/Dataset/diagram2graph/diagram2graph/910.png
#   inflating: content/drive/MyDrive/RA/WUR/Dataset/diagram2graph/diagram2graph/331.png
#   inflating: content/drive/MyDrive/RA/WUR/Dataset/diagram2graph/diagram2graph/239.png
#   inflating: content/drive/MyDrive/RA/WUR/Dataset/diagram2graph/diagram2graph/634.png
#   inflating: content/drive/MyDrive/RA/WUR/Dataset/diagram2graph/diagram2graph/275.png
#   inflating: content/drive/MyDrive/RA/WUR/Dataset/diagram2graph/diagram2graph/134.png
#   inflating: content/drive/MyDrive/RA/WUR/Dataset/diagram2graph/diagram2graph/90.png
#   inflating: content/drive/MyDrive/RA/WUR/Dataset/diagram2graph/diagram2graph/30.png
#   inflating: content/drive/MyDrive/RA/WUR/Dataset/diagram2graph/diagram2graph/709.png
#   inflating: content/drive/MyDrive/RA/WUR/Dataset/diagram2graph/diagram2graph/765.png
#   inflating: content/drive/MyDrive/RA/WUR/Dataset/diagram2graph/diagram2graph/563.png
#   inflating: content/drive/MyDrive/RA/WUR/Dataset/diagram2graph/diagram2graph/116.png
#   inflating: content/drive/MyDrive/RA/WUR/Dataset/diagram2graph/diagram2graph/335.png
#   inflating: content/drive/MyDrive/RA/WUR/Dataset/diagram2graph/diagram2graph/356.png

# %% [markdown]
# # Zero Shot prompting

# %%
import base64
import json
import os
import time
from pathlib import Path
from typing import Optional
import requests
from PIL import Image

# =========================
# 1) CONFIGURATION
# =========================
# Prefer loading your key from an environment variable (more secure).
# export GEMINI_API_KEY="..."
def load_api_key(name, fallback_names=()):
    import os
    import sys
    from pathlib import Path

    candidates = (name, *fallback_names)
    repo_root = next(
        (
            candidate
            for candidate in (Path.cwd(), *Path.cwd().parents)
            if (candidate / "common" / "__init__.py").exists()
        ),
        None,
    )

    get_api_key = None
    if repo_root is not None:
        if str(repo_root) not in sys.path:
            sys.path.insert(0, str(repo_root))
        try:
            from common import get_api_key as shared_get_api_key
        except ImportError:
            pass
        else:
            get_api_key = shared_get_api_key

    if get_api_key is not None:
        for candidate in candidates:
            try:
                return get_api_key(candidate)
            except KeyError:
                pass

    for candidate in candidates:
        value = os.getenv(candidate, "").strip()
        if value:
            return value

    joined = ", ".join(candidates)
    raise RuntimeError(
        f"Missing API key. Set one of [{joined}] in the environment"
        " or the top-level config file."
    )

GEMINI_API_KEY = load_api_key("GEMINI_API_KEY")

MODEL = "gemini-2.5-flash"
ENDPOINT = f"https://generativelanguage.googleapis.com/v1beta/models/{MODEL}:generateContent?key={GEMINI_API_KEY}"

# Input images directory (recursively scanned)
DATASET_DIR = "/kaggle/input/diagram2graph-dataset/diagram2graph"  # <--- change this
# Output directory for per-image TTL files
OUTPUT_DIR = "/kaggle/working/ZeroShot_outputs"  # <--- change this
# Optional: also write a small manifest JSON with image->ttl mapping
WRITE_MANIFEST = True
MANIFEST_PATH = os.path.join(OUTPUT_DIR, "manifest.json")

VALID_IMAGE_EXTS = {".png", ".jpg", ".jpeg", ".bmp", ".webp", ".tif", ".tiff"}

# =========================
# 2) PROMPT (Zero-shot)
# =========================
PROMPT_TEXT = r"""

System
You are a diagram-to-graph extractor. Given a flowchart/diagram image, output ONLY valid Turtle using the diagram2graph (d2g) vocabulary.

Mandatory Instructions (follow exactly)
1) Prefixes (only these two)
@prefix d2g:  <http://example.org/diagram2graph#> .
@prefix rdfs: <http://www.w3.org/2000/01/rdf-schema#> .

2) Identifiers (IRIs)
- Fixed patterns:
  Nodes: <http://example.org/diagram/diagram/node/{N}>
  Edges: <http://example.org/diagram/diagram/edge/{E}>
- Node numbering: visual reading order (top→bottom, left→right).
- Edge IDs (strict rule): build each edge IRI as ST, where S is the source node ID and T is the target node ID.
  Example: the edge from node/1 to node/2 MUST be <http://example.org/diagram/diagram/edge/12>

3) Nodes (create one node per readable shape)
For each shape:
<…/node/N> a d2g:Node, d2g:{Start|Process|Decision|Delay|Terminator} ;
    rdfs:label "exact text from the shape" ;
    d2g:shape d2g:{TartEvent|TaK|Gateway|Delay|EndEvent} .
Required shape mapping (use these exact dataset tokens—even if they look misspelled):
- Start/Begin (rounded oval) → d2g:TartEvent
- End/Stop   (rounded oval) → d2g:EndEvent
- Rectangle  (process)      → d2g:TaK
- Diamond    (decision)     → d2g:Gateway
- Delay      (delay symbol) → d2g:Delay

4) Edges (create a dedicated Edge resource per arrow)
For each arrow:
<…/edge/ST> a d2g:Edge, d2g:{Solid|Dashed} ;
    d2g:source <…/node/S> ;
    d2g:target <…/node/T> ;
    d2g:relationshipType d2g:{Follows|Branches} ;
    [optional] d2g:relationshipValue "label on the arrow (e.g., Yes/No)" .
Rules:
- Outgoing arrows from a Decision node must use relationshipType = d2g:Branches, and include relationshipValue if text exists (Yes/No/etc.).
- All other arrows use relationshipType = d2g:Follows.
- Set line style precisely: d2g:Solid for solid lines; d2g:Dashed for dotted/dashed lines.

5) Convenience node-to-node triples (also required)
- For Follows:  <…/node/S> d2g:follows  <…/node/T> .
- For Branches: <…/node/S> d2g:branches <…/node/T> .

6) Output rules
- Output Turtle only; no explanations or extra text.
- Group by subject; one triple per line; end every line with a period.
- Every edge’s source/target must reference existing node IRIs.
- Do NOT use any prefixes or vocabularies other than d2g and rdfs.
- Write class and shape tokens EXACTLY as specified above (no spelling changes).

"""

# =========================
# 3) HELPERS
# =========================
def get_mime_type(path: str) -> str:
    ext = Path(path).suffix.lower()
    if ext in {".jpg", ".jpeg"}:
        return "image/jpeg"
    if ext == ".png":
        return "image/png"
    if ext in {".tif", ".tiff"}:
        return "image/tiff"
    if ext == ".webp":
        return "image/webp"
    if ext == ".bmp":
        return "image/bmp"
    return "image/jpeg"

def encode_image_to_base64(image_path: str) -> Optional[str]:
    try:
        # Ensure the image is readable; PIL open also validates file integrity
        with Image.open(image_path) as _:
            pass
        data = Path(image_path).read_bytes()
        return base64.b64encode(data).decode("utf-8")
    except FileNotFoundError:
        print(f"[WARN] File not found: {image_path}")
        return None
    except Exception as e:
        print(f"[WARN] Failed to read {image_path}: {e}")
        return None

def build_request(image_b64: str, mime_type: str, prompt: str) -> dict:
    return {
        "contents": [
            {
                "role": "user",
                "parts": [
                    {"inlineData": {"mimeType": mime_type, "data": image_b64}},
                    {"text": prompt},
                ],
            }
        ],
        "generationConfig": {
            "temperature": 0.1,
            "topP": 0.9,
            "maxOutputTokens": 8192,
        },
    }

def _strip_code_fences(text: str) -> str:
    """
    Removes ```turtle ... ``` or ``` ... ``` fences if present.
    """
    t = text.strip()
    if t.startswith("```"):
        first_newline = t.find("\n")
        if first_newline != -1 and t[:first_newline].startswith("```"):
            t = t[first_newline + 1 :]
        if t.endswith("```"):
            t = t[:-3].rstrip()
    return t.strip()

def call_gemini(payload: dict, max_retries: int = 4) -> Optional[str]:
    """
    Calls the Gemini API with basic retry/backoff on 429/5xx.
    Returns clean Turtle (TTL) text, or None.
    """
    headers = {"Content-Type": "application/json"}
    backoff = 2.0
    for attempt in range(max_retries):
        try:
            resp = requests.post(ENDPOINT, headers=headers, data=json.dumps(payload), timeout=120)
            if resp.status_code >= 500 or resp.status_code == 429:
                print(f"[INFO] Retryable HTTP {resp.status_code}; attempt {attempt+1}/{max_retries}")
                time.sleep(backoff)
                backoff *= 1.8
                continue
            resp.raise_for_status()
            data = resp.json()
            if "candidates" in data and data["candidates"]:
                raw = data["candidates"][0]["content"]["parts"][0]["text"]
                return _strip_code_fences(raw)
            return None
        except requests.exceptions.RequestException as e:
            print(f"[WARN] Request error: {e}; attempt {attempt+1}/{max_retries}")
            time.sleep(backoff)
            backoff *= 1.8
    return None

def ensure_dir(path: str):
    Path(path).mkdir(parents=True, exist_ok=True)

# =========================
# 4) MAIN: per-image .ttl files
# =========================
def main():
    ensure_dir(OUTPUT_DIR)

    manifest = []  # optional record of what we wrote

    for root, _, files in os.walk(DATASET_DIR):
        for fname in files:
            ext = Path(fname).suffix.lower()
            if ext not in VALID_IMAGE_EXTS:
                continue

            img_path = os.path.join(root, fname)
            stem = Path(fname).stem  # "1.png" -> "1"
            ttl_path = os.path.join(OUTPUT_DIR, f"{stem}.ttl")

            print(f"[INFO] Processing: {img_path} -> {ttl_path}")

            image_b64 = encode_image_to_base64(img_path)
            if not image_b64:
                print(f"[SKIP] Could not encode {img_path}")
                continue

            mime = get_mime_type(img_path)
            payload = build_request(image_b64, mime, PROMPT_TEXT)
            ttl_text = call_gemini(payload)

            if not ttl_text:
                print(f"[WARN] No TTL returned for {img_path}")
                continue

            # Write the TTL file
            with open(ttl_path, "w", encoding="utf-8") as f:
                f.write(ttl_text if ttl_text.endswith("\n") else ttl_text + "\n")

            manifest.append({"source_image": img_path, "ttl_file": ttl_path})

    if WRITE_MANIFEST:
        ensure_dir(OUTPUT_DIR)
        with open(MANIFEST_PATH, "w", encoding="utf-8") as mf:
            json.dump({"items": manifest}, mf, indent=2, ensure_ascii=False)

    print(f"[DONE] Wrote {len(manifest)} TTL files to: {OUTPUT_DIR}")
    if WRITE_MANIFEST:
        print(f"[INFO] Manifest: {MANIFEST_PATH}")

if __name__ == "__main__":
    main()
# Out:
# [INFO] Processing: /kaggle/input/diagram2graph-dataset/diagram2graph/709.png -> /kaggle/working/ZeroShot_outputs/709.ttl
# [INFO] Processing: /kaggle/input/diagram2graph-dataset/diagram2graph/94.png -> /kaggle/working/ZeroShot_outputs/94.ttl
# [INFO] Processing: /kaggle/input/diagram2graph-dataset/diagram2graph/48.png -> /kaggle/working/ZeroShot_outputs/48.ttl
# [INFO] Processing: /kaggle/input/diagram2graph-dataset/diagram2graph/761.png -> /kaggle/working/ZeroShot_outputs/761.ttl
# [INFO] Processing: /kaggle/input/diagram2graph-dataset/diagram2graph/655.png -> /kaggle/working/ZeroShot_outputs/655.ttl
# [INFO] Processing: /kaggle/input/diagram2graph-dataset/diagram2graph/238.png -> /kaggle/working/ZeroShot_outputs/238.ttl
# [INFO] Processing: /kaggle/input/diagram2graph-dataset/diagram2graph/222.png -> /kaggle/working/ZeroShot_outputs/222.ttl
# [INFO] Processing: /kaggle/input/diagram2graph-dataset/diagram2graph/278.png -> /kaggle/working/ZeroShot_outputs/278.ttl
# [INFO] Processing: /kaggle/input/diagram2graph-dataset/diagram2graph/37.png -> /kaggle/working/ZeroShot_outputs/37.ttl
# [INFO] Processing: /kaggle/input/diagram2graph-dataset/diagram2graph/148.png -> /kaggle/working/ZeroShot_outputs/148.ttl
# [INFO] Processing: /kaggle/input/diagram2graph-dataset/diagram2graph/35.png -> /kaggle/working/ZeroShot_outputs/35.ttl
# [INFO] Processing: /kaggle/input/diagram2graph-dataset/diagram2graph/334.png -> /kaggle/working/ZeroShot_outputs/334.ttl
# [INFO] Processing: /kaggle/input/diagram2graph-dataset/diagram2graph/940.png -> /kaggle/working/ZeroShot_outputs/940.ttl
# [INFO] Processing: /kaggle/input/diagram2graph-dataset/diagram2graph/634.png -> /kaggle/working/ZeroShot_outputs/634.ttl
# [INFO] Processing: /kaggle/input/diagram2graph-dataset/diagram2graph/933.png -> /kaggle/working/ZeroShot_outputs/933.ttl
# [INFO] Processing: /kaggle/input/diagram2graph-dataset/diagram2graph/542.png -> /kaggle/working/ZeroShot_outputs/542.ttl
# [INFO] Processing: /kaggle/input/diagram2graph-dataset/diagram2graph/315.png -> /kaggle/working/ZeroShot_outputs/315.ttl
# [INFO] Processing: /kaggle/input/diagram2graph-dataset/diagram2graph/153.png -> /kaggle/working/ZeroShot_outputs/153.ttl
# [INFO] Processing: /kaggle/input/diagram2graph-dataset/diagram2graph/562.png -> /kaggle/working/ZeroShot_outputs/562.ttl
# [INFO] Processing: /kaggle/input/diagram2graph-dataset/diagram2graph/204.png -> /kaggle/working/ZeroShot_outputs/204.ttl
# [INFO] Processing: /kaggle/input/diagram2graph-dataset/diagram2graph/75.png -> /kaggle/working/ZeroShot_outputs/75.ttl
# [INFO] Processing: /kaggle/input/diagram2graph-dataset/diagram2graph/521.png -> /kaggle/working/ZeroShot_outputs/521.ttl
# [INFO] Processing: /kaggle/input/diagram2graph-dataset/diagram2graph/11.png -> /kaggle/working/ZeroShot_outputs/11.ttl
# [INFO] Processing: /kaggle/input/diagram2graph-dataset/diagram2graph/416.png -> /kaggle/working/ZeroShot_outputs/416.ttl
# [INFO] Processing: /kaggle/input/diagram2graph-dataset/diagram2graph/605.png -> /kaggle/working/ZeroShot_outputs/605.ttl
# [INFO] Processing: /kaggle/input/diagram2graph-dataset/diagram2graph/351.png -> /kaggle/working/ZeroShot_outputs/351.ttl
# [INFO] Processing: /kaggle/input/diagram2graph-dataset/diagram2graph/411.png -> /kaggle/working/ZeroShot_outputs/411.ttl
# [INFO] Processing: /kaggle/input/diagram2graph-dataset/diagram2graph/114.png -> /kaggle/working/ZeroShot_outputs/114.ttl
# [INFO] Processing: /kaggle/input/diagram2graph-dataset/diagram2graph/930.png -> /kaggle/working/ZeroShot_outputs/930.ttl
# [INFO] Processing: /kaggle/input/diagram2graph-dataset/diagram2graph/457.png -> /kaggle/working/ZeroShot_outputs/457.ttl
# [INFO] Processing: /kaggle/input/diagram2graph-dataset/diagram2graph/907.png -> /kaggle/working/ZeroShot_outputs/907.ttl
# [INFO] Processing: /kaggle/input/diagram2graph-dataset/diagram2graph/432.png -> /kaggle/working/ZeroShot_outputs/432.ttl
# [INFO] Processing: /kaggle/input/diagram2graph-dataset/diagram2graph/119.png -> /kaggle/working/ZeroShot_outputs/119.ttl
# [INFO] Processing: /kaggle/input/diagram2graph-dataset/diagram2graph/100.png -> /kaggle/working/ZeroShot_outputs/100.ttl
# [INFO] Processing: /kaggle/input/diagram2graph-dataset/diagram2graph/322.png -> /kaggle/working/ZeroShot_outputs/322.ttl
# [INFO] Processing: /kaggle/input/diagram2graph-dataset/diagram2graph/76.png -> /kaggle/working/ZeroShot_outputs/76.ttl
# [INFO] Processing: /kaggle/input/diagram2graph-dataset/diagram2graph/193.png -> /kaggle/working/ZeroShot_outputs/193.ttl
# [INFO] Processing: /kaggle/input/diagram2graph-dataset/diagram2graph/163.png -> /kaggle/working/ZeroShot_outputs/163.ttl
# [INFO] Processing: /kaggle/input/diagram2graph-dataset/diagram2graph/31.png -> /kaggle/working/ZeroShot_outputs/31.ttl
# [INFO] Processing: /kaggle/input/diagram2graph-dataset/diagram2graph/4.png -> /kaggle/working/ZeroShot_outputs/4.ttl
# [INFO] Processing: /kaggle/input/diagram2graph-dataset/diagram2graph/192.png -> /kaggle/working/ZeroShot_outputs/192.ttl
# [INFO] Processing: /kaggle/input/diagram2graph-dataset/diagram2graph/229.png -> /kaggle/working/ZeroShot_outputs/229.ttl
# [INFO] Processing: /kaggle/input/diagram2graph-dataset/diagram2graph/331.png -> /kaggle/working/ZeroShot_outputs/331.ttl
# [INFO] Processing: /kaggle/input/diagram2graph-dataset/diagram2graph/672.png -> /kaggle/working/ZeroShot_outputs/672.ttl
# [INFO] Processing: /kaggle/input/diagram2graph-dataset/diagram2graph/580.png -> /kaggle/working/ZeroShot_outputs/580.ttl
# [INFO] Processing: /kaggle/input/diagram2graph-dataset/diagram2graph/345.png -> /kaggle/working/ZeroShot_outputs/345.ttl
# [INFO] Processing: /kaggle/input/diagram2graph-dataset/diagram2graph/171.png -> /kaggle/working/ZeroShot_outputs/171.ttl
# [INFO] Processing: /kaggle/input/diagram2graph-dataset/diagram2graph/40.png -> /kaggle/working/ZeroShot_outputs/40.ttl
# [INFO] Processing: /kaggle/input/diagram2graph-dataset/diagram2graph/33.png -> /kaggle/working/ZeroShot_outputs/33.ttl
# [INFO] Processing: /kaggle/input/diagram2graph-dataset/diagram2graph/147.png -> /kaggle/working/ZeroShot_outputs/147.ttl
# [INFO] Processing: /kaggle/input/diagram2graph-dataset/diagram2graph/9.png -> /kaggle/working/ZeroShot_outputs/9.ttl
# [INFO] Processing: /kaggle/input/diagram2graph-dataset/diagram2graph/254.png -> /kaggle/working/ZeroShot_outputs/254.ttl
# [INFO] Processing: /kaggle/input/diagram2graph-dataset/diagram2graph/931.png -> /kaggle/working/ZeroShot_outputs/931.ttl
# [INFO] Processing: /kaggle/input/diagram2graph-dataset/diagram2graph/823.png -> /kaggle/working/ZeroShot_outputs/823.ttl
# [INFO] Processing: /kaggle/input/diagram2graph-dataset/diagram2graph/891.png -> /kaggle/working/ZeroShot_outputs/891.ttl
# [INFO] Processing: /kaggle/input/diagram2graph-dataset/diagram2graph/233.png -> /kaggle/working/ZeroShot_outputs/233.ttl
# [INFO] Processing: /kaggle/input/diagram2graph-dataset/diagram2graph/284.png -> /kaggle/working/ZeroShot_outputs/284.ttl
# [INFO] Processing: /kaggle/input/diagram2graph-dataset/diagram2graph/888.png -> /kaggle/working/ZeroShot_outputs/888.ttl
# [INFO] Processing: /kaggle/input/diagram2graph-dataset/diagram2graph/818.png -> /kaggle/working/ZeroShot_outputs/818.ttl
# [INFO] Processing: /kaggle/input/diagram2graph-dataset/diagram2graph/911.png -> /kaggle/working/ZeroShot_outputs/911.ttl
# [INFO] Processing: /kaggle/input/diagram2graph-dataset/diagram2graph/116.png -> /kaggle/working/ZeroShot_outputs/116.ttl
# [INFO] Processing: /kaggle/input/diagram2graph-dataset/diagram2graph/520.png -> /kaggle/working/ZeroShot_outputs/520.ttl
# [INFO] Processing: /kaggle/input/diagram2graph-dataset/diagram2graph/80.png -> /kaggle/working/ZeroShot_outputs/80.ttl
# [INFO] Processing: /kaggle/input/diagram2graph-dataset/diagram2graph/55.png -> /kaggle/working/ZeroShot_outputs/55.ttl
# [INFO] Processing: /kaggle/input/diagram2graph-dataset/diagram2graph/291.png -> /kaggle/working/ZeroShot_outputs/291.ttl
# [INFO] Processing: /kaggle/input/diagram2graph-dataset/diagram2graph/288.png -> /kaggle/working/ZeroShot_outputs/288.ttl
# [INFO] Processing: /kaggle/input/diagram2graph-dataset/diagram2graph/589.png -> /kaggle/working/ZeroShot_outputs/589.ttl
# [INFO] Processing: /kaggle/input/diagram2graph-dataset/diagram2graph/607.png -> /kaggle/working/ZeroShot_outputs/607.ttl
# [INFO] Processing: /kaggle/input/diagram2graph-dataset/diagram2graph/938.png -> /kaggle/working/ZeroShot_outputs/938.ttl
# [INFO] Processing: /kaggle/input/diagram2graph-dataset/diagram2graph/49.png -> /kaggle/working/ZeroShot_outputs/49.ttl
# [INFO] Processing: /kaggle/input/diagram2graph-dataset/diagram2graph/268.png -> /kaggle/working/ZeroShot_outputs/268.ttl
# [INFO] Processing: /kaggle/input/diagram2graph-dataset/diagram2graph/93.png -> /kaggle/working/ZeroShot_outputs/93.ttl
# [INFO] Processing: /kaggle/input/diagram2graph-dataset/diagram2graph/113.png -> /kaggle/working/ZeroShot_outputs/113.ttl
# [INFO] Processing: /kaggle/input/diagram2graph-dataset/diagram2graph/332.png -> /kaggle/working/ZeroShot_outputs/332.ttl
# [INFO] Processing: /kaggle/input/diagram2graph-dataset/diagram2graph/170.png -> /kaggle/working/ZeroShot_outputs/170.ttl
# [INFO] Processing: /kaggle/input/diagram2graph-dataset/diagram2graph/198.png -> /kaggle/working/ZeroShot_outputs/198.ttl
# [INFO] Processing: /kaggle/input/diagram2graph-dataset/diagram2graph/924.png -> /kaggle/working/ZeroShot_outputs/924.ttl
# [INFO] Processing: /kaggle/input/diagram2graph-dataset/diagram2graph/401.png -> /kaggle/working/ZeroShot_outputs/401.ttl
# [INFO] Processing: /kaggle/input/diagram2graph-dataset/diagram2graph/14.png -> /kaggle/working/ZeroShot_outputs/14.ttl
# [INFO] Processing: /kaggle/input/diagram2graph-dataset/diagram2graph/65.png -> /kaggle/working/ZeroShot_outputs/65.ttl
# [INFO] Processing: /kaggle/input/diagram2graph-dataset/diagram2graph/706.png -> /kaggle/working/ZeroShot_outputs/706.ttl
# [INFO] Processing: /kaggle/input/diagram2graph-dataset/diagram2graph/293.png -> /kaggle/working/ZeroShot_outputs/293.ttl
# [INFO] Processing: /kaggle/input/diagram2graph-dataset/diagram2graph/576.png -> /kaggle/working/ZeroShot_outputs/576.ttl
# [INFO] Processing: /kaggle/input/diagram2graph-dataset/diagram2graph/701.png -> /kaggle/working/ZeroShot_outputs/701.ttl
# [INFO] Processing: /kaggle/input/diagram2graph-dataset/diagram2graph/926.png -> /kaggle/working/ZeroShot_outputs/926.ttl
# [INFO] Processing: /kaggle/input/diagram2graph-dataset/diagram2graph/39.png -> /kaggle/working/ZeroShot_outputs/39.ttl
# [INFO] Processing: /kaggle/input/diagram2graph-dataset/diagram2graph/380.png -> /kaggle/working/ZeroShot_outputs/380.ttl
# [INFO] Processing: /kaggle/input/diagram2graph-dataset/diagram2graph/446.png -> /kaggle/working/ZeroShot_outputs/446.ttl
# [INFO] Processing: /kaggle/input/diagram2graph-dataset/diagram2graph/433.png -> /kaggle/working/ZeroShot_outputs/433.ttl
# [INFO] Processing: /kaggle/input/diagram2graph-dataset/diagram2graph/319.png -> /kaggle/working/ZeroShot_outputs/319.ttl
# [INFO] Processing: /kaggle/input/diagram2graph-dataset/diagram2graph/107.png -> /kaggle/working/ZeroShot_outputs/107.ttl
# [INFO] Processing: /kaggle/input/diagram2graph-dataset/diagram2graph/90.png -> /kaggle/working/ZeroShot_outputs/90.ttl
# [INFO] Processing: /kaggle/input/diagram2graph-dataset/diagram2graph/262.png -> /kaggle/working/ZeroShot_outputs/262.ttl
# [INFO] Processing: /kaggle/input/diagram2graph-dataset/diagram2graph/215.png -> /kaggle/working/ZeroShot_outputs/215.ttl
# [INFO] Processing: /kaggle/input/diagram2graph-dataset/diagram2graph/920.png -> /kaggle/working/ZeroShot_outputs/920.ttl
# [INFO] Processing: /kaggle/input/diagram2graph-dataset/diagram2graph/412.png -> /kaggle/working/ZeroShot_outputs/412.ttl
# [INFO] Processing: /kaggle/input/diagram2graph-dataset/diagram2graph/910.png -> /kaggle/working/ZeroShot_outputs/910.ttl
# [INFO] Processing: /kaggle/input/diagram2graph-dataset/diagram2graph/731.png -> /kaggle/working/ZeroShot_outputs/731.ttl
# [INFO] Processing: /kaggle/input/diagram2graph-dataset/diagram2graph/38.png -> /kaggle/working/ZeroShot_outputs/38.ttl
# [INFO] Processing: /kaggle/input/diagram2graph-dataset/diagram2graph/2.png -> /kaggle/working/ZeroShot_outputs/2.ttl
# [INFO] Processing: /kaggle/input/diagram2graph-dataset/diagram2graph/900.png -> /kaggle/working/ZeroShot_outputs/900.ttl
# [INFO] Processing: /kaggle/input/diagram2graph-dataset/diagram2graph/335.png -> /kaggle/working/ZeroShot_outputs/335.ttl
# [INFO] Processing: /kaggle/input/diagram2graph-dataset/diagram2graph/10.png -> /kaggle/working/ZeroShot_outputs/10.ttl
# [INFO] Processing: /kaggle/input/diagram2graph-dataset/diagram2graph/598.png -> /kaggle/working/ZeroShot_outputs/598.ttl
# [INFO] Processing: /kaggle/input/diagram2graph-dataset/diagram2graph/174.png -> /kaggle/working/ZeroShot_outputs/174.ttl
# [INFO] Processing: /kaggle/input/diagram2graph-dataset/diagram2graph/250.png -> /kaggle/working/ZeroShot_outputs/250.ttl
# [INFO] Processing: /kaggle/input/diagram2graph-dataset/diagram2graph/908.png -> /kaggle/working/ZeroShot_outputs/908.ttl
# [INFO] Processing: /kaggle/input/diagram2graph-dataset/diagram2graph/556.png -> /kaggle/working/ZeroShot_outputs/556.ttl
# [INFO] Processing: /kaggle/input/diagram2graph-dataset/diagram2graph/81.png -> /kaggle/working/ZeroShot_outputs/81.ttl
# [INFO] Processing: /kaggle/input/diagram2graph-dataset/diagram2graph/239.png -> /kaggle/working/ZeroShot_outputs/239.ttl
# [INFO] Processing: /kaggle/input/diagram2graph-dataset/diagram2graph/66.png -> /kaggle/working/ZeroShot_outputs/66.ttl
# [INFO] Processing: /kaggle/input/diagram2graph-dataset/diagram2graph/902.png -> /kaggle/working/ZeroShot_outputs/902.ttl
# [INFO] Processing: /kaggle/input/diagram2graph-dataset/diagram2graph/684.png -> /kaggle/working/ZeroShot_outputs/684.ttl
# [INFO] Processing: /kaggle/input/diagram2graph-dataset/diagram2graph/735.png -> /kaggle/working/ZeroShot_outputs/735.ttl
# [INFO] Processing: /kaggle/input/diagram2graph-dataset/diagram2graph/914.png -> /kaggle/working/ZeroShot_outputs/914.ttl
# [INFO] Processing: /kaggle/input/diagram2graph-dataset/diagram2graph/934.png -> /kaggle/working/ZeroShot_outputs/934.ttl
# [INFO] Processing: /kaggle/input/diagram2graph-dataset/diagram2graph/276.png -> /kaggle/working/ZeroShot_outputs/276.ttl
# [INFO] Processing: /kaggle/input/diagram2graph-dataset/diagram2graph/848.png -> /kaggle/working/ZeroShot_outputs/848.ttl
# [INFO] Processing: /kaggle/input/diagram2graph-dataset/diagram2graph/279.png -> /kaggle/working/ZeroShot_outputs/279.ttl
# [INFO] Processing: /kaggle/input/diagram2graph-dataset/diagram2graph/577.png -> /kaggle/working/ZeroShot_outputs/577.ttl
# [INFO] Processing: /kaggle/input/diagram2graph-dataset/diagram2graph/356.png -> /kaggle/working/ZeroShot_outputs/356.ttl
# [INFO] Processing: /kaggle/input/diagram2graph-dataset/diagram2graph/937.png -> /kaggle/working/ZeroShot_outputs/937.ttl
# [INFO] Processing: /kaggle/input/diagram2graph-dataset/diagram2graph/244.png -> /kaggle/working/ZeroShot_outputs/244.ttl
# [INFO] Processing: /kaggle/input/diagram2graph-dataset/diagram2graph/263.png -> /kaggle/working/ZeroShot_outputs/263.ttl
# [INFO] Processing: /kaggle/input/diagram2graph-dataset/diagram2graph/166.png -> /kaggle/working/ZeroShot_outputs/166.ttl
# [INFO] Processing: /kaggle/input/diagram2graph-dataset/diagram2graph/18.png -> /kaggle/working/ZeroShot_outputs/18.ttl
# [INFO] Processing: /kaggle/input/diagram2graph-dataset/diagram2graph/63.png -> /kaggle/working/ZeroShot_outputs/63.ttl
# [INFO] Processing: /kaggle/input/diagram2graph-dataset/diagram2graph/936.png -> /kaggle/working/ZeroShot_outputs/936.ttl
# [INFO] Processing: /kaggle/input/diagram2graph-dataset/diagram2graph/12.png -> /kaggle/working/ZeroShot_outputs/12.ttl
# [INFO] Processing: /kaggle/input/diagram2graph-dataset/diagram2graph/627.png -> /kaggle/working/ZeroShot_outputs/627.ttl
# [INFO] Processing: /kaggle/input/diagram2graph-dataset/diagram2graph/28.png -> /kaggle/working/ZeroShot_outputs/28.ttl
# [INFO] Processing: /kaggle/input/diagram2graph-dataset/diagram2graph/67.png -> /kaggle/working/ZeroShot_outputs/67.ttl
# [INFO] Processing: /kaggle/input/diagram2graph-dataset/diagram2graph/34.png -> /kaggle/working/ZeroShot_outputs/34.ttl
# [INFO] Processing: /kaggle/input/diagram2graph-dataset/diagram2graph/813.png -> /kaggle/working/ZeroShot_outputs/813.ttl
# [INFO] Processing: /kaggle/input/diagram2graph-dataset/diagram2graph/41.png -> /kaggle/working/ZeroShot_outputs/41.ttl
# [INFO] Processing: /kaggle/input/diagram2graph-dataset/diagram2graph/563.png -> /kaggle/working/ZeroShot_outputs/563.ttl
# [INFO] Processing: /kaggle/input/diagram2graph-dataset/diagram2graph/125.png -> /kaggle/working/ZeroShot_outputs/125.ttl
# [INFO] Processing: /kaggle/input/diagram2graph-dataset/diagram2graph/121.png -> /kaggle/working/ZeroShot_outputs/121.ttl
# [INFO] Processing: /kaggle/input/diagram2graph-dataset/diagram2graph/905.png -> /kaggle/working/ZeroShot_outputs/905.ttl
# [INFO] Processing: /kaggle/input/diagram2graph-dataset/diagram2graph/663.png -> /kaggle/working/ZeroShot_outputs/663.ttl
# [INFO] Processing: /kaggle/input/diagram2graph-dataset/diagram2graph/915.png -> /kaggle/working/ZeroShot_outputs/915.ttl
# [INFO] Processing: /kaggle/input/diagram2graph-dataset/diagram2graph/86.png -> /kaggle/working/ZeroShot_outputs/86.ttl
# [INFO] Processing: /kaggle/input/diagram2graph-dataset/diagram2graph/916.png -> /kaggle/working/ZeroShot_outputs/916.ttl
# [INFO] Processing: /kaggle/input/diagram2graph-dataset/diagram2graph/258.png -> /kaggle/working/ZeroShot_outputs/258.ttl
# [INFO] Processing: /kaggle/input/diagram2graph-dataset/diagram2graph/498.png -> /kaggle/working/ZeroShot_outputs/498.ttl
# [INFO] Processing: /kaggle/input/diagram2graph-dataset/diagram2graph/29.png -> /kaggle/working/ZeroShot_outputs/29.ttl
# [INFO] Processing: /kaggle/input/diagram2graph-dataset/diagram2graph/109.png -> /kaggle/working/ZeroShot_outputs/109.ttl
# [INFO] Processing: /kaggle/input/diagram2graph-dataset/diagram2graph/224.png -> /kaggle/working/ZeroShot_outputs/224.ttl
# [INFO] Processing: /kaggle/input/diagram2graph-dataset/diagram2graph/361.png -> /kaggle/working/ZeroShot_outputs/361.ttl
# [INFO] Processing: /kaggle/input/diagram2graph-dataset/diagram2graph/753.png -> /kaggle/working/ZeroShot_outputs/753.ttl
# [INFO] Processing: /kaggle/input/diagram2graph-dataset/diagram2graph/71.png -> /kaggle/working/ZeroShot_outputs/71.ttl
# [INFO] Processing: /kaggle/input/diagram2graph-dataset/diagram2graph/525.png -> /kaggle/working/ZeroShot_outputs/525.ttl
# [INFO] Processing: /kaggle/input/diagram2graph-dataset/diagram2graph/120.png -> /kaggle/working/ZeroShot_outputs/120.ttl
# [INFO] Processing: /kaggle/input/diagram2graph-dataset/diagram2graph/935.png -> /kaggle/working/ZeroShot_outputs/935.ttl
# [INFO] Processing: /kaggle/input/diagram2graph-dataset/diagram2graph/630.png -> /kaggle/working/ZeroShot_outputs/630.ttl
# [INFO] Processing: /kaggle/input/diagram2graph-dataset/diagram2graph/310.png -> /kaggle/working/ZeroShot_outputs/310.ttl
# [INFO] Processing: /kaggle/input/diagram2graph-dataset/diagram2graph/118.png -> /kaggle/working/ZeroShot_outputs/118.ttl
# [INFO] Processing: /kaggle/input/diagram2graph-dataset/diagram2graph/17.png -> /kaggle/working/ZeroShot_outputs/17.ttl
# [INFO] Processing: /kaggle/input/diagram2graph-dataset/diagram2graph/620.png -> /kaggle/working/ZeroShot_outputs/620.ttl
# [INFO] Processing: /kaggle/input/diagram2graph-dataset/diagram2graph/904.png -> /kaggle/working/ZeroShot_outputs/904.ttl
# [INFO] Processing: /kaggle/input/diagram2graph-dataset/diagram2graph/52.png -> /kaggle/working/ZeroShot_outputs/52.ttl
# [INFO] Processing: /kaggle/input/diagram2graph-dataset/diagram2graph/3.png -> /kaggle/working/ZeroShot_outputs/3.ttl
# [INFO] Processing: /kaggle/input/diagram2graph-dataset/diagram2graph/64.png -> /kaggle/working/ZeroShot_outputs/64.ttl
# [INFO] Processing: /kaggle/input/diagram2graph-dataset/diagram2graph/347.png -> /kaggle/working/ZeroShot_outputs/347.ttl
# [INFO] Processing: /kaggle/input/diagram2graph-dataset/diagram2graph/800.png -> /kaggle/working/ZeroShot_outputs/800.ttl
# [INFO] Processing: /kaggle/input/diagram2graph-dataset/diagram2graph/328.png -> /kaggle/working/ZeroShot_outputs/328.ttl
# [INFO] Processing: /kaggle/input/diagram2graph-dataset/diagram2graph/203.png -> /kaggle/working/ZeroShot_outputs/203.ttl
# [INFO] Processing: /kaggle/input/diagram2graph-dataset/diagram2graph/8.png -> /kaggle/working/ZeroShot_outputs/8.ttl
# [INFO] Processing: /kaggle/input/diagram2graph-dataset/diagram2graph/45.png -> /kaggle/working/ZeroShot_outputs/45.ttl
# [INFO] Processing: /kaggle/input/diagram2graph-dataset/diagram2graph/548.png -> /kaggle/working/ZeroShot_outputs/548.ttl
# [INFO] Processing: /kaggle/input/diagram2graph-dataset/diagram2graph/444.png -> /kaggle/working/ZeroShot_outputs/444.ttl
# [INFO] Processing: /kaggle/input/diagram2graph-dataset/diagram2graph/922.png -> /kaggle/working/ZeroShot_outputs/922.ttl
# [INFO] Processing: /kaggle/input/diagram2graph-dataset/diagram2graph/624.png -> /kaggle/working/ZeroShot_outputs/624.ttl
# [INFO] Processing: /kaggle/input/diagram2graph-dataset/diagram2graph/274.png -> /kaggle/working/ZeroShot_outputs/274.ttl
# [INFO] Processing: /kaggle/input/diagram2graph-dataset/diagram2graph/6.png -> /kaggle/working/ZeroShot_outputs/6.ttl
# [INFO] Processing: /kaggle/input/diagram2graph-dataset/diagram2graph/23.png -> /kaggle/working/ZeroShot_outputs/23.ttl
# [INFO] Processing: /kaggle/input/diagram2graph-dataset/diagram2graph/87.png -> /kaggle/working/ZeroShot_outputs/87.ttl
# [INFO] Processing: /kaggle/input/diagram2graph-dataset/diagram2graph/275.png -> /kaggle/working/ZeroShot_outputs/275.ttl
# [INFO] Processing: /kaggle/input/diagram2graph-dataset/diagram2graph/728.png -> /kaggle/working/ZeroShot_outputs/728.ttl
# [INFO] Processing: /kaggle/input/diagram2graph-dataset/diagram2graph/591.png -> /kaggle/working/ZeroShot_outputs/591.ttl
# [INFO] Processing: /kaggle/input/diagram2graph-dataset/diagram2graph/44.png -> /kaggle/working/ZeroShot_outputs/44.ttl
# [INFO] Processing: /kaggle/input/diagram2graph-dataset/diagram2graph/68.png -> /kaggle/working/ZeroShot_outputs/68.ttl
# [INFO] Processing: /kaggle/input/diagram2graph-dataset/diagram2graph/286.png -> /kaggle/working/ZeroShot_outputs/286.ttl
# [INFO] Processing: /kaggle/input/diagram2graph-dataset/diagram2graph/46.png -> /kaggle/working/ZeroShot_outputs/46.ttl
# [INFO] Processing: /kaggle/input/diagram2graph-dataset/diagram2graph/470.png -> /kaggle/working/ZeroShot_outputs/470.ttl
# [INFO] Processing: /kaggle/input/diagram2graph-dataset/diagram2graph/929.png -> /kaggle/working/ZeroShot_outputs/929.ttl
# [INFO] Processing: /kaggle/input/diagram2graph-dataset/diagram2graph/57.png -> /kaggle/working/ZeroShot_outputs/57.ttl
# [INFO] Processing: /kaggle/input/diagram2graph-dataset/diagram2graph/358.png -> /kaggle/working/ZeroShot_outputs/358.ttl
# [INFO] Processing: /kaggle/input/diagram2graph-dataset/diagram2graph/652.png -> /kaggle/working/ZeroShot_outputs/652.ttl
# [INFO] Processing: /kaggle/input/diagram2graph-dataset/diagram2graph/252.png -> /kaggle/working/ZeroShot_outputs/252.ttl
# [INFO] Processing: /kaggle/input/diagram2graph-dataset/diagram2graph/30.png -> /kaggle/working/ZeroShot_outputs/30.ttl
# [INFO] Processing: /kaggle/input/diagram2graph-dataset/diagram2graph/919.png -> /kaggle/working/ZeroShot_outputs/919.ttl
# [INFO] Processing: /kaggle/input/diagram2graph-dataset/diagram2graph/429.png -> /kaggle/working/ZeroShot_outputs/429.ttl
# [INFO] Processing: /kaggle/input/diagram2graph-dataset/diagram2graph/60.png -> /kaggle/working/ZeroShot_outputs/60.ttl
# [INFO] Processing: /kaggle/input/diagram2graph-dataset/diagram2graph/99.png -> /kaggle/working/ZeroShot_outputs/99.ttl
# [INFO] Processing: /kaggle/input/diagram2graph-dataset/diagram2graph/765.png -> /kaggle/working/ZeroShot_outputs/765.ttl
# [INFO] Processing: /kaggle/input/diagram2graph-dataset/diagram2graph/692.png -> /kaggle/working/ZeroShot_outputs/692.ttl
# [INFO] Processing: /kaggle/input/diagram2graph-dataset/diagram2graph/295.png -> /kaggle/working/ZeroShot_outputs/295.ttl
# [INFO] Processing: /kaggle/input/diagram2graph-dataset/diagram2graph/394.png -> /kaggle/working/ZeroShot_outputs/394.ttl
# [INFO] Processing: /kaggle/input/diagram2graph-dataset/diagram2graph/273.png -> /kaggle/working/ZeroShot_outputs/273.ttl
# [INFO] Processing: /kaggle/input/diagram2graph-dataset/diagram2graph/413.png -> /kaggle/working/ZeroShot_outputs/413.ttl
# [INFO] Processing: /kaggle/input/diagram2graph-dataset/diagram2graph/78.png -> /kaggle/working/ZeroShot_outputs/78.ttl
# [INFO] Processing: /kaggle/input/diagram2graph-dataset/diagram2graph/212.png -> /kaggle/working/ZeroShot_outputs/212.ttl
# [INFO] Processing: /kaggle/input/diagram2graph-dataset/diagram2graph/47.png -> /kaggle/working/ZeroShot_outputs/47.ttl
# [INFO] Processing: /kaggle/input/diagram2graph-dataset/diagram2graph/13.png -> /kaggle/working/ZeroShot_outputs/13.ttl
# [INFO] Processing: /kaggle/input/diagram2graph-dataset/diagram2graph/134.png -> /kaggle/working/ZeroShot_outputs/134.ttl
# [INFO] Processing: /kaggle/input/diagram2graph-dataset/diagram2graph/921.png -> /kaggle/working/ZeroShot_outputs/921.ttl
# [INFO] Processing: /kaggle/input/diagram2graph-dataset/diagram2graph/259.png -> /kaggle/working/ZeroShot_outputs/259.ttl
# [INFO] Processing: /kaggle/input/diagram2graph-dataset/diagram2graph/25.png -> /kaggle/working/ZeroShot_outputs/25.ttl
# [INFO] Processing: /kaggle/input/diagram2graph-dataset/diagram2graph/341.png -> /kaggle/working/ZeroShot_outputs/341.ttl
# [INFO] Processing: /kaggle/input/diagram2graph-dataset/diagram2graph/111.png -> /kaggle/working/ZeroShot_outputs/111.ttl
# [INFO] Processing: /kaggle/input/diagram2graph-dataset/diagram2graph/62.png -> /kaggle/working/ZeroShot_outputs/62.ttl
# [INFO] Processing: /kaggle/input/diagram2graph-dataset/diagram2graph/699.png -> /kaggle/working/ZeroShot_outputs/699.ttl
# [INFO] Processing: /kaggle/input/diagram2graph-dataset/diagram2graph/0.png -> /kaggle/working/ZeroShot_outputs/0.ttl
# [INFO] Processing: /kaggle/input/diagram2graph-dataset/diagram2graph/309.png -> /kaggle/working/ZeroShot_outputs/309.ttl
# [INFO] Processing: /kaggle/input/diagram2graph-dataset/diagram2graph/918.png -> /kaggle/working/ZeroShot_outputs/918.ttl
# [INFO] Processing: /kaggle/input/diagram2graph-dataset/diagram2graph/428.png -> /kaggle/working/ZeroShot_outputs/428.ttl
# [INFO] Processing: /kaggle/input/diagram2graph-dataset/diagram2graph/418.png -> /kaggle/working/ZeroShot_outputs/418.ttl
# [INFO] Processing: /kaggle/input/diagram2graph-dataset/diagram2graph/497.png -> /kaggle/working/ZeroShot_outputs/497.ttl
# [DONE] Wrote 219 TTL files to: /kaggle/working/ZeroShot_outputs
# [INFO] Manifest: /kaggle/working/ZeroShot_outputs/manifest.json

# %% [markdown]
# # Zip output

# %%
# !zip -r /kaggle/working/Zeroshot_output.zip /kaggle/working/ZeroShot_outputs
# Out:
#   adding: kaggle/working/ZeroShot_outputs/ (stored 0%)
#   adding: kaggle/working/ZeroShot_outputs/497.ttl (deflated 87%)
#   adding: kaggle/working/ZeroShot_outputs/498.ttl (deflated 82%)
#   adding: kaggle/working/ZeroShot_outputs/276.ttl (deflated 84%)
#   adding: kaggle/working/ZeroShot_outputs/655.ttl (deflated 84%)
#   adding: kaggle/working/ZeroShot_outputs/319.ttl (deflated 83%)
#   adding: kaggle/working/ZeroShot_outputs/921.ttl (deflated 87%)
#   adding: kaggle/working/ZeroShot_outputs/192.ttl (deflated 86%)
#   adding: kaggle/working/ZeroShot_outputs/413.ttl (deflated 82%)
#   adding: kaggle/working/ZeroShot_outputs/706.ttl (deflated 87%)
#   adding: kaggle/working/ZeroShot_outputs/542.ttl (deflated 85%)
#   adding: kaggle/working/ZeroShot_outputs/250.ttl (deflated 88%)
#   adding: kaggle/working/ZeroShot_outputs/263.ttl (deflated 84%)
#   adding: kaggle/working/ZeroShot_outputs/224.ttl (deflated 88%)
#   adding: kaggle/working/ZeroShot_outputs/274.ttl (deflated 84%)
#   adding: kaggle/working/ZeroShot_outputs/14.ttl (deflated 85%)
#   adding: kaggle/working/ZeroShot_outputs/924.ttl (deflated 80%)
#   adding: kaggle/working/ZeroShot_outputs/12.ttl (deflated 87%)
#   adding: kaggle/working/ZeroShot_outputs/66.ttl (deflated 87%)
#   adding: kaggle/working/ZeroShot_outputs/598.ttl (deflated 85%)
#   adding: kaggle/working/ZeroShot_outputs/8.ttl (deflated 82%)
#   adding: kaggle/working/ZeroShot_outputs/915.ttl (deflated 88%)
#   adding: kaggle/working/ZeroShot_outputs/49.ttl (deflated 82%)
#   adding: kaggle/working/ZeroShot_outputs/291.ttl (deflated 87%)
#   adding: kaggle/working/ZeroShot_outputs/823.ttl (deflated 87%)
#   adding: kaggle/working/ZeroShot_outputs/111.ttl (deflated 85%)
#   adding: kaggle/working/ZeroShot_outputs/48.ttl (deflated 87%)
#   adding: kaggle/working/ZeroShot_outputs/81.ttl (deflated 87%)
#   adding: kaggle/working/ZeroShot_outputs/35.ttl (deflated 84%)
#   adding: kaggle/working/ZeroShot_outputs/288.ttl (deflated 88%)
#   adding: kaggle/working/ZeroShot_outputs/100.ttl (deflated 80%)
#   adding: kaggle/working/ZeroShot_outputs/322.ttl (deflated 86%)
#   adding: kaggle/working/ZeroShot_outputs/9.ttl (deflated 86%)
#   adding: kaggle/working/ZeroShot_outputs/684.ttl (deflated 88%)
#   adding: kaggle/working/ZeroShot_outputs/57.ttl (deflated 88%)
#   adding: kaggle/working/ZeroShot_outputs/25.ttl (deflated 85%)
#   adding: kaggle/working/ZeroShot_outputs/428.ttl (deflated 89%)
#   adding: kaggle/working/ZeroShot_outputs/279.ttl (deflated 89%)
#   adding: kaggle/working/ZeroShot_outputs/418.ttl (deflated 85%)
#   adding: kaggle/working/ZeroShot_outputs/937.ttl (deflated 88%)
#   adding: kaggle/working/ZeroShot_outputs/446.ttl (deflated 84%)
#   adding: kaggle/working/ZeroShot_outputs/238.ttl (deflated 89%)
#   adding: kaggle/working/ZeroShot_outputs/728.ttl (deflated 86%)
#   adding: kaggle/working/ZeroShot_outputs/4.ttl (deflated 88%)
#   adding: kaggle/working/ZeroShot_outputs/manifest.json (deflated 96%)
#   adding: kaggle/working/ZeroShot_outputs/358.ttl (deflated 84%)
#   adding: kaggle/working/ZeroShot_outputs/86.ttl (deflated 86%)
#   adding: kaggle/working/ZeroShot_outputs/624.ttl (deflated 90%)
#   adding: kaggle/working/ZeroShot_outputs/193.ttl (deflated 89%)
#   adding: kaggle/working/ZeroShot_outputs/394.ttl (deflated 86%)
#   adding: kaggle/working/ZeroShot_outputs/341.ttl (deflated 84%)
#   adding: kaggle/working/ZeroShot_outputs/692.ttl (deflated 87%)
#   adding: kaggle/working/ZeroShot_outputs/765.ttl (deflated 84%)
#   adding: kaggle/working/ZeroShot_outputs/929.ttl (deflated 87%)
#   adding: kaggle/working/ZeroShot_outputs/634.ttl (deflated 90%)
#   adding: kaggle/working/ZeroShot_outputs/934.ttl (deflated 88%)
#   adding: kaggle/working/ZeroShot_outputs/46.ttl (deflated 85%)
#   adding: kaggle/working/ZeroShot_outputs/310.ttl (deflated 87%)
#   adding: kaggle/working/ZeroShot_outputs/229.ttl (deflated 85%)
#   adding: kaggle/working/ZeroShot_outputs/0.ttl (deflated 85%)
#   adding: kaggle/working/ZeroShot_outputs/605.ttl (deflated 88%)
#   adding: kaggle/working/ZeroShot_outputs/80.ttl (deflated 86%)
#   adding: kaggle/working/ZeroShot_outputs/60.ttl (deflated 83%)
#   adding: kaggle/working/ZeroShot_outputs/23.ttl (deflated 86%)
#   adding: kaggle/working/ZeroShot_outputs/114.ttl (deflated 86%)
#   adding: kaggle/working/ZeroShot_outputs/328.ttl (deflated 87%)
#   adding: kaggle/working/ZeroShot_outputs/576.ttl (deflated 87%)
#   adding: kaggle/working/ZeroShot_outputs/293.ttl (deflated 86%)
#   adding: kaggle/working/ZeroShot_outputs/259.ttl (deflated 87%)
#   adding: kaggle/working/ZeroShot_outputs/254.ttl (deflated 88%)
#   adding: kaggle/working/ZeroShot_outputs/620.ttl (deflated 88%)
#   adding: kaggle/working/ZeroShot_outputs/170.ttl (deflated 87%)
#   adding: kaggle/working/ZeroShot_outputs/147.ttl (deflated 86%)
#   adding: kaggle/working/ZeroShot_outputs/39.ttl (deflated 83%)
#   adding: kaggle/working/ZeroShot_outputs/429.ttl (deflated 87%)
#   adding: kaggle/working/ZeroShot_outputs/800.ttl (deflated 90%)
#   adding: kaggle/working/ZeroShot_outputs/62.ttl (deflated 88%)
#   adding: kaggle/working/ZeroShot_outputs/76.ttl (deflated 87%)
#   adding: kaggle/working/ZeroShot_outputs/275.ttl (deflated 88%)
#   adding: kaggle/working/ZeroShot_outputs/926.ttl (deflated 83%)
#   adding: kaggle/working/ZeroShot_outputs/556.ttl (deflated 77%)
#   adding: kaggle/working/ZeroShot_outputs/2.ttl (deflated 86%)
#   adding: kaggle/working/ZeroShot_outputs/525.ttl (deflated 83%)
#   adding: kaggle/working/ZeroShot_outputs/911.ttl (deflated 85%)
#   adding: kaggle/working/ZeroShot_outputs/286.ttl (deflated 84%)
#   adding: kaggle/working/ZeroShot_outputs/412.ttl (deflated 86%)
#   adding: kaggle/working/ZeroShot_outputs/891.ttl (deflated 86%)
#   adding: kaggle/working/ZeroShot_outputs/663.ttl (deflated 84%)
#   adding: kaggle/working/ZeroShot_outputs/562.ttl (deflated 88%)
#   adding: kaggle/working/ZeroShot_outputs/347.ttl (deflated 84%)
#   adding: kaggle/working/ZeroShot_outputs/204.ttl (deflated 89%)
#   adding: kaggle/working/ZeroShot_outputs/380.ttl (deflated 84%)
#   adding: kaggle/working/ZeroShot_outputs/309.ttl (deflated 87%)
#   adding: kaggle/working/ZeroShot_outputs/44.ttl (deflated 87%)
#   adding: kaggle/working/ZeroShot_outputs/701.ttl (deflated 81%)
#   adding: kaggle/working/ZeroShot_outputs/735.ttl (deflated 80%)
#   adding: kaggle/working/ZeroShot_outputs/55.ttl (deflated 80%)
#   adding: kaggle/working/ZeroShot_outputs/222.ttl (deflated 84%)
#   adding: kaggle/working/ZeroShot_outputs/908.ttl (deflated 87%)
#   adding: kaggle/working/ZeroShot_outputs/284.ttl (deflated 86%)
#   adding: kaggle/working/ZeroShot_outputs/905.ttl (deflated 85%)
#   adding: kaggle/working/ZeroShot_outputs/47.ttl (deflated 81%)
#   adding: kaggle/working/ZeroShot_outputs/935.ttl (deflated 86%)
#   adding: kaggle/working/ZeroShot_outputs/68.ttl (deflated 88%)
#   adding: kaggle/working/ZeroShot_outputs/918.ttl (deflated 87%)
#   adding: kaggle/working/ZeroShot_outputs/10.ttl (deflated 80%)
#   adding: kaggle/working/ZeroShot_outputs/607.ttl (deflated 86%)
#   adding: kaggle/working/ZeroShot_outputs/94.ttl (deflated 86%)
#   adding: kaggle/working/ZeroShot_outputs/113.ttl (deflated 87%)
#   adding: kaggle/working/ZeroShot_outputs/433.ttl (deflated 87%)
#   adding: kaggle/working/ZeroShot_outputs/699.ttl (deflated 87%)
#   adding: kaggle/working/ZeroShot_outputs/99.ttl (deflated 89%)
#   adding: kaggle/working/ZeroShot_outputs/273.ttl (deflated 87%)
#   adding: kaggle/working/ZeroShot_outputs/295.ttl (deflated 84%)
#   adding: kaggle/working/ZeroShot_outputs/31.ttl (deflated 86%)
#   adding: kaggle/working/ZeroShot_outputs/591.ttl (deflated 85%)
#   adding: kaggle/working/ZeroShot_outputs/521.ttl (deflated 87%)
#   adding: kaggle/working/ZeroShot_outputs/134.ttl (deflated 86%)
#   adding: kaggle/working/ZeroShot_outputs/589.ttl (deflated 84%)
#   adding: kaggle/working/ZeroShot_outputs/457.ttl (deflated 88%)
#   adding: kaggle/working/ZeroShot_outputs/351.ttl (deflated 84%)
#   adding: kaggle/working/ZeroShot_outputs/233.ttl (deflated 87%)
#   adding: kaggle/working/ZeroShot_outputs/315.ttl (deflated 83%)
#   adding: kaggle/working/ZeroShot_outputs/444.ttl (deflated 84%)
#   adding: kaggle/working/ZeroShot_outputs/709.ttl (deflated 88%)
#   adding: kaggle/working/ZeroShot_outputs/174.ttl (deflated 86%)
#   adding: kaggle/working/ZeroShot_outputs/64.ttl (deflated 87%)
#   adding: kaggle/working/ZeroShot_outputs/432.ttl (deflated 88%)
#   adding: kaggle/working/ZeroShot_outputs/148.ttl (deflated 82%)
#   adding: kaggle/working/ZeroShot_outputs/163.ttl (deflated 87%)
#   adding: kaggle/working/ZeroShot_outputs/548.ttl (deflated 86%)
#   adding: kaggle/working/ZeroShot_outputs/67.ttl (deflated 89%)
#   adding: kaggle/working/ZeroShot_outputs/239.ttl (deflated 84%)
#   adding: kaggle/working/ZeroShot_outputs/580.ttl (deflated 87%)
#   adding: kaggle/working/ZeroShot_outputs/818.ttl (deflated 83%)
#   adding: kaggle/working/ZeroShot_outputs/904.ttl (deflated 88%)
#   adding: kaggle/working/ZeroShot_outputs/907.ttl (deflated 87%)
#   adding: kaggle/working/ZeroShot_outputs/922.ttl (deflated 86%)
#   adding: kaggle/working/ZeroShot_outputs/28.ttl (deflated 89%)
#   adding: kaggle/working/ZeroShot_outputs/17.ttl (deflated 83%)
#   adding: kaggle/working/ZeroShot_outputs/938.ttl (deflated 81%)
#   adding: kaggle/working/ZeroShot_outputs/125.ttl (deflated 86%)
#   adding: kaggle/working/ZeroShot_outputs/331.ttl (deflated 83%)
#   adding: kaggle/working/ZeroShot_outputs/262.ttl (deflated 88%)
#   adding: kaggle/working/ZeroShot_outputs/361.ttl (deflated 84%)
#   adding: kaggle/working/ZeroShot_outputs/34.ttl (deflated 87%)
#   adding: kaggle/working/ZeroShot_outputs/71.ttl (deflated 89%)
#   adding: kaggle/working/ZeroShot_outputs/37.ttl (deflated 88%)
#   adding: kaggle/working/ZeroShot_outputs/914.ttl (deflated 87%)
#   adding: kaggle/working/ZeroShot_outputs/470.ttl (deflated 85%)
#   adding: kaggle/working/ZeroShot_outputs/90.ttl (deflated 87%)
#   adding: kaggle/working/ZeroShot_outputs/52.ttl (deflated 86%)
#   adding: kaggle/working/ZeroShot_outputs/652.ttl (deflated 88%)
#   adding: kaggle/working/ZeroShot_outputs/916.ttl (deflated 82%)
#   adding: kaggle/working/ZeroShot_outputs/931.ttl (deflated 80%)
#   adding: kaggle/working/ZeroShot_outputs/848.ttl (deflated 87%)
#   adding: kaggle/working/ZeroShot_outputs/87.ttl (deflated 88%)
#   adding: kaggle/working/ZeroShot_outputs/731.ttl (deflated 87%)
#   adding: kaggle/working/ZeroShot_outputs/18.ttl (deflated 85%)
#   adding: kaggle/working/ZeroShot_outputs/116.ttl (deflated 88%)
#   adding: kaggle/working/ZeroShot_outputs/75.ttl (deflated 90%)
#   adding: kaggle/working/ZeroShot_outputs/761.ttl (deflated 88%)
#   adding: kaggle/working/ZeroShot_outputs/520.ttl (deflated 87%)
#   adding: kaggle/working/ZeroShot_outputs/335.ttl (deflated 84%)
#   adding: kaggle/working/ZeroShot_outputs/563.ttl (deflated 87%)
#   adding: kaggle/working/ZeroShot_outputs/13.ttl (deflated 84%)
#   adding: kaggle/working/ZeroShot_outputs/919.ttl (deflated 88%)
#   adding: kaggle/working/ZeroShot_outputs/65.ttl (deflated 84%)
#   adding: kaggle/working/ZeroShot_outputs/6.ttl (deflated 89%)
#   adding: kaggle/working/ZeroShot_outputs/38.ttl (deflated 89%)
#   adding: kaggle/working/ZeroShot_outputs/33.ttl (deflated 85%)
#   adding: kaggle/working/ZeroShot_outputs/900.ttl (deflated 85%)
#   adding: kaggle/working/ZeroShot_outputs/212.ttl (deflated 86%)
#   adding: kaggle/working/ZeroShot_outputs/902.ttl (deflated 88%)
#   adding: kaggle/working/ZeroShot_outputs/416.ttl (deflated 85%)
#   adding: kaggle/working/ZeroShot_outputs/120.ttl (deflated 86%)
#   adding: kaggle/working/ZeroShot_outputs/153.ttl (deflated 86%)
#   adding: kaggle/working/ZeroShot_outputs/119.ttl (deflated 84%)
#   adding: kaggle/working/ZeroShot_outputs/93.ttl (deflated 84%)
#   adding: kaggle/working/ZeroShot_outputs/258.ttl (deflated 82%)
#   adding: kaggle/working/ZeroShot_outputs/171.ttl (deflated 87%)
#   adding: kaggle/working/ZeroShot_outputs/107.ttl (deflated 85%)
#   adding: kaggle/working/ZeroShot_outputs/166.ttl (deflated 85%)
#   adding: kaggle/working/ZeroShot_outputs/78.ttl (deflated 86%)
#   adding: kaggle/working/ZeroShot_outputs/121.ttl (deflated 86%)
#   adding: kaggle/working/ZeroShot_outputs/29.ttl (deflated 86%)
#   adding: kaggle/working/ZeroShot_outputs/920.ttl (deflated 88%)
#   adding: kaggle/working/ZeroShot_outputs/936.ttl (deflated 87%)
#   adding: kaggle/working/ZeroShot_outputs/332.ttl (deflated 83%)
#   adding: kaggle/working/ZeroShot_outputs/630.ttl (deflated 87%)
#   adding: kaggle/working/ZeroShot_outputs/45.ttl (deflated 85%)
#   adding: kaggle/working/ZeroShot_outputs/930.ttl (deflated 86%)
#   adding: kaggle/working/ZeroShot_outputs/411.ttl (deflated 86%)
#   adding: kaggle/working/ZeroShot_outputs/40.ttl (deflated 87%)
#   adding: kaggle/working/ZeroShot_outputs/30.ttl (deflated 86%)
#   adding: kaggle/working/ZeroShot_outputs/203.ttl (deflated 89%)
#   adding: kaggle/working/ZeroShot_outputs/888.ttl (deflated 87%)
#   adding: kaggle/working/ZeroShot_outputs/627.ttl (deflated 86%)
#   adding: kaggle/working/ZeroShot_outputs/41.ttl (deflated 84%)
#   adding: kaggle/working/ZeroShot_outputs/940.ttl (deflated 89%)
#   adding: kaggle/working/ZeroShot_outputs/3.ttl (deflated 88%)
#   adding: kaggle/working/ZeroShot_outputs/11.ttl (deflated 83%)
#   adding: kaggle/working/ZeroShot_outputs/268.ttl (deflated 84%)
#   adding: kaggle/working/ZeroShot_outputs/215.ttl (deflated 86%)
#   adding: kaggle/working/ZeroShot_outputs/118.ttl (deflated 85%)
#   adding: kaggle/working/ZeroShot_outputs/252.ttl (deflated 87%)
#   adding: kaggle/working/ZeroShot_outputs/356.ttl (deflated 85%)
#   adding: kaggle/working/ZeroShot_outputs/401.ttl (deflated 86%)
#   adding: kaggle/working/ZeroShot_outputs/577.ttl (deflated 85%)
#   adding: kaggle/working/ZeroShot_outputs/753.ttl (deflated 84%)
#   adding: kaggle/working/ZeroShot_outputs/198.ttl (deflated 79%)
#   adding: kaggle/working/ZeroShot_outputs/63.ttl (deflated 87%)
#   adding: kaggle/working/ZeroShot_outputs/345.ttl (deflated 86%)
#   adding: kaggle/working/ZeroShot_outputs/672.ttl (deflated 86%)
#   adding: kaggle/working/ZeroShot_outputs/910.ttl (deflated 88%)
#   adding: kaggle/working/ZeroShot_outputs/244.ttl (deflated 88%)
#   adding: kaggle/working/ZeroShot_outputs/813.ttl (deflated 85%)
#   adding: kaggle/working/ZeroShot_outputs/278.ttl (deflated 87%)
#   adding: kaggle/working/ZeroShot_outputs/109.ttl (deflated 86%)
#   adding: kaggle/working/ZeroShot_outputs/933.ttl (deflated 85%)
#   adding: kaggle/working/ZeroShot_outputs/334.ttl (deflated 83%)

# %% [markdown]
# # OneShot Prompting

# %%
import base64
import json
import os
import time
from pathlib import Path
from typing import Optional
import requests
from PIL import Image

# =========================
# 1) CONFIGURATION
# =========================
# Prefer loading your key from an environment variable (more secure).
# export GEMINI_API_KEY="..."
def load_api_key(name, fallback_names=()):
    import os
    import sys
    from pathlib import Path

    candidates = (name, *fallback_names)
    repo_root = next(
        (
            candidate
            for candidate in (Path.cwd(), *Path.cwd().parents)
            if (candidate / "common" / "__init__.py").exists()
        ),
        None,
    )

    get_api_key = None
    if repo_root is not None:
        if str(repo_root) not in sys.path:
            sys.path.insert(0, str(repo_root))
        try:
            from common import get_api_key as shared_get_api_key
        except ImportError:
            pass
        else:
            get_api_key = shared_get_api_key

    if get_api_key is not None:
        for candidate in candidates:
            try:
                return get_api_key(candidate)
            except KeyError:
                pass

    for candidate in candidates:
        value = os.getenv(candidate, "").strip()
        if value:
            return value

    joined = ", ".join(candidates)
    raise RuntimeError(
        f"Missing API key. Set one of [{joined}] in the environment"
        " or the top-level config file."
    )

GEMINI_API_KEY = load_api_key("GEMINI_API_KEY")

MODEL = "gemini-2.5-flash"
ENDPOINT = f"https://generativelanguage.googleapis.com/v1beta/models/{MODEL}:generateContent?key={GEMINI_API_KEY}"

# Input images directory (recursively scanned)
DATASET_DIR = "/kaggle/input/diagram2graph-dataset/diagram2graph"  # <--- change this
# Output directory for per-image TTL files
OUTPUT_DIR = "/kaggle/working/ttl_Onshot_outputs3"  # <--- change this
# Optional: also write a small manifest JSON with image->ttl mapping
WRITE_MANIFEST = True
MANIFEST_PATH = os.path.join(OUTPUT_DIR, "manifest.json")

VALID_IMAGE_EXTS = {".png", ".jpg", ".jpeg", ".bmp", ".webp", ".tif", ".tiff"}

# =========================
# 2) PROMPT (one-shot)
# =========================
PROMPT_TEXT = r"""

System
You are a diagram-to-graph extractor. Given a flowchart/diagram image, output ONLY valid Turtle using the diagram2graph (d2g) vocabulary.

Mandatory Instructions (follow exactly)
1) Prefixes (only these two)
@prefix d2g:  <http://example.org/diagram2graph#> .
@prefix rdfs: <http://www.w3.org/2000/01/rdf-schema#> .

2) Identifiers (IRIs)
- Fixed patterns:
  Nodes: <http://example.org/diagram/diagram/node/{N}>
  Edges: <http://example.org/diagram/diagram/edge/{E}>
- Node numbering: visual reading order (top→bottom, left→right).
- Edge IDs (strict rule): build each edge IRI as ST, where S is the source node ID and T is the target node ID.
  Example: the edge between node/1 and node/2 MUST be <http://example.org/diagram/diagram/edge/12>

3) Nodes (create one node per readable shape)
For each shape:
<…/node/N> a d2g:Node, d2g:{Start|Process|Decision|Delay|Terminator} ;
    rdfs:label "exact text from the shape" ;
    d2g:shape d2g:{TartEvent|TaK|Gateway|Delay|EndEvent} .
Required shape mapping (use these exact dataset tokens—even if they look misspelled):
- Start/Begin (rounded oval) → d2g:TartEvent
- End/Stop   (rounded oval) → d2g:EndEvent
- Rectangle  (process)      → d2g:TaK
- Diamond    (decision)     → d2g:Gateway
- Delay      (delay symbol) → d2g:Delay

4) Edges (create a dedicated Edge resource per arrow)
For each arrow:
<…/edge/ST> a d2g:Edge, d2g:{Solid|Dashed} ;
    d2g:source <…/node/S> ;
    d2g:target <…/node/T> ;
    d2g:relationshipType d2g:{Follows|Branches} ;
    [optional] d2g:relationshipValue "label on the arrow (e.g., Yes/No)" .
Rules:
- Outgoing arrows from a Decision node must use relationshipType = d2g:Branches, and include relationshipValue if text exists (Yes/No/etc.).
- All other arrows use relationshipType = d2g:Follows.
- Set line style precisely: d2g:Solid for solid lines; d2g:Dashed for dotted/dashed lines.

5) Convenience node-to-node triples (also required)
- For Follows:  <…/node/S> d2g:follows  <…/node/T> .
- For Branches: <…/node/S> d2g:branches <…/node/T> .

6) Output rules
- Output Turtle only; no explanations or extra text.
- Group by subject; one triple per line; end every line with a period.
- Every edge’s source/target must reference existing node IRIs.
- Do NOT use any prefixes or vocabularies other than d2g and rdfs.
- Write class and shape tokens EXACTLY as specified above (no spelling changes).

One-shot Example (complete example obeying edge-ID ST rule and exact shape tokens)

@prefix d2g:  <http://example.org/diagram2graph#> .
@prefix rdfs: <http://www.w3.org/2000/01/rdf-schema#> .

<http://example.org/diagram/diagram/node/1> a d2g:Start, d2g:Node ;
    rdfs:label "Start" ;
    d2g:shape d2g:TartEvent .

<http://example.org/diagram/diagram/node/2> a d2g:Process, d2g:Node ;
    rdfs:label "Initialize" ;
    d2g:shape d2g:TaK .

<http://example.org/diagram/diagram/node/3> a d2g:Decision, d2g:Node ;
    rdfs:label "Decision" ;
    d2g:shape d2g:Gateway .

<http://example.org/diagram/diagram/node/4> a d2g:Delay, d2g:Node ;
    rdfs:label "Delay" ;
    d2g:shape d2g:Delay .

<http://example.org/diagram/diagram/node/5> a d2g:Process, d2g:Node ;
    rdfs:label "Process" ;
    d2g:shape d2g:TaK .

<http://example.org/diagram/diagram/node/6> a d2g:Process, d2g:Node ;
    rdfs:label "Print result" ;
    d2g:shape d2g:TaK .

<http://example.org/diagram/diagram/node/7> a d2g:Terminator, d2g:Node ;
    rdfs:label "End" ;
    d2g:shape d2g:EndEvent .

<http://example.org/diagram/diagram/edge/12> a d2g:Edge, d2g:Solid ;
    d2g:source <http://example.org/diagram/diagram/node/1> ;
    d2g:target <http://example.org/diagram/diagram/node/2> ;
    d2g:relationshipType d2g:Follows .

<http://example.org/diagram/diagram/edge/23> a d2g:Edge, d2g:Solid ;
    d2g:source <http://example.org/diagram/diagram/node/2> ;
    d2g:target <http://example.org/diagram/diagram/node/3> ;
    d2g:relationshipType d2g:Follows .

<http://example.org/diagram/diagram/edge/36> a d2g:Edge, d2g:Solid ;
    d2g:source <http://example.org/diagram/diagram/node/3> ;
    d2g:target <http://example.org/diagram/diagram/node/6> ;
    d2g:relationshipType d2g:Branches ;
    d2g:relationshipValue "Yes" .

<http://example.org/diagram/diagram/edge/34> a d2g:Edge, d2g:Dashed ;
    d2g:source <http://example.org/diagram/diagram/node/3> ;
    d2g:target <http://example.org/diagram/diagram/node/5> ;
    d2g:relationshipType d2g:Branches ;
    d2g:relationshipValue "No" .

<http://example.org/diagram/diagram/edge/45> a d2g:Edge, d2g:Dashed ;
    d2g:source <http://example.org/diagram/diagram/node/5> ;
    d2g:target <http://example.org/diagram/diagram/node/4> ;
    d2g:relationshipType d2g:Follows .

<http://example.org/diagram/diagram/edge/52> a d2g:Edge, d2g:Dashed ;
    d2g:source <http://example.org/diagram/diagram/node/4> ;
    d2g:target <http://example.org/diagram/diagram/node/2> ;
    d2g:relationshipType d2g:Follows .

<http://example.org/diagram/diagram/edge/67> a d2g:Edge, d2g:Solid ;
    d2g:source <http://example.org/diagram/diagram/node/6> ;
    d2g:target <http://example.org/diagram/diagram/node/7> ;
    d2g:relationshipType d2g:Follows .

<http://example.org/diagram/diagram/node/1> d2g:follows <http://example.org/diagram/diagram/node/2> .
<http://example.org/diagram/diagram/node/2> d2g:follows <http://example.org/diagram/diagram/node/3> .
<http://example.org/diagram/diagram/node/3> d2g:branches <http://example.org/diagram/diagram/node/6> .
<http://example.org/diagram/diagram/node/3> d2g:branches <http://example.org/diagram/diagram/node/5> .
<http://example.org/diagram/diagram/node/5> d2g:follows <http://example.org/diagram/diagram/node/4> .
<http://example.org/diagram/diagram/node/4> d2g:follows <http://example.org/diagram/diagram/node/2> .
<http://example.org/diagram/diagram/node/6> d2g:follows <http://example.org/diagram/diagram/node/7> .

"""

# =========================
# 3) HELPERS
# =========================
def get_mime_type(path: str) -> str:
    ext = Path(path).suffix.lower()
    if ext in {".jpg", ".jpeg"}:
        return "image/jpeg"
    if ext == ".png":
        return "image/png"
    if ext in {".tif", ".tiff"}:
        return "image/tiff"
    if ext == ".webp":
        return "image/webp"
    if ext == ".bmp":
        return "image/bmp"
    return "image/jpeg"

def encode_image_to_base64(image_path: str) -> Optional[str]:
    try:
        # Ensure the image is readable; PIL open also validates file integrity
        with Image.open(image_path) as _:
            pass
        data = Path(image_path).read_bytes()
        return base64.b64encode(data).decode("utf-8")
    except FileNotFoundError:
        print(f"[WARN] File not found: {image_path}")
        return None
    except Exception as e:
        print(f"[WARN] Failed to read {image_path}: {e}")
        return None

def build_request(image_b64: str, mime_type: str, prompt: str) -> dict:
    return {
        "contents": [
            {
                "role": "user",
                "parts": [
                    {"inlineData": {"mimeType": mime_type, "data": image_b64}},
                    {"text": prompt},
                ],
            }
        ],
        "generationConfig": {
            "temperature": 0.1,
            "topP": 0.9,
            "maxOutputTokens": 8192,
        },
    }

def _strip_code_fences(text: str) -> str:
    """
    Removes ```turtle ... ``` or ``` ... ``` fences if present.
    """
    t = text.strip()
    if t.startswith("```"):
        first_newline = t.find("\n")
        if first_newline != -1 and t[:first_newline].startswith("```"):
            t = t[first_newline + 1 :]
        if t.endswith("```"):
            t = t[:-3].rstrip()
    return t.strip()

def call_gemini(payload: dict, max_retries: int = 4) -> Optional[str]:
    """
    Calls the Gemini API with basic retry/backoff on 429/5xx.
    Returns clean Turtle (TTL) text, or None.
    """
    headers = {"Content-Type": "application/json"}
    backoff = 2.0
    for attempt in range(max_retries):
        try:
            resp = requests.post(ENDPOINT, headers=headers, data=json.dumps(payload), timeout=120)
            if resp.status_code >= 500 or resp.status_code == 429:
                print(f"[INFO] Retryable HTTP {resp.status_code}; attempt {attempt+1}/{max_retries}")
                time.sleep(backoff)
                backoff *= 1.8
                continue
            resp.raise_for_status()
            data = resp.json()
            if "candidates" in data and data["candidates"]:
                raw = data["candidates"][0]["content"]["parts"][0]["text"]
                return _strip_code_fences(raw)
            return None
        except requests.exceptions.RequestException as e:
            print(f"[WARN] Request error: {e}; attempt {attempt+1}/{max_retries}")
            time.sleep(backoff)
            backoff *= 1.8
    return None

def ensure_dir(path: str):
    Path(path).mkdir(parents=True, exist_ok=True)

# =========================
# 4) MAIN: per-image .ttl files
# =========================
def main():
    ensure_dir(OUTPUT_DIR)

    manifest = []  # optional record of what we wrote

    for root, _, files in os.walk(DATASET_DIR):
        for fname in files:
            ext = Path(fname).suffix.lower()
            if ext not in VALID_IMAGE_EXTS:
                continue

            img_path = os.path.join(root, fname)
            stem = Path(fname).stem  # "1.png" -> "1"
            ttl_path = os.path.join(OUTPUT_DIR, f"{stem}.ttl")

            print(f"[INFO] Processing: {img_path} -> {ttl_path}")

            image_b64 = encode_image_to_base64(img_path)
            if not image_b64:
                print(f"[SKIP] Could not encode {img_path}")
                continue

            mime = get_mime_type(img_path)
            payload = build_request(image_b64, mime, PROMPT_TEXT)
            ttl_text = call_gemini(payload)

            if not ttl_text:
                print(f"[WARN] No TTL returned for {img_path}")
                continue

            # Write the TTL file
            with open(ttl_path, "w", encoding="utf-8") as f:
                f.write(ttl_text if ttl_text.endswith("\n") else ttl_text + "\n")

            manifest.append({"source_image": img_path, "ttl_file": ttl_path})

    if WRITE_MANIFEST:
        ensure_dir(OUTPUT_DIR)
        with open(MANIFEST_PATH, "w", encoding="utf-8") as mf:
            json.dump({"items": manifest}, mf, indent=2, ensure_ascii=False)

    print(f"[DONE] Wrote {len(manifest)} TTL files to: {OUTPUT_DIR}")
    if WRITE_MANIFEST:
        print(f"[INFO] Manifest: {MANIFEST_PATH}")

if __name__ == "__main__":
    main()
# Out:
# [INFO] Processing: /kaggle/input/diagram2graph-dataset/diagram2graph/709.png -> /kaggle/working/ttl_Onshot_outputs3/709.ttl
# [INFO] Processing: /kaggle/input/diagram2graph-dataset/diagram2graph/94.png -> /kaggle/working/ttl_Onshot_outputs3/94.ttl
# [INFO] Processing: /kaggle/input/diagram2graph-dataset/diagram2graph/48.png -> /kaggle/working/ttl_Onshot_outputs3/48.ttl
# [INFO] Processing: /kaggle/input/diagram2graph-dataset/diagram2graph/761.png -> /kaggle/working/ttl_Onshot_outputs3/761.ttl
# [INFO] Processing: /kaggle/input/diagram2graph-dataset/diagram2graph/655.png -> /kaggle/working/ttl_Onshot_outputs3/655.ttl
# [INFO] Processing: /kaggle/input/diagram2graph-dataset/diagram2graph/238.png -> /kaggle/working/ttl_Onshot_outputs3/238.ttl
# [INFO] Processing: /kaggle/input/diagram2graph-dataset/diagram2graph/222.png -> /kaggle/working/ttl_Onshot_outputs3/222.ttl
# [INFO] Processing: /kaggle/input/diagram2graph-dataset/diagram2graph/278.png -> /kaggle/working/ttl_Onshot_outputs3/278.ttl
# [INFO] Processing: /kaggle/input/diagram2graph-dataset/diagram2graph/37.png -> /kaggle/working/ttl_Onshot_outputs3/37.ttl
# [INFO] Processing: /kaggle/input/diagram2graph-dataset/diagram2graph/148.png -> /kaggle/working/ttl_Onshot_outputs3/148.ttl
# [INFO] Processing: /kaggle/input/diagram2graph-dataset/diagram2graph/35.png -> /kaggle/working/ttl_Onshot_outputs3/35.ttl
# [INFO] Processing: /kaggle/input/diagram2graph-dataset/diagram2graph/334.png -> /kaggle/working/ttl_Onshot_outputs3/334.ttl
# [INFO] Processing: /kaggle/input/diagram2graph-dataset/diagram2graph/940.png -> /kaggle/working/ttl_Onshot_outputs3/940.ttl
# [INFO] Processing: /kaggle/input/diagram2graph-dataset/diagram2graph/634.png -> /kaggle/working/ttl_Onshot_outputs3/634.ttl
# [INFO] Processing: /kaggle/input/diagram2graph-dataset/diagram2graph/933.png -> /kaggle/working/ttl_Onshot_outputs3/933.ttl
# [INFO] Processing: /kaggle/input/diagram2graph-dataset/diagram2graph/542.png -> /kaggle/working/ttl_Onshot_outputs3/542.ttl
# [INFO] Processing: /kaggle/input/diagram2graph-dataset/diagram2graph/315.png -> /kaggle/working/ttl_Onshot_outputs3/315.ttl
# [INFO] Processing: /kaggle/input/diagram2graph-dataset/diagram2graph/153.png -> /kaggle/working/ttl_Onshot_outputs3/153.ttl
# [INFO] Processing: /kaggle/input/diagram2graph-dataset/diagram2graph/562.png -> /kaggle/working/ttl_Onshot_outputs3/562.ttl
# [INFO] Processing: /kaggle/input/diagram2graph-dataset/diagram2graph/204.png -> /kaggle/working/ttl_Onshot_outputs3/204.ttl
# [INFO] Processing: /kaggle/input/diagram2graph-dataset/diagram2graph/75.png -> /kaggle/working/ttl_Onshot_outputs3/75.ttl
# [INFO] Processing: /kaggle/input/diagram2graph-dataset/diagram2graph/521.png -> /kaggle/working/ttl_Onshot_outputs3/521.ttl
# [INFO] Processing: /kaggle/input/diagram2graph-dataset/diagram2graph/11.png -> /kaggle/working/ttl_Onshot_outputs3/11.ttl
# [INFO] Processing: /kaggle/input/diagram2graph-dataset/diagram2graph/416.png -> /kaggle/working/ttl_Onshot_outputs3/416.ttl
# [INFO] Processing: /kaggle/input/diagram2graph-dataset/diagram2graph/605.png -> /kaggle/working/ttl_Onshot_outputs3/605.ttl
# [INFO] Processing: /kaggle/input/diagram2graph-dataset/diagram2graph/351.png -> /kaggle/working/ttl_Onshot_outputs3/351.ttl
# [INFO] Processing: /kaggle/input/diagram2graph-dataset/diagram2graph/411.png -> /kaggle/working/ttl_Onshot_outputs3/411.ttl
# [INFO] Processing: /kaggle/input/diagram2graph-dataset/diagram2graph/114.png -> /kaggle/working/ttl_Onshot_outputs3/114.ttl
# [INFO] Processing: /kaggle/input/diagram2graph-dataset/diagram2graph/930.png -> /kaggle/working/ttl_Onshot_outputs3/930.ttl
# [INFO] Processing: /kaggle/input/diagram2graph-dataset/diagram2graph/457.png -> /kaggle/working/ttl_Onshot_outputs3/457.ttl
# [INFO] Processing: /kaggle/input/diagram2graph-dataset/diagram2graph/907.png -> /kaggle/working/ttl_Onshot_outputs3/907.ttl
# [INFO] Processing: /kaggle/input/diagram2graph-dataset/diagram2graph/432.png -> /kaggle/working/ttl_Onshot_outputs3/432.ttl
# [INFO] Processing: /kaggle/input/diagram2graph-dataset/diagram2graph/119.png -> /kaggle/working/ttl_Onshot_outputs3/119.ttl
# [INFO] Processing: /kaggle/input/diagram2graph-dataset/diagram2graph/100.png -> /kaggle/working/ttl_Onshot_outputs3/100.ttl
# [INFO] Processing: /kaggle/input/diagram2graph-dataset/diagram2graph/322.png -> /kaggle/working/ttl_Onshot_outputs3/322.ttl
# [INFO] Processing: /kaggle/input/diagram2graph-dataset/diagram2graph/76.png -> /kaggle/working/ttl_Onshot_outputs3/76.ttl
# [INFO] Processing: /kaggle/input/diagram2graph-dataset/diagram2graph/193.png -> /kaggle/working/ttl_Onshot_outputs3/193.ttl
# [INFO] Processing: /kaggle/input/diagram2graph-dataset/diagram2graph/163.png -> /kaggle/working/ttl_Onshot_outputs3/163.ttl
# [INFO] Processing: /kaggle/input/diagram2graph-dataset/diagram2graph/31.png -> /kaggle/working/ttl_Onshot_outputs3/31.ttl
# [INFO] Processing: /kaggle/input/diagram2graph-dataset/diagram2graph/4.png -> /kaggle/working/ttl_Onshot_outputs3/4.ttl
# [INFO] Processing: /kaggle/input/diagram2graph-dataset/diagram2graph/192.png -> /kaggle/working/ttl_Onshot_outputs3/192.ttl
# [INFO] Processing: /kaggle/input/diagram2graph-dataset/diagram2graph/229.png -> /kaggle/working/ttl_Onshot_outputs3/229.ttl
# [INFO] Processing: /kaggle/input/diagram2graph-dataset/diagram2graph/331.png -> /kaggle/working/ttl_Onshot_outputs3/331.ttl
# [INFO] Processing: /kaggle/input/diagram2graph-dataset/diagram2graph/672.png -> /kaggle/working/ttl_Onshot_outputs3/672.ttl
# [INFO] Processing: /kaggle/input/diagram2graph-dataset/diagram2graph/580.png -> /kaggle/working/ttl_Onshot_outputs3/580.ttl
# [INFO] Processing: /kaggle/input/diagram2graph-dataset/diagram2graph/345.png -> /kaggle/working/ttl_Onshot_outputs3/345.ttl
# [INFO] Processing: /kaggle/input/diagram2graph-dataset/diagram2graph/171.png -> /kaggle/working/ttl_Onshot_outputs3/171.ttl
# [INFO] Processing: /kaggle/input/diagram2graph-dataset/diagram2graph/40.png -> /kaggle/working/ttl_Onshot_outputs3/40.ttl
# [INFO] Processing: /kaggle/input/diagram2graph-dataset/diagram2graph/33.png -> /kaggle/working/ttl_Onshot_outputs3/33.ttl
# [INFO] Processing: /kaggle/input/diagram2graph-dataset/diagram2graph/147.png -> /kaggle/working/ttl_Onshot_outputs3/147.ttl
# [INFO] Processing: /kaggle/input/diagram2graph-dataset/diagram2graph/9.png -> /kaggle/working/ttl_Onshot_outputs3/9.ttl
# [INFO] Processing: /kaggle/input/diagram2graph-dataset/diagram2graph/254.png -> /kaggle/working/ttl_Onshot_outputs3/254.ttl
# [INFO] Processing: /kaggle/input/diagram2graph-dataset/diagram2graph/931.png -> /kaggle/working/ttl_Onshot_outputs3/931.ttl
# [INFO] Processing: /kaggle/input/diagram2graph-dataset/diagram2graph/823.png -> /kaggle/working/ttl_Onshot_outputs3/823.ttl
# [INFO] Processing: /kaggle/input/diagram2graph-dataset/diagram2graph/891.png -> /kaggle/working/ttl_Onshot_outputs3/891.ttl
# [INFO] Processing: /kaggle/input/diagram2graph-dataset/diagram2graph/233.png -> /kaggle/working/ttl_Onshot_outputs3/233.ttl
# [INFO] Processing: /kaggle/input/diagram2graph-dataset/diagram2graph/284.png -> /kaggle/working/ttl_Onshot_outputs3/284.ttl
# [INFO] Processing: /kaggle/input/diagram2graph-dataset/diagram2graph/888.png -> /kaggle/working/ttl_Onshot_outputs3/888.ttl
# [INFO] Processing: /kaggle/input/diagram2graph-dataset/diagram2graph/818.png -> /kaggle/working/ttl_Onshot_outputs3/818.ttl
# [INFO] Processing: /kaggle/input/diagram2graph-dataset/diagram2graph/911.png -> /kaggle/working/ttl_Onshot_outputs3/911.ttl
# [INFO] Processing: /kaggle/input/diagram2graph-dataset/diagram2graph/116.png -> /kaggle/working/ttl_Onshot_outputs3/116.ttl
# [INFO] Processing: /kaggle/input/diagram2graph-dataset/diagram2graph/520.png -> /kaggle/working/ttl_Onshot_outputs3/520.ttl
# [INFO] Processing: /kaggle/input/diagram2graph-dataset/diagram2graph/80.png -> /kaggle/working/ttl_Onshot_outputs3/80.ttl
# [INFO] Processing: /kaggle/input/diagram2graph-dataset/diagram2graph/55.png -> /kaggle/working/ttl_Onshot_outputs3/55.ttl
# [INFO] Processing: /kaggle/input/diagram2graph-dataset/diagram2graph/291.png -> /kaggle/working/ttl_Onshot_outputs3/291.ttl
# [INFO] Processing: /kaggle/input/diagram2graph-dataset/diagram2graph/288.png -> /kaggle/working/ttl_Onshot_outputs3/288.ttl
# [INFO] Processing: /kaggle/input/diagram2graph-dataset/diagram2graph/589.png -> /kaggle/working/ttl_Onshot_outputs3/589.ttl
# [INFO] Processing: /kaggle/input/diagram2graph-dataset/diagram2graph/607.png -> /kaggle/working/ttl_Onshot_outputs3/607.ttl
# [INFO] Processing: /kaggle/input/diagram2graph-dataset/diagram2graph/938.png -> /kaggle/working/ttl_Onshot_outputs3/938.ttl
# [INFO] Processing: /kaggle/input/diagram2graph-dataset/diagram2graph/49.png -> /kaggle/working/ttl_Onshot_outputs3/49.ttl
# [INFO] Processing: /kaggle/input/diagram2graph-dataset/diagram2graph/268.png -> /kaggle/working/ttl_Onshot_outputs3/268.ttl
# [INFO] Processing: /kaggle/input/diagram2graph-dataset/diagram2graph/93.png -> /kaggle/working/ttl_Onshot_outputs3/93.ttl
# [INFO] Processing: /kaggle/input/diagram2graph-dataset/diagram2graph/113.png -> /kaggle/working/ttl_Onshot_outputs3/113.ttl
# [INFO] Processing: /kaggle/input/diagram2graph-dataset/diagram2graph/332.png -> /kaggle/working/ttl_Onshot_outputs3/332.ttl
# [INFO] Processing: /kaggle/input/diagram2graph-dataset/diagram2graph/170.png -> /kaggle/working/ttl_Onshot_outputs3/170.ttl
# [INFO] Processing: /kaggle/input/diagram2graph-dataset/diagram2graph/198.png -> /kaggle/working/ttl_Onshot_outputs3/198.ttl
# [INFO] Processing: /kaggle/input/diagram2graph-dataset/diagram2graph/924.png -> /kaggle/working/ttl_Onshot_outputs3/924.ttl
# [INFO] Processing: /kaggle/input/diagram2graph-dataset/diagram2graph/401.png -> /kaggle/working/ttl_Onshot_outputs3/401.ttl
# [INFO] Processing: /kaggle/input/diagram2graph-dataset/diagram2graph/14.png -> /kaggle/working/ttl_Onshot_outputs3/14.ttl
# [INFO] Processing: /kaggle/input/diagram2graph-dataset/diagram2graph/65.png -> /kaggle/working/ttl_Onshot_outputs3/65.ttl
# [INFO] Processing: /kaggle/input/diagram2graph-dataset/diagram2graph/706.png -> /kaggle/working/ttl_Onshot_outputs3/706.ttl
# [INFO] Processing: /kaggle/input/diagram2graph-dataset/diagram2graph/293.png -> /kaggle/working/ttl_Onshot_outputs3/293.ttl
# [INFO] Processing: /kaggle/input/diagram2graph-dataset/diagram2graph/576.png -> /kaggle/working/ttl_Onshot_outputs3/576.ttl
# [INFO] Processing: /kaggle/input/diagram2graph-dataset/diagram2graph/701.png -> /kaggle/working/ttl_Onshot_outputs3/701.ttl
# [INFO] Processing: /kaggle/input/diagram2graph-dataset/diagram2graph/926.png -> /kaggle/working/ttl_Onshot_outputs3/926.ttl
# [INFO] Processing: /kaggle/input/diagram2graph-dataset/diagram2graph/39.png -> /kaggle/working/ttl_Onshot_outputs3/39.ttl
# [INFO] Processing: /kaggle/input/diagram2graph-dataset/diagram2graph/380.png -> /kaggle/working/ttl_Onshot_outputs3/380.ttl
# [INFO] Processing: /kaggle/input/diagram2graph-dataset/diagram2graph/446.png -> /kaggle/working/ttl_Onshot_outputs3/446.ttl
# [INFO] Processing: /kaggle/input/diagram2graph-dataset/diagram2graph/433.png -> /kaggle/working/ttl_Onshot_outputs3/433.ttl
# [INFO] Processing: /kaggle/input/diagram2graph-dataset/diagram2graph/319.png -> /kaggle/working/ttl_Onshot_outputs3/319.ttl
# [INFO] Processing: /kaggle/input/diagram2graph-dataset/diagram2graph/107.png -> /kaggle/working/ttl_Onshot_outputs3/107.ttl
# [INFO] Processing: /kaggle/input/diagram2graph-dataset/diagram2graph/90.png -> /kaggle/working/ttl_Onshot_outputs3/90.ttl
# [INFO] Processing: /kaggle/input/diagram2graph-dataset/diagram2graph/262.png -> /kaggle/working/ttl_Onshot_outputs3/262.ttl
# [INFO] Processing: /kaggle/input/diagram2graph-dataset/diagram2graph/215.png -> /kaggle/working/ttl_Onshot_outputs3/215.ttl
# [INFO] Processing: /kaggle/input/diagram2graph-dataset/diagram2graph/920.png -> /kaggle/working/ttl_Onshot_outputs3/920.ttl
# [INFO] Processing: /kaggle/input/diagram2graph-dataset/diagram2graph/412.png -> /kaggle/working/ttl_Onshot_outputs3/412.ttl
# [INFO] Processing: /kaggle/input/diagram2graph-dataset/diagram2graph/910.png -> /kaggle/working/ttl_Onshot_outputs3/910.ttl
# [INFO] Processing: /kaggle/input/diagram2graph-dataset/diagram2graph/731.png -> /kaggle/working/ttl_Onshot_outputs3/731.ttl
# [INFO] Processing: /kaggle/input/diagram2graph-dataset/diagram2graph/38.png -> /kaggle/working/ttl_Onshot_outputs3/38.ttl
# [INFO] Processing: /kaggle/input/diagram2graph-dataset/diagram2graph/2.png -> /kaggle/working/ttl_Onshot_outputs3/2.ttl
# [INFO] Processing: /kaggle/input/diagram2graph-dataset/diagram2graph/900.png -> /kaggle/working/ttl_Onshot_outputs3/900.ttl
# [INFO] Processing: /kaggle/input/diagram2graph-dataset/diagram2graph/335.png -> /kaggle/working/ttl_Onshot_outputs3/335.ttl
# [INFO] Processing: /kaggle/input/diagram2graph-dataset/diagram2graph/10.png -> /kaggle/working/ttl_Onshot_outputs3/10.ttl
# [INFO] Processing: /kaggle/input/diagram2graph-dataset/diagram2graph/598.png -> /kaggle/working/ttl_Onshot_outputs3/598.ttl
# [INFO] Processing: /kaggle/input/diagram2graph-dataset/diagram2graph/174.png -> /kaggle/working/ttl_Onshot_outputs3/174.ttl
# [INFO] Processing: /kaggle/input/diagram2graph-dataset/diagram2graph/250.png -> /kaggle/working/ttl_Onshot_outputs3/250.ttl
# [INFO] Processing: /kaggle/input/diagram2graph-dataset/diagram2graph/908.png -> /kaggle/working/ttl_Onshot_outputs3/908.ttl
# [INFO] Processing: /kaggle/input/diagram2graph-dataset/diagram2graph/556.png -> /kaggle/working/ttl_Onshot_outputs3/556.ttl
# [INFO] Processing: /kaggle/input/diagram2graph-dataset/diagram2graph/81.png -> /kaggle/working/ttl_Onshot_outputs3/81.ttl
# [INFO] Processing: /kaggle/input/diagram2graph-dataset/diagram2graph/239.png -> /kaggle/working/ttl_Onshot_outputs3/239.ttl
# [INFO] Processing: /kaggle/input/diagram2graph-dataset/diagram2graph/66.png -> /kaggle/working/ttl_Onshot_outputs3/66.ttl
# [INFO] Processing: /kaggle/input/diagram2graph-dataset/diagram2graph/902.png -> /kaggle/working/ttl_Onshot_outputs3/902.ttl
# [INFO] Processing: /kaggle/input/diagram2graph-dataset/diagram2graph/684.png -> /kaggle/working/ttl_Onshot_outputs3/684.ttl
# [INFO] Processing: /kaggle/input/diagram2graph-dataset/diagram2graph/735.png -> /kaggle/working/ttl_Onshot_outputs3/735.ttl
# [INFO] Processing: /kaggle/input/diagram2graph-dataset/diagram2graph/914.png -> /kaggle/working/ttl_Onshot_outputs3/914.ttl
# [INFO] Processing: /kaggle/input/diagram2graph-dataset/diagram2graph/934.png -> /kaggle/working/ttl_Onshot_outputs3/934.ttl
# [INFO] Processing: /kaggle/input/diagram2graph-dataset/diagram2graph/276.png -> /kaggle/working/ttl_Onshot_outputs3/276.ttl
# [INFO] Processing: /kaggle/input/diagram2graph-dataset/diagram2graph/848.png -> /kaggle/working/ttl_Onshot_outputs3/848.ttl
# [INFO] Processing: /kaggle/input/diagram2graph-dataset/diagram2graph/279.png -> /kaggle/working/ttl_Onshot_outputs3/279.ttl
# [INFO] Processing: /kaggle/input/diagram2graph-dataset/diagram2graph/577.png -> /kaggle/working/ttl_Onshot_outputs3/577.ttl
# [INFO] Processing: /kaggle/input/diagram2graph-dataset/diagram2graph/356.png -> /kaggle/working/ttl_Onshot_outputs3/356.ttl
# [INFO] Processing: /kaggle/input/diagram2graph-dataset/diagram2graph/937.png -> /kaggle/working/ttl_Onshot_outputs3/937.ttl
# [INFO] Processing: /kaggle/input/diagram2graph-dataset/diagram2graph/244.png -> /kaggle/working/ttl_Onshot_outputs3/244.ttl
# [INFO] Processing: /kaggle/input/diagram2graph-dataset/diagram2graph/263.png -> /kaggle/working/ttl_Onshot_outputs3/263.ttl
# [INFO] Processing: /kaggle/input/diagram2graph-dataset/diagram2graph/166.png -> /kaggle/working/ttl_Onshot_outputs3/166.ttl
# [INFO] Processing: /kaggle/input/diagram2graph-dataset/diagram2graph/18.png -> /kaggle/working/ttl_Onshot_outputs3/18.ttl
# [INFO] Processing: /kaggle/input/diagram2graph-dataset/diagram2graph/63.png -> /kaggle/working/ttl_Onshot_outputs3/63.ttl
# [INFO] Processing: /kaggle/input/diagram2graph-dataset/diagram2graph/936.png -> /kaggle/working/ttl_Onshot_outputs3/936.ttl
# [INFO] Processing: /kaggle/input/diagram2graph-dataset/diagram2graph/12.png -> /kaggle/working/ttl_Onshot_outputs3/12.ttl
# [INFO] Processing: /kaggle/input/diagram2graph-dataset/diagram2graph/627.png -> /kaggle/working/ttl_Onshot_outputs3/627.ttl
# [INFO] Processing: /kaggle/input/diagram2graph-dataset/diagram2graph/28.png -> /kaggle/working/ttl_Onshot_outputs3/28.ttl
# [INFO] Processing: /kaggle/input/diagram2graph-dataset/diagram2graph/67.png -> /kaggle/working/ttl_Onshot_outputs3/67.ttl
# [INFO] Processing: /kaggle/input/diagram2graph-dataset/diagram2graph/34.png -> /kaggle/working/ttl_Onshot_outputs3/34.ttl
# [INFO] Processing: /kaggle/input/diagram2graph-dataset/diagram2graph/813.png -> /kaggle/working/ttl_Onshot_outputs3/813.ttl
# [INFO] Processing: /kaggle/input/diagram2graph-dataset/diagram2graph/41.png -> /kaggle/working/ttl_Onshot_outputs3/41.ttl
# [INFO] Processing: /kaggle/input/diagram2graph-dataset/diagram2graph/563.png -> /kaggle/working/ttl_Onshot_outputs3/563.ttl
# [INFO] Processing: /kaggle/input/diagram2graph-dataset/diagram2graph/125.png -> /kaggle/working/ttl_Onshot_outputs3/125.ttl
# [INFO] Processing: /kaggle/input/diagram2graph-dataset/diagram2graph/121.png -> /kaggle/working/ttl_Onshot_outputs3/121.ttl
# [INFO] Processing: /kaggle/input/diagram2graph-dataset/diagram2graph/905.png -> /kaggle/working/ttl_Onshot_outputs3/905.ttl
# [INFO] Processing: /kaggle/input/diagram2graph-dataset/diagram2graph/663.png -> /kaggle/working/ttl_Onshot_outputs3/663.ttl
# [INFO] Processing: /kaggle/input/diagram2graph-dataset/diagram2graph/915.png -> /kaggle/working/ttl_Onshot_outputs3/915.ttl
# [INFO] Processing: /kaggle/input/diagram2graph-dataset/diagram2graph/86.png -> /kaggle/working/ttl_Onshot_outputs3/86.ttl
# [INFO] Processing: /kaggle/input/diagram2graph-dataset/diagram2graph/916.png -> /kaggle/working/ttl_Onshot_outputs3/916.ttl
# [INFO] Processing: /kaggle/input/diagram2graph-dataset/diagram2graph/258.png -> /kaggle/working/ttl_Onshot_outputs3/258.ttl
# [INFO] Processing: /kaggle/input/diagram2graph-dataset/diagram2graph/498.png -> /kaggle/working/ttl_Onshot_outputs3/498.ttl
# [INFO] Processing: /kaggle/input/diagram2graph-dataset/diagram2graph/29.png -> /kaggle/working/ttl_Onshot_outputs3/29.ttl
# [INFO] Processing: /kaggle/input/diagram2graph-dataset/diagram2graph/109.png -> /kaggle/working/ttl_Onshot_outputs3/109.ttl
# [INFO] Processing: /kaggle/input/diagram2graph-dataset/diagram2graph/224.png -> /kaggle/working/ttl_Onshot_outputs3/224.ttl
# [INFO] Processing: /kaggle/input/diagram2graph-dataset/diagram2graph/361.png -> /kaggle/working/ttl_Onshot_outputs3/361.ttl
# [INFO] Processing: /kaggle/input/diagram2graph-dataset/diagram2graph/753.png -> /kaggle/working/ttl_Onshot_outputs3/753.ttl
# [INFO] Processing: /kaggle/input/diagram2graph-dataset/diagram2graph/71.png -> /kaggle/working/ttl_Onshot_outputs3/71.ttl
# [INFO] Processing: /kaggle/input/diagram2graph-dataset/diagram2graph/525.png -> /kaggle/working/ttl_Onshot_outputs3/525.ttl
# [INFO] Processing: /kaggle/input/diagram2graph-dataset/diagram2graph/120.png -> /kaggle/working/ttl_Onshot_outputs3/120.ttl
# [INFO] Processing: /kaggle/input/diagram2graph-dataset/diagram2graph/935.png -> /kaggle/working/ttl_Onshot_outputs3/935.ttl
# [INFO] Processing: /kaggle/input/diagram2graph-dataset/diagram2graph/630.png -> /kaggle/working/ttl_Onshot_outputs3/630.ttl
# [INFO] Processing: /kaggle/input/diagram2graph-dataset/diagram2graph/310.png -> /kaggle/working/ttl_Onshot_outputs3/310.ttl
# [INFO] Processing: /kaggle/input/diagram2graph-dataset/diagram2graph/118.png -> /kaggle/working/ttl_Onshot_outputs3/118.ttl
# [INFO] Processing: /kaggle/input/diagram2graph-dataset/diagram2graph/17.png -> /kaggle/working/ttl_Onshot_outputs3/17.ttl
# [INFO] Processing: /kaggle/input/diagram2graph-dataset/diagram2graph/620.png -> /kaggle/working/ttl_Onshot_outputs3/620.ttl
# [INFO] Processing: /kaggle/input/diagram2graph-dataset/diagram2graph/904.png -> /kaggle/working/ttl_Onshot_outputs3/904.ttl
# [INFO] Processing: /kaggle/input/diagram2graph-dataset/diagram2graph/52.png -> /kaggle/working/ttl_Onshot_outputs3/52.ttl
# [INFO] Processing: /kaggle/input/diagram2graph-dataset/diagram2graph/3.png -> /kaggle/working/ttl_Onshot_outputs3/3.ttl
# [INFO] Processing: /kaggle/input/diagram2graph-dataset/diagram2graph/64.png -> /kaggle/working/ttl_Onshot_outputs3/64.ttl
# [INFO] Processing: /kaggle/input/diagram2graph-dataset/diagram2graph/347.png -> /kaggle/working/ttl_Onshot_outputs3/347.ttl
# [INFO] Processing: /kaggle/input/diagram2graph-dataset/diagram2graph/800.png -> /kaggle/working/ttl_Onshot_outputs3/800.ttl
# [INFO] Processing: /kaggle/input/diagram2graph-dataset/diagram2graph/328.png -> /kaggle/working/ttl_Onshot_outputs3/328.ttl
# [INFO] Processing: /kaggle/input/diagram2graph-dataset/diagram2graph/203.png -> /kaggle/working/ttl_Onshot_outputs3/203.ttl
# [INFO] Processing: /kaggle/input/diagram2graph-dataset/diagram2graph/8.png -> /kaggle/working/ttl_Onshot_outputs3/8.ttl
# [INFO] Processing: /kaggle/input/diagram2graph-dataset/diagram2graph/45.png -> /kaggle/working/ttl_Onshot_outputs3/45.ttl
# [INFO] Processing: /kaggle/input/diagram2graph-dataset/diagram2graph/548.png -> /kaggle/working/ttl_Onshot_outputs3/548.ttl
# [INFO] Processing: /kaggle/input/diagram2graph-dataset/diagram2graph/444.png -> /kaggle/working/ttl_Onshot_outputs3/444.ttl
# [INFO] Processing: /kaggle/input/diagram2graph-dataset/diagram2graph/922.png -> /kaggle/working/ttl_Onshot_outputs3/922.ttl
# [INFO] Processing: /kaggle/input/diagram2graph-dataset/diagram2graph/624.png -> /kaggle/working/ttl_Onshot_outputs3/624.ttl
# [INFO] Processing: /kaggle/input/diagram2graph-dataset/diagram2graph/274.png -> /kaggle/working/ttl_Onshot_outputs3/274.ttl
# [INFO] Processing: /kaggle/input/diagram2graph-dataset/diagram2graph/6.png -> /kaggle/working/ttl_Onshot_outputs3/6.ttl
# [INFO] Processing: /kaggle/input/diagram2graph-dataset/diagram2graph/23.png -> /kaggle/working/ttl_Onshot_outputs3/23.ttl
# [INFO] Processing: /kaggle/input/diagram2graph-dataset/diagram2graph/87.png -> /kaggle/working/ttl_Onshot_outputs3/87.ttl
# [INFO] Processing: /kaggle/input/diagram2graph-dataset/diagram2graph/275.png -> /kaggle/working/ttl_Onshot_outputs3/275.ttl
# [INFO] Processing: /kaggle/input/diagram2graph-dataset/diagram2graph/728.png -> /kaggle/working/ttl_Onshot_outputs3/728.ttl
# [INFO] Processing: /kaggle/input/diagram2graph-dataset/diagram2graph/591.png -> /kaggle/working/ttl_Onshot_outputs3/591.ttl
# [INFO] Processing: /kaggle/input/diagram2graph-dataset/diagram2graph/44.png -> /kaggle/working/ttl_Onshot_outputs3/44.ttl
# [INFO] Processing: /kaggle/input/diagram2graph-dataset/diagram2graph/68.png -> /kaggle/working/ttl_Onshot_outputs3/68.ttl
# [INFO] Processing: /kaggle/input/diagram2graph-dataset/diagram2graph/286.png -> /kaggle/working/ttl_Onshot_outputs3/286.ttl
# [INFO] Processing: /kaggle/input/diagram2graph-dataset/diagram2graph/46.png -> /kaggle/working/ttl_Onshot_outputs3/46.ttl
# [INFO] Processing: /kaggle/input/diagram2graph-dataset/diagram2graph/470.png -> /kaggle/working/ttl_Onshot_outputs3/470.ttl
# [INFO] Processing: /kaggle/input/diagram2graph-dataset/diagram2graph/929.png -> /kaggle/working/ttl_Onshot_outputs3/929.ttl
# [INFO] Processing: /kaggle/input/diagram2graph-dataset/diagram2graph/57.png -> /kaggle/working/ttl_Onshot_outputs3/57.ttl
# [INFO] Processing: /kaggle/input/diagram2graph-dataset/diagram2graph/358.png -> /kaggle/working/ttl_Onshot_outputs3/358.ttl
# [INFO] Processing: /kaggle/input/diagram2graph-dataset/diagram2graph/652.png -> /kaggle/working/ttl_Onshot_outputs3/652.ttl
# [INFO] Processing: /kaggle/input/diagram2graph-dataset/diagram2graph/252.png -> /kaggle/working/ttl_Onshot_outputs3/252.ttl
# [INFO] Processing: /kaggle/input/diagram2graph-dataset/diagram2graph/30.png -> /kaggle/working/ttl_Onshot_outputs3/30.ttl
# [INFO] Processing: /kaggle/input/diagram2graph-dataset/diagram2graph/919.png -> /kaggle/working/ttl_Onshot_outputs3/919.ttl
# [INFO] Processing: /kaggle/input/diagram2graph-dataset/diagram2graph/429.png -> /kaggle/working/ttl_Onshot_outputs3/429.ttl
# [INFO] Processing: /kaggle/input/diagram2graph-dataset/diagram2graph/60.png -> /kaggle/working/ttl_Onshot_outputs3/60.ttl
# [INFO] Processing: /kaggle/input/diagram2graph-dataset/diagram2graph/99.png -> /kaggle/working/ttl_Onshot_outputs3/99.ttl
# [INFO] Processing: /kaggle/input/diagram2graph-dataset/diagram2graph/765.png -> /kaggle/working/ttl_Onshot_outputs3/765.ttl
# [INFO] Processing: /kaggle/input/diagram2graph-dataset/diagram2graph/692.png -> /kaggle/working/ttl_Onshot_outputs3/692.ttl
# [INFO] Processing: /kaggle/input/diagram2graph-dataset/diagram2graph/295.png -> /kaggle/working/ttl_Onshot_outputs3/295.ttl
# [INFO] Processing: /kaggle/input/diagram2graph-dataset/diagram2graph/394.png -> /kaggle/working/ttl_Onshot_outputs3/394.ttl
# [INFO] Processing: /kaggle/input/diagram2graph-dataset/diagram2graph/273.png -> /kaggle/working/ttl_Onshot_outputs3/273.ttl
# [INFO] Processing: /kaggle/input/diagram2graph-dataset/diagram2graph/413.png -> /kaggle/working/ttl_Onshot_outputs3/413.ttl
# [INFO] Processing: /kaggle/input/diagram2graph-dataset/diagram2graph/78.png -> /kaggle/working/ttl_Onshot_outputs3/78.ttl
# [INFO] Processing: /kaggle/input/diagram2graph-dataset/diagram2graph/212.png -> /kaggle/working/ttl_Onshot_outputs3/212.ttl
# [INFO] Processing: /kaggle/input/diagram2graph-dataset/diagram2graph/47.png -> /kaggle/working/ttl_Onshot_outputs3/47.ttl
# [INFO] Processing: /kaggle/input/diagram2graph-dataset/diagram2graph/13.png -> /kaggle/working/ttl_Onshot_outputs3/13.ttl
# [INFO] Processing: /kaggle/input/diagram2graph-dataset/diagram2graph/134.png -> /kaggle/working/ttl_Onshot_outputs3/134.ttl
# [INFO] Processing: /kaggle/input/diagram2graph-dataset/diagram2graph/921.png -> /kaggle/working/ttl_Onshot_outputs3/921.ttl
# [INFO] Processing: /kaggle/input/diagram2graph-dataset/diagram2graph/259.png -> /kaggle/working/ttl_Onshot_outputs3/259.ttl
# [INFO] Processing: /kaggle/input/diagram2graph-dataset/diagram2graph/25.png -> /kaggle/working/ttl_Onshot_outputs3/25.ttl
# [INFO] Processing: /kaggle/input/diagram2graph-dataset/diagram2graph/341.png -> /kaggle/working/ttl_Onshot_outputs3/341.ttl
# [INFO] Processing: /kaggle/input/diagram2graph-dataset/diagram2graph/111.png -> /kaggle/working/ttl_Onshot_outputs3/111.ttl
# [INFO] Processing: /kaggle/input/diagram2graph-dataset/diagram2graph/62.png -> /kaggle/working/ttl_Onshot_outputs3/62.ttl
# [INFO] Processing: /kaggle/input/diagram2graph-dataset/diagram2graph/699.png -> /kaggle/working/ttl_Onshot_outputs3/699.ttl
# [INFO] Processing: /kaggle/input/diagram2graph-dataset/diagram2graph/0.png -> /kaggle/working/ttl_Onshot_outputs3/0.ttl
# [INFO] Processing: /kaggle/input/diagram2graph-dataset/diagram2graph/309.png -> /kaggle/working/ttl_Onshot_outputs3/309.ttl
# [INFO] Processing: /kaggle/input/diagram2graph-dataset/diagram2graph/918.png -> /kaggle/working/ttl_Onshot_outputs3/918.ttl
# [INFO] Processing: /kaggle/input/diagram2graph-dataset/diagram2graph/428.png -> /kaggle/working/ttl_Onshot_outputs3/428.ttl
# [INFO] Processing: /kaggle/input/diagram2graph-dataset/diagram2graph/418.png -> /kaggle/working/ttl_Onshot_outputs3/418.ttl
# [INFO] Processing: /kaggle/input/diagram2graph-dataset/diagram2graph/497.png -> /kaggle/working/ttl_Onshot_outputs3/497.ttl
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /tmp/ipykernel_37/1225672616.py in <cell line: 0>()
#     308
#     309 if __name__ == "__main__":
# --> 310     main()
#
# /tmp/ipykernel_37/1225672616.py in main()
#     286             mime = get_mime_type(img_path)
#     287             payload = build_request(image_b64, mime, PROMPT_TEXT)
# --> 288             ttl_text = call_gemini(payload)
#     289
#     290             if not ttl_text:
#
# /tmp/ipykernel_37/1225672616.py in call_gemini(payload, max_retries)
#     247             data = resp.json()
#     248             if "candidates" in data and data["candidates"]:
# --> 249                 raw = data["candidates"][0]["content"]["parts"][0]["text"]
#     250                 return _strip_code_fences(raw)
#     251             return None
#
# KeyError: 'parts'

# %%
# !zip -r /kaggle/working/OneShot_outputs_v3.zip /kaggle/working/ttl_Onshot_outputs3
# Out:
#   adding: kaggle/working/ttl_Onshot_outputs3/ (stored 0%)
#   adding: kaggle/working/ttl_Onshot_outputs3/238.ttl (deflated 90%)
#   adding: kaggle/working/ttl_Onshot_outputs3/18.ttl (deflated 86%)
#   adding: kaggle/working/ttl_Onshot_outputs3/358.ttl (deflated 84%)
#   adding: kaggle/working/ttl_Onshot_outputs3/577.ttl (deflated 86%)
#   adding: kaggle/working/ttl_Onshot_outputs3/171.ttl (deflated 87%)
#   adding: kaggle/working/ttl_Onshot_outputs3/624.ttl (deflated 89%)
#   adding: kaggle/working/ttl_Onshot_outputs3/75.ttl (deflated 90%)
#   adding: kaggle/working/ttl_Onshot_outputs3/309.ttl (deflated 88%)
#   adding: kaggle/working/ttl_Onshot_outputs3/295.ttl (deflated 85%)
#   adding: kaggle/working/ttl_Onshot_outputs3/62.ttl (deflated 87%)
#   adding: kaggle/working/ttl_Onshot_outputs3/428.ttl (deflated 90%)
#   adding: kaggle/working/ttl_Onshot_outputs3/37.ttl (deflated 89%)
#   adding: kaggle/working/ttl_Onshot_outputs3/412.ttl (deflated 86%)
#   adding: kaggle/working/ttl_Onshot_outputs3/627.ttl (deflated 86%)
#   adding: kaggle/working/ttl_Onshot_outputs3/331.ttl (deflated 82%)
#   adding: kaggle/working/ttl_Onshot_outputs3/416.ttl (deflated 86%)
#   adding: kaggle/working/ttl_Onshot_outputs3/48.ttl (deflated 87%)
#   adding: kaggle/working/ttl_Onshot_outputs3/68.ttl (deflated 88%)
#   adding: kaggle/working/ttl_Onshot_outputs3/934.ttl (deflated 89%)
#   adding: kaggle/working/ttl_Onshot_outputs3/254.ttl (deflated 88%)
#   adding: kaggle/working/ttl_Onshot_outputs3/663.ttl (deflated 85%)
#   adding: kaggle/working/ttl_Onshot_outputs3/286.ttl (deflated 83%)
#   adding: kaggle/working/ttl_Onshot_outputs3/684.ttl (deflated 88%)
#   adding: kaggle/working/ttl_Onshot_outputs3/284.ttl (deflated 86%)
#   adding: kaggle/working/ttl_Onshot_outputs3/66.ttl (deflated 86%)
#   adding: kaggle/working/ttl_Onshot_outputs3/731.ttl (deflated 87%)
#   adding: kaggle/working/ttl_Onshot_outputs3/672.ttl (deflated 86%)
#   adding: kaggle/working/ttl_Onshot_outputs3/0.ttl (deflated 85%)
#   adding: kaggle/working/ttl_Onshot_outputs3/81.ttl (deflated 87%)
#   adding: kaggle/working/ttl_Onshot_outputs3/125.ttl (deflated 86%)
#   adding: kaggle/working/ttl_Onshot_outputs3/8.ttl (deflated 82%)
#   adding: kaggle/working/ttl_Onshot_outputs3/907.ttl (deflated 88%)
#   adding: kaggle/working/ttl_Onshot_outputs3/525.ttl (deflated 83%)
#   adding: kaggle/working/ttl_Onshot_outputs3/29.ttl (deflated 87%)
#   adding: kaggle/working/ttl_Onshot_outputs3/279.ttl (deflated 89%)
#   adding: kaggle/working/ttl_Onshot_outputs3/262.ttl (deflated 88%)
#   adding: kaggle/working/ttl_Onshot_outputs3/52.ttl (deflated 85%)
#   adding: kaggle/working/ttl_Onshot_outputs3/6.ttl (deflated 89%)
#   adding: kaggle/working/ttl_Onshot_outputs3/315.ttl (deflated 83%)
#   adding: kaggle/working/ttl_Onshot_outputs3/335.ttl (deflated 85%)
#   adding: kaggle/working/ttl_Onshot_outputs3/40.ttl (deflated 87%)
#   adding: kaggle/working/ttl_Onshot_outputs3/605.ttl (deflated 88%)
#   adding: kaggle/working/ttl_Onshot_outputs3/891.ttl (deflated 86%)
#   adding: kaggle/working/ttl_Onshot_outputs3/630.ttl (deflated 87%)
#   adding: kaggle/working/ttl_Onshot_outputs3/229.ttl (deflated 86%)
#   adding: kaggle/working/ttl_Onshot_outputs3/134.ttl (deflated 87%)
#   adding: kaggle/working/ttl_Onshot_outputs3/401.ttl (deflated 86%)
#   adding: kaggle/working/ttl_Onshot_outputs3/580.ttl (deflated 87%)
#   adding: kaggle/working/ttl_Onshot_outputs3/924.ttl (deflated 81%)
#   adding: kaggle/working/ttl_Onshot_outputs3/293.ttl (deflated 87%)
#   adding: kaggle/working/ttl_Onshot_outputs3/147.ttl (deflated 87%)
#   adding: kaggle/working/ttl_Onshot_outputs3/310.ttl (deflated 87%)
#   adding: kaggle/working/ttl_Onshot_outputs3/291.ttl (deflated 88%)
#   adding: kaggle/working/ttl_Onshot_outputs3/444.ttl (deflated 84%)
#   adding: kaggle/working/ttl_Onshot_outputs3/212.ttl (deflated 86%)
#   adding: kaggle/working/ttl_Onshot_outputs3/4.ttl (deflated 88%)
#   adding: kaggle/working/ttl_Onshot_outputs3/470.ttl (deflated 86%)
#   adding: kaggle/working/ttl_Onshot_outputs3/701.ttl (deflated 83%)
#   adding: kaggle/working/ttl_Onshot_outputs3/922.ttl (deflated 86%)
#   adding: kaggle/working/ttl_Onshot_outputs3/931.ttl (deflated 82%)
#   adding: kaggle/working/ttl_Onshot_outputs3/446.ttl (deflated 84%)
#   adding: kaggle/working/ttl_Onshot_outputs3/598.ttl (deflated 89%)
#   adding: kaggle/working/ttl_Onshot_outputs3/204.ttl (deflated 89%)
#   adding: kaggle/working/ttl_Onshot_outputs3/39.ttl (deflated 84%)
#   adding: kaggle/working/ttl_Onshot_outputs3/380.ttl (deflated 84%)
#   adding: kaggle/working/ttl_Onshot_outputs3/926.ttl (deflated 85%)
#   adding: kaggle/working/ttl_Onshot_outputs3/823.ttl (deflated 88%)
#   adding: kaggle/working/ttl_Onshot_outputs3/99.ttl (deflated 90%)
#   adding: kaggle/working/ttl_Onshot_outputs3/11.ttl (deflated 83%)
#   adding: kaggle/working/ttl_Onshot_outputs3/12.ttl (deflated 88%)
#   adding: kaggle/working/ttl_Onshot_outputs3/170.ttl (deflated 87%)
#   adding: kaggle/working/ttl_Onshot_outputs3/900.ttl (deflated 86%)
#   adding: kaggle/working/ttl_Onshot_outputs3/71.ttl (deflated 89%)
#   adding: kaggle/working/ttl_Onshot_outputs3/250.ttl (deflated 88%)
#   adding: kaggle/working/ttl_Onshot_outputs3/728.ttl (deflated 85%)
#   adding: kaggle/working/ttl_Onshot_outputs3/23.ttl (deflated 86%)
#   adding: kaggle/working/ttl_Onshot_outputs3/345.ttl (deflated 86%)
#   adding: kaggle/working/ttl_Onshot_outputs3/930.ttl (deflated 86%)
#   adding: kaggle/working/ttl_Onshot_outputs3/41.ttl (deflated 83%)
#   adding: kaggle/working/ttl_Onshot_outputs3/258.ttl (deflated 84%)
#   adding: kaggle/working/ttl_Onshot_outputs3/332.ttl (deflated 83%)
#   adding: kaggle/working/ttl_Onshot_outputs3/224.ttl (deflated 87%)
#   adding: kaggle/working/ttl_Onshot_outputs3/121.ttl (deflated 85%)
#   adding: kaggle/working/ttl_Onshot_outputs3/118.ttl (deflated 85%)
#   adding: kaggle/working/ttl_Onshot_outputs3/17.ttl (deflated 83%)
#   adding: kaggle/working/ttl_Onshot_outputs3/521.ttl (deflated 88%)
#   adding: kaggle/working/ttl_Onshot_outputs3/86.ttl (deflated 86%)
#   adding: kaggle/working/ttl_Onshot_outputs3/356.ttl (deflated 85%)
#   adding: kaggle/working/ttl_Onshot_outputs3/935.ttl (deflated 85%)
#   adding: kaggle/working/ttl_Onshot_outputs3/276.ttl (deflated 85%)
#   adding: kaggle/working/ttl_Onshot_outputs3/31.ttl (deflated 86%)
#   adding: kaggle/working/ttl_Onshot_outputs3/268.ttl (deflated 85%)
#   adding: kaggle/working/ttl_Onshot_outputs3/910.ttl (deflated 88%)
#   adding: kaggle/working/ttl_Onshot_outputs3/589.ttl (deflated 84%)
#   adding: kaggle/working/ttl_Onshot_outputs3/918.ttl (deflated 88%)
#   adding: kaggle/working/ttl_Onshot_outputs3/114.ttl (deflated 87%)
#   adding: kaggle/working/ttl_Onshot_outputs3/556.ttl (deflated 79%)
#   adding: kaggle/working/ttl_Onshot_outputs3/432.ttl (deflated 89%)
#   adding: kaggle/working/ttl_Onshot_outputs3/818.ttl (deflated 84%)
#   adding: kaggle/working/ttl_Onshot_outputs3/341.ttl (deflated 85%)
#   adding: kaggle/working/ttl_Onshot_outputs3/3.ttl (deflated 88%)
#   adding: kaggle/working/ttl_Onshot_outputs3/915.ttl (deflated 88%)
#   adding: kaggle/working/ttl_Onshot_outputs3/10.ttl (deflated 79%)
#   adding: kaggle/working/ttl_Onshot_outputs3/252.ttl (deflated 86%)
#   adding: kaggle/working/ttl_Onshot_outputs3/919.ttl (deflated 88%)
#   adding: kaggle/working/ttl_Onshot_outputs3/634.ttl (deflated 90%)
#   adding: kaggle/working/ttl_Onshot_outputs3/192.ttl (deflated 87%)
#   adding: kaggle/working/ttl_Onshot_outputs3/813.ttl (deflated 83%)
#   adding: kaggle/working/ttl_Onshot_outputs3/55.ttl (deflated 82%)
#   adding: kaggle/working/ttl_Onshot_outputs3/153.ttl (deflated 86%)
#   adding: kaggle/working/ttl_Onshot_outputs3/498.ttl (deflated 83%)
#   adding: kaggle/working/ttl_Onshot_outputs3/14.ttl (deflated 85%)
#   adding: kaggle/working/ttl_Onshot_outputs3/940.ttl (deflated 89%)
#   adding: kaggle/working/ttl_Onshot_outputs3/28.ttl (deflated 89%)
#   adding: kaggle/working/ttl_Onshot_outputs3/76.ttl (deflated 87%)
#   adding: kaggle/working/ttl_Onshot_outputs3/765.ttl (deflated 85%)
#   adding: kaggle/working/ttl_Onshot_outputs3/457.ttl (deflated 88%)
#   adding: kaggle/working/ttl_Onshot_outputs3/65.ttl (deflated 84%)
#   adding: kaggle/working/ttl_Onshot_outputs3/562.ttl (deflated 88%)
#   adding: kaggle/working/ttl_Onshot_outputs3/429.ttl (deflated 87%)
#   adding: kaggle/working/ttl_Onshot_outputs3/94.ttl (deflated 87%)
#   adding: kaggle/working/ttl_Onshot_outputs3/904.ttl (deflated 88%)
#   adding: kaggle/working/ttl_Onshot_outputs3/652.ttl (deflated 89%)
#   adding: kaggle/working/ttl_Onshot_outputs3/63.ttl (deflated 87%)
#   adding: kaggle/working/ttl_Onshot_outputs3/222.ttl (deflated 85%)
#   adding: kaggle/working/ttl_Onshot_outputs3/591.ttl (deflated 85%)
#   adding: kaggle/working/ttl_Onshot_outputs3/761.ttl (deflated 88%)
#   adding: kaggle/working/ttl_Onshot_outputs3/936.ttl (deflated 87%)
#   adding: kaggle/working/ttl_Onshot_outputs3/34.ttl (deflated 88%)
#   adding: kaggle/working/ttl_Onshot_outputs3/13.ttl (deflated 85%)
#   adding: kaggle/working/ttl_Onshot_outputs3/78.ttl (deflated 86%)
#   adding: kaggle/working/ttl_Onshot_outputs3/655.ttl (deflated 86%)
#   adding: kaggle/working/ttl_Onshot_outputs3/911.ttl (deflated 86%)
#   adding: kaggle/working/ttl_Onshot_outputs3/709.ttl (deflated 88%)
#   adding: kaggle/working/ttl_Onshot_outputs3/203.ttl (deflated 89%)
#   adding: kaggle/working/ttl_Onshot_outputs3/30.ttl (deflated 86%)
#   adding: kaggle/working/ttl_Onshot_outputs3/413.ttl (deflated 82%)
#   adding: kaggle/working/ttl_Onshot_outputs3/263.ttl (deflated 85%)
#   adding: kaggle/working/ttl_Onshot_outputs3/328.ttl (deflated 88%)
#   adding: kaggle/working/ttl_Onshot_outputs3/274.ttl (deflated 84%)
#   adding: kaggle/working/ttl_Onshot_outputs3/351.ttl (deflated 84%)
#   adding: kaggle/working/ttl_Onshot_outputs3/699.ttl (deflated 87%)
#   adding: kaggle/working/ttl_Onshot_outputs3/273.ttl (deflated 87%)
#   adding: kaggle/working/ttl_Onshot_outputs3/418.ttl (deflated 86%)
#   adding: kaggle/working/ttl_Onshot_outputs3/45.ttl (deflated 86%)
#   adding: kaggle/working/ttl_Onshot_outputs3/38.ttl (deflated 89%)
#   adding: kaggle/working/ttl_Onshot_outputs3/902.ttl (deflated 87%)
#   adding: kaggle/working/ttl_Onshot_outputs3/80.ttl (deflated 87%)
#   adding: kaggle/working/ttl_Onshot_outputs3/109.ttl (deflated 86%)
#   adding: kaggle/working/ttl_Onshot_outputs3/25.ttl (deflated 88%)
#   adding: kaggle/working/ttl_Onshot_outputs3/46.ttl (deflated 84%)
#   adding: kaggle/working/ttl_Onshot_outputs3/334.ttl (deflated 83%)
#   adding: kaggle/working/ttl_Onshot_outputs3/33.ttl (deflated 85%)
#   adding: kaggle/working/ttl_Onshot_outputs3/100.ttl (deflated 80%)
#   adding: kaggle/working/ttl_Onshot_outputs3/166.ttl (deflated 86%)
#   adding: kaggle/working/ttl_Onshot_outputs3/163.ttl (deflated 87%)
#   adding: kaggle/working/ttl_Onshot_outputs3/706.ttl (deflated 87%)
#   adding: kaggle/working/ttl_Onshot_outputs3/47.ttl (deflated 82%)
#   adding: kaggle/working/ttl_Onshot_outputs3/576.ttl (deflated 87%)
#   adding: kaggle/working/ttl_Onshot_outputs3/87.ttl (deflated 89%)
#   adding: kaggle/working/ttl_Onshot_outputs3/9.ttl (deflated 86%)
#   adding: kaggle/working/ttl_Onshot_outputs3/239.ttl (deflated 84%)
#   adding: kaggle/working/ttl_Onshot_outputs3/90.ttl (deflated 87%)
#   adding: kaggle/working/ttl_Onshot_outputs3/908.ttl (deflated 86%)
#   adding: kaggle/working/ttl_Onshot_outputs3/520.ttl (deflated 87%)
#   adding: kaggle/working/ttl_Onshot_outputs3/933.ttl (deflated 85%)
#   adding: kaggle/working/ttl_Onshot_outputs3/93.ttl (deflated 84%)
#   adding: kaggle/working/ttl_Onshot_outputs3/542.ttl (deflated 86%)
#   adding: kaggle/working/ttl_Onshot_outputs3/937.ttl (deflated 88%)
#   adding: kaggle/working/ttl_Onshot_outputs3/921.ttl (deflated 87%)
#   adding: kaggle/working/ttl_Onshot_outputs3/259.ttl (deflated 87%)
#   adding: kaggle/working/ttl_Onshot_outputs3/275.ttl (deflated 88%)
#   adding: kaggle/working/ttl_Onshot_outputs3/411.ttl (deflated 86%)
#   adding: kaggle/working/ttl_Onshot_outputs3/394.ttl (deflated 86%)
#   adding: kaggle/working/ttl_Onshot_outputs3/563.ttl (deflated 87%)
#   adding: kaggle/working/ttl_Onshot_outputs3/433.ttl (deflated 87%)
#   adding: kaggle/working/ttl_Onshot_outputs3/244.ttl (deflated 88%)
#   adding: kaggle/working/ttl_Onshot_outputs3/888.ttl (deflated 87%)
#   adding: kaggle/working/ttl_Onshot_outputs3/607.ttl (deflated 86%)
#   adding: kaggle/working/ttl_Onshot_outputs3/692.ttl (deflated 87%)
#   adding: kaggle/working/ttl_Onshot_outputs3/848.ttl (deflated 87%)
#   adding: kaggle/working/ttl_Onshot_outputs3/198.ttl (deflated 79%)
#   adding: kaggle/working/ttl_Onshot_outputs3/361.ttl (deflated 83%)
#   adding: kaggle/working/ttl_Onshot_outputs3/905.ttl (deflated 86%)
#   adding: kaggle/working/ttl_Onshot_outputs3/620.ttl (deflated 88%)
#   adding: kaggle/working/ttl_Onshot_outputs3/57.ttl (deflated 88%)
#   adding: kaggle/working/ttl_Onshot_outputs3/735.ttl (deflated 81%)
#   adding: kaggle/working/ttl_Onshot_outputs3/174.ttl (deflated 87%)
#   adding: kaggle/working/ttl_Onshot_outputs3/800.ttl (deflated 90%)
#   adding: kaggle/working/ttl_Onshot_outputs3/288.ttl (deflated 89%)
#   adding: kaggle/working/ttl_Onshot_outputs3/44.ttl (deflated 88%)
#   adding: kaggle/working/ttl_Onshot_outputs3/914.ttl (deflated 88%)
#   adding: kaggle/working/ttl_Onshot_outputs3/49.ttl (deflated 82%)
#   adding: kaggle/working/ttl_Onshot_outputs3/35.ttl (deflated 85%)
#   adding: kaggle/working/ttl_Onshot_outputs3/64.ttl (deflated 87%)
#   adding: kaggle/working/ttl_Onshot_outputs3/278.ttl (deflated 87%)
#   adding: kaggle/working/ttl_Onshot_outputs3/148.ttl (deflated 83%)
#   adding: kaggle/working/ttl_Onshot_outputs3/920.ttl (deflated 89%)
#   adding: kaggle/working/ttl_Onshot_outputs3/193.ttl (deflated 88%)
#   adding: kaggle/working/ttl_Onshot_outputs3/548.ttl (deflated 86%)
#   adding: kaggle/working/ttl_Onshot_outputs3/2.ttl (deflated 86%)
#   adding: kaggle/working/ttl_Onshot_outputs3/938.ttl (deflated 83%)
#   adding: kaggle/working/ttl_Onshot_outputs3/107.ttl (deflated 85%)
#   adding: kaggle/working/ttl_Onshot_outputs3/347.ttl (deflated 84%)
#   adding: kaggle/working/ttl_Onshot_outputs3/929.ttl (deflated 87%)
#   adding: kaggle/working/ttl_Onshot_outputs3/116.ttl (deflated 89%)
#   adding: kaggle/working/ttl_Onshot_outputs3/119.ttl (deflated 85%)
#   adding: kaggle/working/ttl_Onshot_outputs3/67.ttl (deflated 88%)
#   adding: kaggle/working/ttl_Onshot_outputs3/322.ttl (deflated 86%)
#   adding: kaggle/working/ttl_Onshot_outputs3/319.ttl (deflated 83%)
#   adding: kaggle/working/ttl_Onshot_outputs3/60.ttl (deflated 84%)
#   adding: kaggle/working/ttl_Onshot_outputs3/111.ttl (deflated 86%)
#   adding: kaggle/working/ttl_Onshot_outputs3/753.ttl (deflated 84%)
#   adding: kaggle/working/ttl_Onshot_outputs3/233.ttl (deflated 87%)
#   adding: kaggle/working/ttl_Onshot_outputs3/120.ttl (deflated 85%)
#   adding: kaggle/working/ttl_Onshot_outputs3/916.ttl (deflated 83%)
#   adding: kaggle/working/ttl_Onshot_outputs3/215.ttl (deflated 87%)
#   adding: kaggle/working/ttl_Onshot_outputs3/113.ttl (deflated 88%)

# %%
# !zip -r /kaggle/working/Onshot_outputs.zip /kaggle/working/ttl_Onshot_outputs2
# Out:
#   adding: kaggle/working/ttl_Onshot_outputs2/ (stored 0%)
#   adding: kaggle/working/ttl_Onshot_outputs2/238.ttl (deflated 90%)
#   adding: kaggle/working/ttl_Onshot_outputs2/18.ttl (deflated 86%)
#   adding: kaggle/working/ttl_Onshot_outputs2/358.ttl (deflated 84%)
#   adding: kaggle/working/ttl_Onshot_outputs2/577.ttl (deflated 86%)
#   adding: kaggle/working/ttl_Onshot_outputs2/171.ttl (deflated 88%)
#   adding: kaggle/working/ttl_Onshot_outputs2/624.ttl (deflated 89%)
#   adding: kaggle/working/ttl_Onshot_outputs2/75.ttl (deflated 90%)
#   adding: kaggle/working/ttl_Onshot_outputs2/309.ttl (deflated 88%)
#   adding: kaggle/working/ttl_Onshot_outputs2/295.ttl (deflated 85%)
#   adding: kaggle/working/ttl_Onshot_outputs2/62.ttl (deflated 88%)
#   adding: kaggle/working/ttl_Onshot_outputs2/428.ttl (deflated 90%)
#   adding: kaggle/working/ttl_Onshot_outputs2/37.ttl (deflated 89%)
#   adding: kaggle/working/ttl_Onshot_outputs2/412.ttl (deflated 86%)
#   adding: kaggle/working/ttl_Onshot_outputs2/627.ttl (deflated 86%)
#   adding: kaggle/working/ttl_Onshot_outputs2/331.ttl (deflated 83%)
#   adding: kaggle/working/ttl_Onshot_outputs2/416.ttl (deflated 86%)
#   adding: kaggle/working/ttl_Onshot_outputs2/48.ttl (deflated 88%)
#   adding: kaggle/working/ttl_Onshot_outputs2/68.ttl (deflated 89%)
#   adding: kaggle/working/ttl_Onshot_outputs2/934.ttl (deflated 89%)
#   adding: kaggle/working/ttl_Onshot_outputs2/254.ttl (deflated 89%)
#   adding: kaggle/working/ttl_Onshot_outputs2/663.ttl (deflated 85%)
#   adding: kaggle/working/ttl_Onshot_outputs2/286.ttl (deflated 83%)
#   adding: kaggle/working/ttl_Onshot_outputs2/684.ttl (deflated 88%)
#   adding: kaggle/working/ttl_Onshot_outputs2/284.ttl (deflated 86%)
#   adding: kaggle/working/ttl_Onshot_outputs2/66.ttl (deflated 87%)
#   adding: kaggle/working/ttl_Onshot_outputs2/731.ttl (deflated 87%)
#   adding: kaggle/working/ttl_Onshot_outputs2/672.ttl (deflated 86%)
#   adding: kaggle/working/ttl_Onshot_outputs2/0.ttl (deflated 85%)
#   adding: kaggle/working/ttl_Onshot_outputs2/81.ttl (deflated 88%)
#   adding: kaggle/working/ttl_Onshot_outputs2/125.ttl (deflated 87%)
#   adding: kaggle/working/ttl_Onshot_outputs2/8.ttl (deflated 82%)
#   adding: kaggle/working/ttl_Onshot_outputs2/907.ttl (deflated 88%)
#   adding: kaggle/working/ttl_Onshot_outputs2/525.ttl (deflated 83%)
#   adding: kaggle/working/ttl_Onshot_outputs2/29.ttl (deflated 87%)
#   adding: kaggle/working/ttl_Onshot_outputs2/279.ttl (deflated 89%)
#   adding: kaggle/working/ttl_Onshot_outputs2/262.ttl (deflated 88%)
#   adding: kaggle/working/ttl_Onshot_outputs2/52.ttl (deflated 86%)
#   adding: kaggle/working/ttl_Onshot_outputs2/6.ttl (deflated 89%)
#   adding: kaggle/working/ttl_Onshot_outputs2/315.ttl (deflated 83%)
#   adding: kaggle/working/ttl_Onshot_outputs2/335.ttl (deflated 86%)
#   adding: kaggle/working/ttl_Onshot_outputs2/40.ttl (deflated 87%)
#   adding: kaggle/working/ttl_Onshot_outputs2/605.ttl (deflated 88%)
#   adding: kaggle/working/ttl_Onshot_outputs2/891.ttl (deflated 86%)
#   adding: kaggle/working/ttl_Onshot_outputs2/630.ttl (deflated 87%)
#   adding: kaggle/working/ttl_Onshot_outputs2/229.ttl (deflated 86%)
#   adding: kaggle/working/ttl_Onshot_outputs2/134.ttl (deflated 87%)
#   adding: kaggle/working/ttl_Onshot_outputs2/401.ttl (deflated 86%)
#   adding: kaggle/working/ttl_Onshot_outputs2/580.ttl (deflated 87%)
#   adding: kaggle/working/ttl_Onshot_outputs2/924.ttl (deflated 81%)
#   adding: kaggle/working/ttl_Onshot_outputs2/293.ttl (deflated 87%)
#   adding: kaggle/working/ttl_Onshot_outputs2/147.ttl (deflated 87%)
#   adding: kaggle/working/ttl_Onshot_outputs2/310.ttl (deflated 87%)
#   adding: kaggle/working/ttl_Onshot_outputs2/291.ttl (deflated 88%)
#   adding: kaggle/working/ttl_Onshot_outputs2/444.ttl (deflated 84%)
#   adding: kaggle/working/ttl_Onshot_outputs2/212.ttl (deflated 86%)
#   adding: kaggle/working/ttl_Onshot_outputs2/4.ttl (deflated 88%)
#   adding: kaggle/working/ttl_Onshot_outputs2/470.ttl (deflated 86%)
#   adding: kaggle/working/ttl_Onshot_outputs2/701.ttl (deflated 83%)
#   adding: kaggle/working/ttl_Onshot_outputs2/922.ttl (deflated 86%)
#   adding: kaggle/working/ttl_Onshot_outputs2/497.ttl (deflated 88%)
#   adding: kaggle/working/ttl_Onshot_outputs2/931.ttl (deflated 82%)
#   adding: kaggle/working/ttl_Onshot_outputs2/manifest.json (deflated 96%)
#   adding: kaggle/working/ttl_Onshot_outputs2/446.ttl (deflated 84%)
#   adding: kaggle/working/ttl_Onshot_outputs2/598.ttl (deflated 89%)
#   adding: kaggle/working/ttl_Onshot_outputs2/204.ttl (deflated 89%)
#   adding: kaggle/working/ttl_Onshot_outputs2/39.ttl (deflated 84%)
#   adding: kaggle/working/ttl_Onshot_outputs2/380.ttl (deflated 85%)
#   adding: kaggle/working/ttl_Onshot_outputs2/926.ttl (deflated 85%)
#   adding: kaggle/working/ttl_Onshot_outputs2/823.ttl (deflated 88%)
#   adding: kaggle/working/ttl_Onshot_outputs2/99.ttl (deflated 90%)
#   adding: kaggle/working/ttl_Onshot_outputs2/11.ttl (deflated 83%)
#   adding: kaggle/working/ttl_Onshot_outputs2/12.ttl (deflated 88%)
#   adding: kaggle/working/ttl_Onshot_outputs2/170.ttl (deflated 87%)
#   adding: kaggle/working/ttl_Onshot_outputs2/900.ttl (deflated 86%)
#   adding: kaggle/working/ttl_Onshot_outputs2/71.ttl (deflated 89%)
#   adding: kaggle/working/ttl_Onshot_outputs2/250.ttl (deflated 88%)
#   adding: kaggle/working/ttl_Onshot_outputs2/728.ttl (deflated 85%)
#   adding: kaggle/working/ttl_Onshot_outputs2/23.ttl (deflated 87%)
#   adding: kaggle/working/ttl_Onshot_outputs2/345.ttl (deflated 86%)
#   adding: kaggle/working/ttl_Onshot_outputs2/930.ttl (deflated 86%)
#   adding: kaggle/working/ttl_Onshot_outputs2/41.ttl (deflated 83%)
#   adding: kaggle/working/ttl_Onshot_outputs2/258.ttl (deflated 84%)
#   adding: kaggle/working/ttl_Onshot_outputs2/332.ttl (deflated 83%)
#   adding: kaggle/working/ttl_Onshot_outputs2/224.ttl (deflated 88%)
#   adding: kaggle/working/ttl_Onshot_outputs2/121.ttl (deflated 86%)
#   adding: kaggle/working/ttl_Onshot_outputs2/118.ttl (deflated 85%)
#   adding: kaggle/working/ttl_Onshot_outputs2/17.ttl (deflated 83%)
#   adding: kaggle/working/ttl_Onshot_outputs2/521.ttl (deflated 89%)
#   adding: kaggle/working/ttl_Onshot_outputs2/86.ttl (deflated 86%)
#   adding: kaggle/working/ttl_Onshot_outputs2/356.ttl (deflated 86%)
#   adding: kaggle/working/ttl_Onshot_outputs2/935.ttl (deflated 86%)
#   adding: kaggle/working/ttl_Onshot_outputs2/276.ttl (deflated 85%)
#   adding: kaggle/working/ttl_Onshot_outputs2/31.ttl (deflated 86%)
#   adding: kaggle/working/ttl_Onshot_outputs2/268.ttl (deflated 85%)
#   adding: kaggle/working/ttl_Onshot_outputs2/910.ttl (deflated 88%)
#   adding: kaggle/working/ttl_Onshot_outputs2/589.ttl (deflated 84%)
#   adding: kaggle/working/ttl_Onshot_outputs2/918.ttl (deflated 88%)
#   adding: kaggle/working/ttl_Onshot_outputs2/114.ttl (deflated 87%)
#   adding: kaggle/working/ttl_Onshot_outputs2/556.ttl (deflated 80%)
#   adding: kaggle/working/ttl_Onshot_outputs2/432.ttl (deflated 89%)
#   adding: kaggle/working/ttl_Onshot_outputs2/818.ttl (deflated 84%)
#   adding: kaggle/working/ttl_Onshot_outputs2/341.ttl (deflated 86%)
#   adding: kaggle/working/ttl_Onshot_outputs2/3.ttl (deflated 88%)
#   adding: kaggle/working/ttl_Onshot_outputs2/915.ttl (deflated 88%)
#   adding: kaggle/working/ttl_Onshot_outputs2/10.ttl (deflated 79%)
#   adding: kaggle/working/ttl_Onshot_outputs2/252.ttl (deflated 87%)
#   adding: kaggle/working/ttl_Onshot_outputs2/919.ttl (deflated 88%)
#   adding: kaggle/working/ttl_Onshot_outputs2/634.ttl (deflated 90%)
#   adding: kaggle/working/ttl_Onshot_outputs2/192.ttl (deflated 87%)
#   adding: kaggle/working/ttl_Onshot_outputs2/813.ttl (deflated 83%)
#   adding: kaggle/working/ttl_Onshot_outputs2/55.ttl (deflated 82%)
#   adding: kaggle/working/ttl_Onshot_outputs2/153.ttl (deflated 86%)
#   adding: kaggle/working/ttl_Onshot_outputs2/498.ttl (deflated 83%)
#   adding: kaggle/working/ttl_Onshot_outputs2/14.ttl (deflated 85%)
#   adding: kaggle/working/ttl_Onshot_outputs2/940.ttl (deflated 89%)
#   adding: kaggle/working/ttl_Onshot_outputs2/28.ttl (deflated 89%)
#   adding: kaggle/working/ttl_Onshot_outputs2/76.ttl (deflated 87%)
#   adding: kaggle/working/ttl_Onshot_outputs2/765.ttl (deflated 85%)
#   adding: kaggle/working/ttl_Onshot_outputs2/457.ttl (deflated 88%)
#   adding: kaggle/working/ttl_Onshot_outputs2/65.ttl (deflated 84%)
#   adding: kaggle/working/ttl_Onshot_outputs2/562.ttl (deflated 88%)
#   adding: kaggle/working/ttl_Onshot_outputs2/429.ttl (deflated 87%)
#   adding: kaggle/working/ttl_Onshot_outputs2/94.ttl (deflated 87%)
#   adding: kaggle/working/ttl_Onshot_outputs2/904.ttl (deflated 88%)
#   adding: kaggle/working/ttl_Onshot_outputs2/652.ttl (deflated 89%)
#   adding: kaggle/working/ttl_Onshot_outputs2/63.ttl (deflated 87%)
#   adding: kaggle/working/ttl_Onshot_outputs2/222.ttl (deflated 86%)
#   adding: kaggle/working/ttl_Onshot_outputs2/591.ttl (deflated 85%)
#   adding: kaggle/working/ttl_Onshot_outputs2/761.ttl (deflated 88%)
#   adding: kaggle/working/ttl_Onshot_outputs2/936.ttl (deflated 87%)
#   adding: kaggle/working/ttl_Onshot_outputs2/34.ttl (deflated 87%)
#   adding: kaggle/working/ttl_Onshot_outputs2/13.ttl (deflated 85%)
#   adding: kaggle/working/ttl_Onshot_outputs2/78.ttl (deflated 86%)
#   adding: kaggle/working/ttl_Onshot_outputs2/655.ttl (deflated 86%)
#   adding: kaggle/working/ttl_Onshot_outputs2/911.ttl (deflated 86%)
#   adding: kaggle/working/ttl_Onshot_outputs2/709.ttl (deflated 88%)
#   adding: kaggle/working/ttl_Onshot_outputs2/203.ttl (deflated 89%)
#   adding: kaggle/working/ttl_Onshot_outputs2/30.ttl (deflated 86%)
#   adding: kaggle/working/ttl_Onshot_outputs2/413.ttl (deflated 82%)
#   adding: kaggle/working/ttl_Onshot_outputs2/263.ttl (deflated 85%)
#   adding: kaggle/working/ttl_Onshot_outputs2/328.ttl (deflated 88%)
#   adding: kaggle/working/ttl_Onshot_outputs2/274.ttl (deflated 85%)
#   adding: kaggle/working/ttl_Onshot_outputs2/351.ttl (deflated 84%)
#   adding: kaggle/working/ttl_Onshot_outputs2/699.ttl (deflated 87%)
#   adding: kaggle/working/ttl_Onshot_outputs2/273.ttl (deflated 87%)
#   adding: kaggle/working/ttl_Onshot_outputs2/418.ttl (deflated 86%)
#   adding: kaggle/working/ttl_Onshot_outputs2/45.ttl (deflated 86%)
#   adding: kaggle/working/ttl_Onshot_outputs2/38.ttl (deflated 89%)
#   adding: kaggle/working/ttl_Onshot_outputs2/902.ttl (deflated 88%)
#   adding: kaggle/working/ttl_Onshot_outputs2/80.ttl (deflated 87%)
#   adding: kaggle/working/ttl_Onshot_outputs2/109.ttl (deflated 86%)
#   adding: kaggle/working/ttl_Onshot_outputs2/25.ttl (deflated 86%)
#   adding: kaggle/working/ttl_Onshot_outputs2/46.ttl (deflated 85%)
#   adding: kaggle/working/ttl_Onshot_outputs2/334.ttl (deflated 83%)
#   adding: kaggle/working/ttl_Onshot_outputs2/33.ttl (deflated 85%)
#   adding: kaggle/working/ttl_Onshot_outputs2/100.ttl (deflated 80%)
#   adding: kaggle/working/ttl_Onshot_outputs2/166.ttl (deflated 86%)
#   adding: kaggle/working/ttl_Onshot_outputs2/163.ttl (deflated 87%)
#   adding: kaggle/working/ttl_Onshot_outputs2/706.ttl (deflated 87%)
#   adding: kaggle/working/ttl_Onshot_outputs2/47.ttl (deflated 82%)
#   adding: kaggle/working/ttl_Onshot_outputs2/576.ttl (deflated 88%)
#   adding: kaggle/working/ttl_Onshot_outputs2/87.ttl (deflated 89%)
#   adding: kaggle/working/ttl_Onshot_outputs2/9.ttl (deflated 86%)
#   adding: kaggle/working/ttl_Onshot_outputs2/239.ttl (deflated 84%)
#   adding: kaggle/working/ttl_Onshot_outputs2/90.ttl (deflated 87%)
#   adding: kaggle/working/ttl_Onshot_outputs2/908.ttl (deflated 86%)
#   adding: kaggle/working/ttl_Onshot_outputs2/520.ttl (deflated 87%)
#   adding: kaggle/working/ttl_Onshot_outputs2/933.ttl (deflated 85%)
#   adding: kaggle/working/ttl_Onshot_outputs2/93.ttl (deflated 84%)
#   adding: kaggle/working/ttl_Onshot_outputs2/542.ttl (deflated 86%)
#   adding: kaggle/working/ttl_Onshot_outputs2/937.ttl (deflated 88%)
#   adding: kaggle/working/ttl_Onshot_outputs2/921.ttl (deflated 87%)
#   adding: kaggle/working/ttl_Onshot_outputs2/259.ttl (deflated 87%)
#   adding: kaggle/working/ttl_Onshot_outputs2/275.ttl (deflated 88%)
#   adding: kaggle/working/ttl_Onshot_outputs2/411.ttl (deflated 86%)
#   adding: kaggle/working/ttl_Onshot_outputs2/394.ttl (deflated 87%)
#   adding: kaggle/working/ttl_Onshot_outputs2/563.ttl (deflated 87%)
#   adding: kaggle/working/ttl_Onshot_outputs2/433.ttl (deflated 87%)
#   adding: kaggle/working/ttl_Onshot_outputs2/244.ttl (deflated 88%)
#   adding: kaggle/working/ttl_Onshot_outputs2/888.ttl (deflated 87%)
#   adding: kaggle/working/ttl_Onshot_outputs2/607.ttl (deflated 86%)
#   adding: kaggle/working/ttl_Onshot_outputs2/692.ttl (deflated 87%)
#   adding: kaggle/working/ttl_Onshot_outputs2/848.ttl (deflated 88%)
#   adding: kaggle/working/ttl_Onshot_outputs2/198.ttl (deflated 79%)
#   adding: kaggle/working/ttl_Onshot_outputs2/361.ttl (deflated 84%)
#   adding: kaggle/working/ttl_Onshot_outputs2/905.ttl (deflated 86%)
#   adding: kaggle/working/ttl_Onshot_outputs2/620.ttl (deflated 88%)
#   adding: kaggle/working/ttl_Onshot_outputs2/57.ttl (deflated 89%)
#   adding: kaggle/working/ttl_Onshot_outputs2/735.ttl (deflated 80%)
#   adding: kaggle/working/ttl_Onshot_outputs2/174.ttl (deflated 88%)
#   adding: kaggle/working/ttl_Onshot_outputs2/800.ttl (deflated 90%)
#   adding: kaggle/working/ttl_Onshot_outputs2/288.ttl (deflated 90%)
#   adding: kaggle/working/ttl_Onshot_outputs2/44.ttl (deflated 87%)
#   adding: kaggle/working/ttl_Onshot_outputs2/914.ttl (deflated 88%)
#   adding: kaggle/working/ttl_Onshot_outputs2/49.ttl (deflated 83%)
#   adding: kaggle/working/ttl_Onshot_outputs2/35.ttl (deflated 86%)
#   adding: kaggle/working/ttl_Onshot_outputs2/64.ttl (deflated 87%)
#   adding: kaggle/working/ttl_Onshot_outputs2/278.ttl (deflated 88%)
#   adding: kaggle/working/ttl_Onshot_outputs2/148.ttl (deflated 83%)
#   adding: kaggle/working/ttl_Onshot_outputs2/920.ttl (deflated 88%)
#   adding: kaggle/working/ttl_Onshot_outputs2/193.ttl (deflated 89%)
#   adding: kaggle/working/ttl_Onshot_outputs2/548.ttl (deflated 86%)
#   adding: kaggle/working/ttl_Onshot_outputs2/2.ttl (deflated 87%)
#   adding: kaggle/working/ttl_Onshot_outputs2/938.ttl (deflated 83%)
#   adding: kaggle/working/ttl_Onshot_outputs2/107.ttl (deflated 85%)
#   adding: kaggle/working/ttl_Onshot_outputs2/347.ttl (deflated 84%)
#   adding: kaggle/working/ttl_Onshot_outputs2/929.ttl (deflated 87%)
#   adding: kaggle/working/ttl_Onshot_outputs2/116.ttl (deflated 89%)
#   adding: kaggle/working/ttl_Onshot_outputs2/119.ttl (deflated 85%)
#   adding: kaggle/working/ttl_Onshot_outputs2/67.ttl (deflated 88%)
#   adding: kaggle/working/ttl_Onshot_outputs2/322.ttl (deflated 86%)
#   adding: kaggle/working/ttl_Onshot_outputs2/319.ttl (deflated 84%)
#   adding: kaggle/working/ttl_Onshot_outputs2/60.ttl (deflated 84%)
#   adding: kaggle/working/ttl_Onshot_outputs2/111.ttl (deflated 87%)
#   adding: kaggle/working/ttl_Onshot_outputs2/753.ttl (deflated 84%)
#   adding: kaggle/working/ttl_Onshot_outputs2/233.ttl (deflated 87%)
#   adding: kaggle/working/ttl_Onshot_outputs2/120.ttl (deflated 86%)
#   adding: kaggle/working/ttl_Onshot_outputs2/916.ttl (deflated 83%)
#   adding: kaggle/working/ttl_Onshot_outputs2/215.ttl (deflated 88%)
#   adding: kaggle/working/ttl_Onshot_outputs2/113.ttl (deflated 88%)

# %% [markdown]
# # FewShot Prompting

# %%
import base64
import json
import os
import time
from pathlib import Path
from typing import Optional
import requests
from PIL import Image

# =========================
# 1) CONFIGURATION
# =========================
# Prefer loading your key from an environment variable (more secure).
# export GEMINI_API_KEY="..."
def load_api_key(name, fallback_names=()):
    import os
    import sys
    from pathlib import Path

    candidates = (name, *fallback_names)
    repo_root = next(
        (
            candidate
            for candidate in (Path.cwd(), *Path.cwd().parents)
            if (candidate / "common" / "__init__.py").exists()
        ),
        None,
    )

    get_api_key = None
    if repo_root is not None:
        if str(repo_root) not in sys.path:
            sys.path.insert(0, str(repo_root))
        try:
            from common import get_api_key as shared_get_api_key
        except ImportError:
            pass
        else:
            get_api_key = shared_get_api_key

    if get_api_key is not None:
        for candidate in candidates:
            try:
                return get_api_key(candidate)
            except KeyError:
                pass

    for candidate in candidates:
        value = os.getenv(candidate, "").strip()
        if value:
            return value

    joined = ", ".join(candidates)
    raise RuntimeError(
        f"Missing API key. Set one of [{joined}] in the environment"
        " or the top-level config file."
    )

GEMINI_API_KEY = load_api_key("GEMINI_API_KEY")

MODEL = "gemini-2.5-flash"
ENDPOINT = f"https://generativelanguage.googleapis.com/v1beta/models/{MODEL}:generateContent?key={GEMINI_API_KEY}"

# Input images directory (recursively scanned)
DATASET_DIR = "/kaggle/input/diagram2graph-dataset/diagram2graph"  # <--- change this
# Output directory for per-image TTL files
OUTPUT_DIR = "/kaggle/working/ttl_FewShot_outputs"  # <--- change this
# Optional: also write a small manifest JSON with image->ttl mapping
WRITE_MANIFEST = True
MANIFEST_PATH = os.path.join(OUTPUT_DIR, "manifest.json")

VALID_IMAGE_EXTS = {".png", ".jpg", ".jpeg", ".bmp", ".webp", ".tif", ".tiff"}

# =========================
# 2) PROMPT (one-shot)
# =========================
PROMPT_TEXT = r"""

System
You are a diagram-to-graph extractor. Given a flowchart/diagram image, output ONLY valid Turtle using the diagram2graph (d2g) vocabulary.

Mandatory Instructions (follow exactly)
1) Prefixes (only these two)
@prefix d2g:  <http://example.org/diagram2graph#> .
@prefix rdfs: <http://www.w3.org/2000/01/rdf-schema#> .

2) Identifiers (IRIs)
- Fixed patterns:
  Nodes: <http://example.org/diagram/diagram/node/{N}>
  Edges: <http://example.org/diagram/diagram/edge/{E}>
- Node numbering: visual reading order (top→bottom, left→right).
- Edge IDs (strict rule): build each edge IRI as ST, where S is the source node ID and T is the target node ID.
  Example: the edge between node/1 and node/2 MUST be <http://example.org/diagram/diagram/edge/12>

3) Nodes (create one node per readable shape)
For each shape:
<…/node/N> a d2g:Node, d2g:{Start|Process|Decision|Delay|Terminator} ;
    rdfs:label "exact text from the shape" ;
    d2g:shape d2g:{TartEvent|TaK|Gateway|Delay|EndEvent} .
Required shape mapping (use these exact dataset tokens—even if they look misspelled):
- Start/Begin (rounded oval) → d2g:TartEvent
- End/Stop   (rounded oval) → d2g:EndEvent
- Rectangle  (process)      → d2g:TaK
- Diamond    (decision)     → d2g:Gateway
- Delay      (delay symbol) → d2g:Delay

4) Edges (create a dedicated Edge resource per arrow)
For each arrow:
<…/edge/ST> a d2g:Edge, d2g:{Solid|Dashed} ;
    d2g:source <…/node/S> ;
    d2g:target <…/node/T> ;
    d2g:relationshipType d2g:{Follows|Branches} ;
    [optional] d2g:relationshipValue "label on the arrow (e.g., Yes/No)" .
Rules:
- Outgoing arrows from a Decision node must use relationshipType = d2g:Branches, and include relationshipValue if text exists (Yes/No/etc.).
- All other arrows use relationshipType = d2g:Follows.
- Set line style precisely: d2g:Solid for solid lines; d2g:Dashed for dotted/dashed lines.

5) Convenience node-to-node triples (also required)
- For Follows:  <…/node/S> d2g:follows  <…/node/T> .
- For Branches: <…/node/S> d2g:branches <…/node/T> .

6) Output rules
- Output Turtle only; no explanations or extra text.
- Group by subject; one triple per line; end every line with a period.
- Every edge’s source/target must reference existing node IRIs.
- Do NOT use any prefixes or vocabularies other than d2g and rdfs.
- Write class and shape tokens EXACTLY as specified above (no spelling changes).

Few-shot Examples (gold TTL from the dataset)
# Example A (from 3.png / 3.ttl)
@prefix d2g: <http://example.org/diagram2graph#> .
@prefix rdfs: <http://www.w3.org/2000/01/rdf-schema#> .

# === Nodes ===
<http://example.org/diagram/diagram/node/1> a d2g:Start, d2g:Node ;
    rdfs:label "Begin" ;
    d2g:shape d2g:TartEvent .

<http://example.org/diagram/diagram/node/2> a d2g:Process, d2g:Node ;
    rdfs:label "SUM=0" ;
    d2g:shape d2g:TaK .

<http://example.org/diagram/diagram/node/3> a d2g:Process, d2g:Node ;
    rdfs:label "Input N" ;
    d2g:shape d2g:TaK .

<http://example.org/diagram/diagram/node/4> a d2g:Decision, d2g:Node ;
    rdfs:label "N!=0?" ;
    d2g:shape d2g:Gateway .

<http://example.org/diagram/diagram/node/5> a d2g:Process, d2g:Node ;
    rdfs:label "Print SUM" ;
    d2g:shape d2g:TaK .

<http://example.org/diagram/diagram/node/6> a d2g:Process, d2g:Node ;
    rdfs:label "REM=N%10" ;
    d2g:shape d2g:TaK .

<http://example.org/diagram/diagram/node/7> a d2g:Process, d2g:Node ;
    rdfs:label "SUM=SUM+REM" ;
    d2g:shape d2g:TaK .

<http://example.org/diagram/diagram/node/8> a d2g:Process, d2g:Node ;
    rdfs:label "N=N/10" ;
    d2g:shape d2g:TaK .

<http://example.org/diagram/diagram/node/9> a d2g:Terminator, d2g:Node ;
    rdfs:label "Stop" ;
    d2g:shape d2g:EndEvent .

# === Edges ===
<http://example.org/diagram/diagram/edge/12> a d2g:Solid, d2g:Edge ;
    d2g:source <http://example.org/diagram/diagram/node/1> ;
    d2g:target <http://example.org/diagram/diagram/node/2> ;
    d2g:relationshipType d2g:Follows .

<http://example.org/diagram/diagram/node/1> d2g:follows <http://example.org/diagram/diagram/node/2> .

<http://example.org/diagram/diagram/edge/23> a d2g:Solid, d2g:Edge ;
    d2g:source <http://example.org/diagram/diagram/node/2> ;
    d2g:target <http://example.org/diagram/diagram/node/3> ;
    d2g:relationshipType d2g:Follows .

<http://example.org/diagram/diagram/node/2> d2g:follows <http://example.org/diagram/diagram/node/3> .

<http://example.org/diagram/diagram/edge/34> a d2g:Solid, d2g:Edge ;
    d2g:source <http://example.org/diagram/diagram/node/3> ;
    d2g:target <http://example.org/diagram/diagram/node/4> ;
    d2g:relationshipType d2g:Follows .

<http://example.org/diagram/diagram/node/3> d2g:follows <http://example.org/diagram/diagram/node/4> .

<http://example.org/diagram/diagram/edge/45> a d2g:Solid, d2g:Edge ;
    d2g:source <http://example.org/diagram/diagram/node/4> ;
    d2g:target <http://example.org/diagram/diagram/node/5> ;
    d2g:relationshipType d2g:Follows ;
    d2g:relationshipValue "False" .

<http://example.org/diagram/diagram/node/4> d2g:follows <http://example.org/diagram/diagram/node/5> .

<http://example.org/diagram/diagram/edge/46> a d2g:Solid, d2g:Edge ;
    d2g:source <http://example.org/diagram/diagram/node/4> ;
    d2g:target <http://example.org/diagram/diagram/node/6> ;
    d2g:relationshipType d2g:Follows ;
    d2g:relationshipValue "TRUE" .

<http://example.org/diagram/diagram/node/4> d2g:follows <http://example.org/diagram/diagram/node/6> .

<http://example.org/diagram/diagram/edge/67> a d2g:Solid, d2g:Edge ;
    d2g:source <http://example.org/diagram/diagram/node/6> ;
    d2g:target <http://example.org/diagram/diagram/node/7> ;
    d2g:relationshipType d2g:Follows .

<http://example.org/diagram/diagram/node/6> d2g:follows <http://example.org/diagram/diagram/node/7> .

<http://example.org/diagram/diagram/edge/78> a d2g:Solid, d2g:Edge ;
    d2g:source <http://example.org/diagram/diagram/node/7> ;
    d2g:target <http://example.org/diagram/diagram/node/8> ;
    d2g:relationshipType d2g:Follows .

<http://example.org/diagram/diagram/node/7> d2g:follows <http://example.org/diagram/diagram/node/8> .

<http://example.org/diagram/diagram/edge/84> a d2g:Solid, d2g:Edge ;
    d2g:source <http://example.org/diagram/diagram/node/8> ;
    d2g:target <http://example.org/diagram/diagram/node/4> ;
    d2g:relationshipType d2g:Follows .

<http://example.org/diagram/diagram/node/8> d2g:follows <http://example.org/diagram/diagram/node/4> .

<http://example.org/diagram/diagram/edge/59> a d2g:Solid, d2g:Edge ;
    d2g:source <http://example.org/diagram/diagram/node/5> ;
    d2g:target <http://example.org/diagram/diagram/node/9> ;
    d2g:relationshipType d2g:Follows .

<http://example.org/diagram/diagram/node/5> d2g:follows <http://example.org/diagram/diagram/node/9> .
# Example B (from 4.png / 4.ttl)
@prefix d2g: <http://example.org/diagram2graph#> .
@prefix rdfs: <http://www.w3.org/2000/01/rdf-schema#> .

# === Nodes ===
<http://example.org/diagram/diagram/node/1> a d2g:Start, d2g:Node ;
    rdfs:label "Begin" ;
    d2g:shape d2g:TartEvent .

<http://example.org/diagram/diagram/node/2> a d2g:Process, d2g:Node ;
    rdfs:label "Initialize weights and biases With random values" ;
    d2g:shape d2g:TaK .

<http://example.org/diagram/diagram/node/3> a d2g:Process, d2g:Node ;
    rdfs:label "Perform oprations" ;
    d2g:shape d2g:TaK .

<http://example.org/diagram/diagram/node/4> a d2g:Process, d2g:Node ;
    rdfs:label "Calculate Error" ;
    d2g:shape d2g:TaK .

<http://example.org/diagram/diagram/node/5> a d2g:Decision, d2g:Node ;
    rdfs:label "Error<=Error" ;
    d2g:shape d2g:Gateway .

<http://example.org/diagram/diagram/node/6> a d2g:Decision, d2g:Node ;
    rdfs:label "Epoch>=Epoch" ;
    d2g:shape d2g:Gateway .

<http://example.org/diagram/diagram/node/7> a d2g:Process, d2g:Node ;
    rdfs:label "Update weights and biases" ;
    d2g:shape d2g:TaK .

<http://example.org/diagram/diagram/node/8> a d2g:Process, d2g:Node ;
    rdfs:label "Epoch=epoch+1" ;
    d2g:shape d2g:TaK .

<http://example.org/diagram/diagram/node/9> a d2g:Terminator, d2g:Node ;
    rdfs:label "End" ;
    d2g:shape d2g:EndEvent .

# === Edges ===
<http://example.org/diagram/diagram/edge/12> a d2g:Solid, d2g:Edge ;
    d2g:source <http://example.org/diagram/diagram/node/1> ;
    d2g:target <http://example.org/diagram/diagram/node/2> ;
    d2g:relationshipType d2g:Follows .

<http://example.org/diagram/diagram/node/1> d2g:follows <http://example.org/diagram/diagram/node/2> .

<http://example.org/diagram/diagram/edge/23> a d2g:Solid, d2g:Edge ;
    d2g:source <http://example.org/diagram/diagram/node/2> ;
    d2g:target <http://example.org/diagram/diagram/node/3> ;
    d2g:relationshipType d2g:Follows .

<http://example.org/diagram/diagram/node/2> d2g:follows <http://example.org/diagram/diagram/node/3> .

<http://example.org/diagram/diagram/edge/34> a d2g:Solid, d2g:Edge ;
    d2g:source <http://example.org/diagram/diagram/node/3> ;
    d2g:target <http://example.org/diagram/diagram/node/4> ;
    d2g:relationshipType d2g:Follows .

<http://example.org/diagram/diagram/node/3> d2g:follows <http://example.org/diagram/diagram/node/4> .

<http://example.org/diagram/diagram/edge/45> a d2g:Solid, d2g:Edge ;
    d2g:source <http://example.org/diagram/diagram/node/4> ;
    d2g:target <http://example.org/diagram/diagram/node/5> ;
    d2g:relationshipType d2g:Follows .

<http://example.org/diagram/diagram/node/4> d2g:follows <http://example.org/diagram/diagram/node/5> .

<http://example.org/diagram/diagram/edge/59> a d2g:Solid, d2g:Edge ;
    d2g:source <http://example.org/diagram/diagram/node/5> ;
    d2g:target <http://example.org/diagram/diagram/node/9> ;
    d2g:relationshipType d2g:Follows ;
    d2g:relationshipValue "Yes" .

<http://example.org/diagram/diagram/node/5> d2g:follows <http://example.org/diagram/diagram/node/9> .

<http://example.org/diagram/diagram/edge/56> a d2g:Solid, d2g:Edge ;
    d2g:source <http://example.org/diagram/diagram/node/5> ;
    d2g:target <http://example.org/diagram/diagram/node/6> ;
    d2g:relationshipType d2g:Follows ;
    d2g:relationshipValue "No" .

<http://example.org/diagram/diagram/node/5> d2g:follows <http://example.org/diagram/diagram/node/6> .

<http://example.org/diagram/diagram/edge/69> a d2g:Solid, d2g:Edge ;
    d2g:source <http://example.org/diagram/diagram/node/6> ;
    d2g:target <http://example.org/diagram/diagram/node/9> ;
    d2g:relationshipType d2g:Follows ;
    d2g:relationshipValue "Yes" .

<http://example.org/diagram/diagram/node/6> d2g:follows <http://example.org/diagram/diagram/node/9> .

<http://example.org/diagram/diagram/edge/67> a d2g:Solid, d2g:Edge ;
    d2g:source <http://example.org/diagram/diagram/node/6> ;
    d2g:target <http://example.org/diagram/diagram/node/7> ;
    d2g:relationshipType d2g:Follows ;
    d2g:relationshipValue "No" .

<http://example.org/diagram/diagram/node/6> d2g:follows <http://example.org/diagram/diagram/node/7> .

<http://example.org/diagram/diagram/edge/78> a d2g:Solid, d2g:Edge ;
    d2g:source <http://example.org/diagram/diagram/node/7> ;
    d2g:target <http://example.org/diagram/diagram/node/8> ;
    d2g:relationshipType d2g:Follows .

<http://example.org/diagram/diagram/node/7> d2g:follows <http://example.org/diagram/diagram/node/8> .

<http://example.org/diagram/diagram/edge/83> a d2g:Solid, d2g:Edge ;
    d2g:source <http://example.org/diagram/diagram/node/8> ;
    d2g:target <http://example.org/diagram/diagram/node/3> ;
    d2g:relationshipType d2g:Follows .

<http://example.org/diagram/diagram/node/8> d2g:follows <http://example.org/diagram/diagram/node/3> .
# Example C (from 6.png / 6.ttl)
@prefix d2g: <http://example.org/diagram2graph#> .
@prefix rdfs: <http://www.w3.org/2000/01/rdf-schema#> .

# === Nodes ===
<http://example.org/diagram/diagram/node/1> a d2g:Start, d2g:Node ;
    rdfs:label "Start" ;
    d2g:shape d2g:TartEvent .

<http://example.org/diagram/diagram/node/2> a d2g:Decision, d2g:Node ;
    rdfs:label "Is target sector < max sector?" ;
    d2g:shape d2g:Gateway .

<http://example.org/diagram/diagram/node/3> a d2g:Process, d2g:Node ;
    rdfs:label "Increment Sector" ;
    d2g:shape d2g:TaK .

<http://example.org/diagram/diagram/node/4> a d2g:Process, d2g:Node ;
    rdfs:label "Target Sector=0" ;
    d2g:shape d2g:TaK .

<http://example.org/diagram/diagram/node/5> a d2g:Decision, d2g:Node ;
    rdfs:label "Want to update?" ;
    d2g:shape d2g:Gateway .

<http://example.org/diagram/diagram/node/6> a d2g:Process, d2g:Node ;
    rdfs:label "Increment head" ;
    d2g:shape d2g:TaK .

<http://example.org/diagram/diagram/node/7> a d2g:Process, d2g:Node ;
    rdfs:label "Target head=0" ;
    d2g:shape d2g:TaK .

<http://example.org/diagram/diagram/node/8> a d2g:Process, d2g:Node ;
    rdfs:label "Increment" ;
    d2g:shape d2g:TaK .

<http://example.org/diagram/diagram/node/9> a d2g:Terminator, d2g:Node ;
    rdfs:label "End" ;
    d2g:shape d2g:EndEvent .

# === Edges ===
<http://example.org/diagram/diagram/edge/12> a d2g:Solid, d2g:Edge ;
    d2g:source <http://example.org/diagram/diagram/node/1> ;
    d2g:target <http://example.org/diagram/diagram/node/2> ;
    d2g:relationshipType d2g:Follows .

<http://example.org/diagram/diagram/node/1> d2g:follows <http://example.org/diagram/diagram/node/2> .

<http://example.org/diagram/diagram/edge/23> a d2g:Solid, d2g:Edge ;
    d2g:source <http://example.org/diagram/diagram/node/2> ;
    d2g:target <http://example.org/diagram/diagram/node/3> ;
    d2g:relationshipType d2g:Follows ;
    d2g:relationshipValue "Yes" .

<http://example.org/diagram/diagram/node/2> d2g:follows <http://example.org/diagram/diagram/node/3> .

<http://example.org/diagram/diagram/edge/39> a d2g:Solid, d2g:Edge ;
    d2g:source <http://example.org/diagram/diagram/node/3> ;
    d2g:target <http://example.org/diagram/diagram/node/9> ;
    d2g:relationshipType d2g:Follows .

<http://example.org/diagram/diagram/node/3> d2g:follows <http://example.org/diagram/diagram/node/9> .

<http://example.org/diagram/diagram/edge/24> a d2g:Solid, d2g:Edge ;
    d2g:source <http://example.org/diagram/diagram/node/2> ;
    d2g:target <http://example.org/diagram/diagram/node/4> ;
    d2g:relationshipType d2g:Follows ;
    d2g:relationshipValue "No" .

<http://example.org/diagram/diagram/node/2> d2g:follows <http://example.org/diagram/diagram/node/4> .

<http://example.org/diagram/diagram/edge/45> a d2g:Solid, d2g:Edge ;
    d2g:source <http://example.org/diagram/diagram/node/4> ;
    d2g:target <http://example.org/diagram/diagram/node/5> ;
    d2g:relationshipType d2g:Follows .

<http://example.org/diagram/diagram/node/4> d2g:follows <http://example.org/diagram/diagram/node/5> .

<http://example.org/diagram/diagram/edge/56> a d2g:Solid, d2g:Edge ;
    d2g:source <http://example.org/diagram/diagram/node/5> ;
    d2g:target <http://example.org/diagram/diagram/node/6> ;
    d2g:relationshipType d2g:Follows ;
    d2g:relationshipValue "Yes" .

<http://example.org/diagram/diagram/node/5> d2g:follows <http://example.org/diagram/diagram/node/6> .

<http://example.org/diagram/diagram/edge/69> a d2g:Solid, d2g:Edge ;
    d2g:source <http://example.org/diagram/diagram/node/6> ;
    d2g:target <http://example.org/diagram/diagram/node/9> ;
    d2g:relationshipType d2g:Follows .

<http://example.org/diagram/diagram/node/6> d2g:follows <http://example.org/diagram/diagram/node/9> .

<http://example.org/diagram/diagram/edge/57> a d2g:Solid, d2g:Edge ;
    d2g:source <http://example.org/diagram/diagram/node/5> ;
    d2g:target <http://example.org/diagram/diagram/node/7> ;
    d2g:relationshipType d2g:Follows ;
    d2g:relationshipValue "No" .

<http://example.org/diagram/diagram/node/5> d2g:follows <http://example.org/diagram/diagram/node/7> .

<http://example.org/diagram/diagram/edge/78> a d2g:Solid, d2g:Edge ;
    d2g:source <http://example.org/diagram/diagram/node/7> ;
    d2g:target <http://example.org/diagram/diagram/node/8> ;
    d2g:relationshipType d2g:Follows .

<http://example.org/diagram/diagram/node/7> d2g:follows <http://example.org/diagram/diagram/node/8> .

<http://example.org/diagram/diagram/edge/89> a d2g:Solid, d2g:Edge ;
    d2g:source <http://example.org/diagram/diagram/node/8> ;
    d2g:target <http://example.org/diagram/diagram/node/9> ;
    d2g:relationshipType d2g:Follows .

<http://example.org/diagram/diagram/node/8> d2g:follows <http://example.org/diagram/diagram/node/9> .

```

Example B — (image similar to 4.png)
Assistant (expected TTL)
```turtle
@prefix d2g: <http://example.org/diagram2graph#> .
@prefix rdfs: <http://www.w3.org/2000/01/rdf-schema#> .

# === Nodes ===
<http://example.org/diagram/diagram/node/1> a d2g:Start, d2g:Node ;
    rdfs:label "Begin" ;
    d2g:shape d2g:TartEvent .

<http://example.org/diagram/diagram/node/2> a d2g:Process, d2g:Node ;
    rdfs:label "Initialize weights and biases With random values" ;
    d2g:shape d2g:TaK .

<http://example.org/diagram/diagram/node/3> a d2g:Process, d2g:Node ;
    rdfs:label "Perform oprations" ;
    d2g:shape d2g:TaK .

<http://example.org/diagram/diagram/node/4> a d2g:Process, d2g:Node ;
    rdfs:label "Calculate Error" ;
    d2g:shape d2g:TaK .

<http://example.org/diagram/diagram/node/5> a d2g:Decision, d2g:Node ;
    rdfs:label "Error<=Error" ;
    d2g:shape d2g:Gateway .

<http://example.org/diagram/diagram/node/6> a d2g:Decision, d2g:Node ;
    rdfs:label "Epoch>=Epoch" ;
    d2g:shape d2g:Gateway .

<http://example.org/diagram/diagram/node/7> a d2g:Process, d2g:Node ;
    rdfs:label "Update weights and biases" ;
    d2g:shape d2g:TaK .

<http://example.org/diagram/diagram/node/8> a d2g:Process, d2g:Node ;
    rdfs:label "Epoch=epoch+1" ;
    d2g:shape d2g:TaK .

<http://example.org/diagram/diagram/node/9> a d2g:Terminator, d2g:Node ;
    rdfs:label "End" ;
    d2g:shape d2g:EndEvent .

# === Edges ===
<http://example.org/diagram/diagram/edge/12> a d2g:Solid, d2g:Edge ;
    d2g:source <http://example.org/diagram/diagram/node/1> ;
    d2g:target <http://example.org/diagram/diagram/node/2> ;
    d2g:relationshipType d2g:Follows .

<http://example.org/diagram/diagram/node/1> d2g:follows <http://example.org/diagram/diagram/node/2> .

<http://example.org/diagram/diagram/edge/23> a d2g:Solid, d2g:Edge ;
    d2g:source <http://example.org/diagram/diagram/node/2> ;
    d2g:target <http://example.org/diagram/diagram/node/3> ;
    d2g:relationshipType d2g:Follows .

<http://example.org/diagram/diagram/node/2> d2g:follows <http://example.org/diagram/diagram/node/3> .

<http://example.org/diagram/diagram/edge/34> a d2g:Solid, d2g:Edge ;
    d2g:source <http://example.org/diagram/diagram/node/3> ;
    d2g:target <http://example.org/diagram/diagram/node/4> ;
    d2g:relationshipType d2g:Follows .

<http://example.org/diagram/diagram/node/3> d2g:follows <http://example.org/diagram/diagram/node/4> .

<http://example.org/diagram/diagram/edge/45> a d2g:Solid, d2g:Edge ;
    d2g:source <http://example.org/diagram/diagram/node/4> ;
    d2g:target <http://example.org/diagram/diagram/node/5> ;
    d2g:relationshipType d2g:Follows .

<http://example.org/diagram/diagram/node/4> d2g:follows <http://example.org/diagram/diagram/node/5> .

<http://example.org/diagram/diagram/edge/59> a d2g:Solid, d2g:Edge ;
    d2g:source <http://example.org/diagram/diagram/node/5> ;
    d2g:target <http://example.org/diagram/diagram/node/9> ;
    d2g:relationshipType d2g:Follows ;
    d2g:relationshipValue "Yes" .

<http://example.org/diagram/diagram/node/5> d2g:follows <http://example.org/diagram/diagram/node/9> .

<http://example.org/diagram/diagram/edge/56> a d2g:Solid, d2g:Edge ;
    d2g:source <http://example.org/diagram/diagram/node/5> ;
    d2g:target <http://example.org/diagram/diagram/node/6> ;
    d2g:relationshipType d2g:Follows ;
    d2g:relationshipValue "No" .

<http://example.org/diagram/diagram/node/5> d2g:follows <http://example.org/diagram/diagram/node/6> .

<http://example.org/diagram/diagram/edge/69> a d2g:Solid, d2g:Edge ;
    d2g:source <http://example.org/diagram/diagram/node/6> ;
    d2g:target <http://example.org/diagram/diagram/node/9> ;
    d2g:relationshipType d2g:Follows ;
    d2g:relationshipValue "Yes" .

<http://example.org/diagram/diagram/node/6> d2g:follows <http://example.org/diagram/diagram/node/9> .

<http://example.org/diagram/diagram/edge/67> a d2g:Solid, d2g:Edge ;
    d2g:source <http://example.org/diagram/diagram/node/6> ;
    d2g:target <http://example.org/diagram/diagram/node/7> ;
    d2g:relationshipType d2g:Follows ;
    d2g:relationshipValue "No" .

<http://example.org/diagram/diagram/node/6> d2g:follows <http://example.org/diagram/diagram/node/7> .

<http://example.org/diagram/diagram/edge/78> a d2g:Solid, d2g:Edge ;
    d2g:source <http://example.org/diagram/diagram/node/7> ;
    d2g:target <http://example.org/diagram/diagram/node/8> ;
    d2g:relationshipType d2g:Follows .

<http://example.org/diagram/diagram/node/7> d2g:follows <http://example.org/diagram/diagram/node/8> .

<http://example.org/diagram/diagram/edge/83> a d2g:Solid, d2g:Edge ;
    d2g:source <http://example.org/diagram/diagram/node/8> ;
    d2g:target <http://example.org/diagram/diagram/node/3> ;
    d2g:relationshipType d2g:Follows .

<http://example.org/diagram/diagram/node/8> d2g:follows <http://example.org/diagram/diagram/node/3> .

```

Example C — (image similar to 6.png)
Assistant (expected TTL)
```turtle
@prefix d2g: <http://example.org/diagram2graph#> .
@prefix rdfs: <http://www.w3.org/2000/01/rdf-schema#> .

# === Nodes ===
<http://example.org/diagram/diagram/node/1> a d2g:Start, d2g:Node ;
    rdfs:label "Start" ;
    d2g:shape d2g:TartEvent .

<http://example.org/diagram/diagram/node/2> a d2g:Decision, d2g:Node ;
    rdfs:label "Is target sector < max sector?" ;
    d2g:shape d2g:Gateway .

<http://example.org/diagram/diagram/node/3> a d2g:Process, d2g:Node ;
    rdfs:label "Increment Sector" ;
    d2g:shape d2g:TaK .

<http://example.org/diagram/diagram/node/4> a d2g:Process, d2g:Node ;
    rdfs:label "Target Sector=0" ;
    d2g:shape d2g:TaK .

<http://example.org/diagram/diagram/node/5> a d2g:Decision, d2g:Node ;
    rdfs:label "Want to update?" ;
    d2g:shape d2g:Gateway .

<http://example.org/diagram/diagram/node/6> a d2g:Process, d2g:Node ;
    rdfs:label "Increment head" ;
    d2g:shape d2g:TaK .

<http://example.org/diagram/diagram/node/7> a d2g:Process, d2g:Node ;
    rdfs:label "Target head=0" ;
    d2g:shape d2g:TaK .

<http://example.org/diagram/diagram/node/8> a d2g:Process, d2g:Node ;
    rdfs:label "Increment" ;
    d2g:shape d2g:TaK .

<http://example.org/diagram/diagram/node/9> a d2g:Terminator, d2g:Node ;
    rdfs:label "End" ;
    d2g:shape d2g:EndEvent .

# === Edges ===
<http://example.org/diagram/diagram/edge/12> a d2g:Solid, d2g:Edge ;
    d2g:source <http://example.org/diagram/diagram/node/1> ;
    d2g:target <http://example.org/diagram/diagram/node/2> ;
    d2g:relationshipType d2g:Follows .

<http://example.org/diagram/diagram/node/1> d2g:follows <http://example.org/diagram/diagram/node/2> .

<http://example.org/diagram/diagram/edge/23> a d2g:Solid, d2g:Edge ;
    d2g:source <http://example.org/diagram/diagram/node/2> ;
    d2g:target <http://example.org/diagram/diagram/node/3> ;
    d2g:relationshipType d2g:Follows ;
    d2g:relationshipValue "Yes" .

<http://example.org/diagram/diagram/node/2> d2g:follows <http://example.org/diagram/diagram/node/3> .

<http://example.org/diagram/diagram/edge/39> a d2g:Solid, d2g:Edge ;
    d2g:source <http://example.org/diagram/diagram/node/3> ;
    d2g:target <http://example.org/diagram/diagram/node/9> ;
    d2g:relationshipType d2g:Follows .

<http://example.org/diagram/diagram/node/3> d2g:follows <http://example.org/diagram/diagram/node/9> .

<http://example.org/diagram/diagram/edge/24> a d2g:Solid, d2g:Edge ;
    d2g:source <http://example.org/diagram/diagram/node/2> ;
    d2g:target <http://example.org/diagram/diagram/node/4> ;
    d2g:relationshipType d2g:Follows ;
    d2g:relationshipValue "No" .

<http://example.org/diagram/diagram/node/2> d2g:follows <http://example.org/diagram/diagram/node/4> .

<http://example.org/diagram/diagram/edge/45> a d2g:Solid, d2g:Edge ;
    d2g:source <http://example.org/diagram/diagram/node/4> ;
    d2g:target <http://example.org/diagram/diagram/node/5> ;
    d2g:relationshipType d2g:Follows .

<http://example.org/diagram/diagram/node/4> d2g:follows <http://example.org/diagram/diagram/node/5> .

<http://example.org/diagram/diagram/edge/56> a d2g:Solid, d2g:Edge ;
    d2g:source <http://example.org/diagram/diagram/node/5> ;
    d2g:target <http://example.org/diagram/diagram/node/6> ;
    d2g:relationshipType d2g:Follows ;
    d2g:relationshipValue "Yes" .

<http://example.org/diagram/diagram/node/5> d2g:follows <http://example.org/diagram/diagram/node/6> .

<http://example.org/diagram/diagram/edge/69> a d2g:Solid, d2g:Edge ;
    d2g:source <http://example.org/diagram/diagram/node/6> ;
    d2g:target <http://example.org/diagram/diagram/node/9> ;
    d2g:relationshipType d2g:Follows .

<http://example.org/diagram/diagram/node/6> d2g:follows <http://example.org/diagram/diagram/node/9> .

<http://example.org/diagram/diagram/edge/57> a d2g:Solid, d2g:Edge ;
    d2g:source <http://example.org/diagram/diagram/node/5> ;
    d2g:target <http://example.org/diagram/diagram/node/7> ;
    d2g:relationshipType d2g:Follows ;
    d2g:relationshipValue "No" .

<http://example.org/diagram/diagram/node/5> d2g:follows <http://example.org/diagram/diagram/node/7> .

<http://example.org/diagram/diagram/edge/78> a d2g:Solid, d2g:Edge ;
    d2g:source <http://example.org/diagram/diagram/node/7> ;
    d2g:target <http://example.org/diagram/diagram/node/8> ;
    d2g:relationshipType d2g:Follows .

<http://example.org/diagram/diagram/node/7> d2g:follows <http://example.org/diagram/diagram/node/8> .

<http://example.org/diagram/diagram/edge/89> a d2g:Solid, d2g:Edge ;
    d2g:source <http://example.org/diagram/diagram/node/8> ;
    d2g:target <http://example.org/diagram/diagram/node/9> ;
    d2g:relationshipType d2g:Follows .

<http://example.org/diagram/diagram/node/8> d2g:follows <http://example.org/diagram/diagram/node/9> .

```

---
User
Here is a new image. Produce the TTL now.


"""

# =========================
# 3) HELPERS
# =========================
def get_mime_type(path: str) -> str:
    ext = Path(path).suffix.lower()
    if ext in {".jpg", ".jpeg"}:
        return "image/jpeg"
    if ext == ".png":
        return "image/png"
    if ext in {".tif", ".tiff"}:
        return "image/tiff"
    if ext == ".webp":
        return "image/webp"
    if ext == ".bmp":
        return "image/bmp"
    return "image/jpeg"

def encode_image_to_base64(image_path: str) -> Optional[str]:
    try:
        # Ensure the image is readable; PIL open also validates file integrity
        with Image.open(image_path) as _:
            pass
        data = Path(image_path).read_bytes()
        return base64.b64encode(data).decode("utf-8")
    except FileNotFoundError:
        print(f"[WARN] File not found: {image_path}")
        return None
    except Exception as e:
        print(f"[WARN] Failed to read {image_path}: {e}")
        return None

def build_request(image_b64: str, mime_type: str, prompt: str) -> dict:
    return {
        "contents": [
            {
                "role": "user",
                "parts": [
                    {"inlineData": {"mimeType": mime_type, "data": image_b64}},
                    {"text": prompt},
                ],
            }
        ],
        "generationConfig": {
            "temperature": 0.1,
            "topP": 0.9,
            "maxOutputTokens": 8192,
        },
    }

def _strip_code_fences(text: str) -> str:
    """
    Removes ```turtle ... ``` or ``` ... ``` fences if present.
    """
    t = text.strip()
    if t.startswith("```"):
        first_newline = t.find("\n")
        if first_newline != -1 and t[:first_newline].startswith("```"):
            t = t[first_newline + 1 :]
        if t.endswith("```"):
            t = t[:-3].rstrip()
    return t.strip()

def call_gemini(payload: dict, max_retries: int = 4) -> Optional[str]:
    """
    Calls the Gemini API with basic retry/backoff on 429/5xx.
    Returns clean Turtle (TTL) text, or None.
    """
    headers = {"Content-Type": "application/json"}
    backoff = 2.0
    for attempt in range(max_retries):
        try:
            resp = requests.post(ENDPOINT, headers=headers, data=json.dumps(payload), timeout=120)
            if resp.status_code >= 500 or resp.status_code == 429:
                print(f"[INFO] Retryable HTTP {resp.status_code}; attempt {attempt+1}/{max_retries}")
                time.sleep(backoff)
                backoff *= 1.8
                continue
            resp.raise_for_status()
            data = resp.json()
            if "candidates" in data and data["candidates"]:
                raw = data["candidates"][0]["content"]["parts"][0]["text"]
                return _strip_code_fences(raw)
            return None
        except requests.exceptions.RequestException as e:
            print(f"[WARN] Request error: {e}; attempt {attempt+1}/{max_retries}")
            time.sleep(backoff)
            backoff *= 1.8
    return None

def ensure_dir(path: str):
    Path(path).mkdir(parents=True, exist_ok=True)

# =========================
# 4) MAIN: per-image .ttl files
# =========================
def main():
    ensure_dir(OUTPUT_DIR)

    manifest = []  # optional record of what we wrote

    for root, _, files in os.walk(DATASET_DIR):
        for fname in files:
            ext = Path(fname).suffix.lower()
            if ext not in VALID_IMAGE_EXTS:
                continue

            img_path = os.path.join(root, fname)
            stem = Path(fname).stem  # "1.png" -> "1"
            ttl_path = os.path.join(OUTPUT_DIR, f"{stem}.ttl")

            print(f"[INFO] Processing: {img_path} -> {ttl_path}")

            image_b64 = encode_image_to_base64(img_path)
            if not image_b64:
                print(f"[SKIP] Could not encode {img_path}")
                continue

            mime = get_mime_type(img_path)
            payload = build_request(image_b64, mime, PROMPT_TEXT)
            ttl_text = call_gemini(payload)

            if not ttl_text:
                print(f"[WARN] No TTL returned for {img_path}")
                continue

            # Write the TTL file
            with open(ttl_path, "w", encoding="utf-8") as f:
                f.write(ttl_text if ttl_text.endswith("\n") else ttl_text + "\n")

            manifest.append({"source_image": img_path, "ttl_file": ttl_path})

    if WRITE_MANIFEST:
        ensure_dir(OUTPUT_DIR)
        with open(MANIFEST_PATH, "w", encoding="utf-8") as mf:
            json.dump({"items": manifest}, mf, indent=2, ensure_ascii=False)

    print(f"[DONE] Wrote {len(manifest)} TTL files to: {OUTPUT_DIR}")
    if WRITE_MANIFEST:
        print(f"[INFO] Manifest: {MANIFEST_PATH}")

if __name__ == "__main__":
    main()
# Out:
# [INFO] Processing: /kaggle/input/diagram2graph-dataset/diagram2graph/709.png -> /kaggle/working/ttl_FewShot_outputs/709.ttl
# [INFO] Processing: /kaggle/input/diagram2graph-dataset/diagram2graph/94.png -> /kaggle/working/ttl_FewShot_outputs/94.ttl
# [INFO] Processing: /kaggle/input/diagram2graph-dataset/diagram2graph/48.png -> /kaggle/working/ttl_FewShot_outputs/48.ttl
# [INFO] Processing: /kaggle/input/diagram2graph-dataset/diagram2graph/761.png -> /kaggle/working/ttl_FewShot_outputs/761.ttl
# [INFO] Processing: /kaggle/input/diagram2graph-dataset/diagram2graph/655.png -> /kaggle/working/ttl_FewShot_outputs/655.ttl
# [INFO] Processing: /kaggle/input/diagram2graph-dataset/diagram2graph/238.png -> /kaggle/working/ttl_FewShot_outputs/238.ttl
# [INFO] Processing: /kaggle/input/diagram2graph-dataset/diagram2graph/222.png -> /kaggle/working/ttl_FewShot_outputs/222.ttl
# [INFO] Processing: /kaggle/input/diagram2graph-dataset/diagram2graph/278.png -> /kaggle/working/ttl_FewShot_outputs/278.ttl
# [INFO] Processing: /kaggle/input/diagram2graph-dataset/diagram2graph/37.png -> /kaggle/working/ttl_FewShot_outputs/37.ttl
# [INFO] Processing: /kaggle/input/diagram2graph-dataset/diagram2graph/148.png -> /kaggle/working/ttl_FewShot_outputs/148.ttl
# [INFO] Processing: /kaggle/input/diagram2graph-dataset/diagram2graph/35.png -> /kaggle/working/ttl_FewShot_outputs/35.ttl
# [INFO] Processing: /kaggle/input/diagram2graph-dataset/diagram2graph/334.png -> /kaggle/working/ttl_FewShot_outputs/334.ttl
# [INFO] Processing: /kaggle/input/diagram2graph-dataset/diagram2graph/940.png -> /kaggle/working/ttl_FewShot_outputs/940.ttl
# [INFO] Processing: /kaggle/input/diagram2graph-dataset/diagram2graph/634.png -> /kaggle/working/ttl_FewShot_outputs/634.ttl
# [INFO] Processing: /kaggle/input/diagram2graph-dataset/diagram2graph/933.png -> /kaggle/working/ttl_FewShot_outputs/933.ttl
# [INFO] Processing: /kaggle/input/diagram2graph-dataset/diagram2graph/542.png -> /kaggle/working/ttl_FewShot_outputs/542.ttl
# [INFO] Processing: /kaggle/input/diagram2graph-dataset/diagram2graph/315.png -> /kaggle/working/ttl_FewShot_outputs/315.ttl
# [INFO] Processing: /kaggle/input/diagram2graph-dataset/diagram2graph/153.png -> /kaggle/working/ttl_FewShot_outputs/153.ttl
# [INFO] Processing: /kaggle/input/diagram2graph-dataset/diagram2graph/562.png -> /kaggle/working/ttl_FewShot_outputs/562.ttl
# [INFO] Processing: /kaggle/input/diagram2graph-dataset/diagram2graph/204.png -> /kaggle/working/ttl_FewShot_outputs/204.ttl
# [INFO] Processing: /kaggle/input/diagram2graph-dataset/diagram2graph/75.png -> /kaggle/working/ttl_FewShot_outputs/75.ttl
# [INFO] Processing: /kaggle/input/diagram2graph-dataset/diagram2graph/521.png -> /kaggle/working/ttl_FewShot_outputs/521.ttl
# [INFO] Processing: /kaggle/input/diagram2graph-dataset/diagram2graph/11.png -> /kaggle/working/ttl_FewShot_outputs/11.ttl
# [INFO] Processing: /kaggle/input/diagram2graph-dataset/diagram2graph/416.png -> /kaggle/working/ttl_FewShot_outputs/416.ttl
# [INFO] Processing: /kaggle/input/diagram2graph-dataset/diagram2graph/605.png -> /kaggle/working/ttl_FewShot_outputs/605.ttl
# [INFO] Processing: /kaggle/input/diagram2graph-dataset/diagram2graph/351.png -> /kaggle/working/ttl_FewShot_outputs/351.ttl
# [INFO] Processing: /kaggle/input/diagram2graph-dataset/diagram2graph/411.png -> /kaggle/working/ttl_FewShot_outputs/411.ttl
# [INFO] Processing: /kaggle/input/diagram2graph-dataset/diagram2graph/114.png -> /kaggle/working/ttl_FewShot_outputs/114.ttl
# [INFO] Processing: /kaggle/input/diagram2graph-dataset/diagram2graph/930.png -> /kaggle/working/ttl_FewShot_outputs/930.ttl
# [INFO] Processing: /kaggle/input/diagram2graph-dataset/diagram2graph/457.png -> /kaggle/working/ttl_FewShot_outputs/457.ttl
# [INFO] Processing: /kaggle/input/diagram2graph-dataset/diagram2graph/907.png -> /kaggle/working/ttl_FewShot_outputs/907.ttl
# [INFO] Processing: /kaggle/input/diagram2graph-dataset/diagram2graph/432.png -> /kaggle/working/ttl_FewShot_outputs/432.ttl
# [INFO] Processing: /kaggle/input/diagram2graph-dataset/diagram2graph/119.png -> /kaggle/working/ttl_FewShot_outputs/119.ttl
# [INFO] Processing: /kaggle/input/diagram2graph-dataset/diagram2graph/100.png -> /kaggle/working/ttl_FewShot_outputs/100.ttl
# [INFO] Processing: /kaggle/input/diagram2graph-dataset/diagram2graph/322.png -> /kaggle/working/ttl_FewShot_outputs/322.ttl
# [INFO] Processing: /kaggle/input/diagram2graph-dataset/diagram2graph/76.png -> /kaggle/working/ttl_FewShot_outputs/76.ttl
# [INFO] Processing: /kaggle/input/diagram2graph-dataset/diagram2graph/193.png -> /kaggle/working/ttl_FewShot_outputs/193.ttl
# [INFO] Processing: /kaggle/input/diagram2graph-dataset/diagram2graph/163.png -> /kaggle/working/ttl_FewShot_outputs/163.ttl
# [INFO] Processing: /kaggle/input/diagram2graph-dataset/diagram2graph/31.png -> /kaggle/working/ttl_FewShot_outputs/31.ttl
# [INFO] Processing: /kaggle/input/diagram2graph-dataset/diagram2graph/4.png -> /kaggle/working/ttl_FewShot_outputs/4.ttl
# [INFO] Processing: /kaggle/input/diagram2graph-dataset/diagram2graph/192.png -> /kaggle/working/ttl_FewShot_outputs/192.ttl
# [INFO] Processing: /kaggle/input/diagram2graph-dataset/diagram2graph/229.png -> /kaggle/working/ttl_FewShot_outputs/229.ttl
# [INFO] Processing: /kaggle/input/diagram2graph-dataset/diagram2graph/331.png -> /kaggle/working/ttl_FewShot_outputs/331.ttl
# [INFO] Processing: /kaggle/input/diagram2graph-dataset/diagram2graph/672.png -> /kaggle/working/ttl_FewShot_outputs/672.ttl
# [INFO] Processing: /kaggle/input/diagram2graph-dataset/diagram2graph/580.png -> /kaggle/working/ttl_FewShot_outputs/580.ttl
# [INFO] Processing: /kaggle/input/diagram2graph-dataset/diagram2graph/345.png -> /kaggle/working/ttl_FewShot_outputs/345.ttl
# [INFO] Processing: /kaggle/input/diagram2graph-dataset/diagram2graph/171.png -> /kaggle/working/ttl_FewShot_outputs/171.ttl
# [INFO] Processing: /kaggle/input/diagram2graph-dataset/diagram2graph/40.png -> /kaggle/working/ttl_FewShot_outputs/40.ttl
# [INFO] Processing: /kaggle/input/diagram2graph-dataset/diagram2graph/33.png -> /kaggle/working/ttl_FewShot_outputs/33.ttl
# [INFO] Processing: /kaggle/input/diagram2graph-dataset/diagram2graph/147.png -> /kaggle/working/ttl_FewShot_outputs/147.ttl
# [INFO] Processing: /kaggle/input/diagram2graph-dataset/diagram2graph/9.png -> /kaggle/working/ttl_FewShot_outputs/9.ttl
# [INFO] Processing: /kaggle/input/diagram2graph-dataset/diagram2graph/254.png -> /kaggle/working/ttl_FewShot_outputs/254.ttl
# [INFO] Processing: /kaggle/input/diagram2graph-dataset/diagram2graph/931.png -> /kaggle/working/ttl_FewShot_outputs/931.ttl
# [INFO] Processing: /kaggle/input/diagram2graph-dataset/diagram2graph/823.png -> /kaggle/working/ttl_FewShot_outputs/823.ttl
# [INFO] Processing: /kaggle/input/diagram2graph-dataset/diagram2graph/891.png -> /kaggle/working/ttl_FewShot_outputs/891.ttl
# [INFO] Processing: /kaggle/input/diagram2graph-dataset/diagram2graph/233.png -> /kaggle/working/ttl_FewShot_outputs/233.ttl
# [INFO] Processing: /kaggle/input/diagram2graph-dataset/diagram2graph/284.png -> /kaggle/working/ttl_FewShot_outputs/284.ttl
# [INFO] Processing: /kaggle/input/diagram2graph-dataset/diagram2graph/888.png -> /kaggle/working/ttl_FewShot_outputs/888.ttl
# [INFO] Processing: /kaggle/input/diagram2graph-dataset/diagram2graph/818.png -> /kaggle/working/ttl_FewShot_outputs/818.ttl
# [INFO] Processing: /kaggle/input/diagram2graph-dataset/diagram2graph/911.png -> /kaggle/working/ttl_FewShot_outputs/911.ttl
# [INFO] Processing: /kaggle/input/diagram2graph-dataset/diagram2graph/116.png -> /kaggle/working/ttl_FewShot_outputs/116.ttl
# [INFO] Processing: /kaggle/input/diagram2graph-dataset/diagram2graph/520.png -> /kaggle/working/ttl_FewShot_outputs/520.ttl
# [INFO] Processing: /kaggle/input/diagram2graph-dataset/diagram2graph/80.png -> /kaggle/working/ttl_FewShot_outputs/80.ttl
# [INFO] Processing: /kaggle/input/diagram2graph-dataset/diagram2graph/55.png -> /kaggle/working/ttl_FewShot_outputs/55.ttl
# [INFO] Processing: /kaggle/input/diagram2graph-dataset/diagram2graph/291.png -> /kaggle/working/ttl_FewShot_outputs/291.ttl
# [INFO] Processing: /kaggle/input/diagram2graph-dataset/diagram2graph/288.png -> /kaggle/working/ttl_FewShot_outputs/288.ttl
# [INFO] Processing: /kaggle/input/diagram2graph-dataset/diagram2graph/589.png -> /kaggle/working/ttl_FewShot_outputs/589.ttl
# [INFO] Processing: /kaggle/input/diagram2graph-dataset/diagram2graph/607.png -> /kaggle/working/ttl_FewShot_outputs/607.ttl
# [INFO] Processing: /kaggle/input/diagram2graph-dataset/diagram2graph/938.png -> /kaggle/working/ttl_FewShot_outputs/938.ttl
# [INFO] Processing: /kaggle/input/diagram2graph-dataset/diagram2graph/49.png -> /kaggle/working/ttl_FewShot_outputs/49.ttl
# [INFO] Processing: /kaggle/input/diagram2graph-dataset/diagram2graph/268.png -> /kaggle/working/ttl_FewShot_outputs/268.ttl
# [INFO] Processing: /kaggle/input/diagram2graph-dataset/diagram2graph/93.png -> /kaggle/working/ttl_FewShot_outputs/93.ttl
# [INFO] Processing: /kaggle/input/diagram2graph-dataset/diagram2graph/113.png -> /kaggle/working/ttl_FewShot_outputs/113.ttl
# [INFO] Processing: /kaggle/input/diagram2graph-dataset/diagram2graph/332.png -> /kaggle/working/ttl_FewShot_outputs/332.ttl
# [INFO] Processing: /kaggle/input/diagram2graph-dataset/diagram2graph/170.png -> /kaggle/working/ttl_FewShot_outputs/170.ttl
# [INFO] Processing: /kaggle/input/diagram2graph-dataset/diagram2graph/198.png -> /kaggle/working/ttl_FewShot_outputs/198.ttl
# [INFO] Processing: /kaggle/input/diagram2graph-dataset/diagram2graph/924.png -> /kaggle/working/ttl_FewShot_outputs/924.ttl
# [INFO] Processing: /kaggle/input/diagram2graph-dataset/diagram2graph/401.png -> /kaggle/working/ttl_FewShot_outputs/401.ttl
# [INFO] Processing: /kaggle/input/diagram2graph-dataset/diagram2graph/14.png -> /kaggle/working/ttl_FewShot_outputs/14.ttl
# [INFO] Processing: /kaggle/input/diagram2graph-dataset/diagram2graph/65.png -> /kaggle/working/ttl_FewShot_outputs/65.ttl
# [INFO] Processing: /kaggle/input/diagram2graph-dataset/diagram2graph/706.png -> /kaggle/working/ttl_FewShot_outputs/706.ttl
# [INFO] Processing: /kaggle/input/diagram2graph-dataset/diagram2graph/293.png -> /kaggle/working/ttl_FewShot_outputs/293.ttl
# [INFO] Processing: /kaggle/input/diagram2graph-dataset/diagram2graph/576.png -> /kaggle/working/ttl_FewShot_outputs/576.ttl
# [INFO] Processing: /kaggle/input/diagram2graph-dataset/diagram2graph/701.png -> /kaggle/working/ttl_FewShot_outputs/701.ttl
# [INFO] Processing: /kaggle/input/diagram2graph-dataset/diagram2graph/926.png -> /kaggle/working/ttl_FewShot_outputs/926.ttl
# [INFO] Processing: /kaggle/input/diagram2graph-dataset/diagram2graph/39.png -> /kaggle/working/ttl_FewShot_outputs/39.ttl
# [INFO] Processing: /kaggle/input/diagram2graph-dataset/diagram2graph/380.png -> /kaggle/working/ttl_FewShot_outputs/380.ttl
# [INFO] Processing: /kaggle/input/diagram2graph-dataset/diagram2graph/446.png -> /kaggle/working/ttl_FewShot_outputs/446.ttl
# [INFO] Processing: /kaggle/input/diagram2graph-dataset/diagram2graph/433.png -> /kaggle/working/ttl_FewShot_outputs/433.ttl
# [INFO] Processing: /kaggle/input/diagram2graph-dataset/diagram2graph/319.png -> /kaggle/working/ttl_FewShot_outputs/319.ttl
# [INFO] Processing: /kaggle/input/diagram2graph-dataset/diagram2graph/107.png -> /kaggle/working/ttl_FewShot_outputs/107.ttl
# [INFO] Processing: /kaggle/input/diagram2graph-dataset/diagram2graph/90.png -> /kaggle/working/ttl_FewShot_outputs/90.ttl
# [INFO] Processing: /kaggle/input/diagram2graph-dataset/diagram2graph/262.png -> /kaggle/working/ttl_FewShot_outputs/262.ttl
# [INFO] Processing: /kaggle/input/diagram2graph-dataset/diagram2graph/215.png -> /kaggle/working/ttl_FewShot_outputs/215.ttl
# [INFO] Processing: /kaggle/input/diagram2graph-dataset/diagram2graph/920.png -> /kaggle/working/ttl_FewShot_outputs/920.ttl
# [INFO] Processing: /kaggle/input/diagram2graph-dataset/diagram2graph/412.png -> /kaggle/working/ttl_FewShot_outputs/412.ttl
# [INFO] Processing: /kaggle/input/diagram2graph-dataset/diagram2graph/910.png -> /kaggle/working/ttl_FewShot_outputs/910.ttl
# [INFO] Processing: /kaggle/input/diagram2graph-dataset/diagram2graph/731.png -> /kaggle/working/ttl_FewShot_outputs/731.ttl
# [INFO] Processing: /kaggle/input/diagram2graph-dataset/diagram2graph/38.png -> /kaggle/working/ttl_FewShot_outputs/38.ttl
# [INFO] Processing: /kaggle/input/diagram2graph-dataset/diagram2graph/2.png -> /kaggle/working/ttl_FewShot_outputs/2.ttl
# [INFO] Processing: /kaggle/input/diagram2graph-dataset/diagram2graph/900.png -> /kaggle/working/ttl_FewShot_outputs/900.ttl
# [INFO] Processing: /kaggle/input/diagram2graph-dataset/diagram2graph/335.png -> /kaggle/working/ttl_FewShot_outputs/335.ttl
# [INFO] Processing: /kaggle/input/diagram2graph-dataset/diagram2graph/10.png -> /kaggle/working/ttl_FewShot_outputs/10.ttl
# [INFO] Processing: /kaggle/input/diagram2graph-dataset/diagram2graph/598.png -> /kaggle/working/ttl_FewShot_outputs/598.ttl
# [INFO] Processing: /kaggle/input/diagram2graph-dataset/diagram2graph/174.png -> /kaggle/working/ttl_FewShot_outputs/174.ttl
# [INFO] Processing: /kaggle/input/diagram2graph-dataset/diagram2graph/250.png -> /kaggle/working/ttl_FewShot_outputs/250.ttl
# [INFO] Processing: /kaggle/input/diagram2graph-dataset/diagram2graph/908.png -> /kaggle/working/ttl_FewShot_outputs/908.ttl
# [INFO] Processing: /kaggle/input/diagram2graph-dataset/diagram2graph/556.png -> /kaggle/working/ttl_FewShot_outputs/556.ttl
# [INFO] Processing: /kaggle/input/diagram2graph-dataset/diagram2graph/81.png -> /kaggle/working/ttl_FewShot_outputs/81.ttl
# [INFO] Processing: /kaggle/input/diagram2graph-dataset/diagram2graph/239.png -> /kaggle/working/ttl_FewShot_outputs/239.ttl
# [INFO] Processing: /kaggle/input/diagram2graph-dataset/diagram2graph/66.png -> /kaggle/working/ttl_FewShot_outputs/66.ttl
# [INFO] Processing: /kaggle/input/diagram2graph-dataset/diagram2graph/902.png -> /kaggle/working/ttl_FewShot_outputs/902.ttl
# [INFO] Processing: /kaggle/input/diagram2graph-dataset/diagram2graph/684.png -> /kaggle/working/ttl_FewShot_outputs/684.ttl
# [INFO] Processing: /kaggle/input/diagram2graph-dataset/diagram2graph/735.png -> /kaggle/working/ttl_FewShot_outputs/735.ttl
# [INFO] Processing: /kaggle/input/diagram2graph-dataset/diagram2graph/914.png -> /kaggle/working/ttl_FewShot_outputs/914.ttl
# [INFO] Retryable HTTP 503; attempt 1/4
# [INFO] Processing: /kaggle/input/diagram2graph-dataset/diagram2graph/934.png -> /kaggle/working/ttl_FewShot_outputs/934.ttl
# [INFO] Processing: /kaggle/input/diagram2graph-dataset/diagram2graph/276.png -> /kaggle/working/ttl_FewShot_outputs/276.ttl
# [INFO] Processing: /kaggle/input/diagram2graph-dataset/diagram2graph/848.png -> /kaggle/working/ttl_FewShot_outputs/848.ttl
# [INFO] Processing: /kaggle/input/diagram2graph-dataset/diagram2graph/279.png -> /kaggle/working/ttl_FewShot_outputs/279.ttl
# [INFO] Processing: /kaggle/input/diagram2graph-dataset/diagram2graph/577.png -> /kaggle/working/ttl_FewShot_outputs/577.ttl
# [INFO] Processing: /kaggle/input/diagram2graph-dataset/diagram2graph/356.png -> /kaggle/working/ttl_FewShot_outputs/356.ttl
# [INFO] Processing: /kaggle/input/diagram2graph-dataset/diagram2graph/937.png -> /kaggle/working/ttl_FewShot_outputs/937.ttl
# [INFO] Processing: /kaggle/input/diagram2graph-dataset/diagram2graph/244.png -> /kaggle/working/ttl_FewShot_outputs/244.ttl
# [INFO] Processing: /kaggle/input/diagram2graph-dataset/diagram2graph/263.png -> /kaggle/working/ttl_FewShot_outputs/263.ttl
# [INFO] Processing: /kaggle/input/diagram2graph-dataset/diagram2graph/166.png -> /kaggle/working/ttl_FewShot_outputs/166.ttl
# [INFO] Processing: /kaggle/input/diagram2graph-dataset/diagram2graph/18.png -> /kaggle/working/ttl_FewShot_outputs/18.ttl
# [INFO] Processing: /kaggle/input/diagram2graph-dataset/diagram2graph/63.png -> /kaggle/working/ttl_FewShot_outputs/63.ttl
# [INFO] Processing: /kaggle/input/diagram2graph-dataset/diagram2graph/936.png -> /kaggle/working/ttl_FewShot_outputs/936.ttl
# [INFO] Processing: /kaggle/input/diagram2graph-dataset/diagram2graph/12.png -> /kaggle/working/ttl_FewShot_outputs/12.ttl
# [INFO] Processing: /kaggle/input/diagram2graph-dataset/diagram2graph/627.png -> /kaggle/working/ttl_FewShot_outputs/627.ttl
# [INFO] Processing: /kaggle/input/diagram2graph-dataset/diagram2graph/28.png -> /kaggle/working/ttl_FewShot_outputs/28.ttl
# [INFO] Processing: /kaggle/input/diagram2graph-dataset/diagram2graph/67.png -> /kaggle/working/ttl_FewShot_outputs/67.ttl
# [INFO] Processing: /kaggle/input/diagram2graph-dataset/diagram2graph/34.png -> /kaggle/working/ttl_FewShot_outputs/34.ttl
# [INFO] Processing: /kaggle/input/diagram2graph-dataset/diagram2graph/813.png -> /kaggle/working/ttl_FewShot_outputs/813.ttl
# [INFO] Processing: /kaggle/input/diagram2graph-dataset/diagram2graph/41.png -> /kaggle/working/ttl_FewShot_outputs/41.ttl
# [INFO] Processing: /kaggle/input/diagram2graph-dataset/diagram2graph/563.png -> /kaggle/working/ttl_FewShot_outputs/563.ttl
# [INFO] Processing: /kaggle/input/diagram2graph-dataset/diagram2graph/125.png -> /kaggle/working/ttl_FewShot_outputs/125.ttl
# [INFO] Processing: /kaggle/input/diagram2graph-dataset/diagram2graph/121.png -> /kaggle/working/ttl_FewShot_outputs/121.ttl
# [INFO] Processing: /kaggle/input/diagram2graph-dataset/diagram2graph/905.png -> /kaggle/working/ttl_FewShot_outputs/905.ttl
# [INFO] Processing: /kaggle/input/diagram2graph-dataset/diagram2graph/663.png -> /kaggle/working/ttl_FewShot_outputs/663.ttl
# [INFO] Processing: /kaggle/input/diagram2graph-dataset/diagram2graph/915.png -> /kaggle/working/ttl_FewShot_outputs/915.ttl
# [INFO] Processing: /kaggle/input/diagram2graph-dataset/diagram2graph/86.png -> /kaggle/working/ttl_FewShot_outputs/86.ttl
# [INFO] Processing: /kaggle/input/diagram2graph-dataset/diagram2graph/916.png -> /kaggle/working/ttl_FewShot_outputs/916.ttl
# [INFO] Processing: /kaggle/input/diagram2graph-dataset/diagram2graph/258.png -> /kaggle/working/ttl_FewShot_outputs/258.ttl
# [INFO] Processing: /kaggle/input/diagram2graph-dataset/diagram2graph/498.png -> /kaggle/working/ttl_FewShot_outputs/498.ttl
# [INFO] Processing: /kaggle/input/diagram2graph-dataset/diagram2graph/29.png -> /kaggle/working/ttl_FewShot_outputs/29.ttl
# [INFO] Processing: /kaggle/input/diagram2graph-dataset/diagram2graph/109.png -> /kaggle/working/ttl_FewShot_outputs/109.ttl
# [INFO] Processing: /kaggle/input/diagram2graph-dataset/diagram2graph/224.png -> /kaggle/working/ttl_FewShot_outputs/224.ttl
# [INFO] Processing: /kaggle/input/diagram2graph-dataset/diagram2graph/361.png -> /kaggle/working/ttl_FewShot_outputs/361.ttl
# [INFO] Processing: /kaggle/input/diagram2graph-dataset/diagram2graph/753.png -> /kaggle/working/ttl_FewShot_outputs/753.ttl
# [INFO] Processing: /kaggle/input/diagram2graph-dataset/diagram2graph/71.png -> /kaggle/working/ttl_FewShot_outputs/71.ttl
# [INFO] Processing: /kaggle/input/diagram2graph-dataset/diagram2graph/525.png -> /kaggle/working/ttl_FewShot_outputs/525.ttl
# [INFO] Processing: /kaggle/input/diagram2graph-dataset/diagram2graph/120.png -> /kaggle/working/ttl_FewShot_outputs/120.ttl
# [INFO] Processing: /kaggle/input/diagram2graph-dataset/diagram2graph/935.png -> /kaggle/working/ttl_FewShot_outputs/935.ttl
# [INFO] Processing: /kaggle/input/diagram2graph-dataset/diagram2graph/630.png -> /kaggle/working/ttl_FewShot_outputs/630.ttl
# [INFO] Processing: /kaggle/input/diagram2graph-dataset/diagram2graph/310.png -> /kaggle/working/ttl_FewShot_outputs/310.ttl
# [INFO] Processing: /kaggle/input/diagram2graph-dataset/diagram2graph/118.png -> /kaggle/working/ttl_FewShot_outputs/118.ttl
# [INFO] Processing: /kaggle/input/diagram2graph-dataset/diagram2graph/17.png -> /kaggle/working/ttl_FewShot_outputs/17.ttl
# [INFO] Processing: /kaggle/input/diagram2graph-dataset/diagram2graph/620.png -> /kaggle/working/ttl_FewShot_outputs/620.ttl
# [INFO] Processing: /kaggle/input/diagram2graph-dataset/diagram2graph/904.png -> /kaggle/working/ttl_FewShot_outputs/904.ttl
# [INFO] Processing: /kaggle/input/diagram2graph-dataset/diagram2graph/52.png -> /kaggle/working/ttl_FewShot_outputs/52.ttl
# [INFO] Processing: /kaggle/input/diagram2graph-dataset/diagram2graph/3.png -> /kaggle/working/ttl_FewShot_outputs/3.ttl
# [INFO] Processing: /kaggle/input/diagram2graph-dataset/diagram2graph/64.png -> /kaggle/working/ttl_FewShot_outputs/64.ttl
# [INFO] Processing: /kaggle/input/diagram2graph-dataset/diagram2graph/347.png -> /kaggle/working/ttl_FewShot_outputs/347.ttl
# [INFO] Processing: /kaggle/input/diagram2graph-dataset/diagram2graph/800.png -> /kaggle/working/ttl_FewShot_outputs/800.ttl
# [INFO] Retryable HTTP 503; attempt 1/4
# [INFO] Processing: /kaggle/input/diagram2graph-dataset/diagram2graph/328.png -> /kaggle/working/ttl_FewShot_outputs/328.ttl
# [INFO] Processing: /kaggle/input/diagram2graph-dataset/diagram2graph/203.png -> /kaggle/working/ttl_FewShot_outputs/203.ttl
# [INFO] Processing: /kaggle/input/diagram2graph-dataset/diagram2graph/8.png -> /kaggle/working/ttl_FewShot_outputs/8.ttl
# [INFO] Processing: /kaggle/input/diagram2graph-dataset/diagram2graph/45.png -> /kaggle/working/ttl_FewShot_outputs/45.ttl
# [INFO] Processing: /kaggle/input/diagram2graph-dataset/diagram2graph/548.png -> /kaggle/working/ttl_FewShot_outputs/548.ttl
# [INFO] Processing: /kaggle/input/diagram2graph-dataset/diagram2graph/444.png -> /kaggle/working/ttl_FewShot_outputs/444.ttl
# [INFO] Processing: /kaggle/input/diagram2graph-dataset/diagram2graph/922.png -> /kaggle/working/ttl_FewShot_outputs/922.ttl
# [INFO] Processing: /kaggle/input/diagram2graph-dataset/diagram2graph/624.png -> /kaggle/working/ttl_FewShot_outputs/624.ttl
# [INFO] Processing: /kaggle/input/diagram2graph-dataset/diagram2graph/274.png -> /kaggle/working/ttl_FewShot_outputs/274.ttl
# [INFO] Processing: /kaggle/input/diagram2graph-dataset/diagram2graph/6.png -> /kaggle/working/ttl_FewShot_outputs/6.ttl
# [INFO] Processing: /kaggle/input/diagram2graph-dataset/diagram2graph/23.png -> /kaggle/working/ttl_FewShot_outputs/23.ttl
# [INFO] Processing: /kaggle/input/diagram2graph-dataset/diagram2graph/87.png -> /kaggle/working/ttl_FewShot_outputs/87.ttl
# [INFO] Processing: /kaggle/input/diagram2graph-dataset/diagram2graph/275.png -> /kaggle/working/ttl_FewShot_outputs/275.ttl
# [INFO] Processing: /kaggle/input/diagram2graph-dataset/diagram2graph/728.png -> /kaggle/working/ttl_FewShot_outputs/728.ttl
# [INFO] Processing: /kaggle/input/diagram2graph-dataset/diagram2graph/591.png -> /kaggle/working/ttl_FewShot_outputs/591.ttl
# [INFO] Processing: /kaggle/input/diagram2graph-dataset/diagram2graph/44.png -> /kaggle/working/ttl_FewShot_outputs/44.ttl
# [INFO] Processing: /kaggle/input/diagram2graph-dataset/diagram2graph/68.png -> /kaggle/working/ttl_FewShot_outputs/68.ttl
# [INFO] Processing: /kaggle/input/diagram2graph-dataset/diagram2graph/286.png -> /kaggle/working/ttl_FewShot_outputs/286.ttl
# [INFO] Processing: /kaggle/input/diagram2graph-dataset/diagram2graph/46.png -> /kaggle/working/ttl_FewShot_outputs/46.ttl
# [INFO] Processing: /kaggle/input/diagram2graph-dataset/diagram2graph/470.png -> /kaggle/working/ttl_FewShot_outputs/470.ttl
# [INFO] Processing: /kaggle/input/diagram2graph-dataset/diagram2graph/929.png -> /kaggle/working/ttl_FewShot_outputs/929.ttl
# [INFO] Processing: /kaggle/input/diagram2graph-dataset/diagram2graph/57.png -> /kaggle/working/ttl_FewShot_outputs/57.ttl
# [INFO] Processing: /kaggle/input/diagram2graph-dataset/diagram2graph/358.png -> /kaggle/working/ttl_FewShot_outputs/358.ttl
# [INFO] Processing: /kaggle/input/diagram2graph-dataset/diagram2graph/652.png -> /kaggle/working/ttl_FewShot_outputs/652.ttl
# [INFO] Processing: /kaggle/input/diagram2graph-dataset/diagram2graph/252.png -> /kaggle/working/ttl_FewShot_outputs/252.ttl
# [INFO] Processing: /kaggle/input/diagram2graph-dataset/diagram2graph/30.png -> /kaggle/working/ttl_FewShot_outputs/30.ttl
# [INFO] Processing: /kaggle/input/diagram2graph-dataset/diagram2graph/919.png -> /kaggle/working/ttl_FewShot_outputs/919.ttl
# [INFO] Processing: /kaggle/input/diagram2graph-dataset/diagram2graph/429.png -> /kaggle/working/ttl_FewShot_outputs/429.ttl
# [INFO] Processing: /kaggle/input/diagram2graph-dataset/diagram2graph/60.png -> /kaggle/working/ttl_FewShot_outputs/60.ttl
# [INFO] Processing: /kaggle/input/diagram2graph-dataset/diagram2graph/99.png -> /kaggle/working/ttl_FewShot_outputs/99.ttl
# [INFO] Processing: /kaggle/input/diagram2graph-dataset/diagram2graph/765.png -> /kaggle/working/ttl_FewShot_outputs/765.ttl
# [INFO] Processing: /kaggle/input/diagram2graph-dataset/diagram2graph/692.png -> /kaggle/working/ttl_FewShot_outputs/692.ttl
# [INFO] Processing: /kaggle/input/diagram2graph-dataset/diagram2graph/295.png -> /kaggle/working/ttl_FewShot_outputs/295.ttl
# [INFO] Processing: /kaggle/input/diagram2graph-dataset/diagram2graph/394.png -> /kaggle/working/ttl_FewShot_outputs/394.ttl
# [INFO] Processing: /kaggle/input/diagram2graph-dataset/diagram2graph/273.png -> /kaggle/working/ttl_FewShot_outputs/273.ttl
# [INFO] Processing: /kaggle/input/diagram2graph-dataset/diagram2graph/413.png -> /kaggle/working/ttl_FewShot_outputs/413.ttl
# [INFO] Processing: /kaggle/input/diagram2graph-dataset/diagram2graph/78.png -> /kaggle/working/ttl_FewShot_outputs/78.ttl
# [INFO] Processing: /kaggle/input/diagram2graph-dataset/diagram2graph/212.png -> /kaggle/working/ttl_FewShot_outputs/212.ttl
# [INFO] Processing: /kaggle/input/diagram2graph-dataset/diagram2graph/47.png -> /kaggle/working/ttl_FewShot_outputs/47.ttl
# [INFO] Processing: /kaggle/input/diagram2graph-dataset/diagram2graph/13.png -> /kaggle/working/ttl_FewShot_outputs/13.ttl
# [INFO] Processing: /kaggle/input/diagram2graph-dataset/diagram2graph/134.png -> /kaggle/working/ttl_FewShot_outputs/134.ttl
# [INFO] Processing: /kaggle/input/diagram2graph-dataset/diagram2graph/921.png -> /kaggle/working/ttl_FewShot_outputs/921.ttl
# [INFO] Processing: /kaggle/input/diagram2graph-dataset/diagram2graph/259.png -> /kaggle/working/ttl_FewShot_outputs/259.ttl
# [INFO] Processing: /kaggle/input/diagram2graph-dataset/diagram2graph/25.png -> /kaggle/working/ttl_FewShot_outputs/25.ttl
# [INFO] Processing: /kaggle/input/diagram2graph-dataset/diagram2graph/341.png -> /kaggle/working/ttl_FewShot_outputs/341.ttl
# [INFO] Processing: /kaggle/input/diagram2graph-dataset/diagram2graph/111.png -> /kaggle/working/ttl_FewShot_outputs/111.ttl
# [INFO] Processing: /kaggle/input/diagram2graph-dataset/diagram2graph/62.png -> /kaggle/working/ttl_FewShot_outputs/62.ttl
# [INFO] Processing: /kaggle/input/diagram2graph-dataset/diagram2graph/699.png -> /kaggle/working/ttl_FewShot_outputs/699.ttl
# [INFO] Processing: /kaggle/input/diagram2graph-dataset/diagram2graph/0.png -> /kaggle/working/ttl_FewShot_outputs/0.ttl
# [INFO] Processing: /kaggle/input/diagram2graph-dataset/diagram2graph/309.png -> /kaggle/working/ttl_FewShot_outputs/309.ttl
# [INFO] Processing: /kaggle/input/diagram2graph-dataset/diagram2graph/918.png -> /kaggle/working/ttl_FewShot_outputs/918.ttl
# [INFO] Processing: /kaggle/input/diagram2graph-dataset/diagram2graph/428.png -> /kaggle/working/ttl_FewShot_outputs/428.ttl
# [INFO] Processing: /kaggle/input/diagram2graph-dataset/diagram2graph/418.png -> /kaggle/working/ttl_FewShot_outputs/418.ttl
# [INFO] Processing: /kaggle/input/diagram2graph-dataset/diagram2graph/497.png -> /kaggle/working/ttl_FewShot_outputs/497.ttl
# [DONE] Wrote 219 TTL files to: /kaggle/working/ttl_FewShot_outputs
# [INFO] Manifest: /kaggle/working/ttl_FewShot_outputs/manifest.json

# %%
# !zip -r /kaggle/working/FewShot_outputs.zip /kaggle/working/ttl_FewShot_outputs
# Out:
#   adding: kaggle/working/ttl_FewShot_outputs/ (stored 0%)
#   adding: kaggle/working/ttl_FewShot_outputs/542.ttl (deflated 85%)
#   adding: kaggle/working/ttl_FewShot_outputs/114.ttl (deflated 87%)
#   adding: kaggle/working/ttl_FewShot_outputs/76.ttl (deflated 87%)
#   adding: kaggle/working/ttl_FewShot_outputs/46.ttl (deflated 84%)
#   adding: kaggle/working/ttl_FewShot_outputs/94.ttl (deflated 87%)
#   adding: kaggle/working/ttl_FewShot_outputs/470.ttl (deflated 86%)
#   adding: kaggle/working/ttl_FewShot_outputs/252.ttl (deflated 86%)
#   adding: kaggle/working/ttl_FewShot_outputs/591.ttl (deflated 85%)
#   adding: kaggle/working/ttl_FewShot_outputs/627.ttl (deflated 86%)
#   adding: kaggle/working/ttl_FewShot_outputs/203.ttl (deflated 89%)
#   adding: kaggle/working/ttl_FewShot_outputs/933.ttl (deflated 85%)
#   adding: kaggle/working/ttl_FewShot_outputs/28.ttl (deflated 89%)
#   adding: kaggle/working/ttl_FewShot_outputs/620.ttl (deflated 88%)
#   adding: kaggle/working/ttl_FewShot_outputs/563.ttl (deflated 86%)
#   adding: kaggle/working/ttl_FewShot_outputs/457.ttl (deflated 88%)
#   adding: kaggle/working/ttl_FewShot_outputs/930.ttl (deflated 86%)
#   adding: kaggle/working/ttl_FewShot_outputs/589.ttl (deflated 83%)
#   adding: kaggle/working/ttl_FewShot_outputs/68.ttl (deflated 89%)
#   adding: kaggle/working/ttl_FewShot_outputs/520.ttl (deflated 87%)
#   adding: kaggle/working/ttl_FewShot_outputs/manifest.json (deflated 96%)
#   adding: kaggle/working/ttl_FewShot_outputs/315.ttl (deflated 82%)
#   adding: kaggle/working/ttl_FewShot_outputs/908.ttl (deflated 87%)
#   adding: kaggle/working/ttl_FewShot_outputs/121.ttl (deflated 85%)
#   adding: kaggle/working/ttl_FewShot_outputs/937.ttl (deflated 88%)
#   adding: kaggle/working/ttl_FewShot_outputs/699.ttl (deflated 87%)
#   adding: kaggle/working/ttl_FewShot_outputs/907.ttl (deflated 88%)
#   adding: kaggle/working/ttl_FewShot_outputs/938.ttl (deflated 83%)
#   adding: kaggle/working/ttl_FewShot_outputs/62.ttl (deflated 87%)
#   adding: kaggle/working/ttl_FewShot_outputs/401.ttl (deflated 86%)
#   adding: kaggle/working/ttl_FewShot_outputs/120.ttl (deflated 85%)
#   adding: kaggle/working/ttl_FewShot_outputs/706.ttl (deflated 87%)
#   adding: kaggle/working/ttl_FewShot_outputs/498.ttl (deflated 82%)
#   adding: kaggle/working/ttl_FewShot_outputs/416.ttl (deflated 86%)
#   adding: kaggle/working/ttl_FewShot_outputs/914.ttl (deflated 88%)
#   adding: kaggle/working/ttl_FewShot_outputs/18.ttl (deflated 86%)
#   adding: kaggle/working/ttl_FewShot_outputs/93.ttl (deflated 84%)
#   adding: kaggle/working/ttl_FewShot_outputs/432.ttl (deflated 88%)
#   adding: kaggle/working/ttl_FewShot_outputs/322.ttl (deflated 85%)
#   adding: kaggle/working/ttl_FewShot_outputs/148.ttl (deflated 82%)
#   adding: kaggle/working/ttl_FewShot_outputs/655.ttl (deflated 85%)
#   adding: kaggle/working/ttl_FewShot_outputs/412.ttl (deflated 86%)
#   adding: kaggle/working/ttl_FewShot_outputs/813.ttl (deflated 83%)
#   adding: kaggle/working/ttl_FewShot_outputs/521.ttl (deflated 89%)
#   adding: kaggle/working/ttl_FewShot_outputs/254.ttl (deflated 88%)
#   adding: kaggle/working/ttl_FewShot_outputs/215.ttl (deflated 87%)
#   adding: kaggle/working/ttl_FewShot_outputs/273.ttl (deflated 87%)
#   adding: kaggle/working/ttl_FewShot_outputs/916.ttl (deflated 83%)
#   adding: kaggle/working/ttl_FewShot_outputs/263.ttl (deflated 85%)
#   adding: kaggle/working/ttl_FewShot_outputs/428.ttl (deflated 90%)
#   adding: kaggle/working/ttl_FewShot_outputs/13.ttl (deflated 85%)
#   adding: kaggle/working/ttl_FewShot_outputs/38.ttl (deflated 88%)
#   adding: kaggle/working/ttl_FewShot_outputs/351.ttl (deflated 83%)
#   adding: kaggle/working/ttl_FewShot_outputs/222.ttl (deflated 85%)
#   adding: kaggle/working/ttl_FewShot_outputs/497.ttl (deflated 88%)
#   adding: kaggle/working/ttl_FewShot_outputs/233.ttl (deflated 87%)
#   adding: kaggle/working/ttl_FewShot_outputs/444.ttl (deflated 84%)
#   adding: kaggle/working/ttl_FewShot_outputs/171.ttl (deflated 87%)
#   adding: kaggle/working/ttl_FewShot_outputs/37.ttl (deflated 88%)
#   adding: kaggle/working/ttl_FewShot_outputs/598.ttl (deflated 88%)
#   adding: kaggle/working/ttl_FewShot_outputs/212.ttl (deflated 86%)
#   adding: kaggle/working/ttl_FewShot_outputs/147.ttl (deflated 87%)
#   adding: kaggle/working/ttl_FewShot_outputs/358.ttl (deflated 83%)
#   adding: kaggle/working/ttl_FewShot_outputs/731.ttl (deflated 87%)
#   adding: kaggle/working/ttl_FewShot_outputs/238.ttl (deflated 89%)
#   adding: kaggle/working/ttl_FewShot_outputs/347.ttl (deflated 83%)
#   adding: kaggle/working/ttl_FewShot_outputs/921.ttl (deflated 87%)
#   adding: kaggle/working/ttl_FewShot_outputs/25.ttl (deflated 88%)
#   adding: kaggle/working/ttl_FewShot_outputs/198.ttl (deflated 78%)
#   adding: kaggle/working/ttl_FewShot_outputs/67.ttl (deflated 88%)
#   adding: kaggle/working/ttl_FewShot_outputs/35.ttl (deflated 85%)
#   adding: kaggle/working/ttl_FewShot_outputs/87.ttl (deflated 88%)
#   adding: kaggle/working/ttl_FewShot_outputs/548.ttl (deflated 86%)
#   adding: kaggle/working/ttl_FewShot_outputs/279.ttl (deflated 89%)
#   adding: kaggle/working/ttl_FewShot_outputs/118.ttl (deflated 85%)
#   adding: kaggle/working/ttl_FewShot_outputs/224.ttl (deflated 87%)
#   adding: kaggle/working/ttl_FewShot_outputs/33.ttl (deflated 85%)
#   adding: kaggle/working/ttl_FewShot_outputs/293.ttl (deflated 87%)
#   adding: kaggle/working/ttl_FewShot_outputs/335.ttl (deflated 86%)
#   adding: kaggle/working/ttl_FewShot_outputs/39.ttl (deflated 84%)
#   adding: kaggle/working/ttl_FewShot_outputs/276.ttl (deflated 84%)
#   adding: kaggle/working/ttl_FewShot_outputs/163.ttl (deflated 86%)
#   adding: kaggle/working/ttl_FewShot_outputs/100.ttl (deflated 82%)
#   adding: kaggle/working/ttl_FewShot_outputs/624.ttl (deflated 90%)
#   adding: kaggle/working/ttl_FewShot_outputs/119.ttl (deflated 85%)
#   adding: kaggle/working/ttl_FewShot_outputs/309.ttl (deflated 87%)
#   adding: kaggle/working/ttl_FewShot_outputs/361.ttl (deflated 83%)
#   adding: kaggle/working/ttl_FewShot_outputs/918.ttl (deflated 88%)
#   adding: kaggle/working/ttl_FewShot_outputs/204.ttl (deflated 89%)
#   adding: kaggle/working/ttl_FewShot_outputs/193.ttl (deflated 89%)
#   adding: kaggle/working/ttl_FewShot_outputs/920.ttl (deflated 88%)
#   adding: kaggle/working/ttl_FewShot_outputs/29.ttl (deflated 87%)
#   adding: kaggle/working/ttl_FewShot_outputs/411.ttl (deflated 86%)
#   adding: kaggle/working/ttl_FewShot_outputs/328.ttl (deflated 87%)
#   adding: kaggle/working/ttl_FewShot_outputs/113.ttl (deflated 88%)
#   adding: kaggle/working/ttl_FewShot_outputs/934.ttl (deflated 89%)
#   adding: kaggle/working/ttl_FewShot_outputs/728.ttl (deflated 85%)
#   adding: kaggle/working/ttl_FewShot_outputs/576.ttl (deflated 87%)
#   adding: kaggle/working/ttl_FewShot_outputs/692.ttl (deflated 87%)
#   adding: kaggle/working/ttl_FewShot_outputs/49.ttl (deflated 82%)
#   adding: kaggle/working/ttl_FewShot_outputs/605.ttl (deflated 88%)
#   adding: kaggle/working/ttl_FewShot_outputs/911.ttl (deflated 86%)
#   adding: kaggle/working/ttl_FewShot_outputs/10.ttl (deflated 79%)
#   adding: kaggle/working/ttl_FewShot_outputs/924.ttl (deflated 80%)
#   adding: kaggle/working/ttl_FewShot_outputs/413.ttl (deflated 82%)
#   adding: kaggle/working/ttl_FewShot_outputs/4.ttl (deflated 88%)
#   adding: kaggle/working/ttl_FewShot_outputs/904.ttl (deflated 87%)
#   adding: kaggle/working/ttl_FewShot_outputs/288.ttl (deflated 90%)
#   adding: kaggle/working/ttl_FewShot_outputs/31.ttl (deflated 86%)
#   adding: kaggle/working/ttl_FewShot_outputs/258.ttl (deflated 84%)
#   adding: kaggle/working/ttl_FewShot_outputs/259.ttl (deflated 87%)
#   adding: kaggle/working/ttl_FewShot_outputs/940.ttl (deflated 89%)
#   adding: kaggle/working/ttl_FewShot_outputs/905.ttl (deflated 86%)
#   adding: kaggle/working/ttl_FewShot_outputs/244.ttl (deflated 88%)
#   adding: kaggle/working/ttl_FewShot_outputs/57.ttl (deflated 89%)
#   adding: kaggle/working/ttl_FewShot_outputs/446.ttl (deflated 84%)
#   adding: kaggle/working/ttl_FewShot_outputs/630.ttl (deflated 87%)
#   adding: kaggle/working/ttl_FewShot_outputs/78.ttl (deflated 86%)
#   adding: kaggle/working/ttl_FewShot_outputs/607.ttl (deflated 86%)
#   adding: kaggle/working/ttl_FewShot_outputs/11.ttl (deflated 82%)
#   adding: kaggle/working/ttl_FewShot_outputs/14.ttl (deflated 85%)
#   adding: kaggle/working/ttl_FewShot_outputs/170.ttl (deflated 87%)
#   adding: kaggle/working/ttl_FewShot_outputs/9.ttl (deflated 86%)
#   adding: kaggle/working/ttl_FewShot_outputs/34.ttl (deflated 87%)
#   adding: kaggle/working/ttl_FewShot_outputs/341.ttl (deflated 85%)
#   adding: kaggle/working/ttl_FewShot_outputs/71.ttl (deflated 89%)
#   adding: kaggle/working/ttl_FewShot_outputs/761.ttl (deflated 88%)
#   adding: kaggle/working/ttl_FewShot_outputs/580.ttl (deflated 86%)
#   adding: kaggle/working/ttl_FewShot_outputs/931.ttl (deflated 82%)
#   adding: kaggle/working/ttl_FewShot_outputs/684.ttl (deflated 88%)
#   adding: kaggle/working/ttl_FewShot_outputs/310.ttl (deflated 86%)
#   adding: kaggle/working/ttl_FewShot_outputs/800.ttl (deflated 89%)
#   adding: kaggle/working/ttl_FewShot_outputs/919.ttl (deflated 88%)
#   adding: kaggle/working/ttl_FewShot_outputs/250.ttl (deflated 88%)
#   adding: kaggle/working/ttl_FewShot_outputs/286.ttl (deflated 83%)
#   adding: kaggle/working/ttl_FewShot_outputs/3.ttl (deflated 88%)
#   adding: kaggle/working/ttl_FewShot_outputs/556.ttl (deflated 79%)
#   adding: kaggle/working/ttl_FewShot_outputs/701.ttl (deflated 83%)
#   adding: kaggle/working/ttl_FewShot_outputs/107.ttl (deflated 85%)
#   adding: kaggle/working/ttl_FewShot_outputs/291.ttl (deflated 88%)
#   adding: kaggle/working/ttl_FewShot_outputs/562.ttl (deflated 88%)
#   adding: kaggle/working/ttl_FewShot_outputs/52.ttl (deflated 85%)
#   adding: kaggle/working/ttl_FewShot_outputs/23.ttl (deflated 86%)
#   adding: kaggle/working/ttl_FewShot_outputs/55.ttl (deflated 82%)
#   adding: kaggle/working/ttl_FewShot_outputs/174.ttl (deflated 86%)
#   adding: kaggle/working/ttl_FewShot_outputs/331.ttl (deflated 82%)
#   adding: kaggle/working/ttl_FewShot_outputs/125.ttl (deflated 86%)
#   adding: kaggle/working/ttl_FewShot_outputs/41.ttl (deflated 82%)
#   adding: kaggle/working/ttl_FewShot_outputs/2.ttl (deflated 86%)
#   adding: kaggle/working/ttl_FewShot_outputs/75.ttl (deflated 89%)
#   adding: kaggle/working/ttl_FewShot_outputs/111.ttl (deflated 86%)
#   adding: kaggle/working/ttl_FewShot_outputs/577.ttl (deflated 87%)
#   adding: kaggle/working/ttl_FewShot_outputs/429.ttl (deflated 87%)
#   adding: kaggle/working/ttl_FewShot_outputs/47.ttl (deflated 82%)
#   adding: kaggle/working/ttl_FewShot_outputs/848.ttl (deflated 87%)
#   adding: kaggle/working/ttl_FewShot_outputs/936.ttl (deflated 87%)
#   adding: kaggle/working/ttl_FewShot_outputs/12.ttl (deflated 88%)
#   adding: kaggle/working/ttl_FewShot_outputs/116.ttl (deflated 89%)
#   adding: kaggle/working/ttl_FewShot_outputs/926.ttl (deflated 85%)
#   adding: kaggle/working/ttl_FewShot_outputs/319.ttl (deflated 83%)
#   adding: kaggle/working/ttl_FewShot_outputs/295.ttl (deflated 85%)
#   adding: kaggle/working/ttl_FewShot_outputs/915.ttl (deflated 88%)
#   adding: kaggle/working/ttl_FewShot_outputs/709.ttl (deflated 88%)
#   adding: kaggle/working/ttl_FewShot_outputs/0.ttl (deflated 85%)
#   adding: kaggle/working/ttl_FewShot_outputs/332.ttl (deflated 83%)
#   adding: kaggle/working/ttl_FewShot_outputs/40.ttl (deflated 87%)
#   adding: kaggle/working/ttl_FewShot_outputs/823.ttl (deflated 88%)
#   adding: kaggle/working/ttl_FewShot_outputs/356.ttl (deflated 85%)
#   adding: kaggle/working/ttl_FewShot_outputs/99.ttl (deflated 90%)
#   adding: kaggle/working/ttl_FewShot_outputs/44.ttl (deflated 87%)
#   adding: kaggle/working/ttl_FewShot_outputs/274.ttl (deflated 85%)
#   adding: kaggle/working/ttl_FewShot_outputs/229.ttl (deflated 86%)
#   adding: kaggle/working/ttl_FewShot_outputs/394.ttl (deflated 86%)
#   adding: kaggle/working/ttl_FewShot_outputs/753.ttl (deflated 84%)
#   adding: kaggle/working/ttl_FewShot_outputs/765.ttl (deflated 85%)
#   adding: kaggle/working/ttl_FewShot_outputs/275.ttl (deflated 88%)
#   adding: kaggle/working/ttl_FewShot_outputs/922.ttl (deflated 86%)
#   adding: kaggle/working/ttl_FewShot_outputs/64.ttl (deflated 87%)
#   adding: kaggle/working/ttl_FewShot_outputs/8.ttl (deflated 82%)
#   adding: kaggle/working/ttl_FewShot_outputs/902.ttl (deflated 87%)
#   adding: kaggle/working/ttl_FewShot_outputs/109.ttl (deflated 86%)
#   adding: kaggle/working/ttl_FewShot_outputs/525.ttl (deflated 82%)
#   adding: kaggle/working/ttl_FewShot_outputs/17.ttl (deflated 83%)
#   adding: kaggle/working/ttl_FewShot_outputs/81.ttl (deflated 87%)
#   adding: kaggle/working/ttl_FewShot_outputs/80.ttl (deflated 86%)
#   adding: kaggle/working/ttl_FewShot_outputs/192.ttl (deflated 87%)
#   adding: kaggle/working/ttl_FewShot_outputs/891.ttl (deflated 86%)
#   adding: kaggle/working/ttl_FewShot_outputs/652.ttl (deflated 89%)
#   adding: kaggle/working/ttl_FewShot_outputs/153.ttl (deflated 86%)
#   adding: kaggle/working/ttl_FewShot_outputs/6.ttl (deflated 89%)
#   adding: kaggle/working/ttl_FewShot_outputs/929.ttl (deflated 87%)
#   adding: kaggle/working/ttl_FewShot_outputs/239.ttl (deflated 83%)
#   adding: kaggle/working/ttl_FewShot_outputs/735.ttl (deflated 79%)
#   adding: kaggle/working/ttl_FewShot_outputs/66.ttl (deflated 86%)
#   adding: kaggle/working/ttl_FewShot_outputs/86.ttl (deflated 86%)
#   adding: kaggle/working/ttl_FewShot_outputs/935.ttl (deflated 85%)
#   adding: kaggle/working/ttl_FewShot_outputs/900.ttl (deflated 86%)
#   adding: kaggle/working/ttl_FewShot_outputs/910.ttl (deflated 88%)
#   adding: kaggle/working/ttl_FewShot_outputs/63.ttl (deflated 88%)
#   adding: kaggle/working/ttl_FewShot_outputs/663.ttl (deflated 85%)
#   adding: kaggle/working/ttl_FewShot_outputs/380.ttl (deflated 84%)
#   adding: kaggle/working/ttl_FewShot_outputs/134.ttl (deflated 86%)
#   adding: kaggle/working/ttl_FewShot_outputs/60.ttl (deflated 84%)
#   adding: kaggle/working/ttl_FewShot_outputs/48.ttl (deflated 87%)
#   adding: kaggle/working/ttl_FewShot_outputs/278.ttl (deflated 87%)
#   adding: kaggle/working/ttl_FewShot_outputs/284.ttl (deflated 86%)
#   adding: kaggle/working/ttl_FewShot_outputs/90.ttl (deflated 87%)
#   adding: kaggle/working/ttl_FewShot_outputs/672.ttl (deflated 86%)
#   adding: kaggle/working/ttl_FewShot_outputs/634.ttl (deflated 90%)
#   adding: kaggle/working/ttl_FewShot_outputs/334.ttl (deflated 82%)
#   adding: kaggle/working/ttl_FewShot_outputs/65.ttl (deflated 83%)
#   adding: kaggle/working/ttl_FewShot_outputs/418.ttl (deflated 86%)
#   adding: kaggle/working/ttl_FewShot_outputs/262.ttl (deflated 88%)
#   adding: kaggle/working/ttl_FewShot_outputs/268.ttl (deflated 85%)
#   adding: kaggle/working/ttl_FewShot_outputs/818.ttl (deflated 83%)
#   adding: kaggle/working/ttl_FewShot_outputs/30.ttl (deflated 86%)
#   adding: kaggle/working/ttl_FewShot_outputs/888.ttl (deflated 87%)
#   adding: kaggle/working/ttl_FewShot_outputs/45.ttl (deflated 86%)
#   adding: kaggle/working/ttl_FewShot_outputs/433.ttl (deflated 87%)
#   adding: kaggle/working/ttl_FewShot_outputs/345.ttl (deflated 86%)
#   adding: kaggle/working/ttl_FewShot_outputs/166.ttl (deflated 86%)
